# %%
from nnodely import *
from nnodely.support import earlystopping
import matplotlib.pyplot as plt
import numpy as np
import os

workspace = os.path.join(os.getcwd(), "saved_models")
inverted_pendulum = Modely(workspace=workspace)
# Out:
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>-- nnodely_v1.5.2 --<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

# %%
def init_random_range(indexes, params_size, dict_param={'min_value': 0.0, 'max_value': 1.0}):
    import numpy as np
    min_val = dict_param.get('min_value', 0.0)
    max_val = dict_param.get('max_value', 1.0)
    return np.random.uniform(low=min_val, high=max_val)

# %%
# Create neural model

model_name = 'physics_augmented_neural_network'
pos                 = Input('Xpos')
Ypos                = Input('Ypos')
velocity            = Input('Xvelocity')
Yvelocity           = Input('Yvelocity')
angle               = Input('Xangle')
Yangle              = Input('Yangle')
angular_velocity    = Input('Xangular_velocity')
Yangular_velocity   = Input('Yangular_velocity')
F                   = Input('action')

noise1          = Input('noise1')
noise2          = Input('noise2')
noise3          = Input('noise3')
noise4          = Input('noise4')
sigma_x         = Constant('sigma_x', values=0.0)
sigma_v         = Constant('sigma_v', values=0.0)
sigma_theta     = Constant('sigma_theta', values=0.0)
sigma_omega     = Constant('sigma_omega', values=0.0)

g               = Constant('g', values=9.81)
dt              = Constant('dt', values=0.02)
gear            = Constant('gear', values=100)
m1              = Parameter('m1')
m2              = Parameter('m2')
l               = Parameter('l')
b               = Parameter('b')
d               = Parameter('d')
I               = Parameter('I')

def inv_pend(p, v, alpha, omega, u):
    # Equations of motion for the inverted pendulum on a cart
    sin_theta = Sin(alpha)
    cos_theta = Cos(alpha)
    I_eff = I + m2 * l**2
    denom = (m1+m2)*I_eff - (m2*l*cos_theta)**2

    # Input force
    F = gear * u
    
    # Friction
    friction_cart = I_eff * b*v
    friction_pend = (m1+m2) * d*omega

    # Angular acceleration (omega_dot)
    omega_dot = (- m2**2*l**2*omega**2*sin_theta*cos_theta
                 - friction_pend
                 + (m1+m2)*m2*g*l*sin_theta
                 + m2*l*b*v*cos_theta
                 - m2*l*cos_theta*F
    )/ denom

    # Linear acceleration of the cart (v_dot)
    v_dot = (I_eff*m2*l*omega**2*sin_theta
             - friction_cart
             - m2**2*l**2*g*sin_theta*cos_theta
             + m2*l*d*omega*cos_theta
             + F*I_eff
    )/ denom

    p_dot = v
    alpha_dot = omega

    return [p_dot, v_dot, alpha_dot, omega_dot]

# Adding noise to the inputs
x_noisy = pos.last() + noise4.last()*sigma_x
vel_noisy = velocity.last() + noise1.last()*sigma_v
ang_vel_noisy = angular_velocity.last() + noise3.last()*sigma_omega
theta_noisy = angle.last() + noise2.last()*sigma_theta

# Residual neural network
hidden_size = 10
dropout = 0.0
init_value = 0.01
l1 = Linear(output_dimension = hidden_size, dropout=dropout, W_init=init_random_range, W_init_params={'min_value': -init_value, 'max_value': init_value})(theta_noisy)
l2 = Linear(output_dimension = hidden_size, dropout=dropout, W_init=init_random_range, W_init_params={'min_value': -init_value, 'max_value': init_value})(vel_noisy)
l3 = Linear(output_dimension = hidden_size, dropout=dropout, W_init=init_random_range, W_init_params={'min_value': -init_value, 'max_value': init_value})(Sin(theta_noisy))
l4 = Linear(output_dimension = hidden_size, dropout=dropout, W_init=init_random_range, W_init_params={'min_value': -init_value, 'max_value': init_value})(Cos(theta_noisy))
l5 = Linear(output_dimension = hidden_size, dropout=dropout, W_init=init_random_range, W_init_params={'min_value': -init_value, 'max_value': init_value})(ang_vel_noisy)
l6 = Linear(output_dimension = hidden_size, dropout=dropout, W_init=init_random_range, W_init_params={'min_value': -init_value, 'max_value': init_value})(F.last())
x1 = Tanh(l1 + l2 + l3 + l4 + l5 + l6)
x2 = Tanh(Linear(output_dimension = hidden_size, dropout=dropout, W_init=init_random_range, W_init_params={'min_value': -init_value, 'max_value': init_value})(x1))
nn_out = Linear(output_dimension = 4, W_init=init_random_range, W_init_params={'min_value': -init_value, 'max_value': init_value})(x2)

# Runge-Kutta 4th order method
k1 = inv_pend(x_noisy, vel_noisy, theta_noisy, ang_vel_noisy, F.last())
k2 = inv_pend(x_noisy + k1[0]*dt/2, vel_noisy + k1[1]*dt/2, theta_noisy + k1[2]*dt/2, ang_vel_noisy + k1[3]*dt/2, F.last())
k3 = inv_pend(x_noisy + k2[0]*dt/2, vel_noisy + k2[1]*dt/2, theta_noisy + k2[2]*dt/2, ang_vel_noisy + k2[3]*dt/2, F.last())
k4 = inv_pend(x_noisy + k3[0]*dt, vel_noisy + k3[1]*dt, theta_noisy + k3[2]*dt, ang_vel_noisy + k3[3]*dt, F.last())

# Update state variables
dt_xdot = (k1[1] + 2*k2[1] + 2*k3[1] + k4[1])*dt/6
xdot = vel_noisy + dt_xdot + Select(nn_out, 0)
xdot.closedLoop(velocity)

dt_x = (k1[0] + 2*k2[0] + 2*k3[0] + k4[0])*dt/6
x = x_noisy + dt_x + Select(nn_out, 1)
x.closedLoop(pos)

dt_thetadot = (k1[3] + 2*k2[3] + 2*k3[3] + k4[3])*dt/6
thetadot = ang_vel_noisy + dt_thetadot + Select(nn_out, 2)
thetadot.closedLoop(angular_velocity)

dt_theta = (k1[2] + 2*k2[2] + 2*k3[2] + k4[2])*dt/6
theta = theta_noisy + dt_theta + Select(nn_out, 3)
theta.closedLoop(angle)

# Output and loss
est_theta = Output('est_theta', theta)
contr_theta = Output('contr_theta', Select(nn_out, 3))
est_thetadot = Output('est_thetadot', thetadot)
contr_thetadot = Output('contr_thetadot', Select(nn_out, 2))
est_xdot = Output('est_xdot', xdot)
contr_xdot = Output('contr_xdot', Select(nn_out, 1))
est_x = Output('est_x', x)
contr_x = Output('contr_x', Select(nn_out, 0))

inverted_pendulum.addModel('pendulum', [est_thetadot, est_theta, est_xdot, est_x, contr_thetadot, contr_theta, contr_xdot, contr_x])
inverted_pendulum.addMinimize('ang_vel_error', Yangular_velocity.last(), thetadot, loss_function='mse')
inverted_pendulum.addMinimize('angle_error', Yangle.last(), theta, loss_function='mse')
inverted_pendulum.addMinimize('vel_error', Yvelocity.last(), xdot, loss_function='mse')
inverted_pendulum.addMinimize('pos_error', Ypos.last(), x, loss_function='mse')
inverted_pendulum.neuralizeModel(sample_time = 0.02)
# Out:
# [neuralizeModel] Closed loop on Xpos with sample in the future.
# [neuralizeModel] Closed loop on Xangular_velocity with sample in the future.
# [neuralizeModel] Closed loop on Xangle with sample in the future.
# [neuralizeModel] Closed loop on Xvelocity with sample in the future.
# ================================ nnodely Model =================================
# {'Constants': {'Constant43': {'dim': 1, 'values': [2.0]},
#                'Constant44': {'dim': 1, 'values': [2.0]},
#                'Constant45': {'dim': 1, 'values': [2.0]},
#                'Constant46': {'dim': 1, 'values': [2.0]},
#                'Constant47': {'dim': 1, 'values': [2.0]},
#                'Constant48': {'dim': 1, 'values': [2.0]},
#                'Constant49': {'dim': 1, 'values': [2.0]},
#                'Constant50': {'dim': 1, 'values': [2.0]},
#                'Constant52': {'dim': 1, 'values': [2.0]},
#                'Constant53': {'dim': 1, 'values': [2.0]},
#                'Constant54': {'dim': 1, 'values': [2.0]},
#                'Constant55': {'dim': 1, 'values': [2.0]},
#                'Constant56': {'dim': 1, 'values': [2.0]},
#                'Constant57': {'dim': 1, 'values': [2.0]},
#                'Constant58': {'dim': 1, 'values': [2.0]},
#                'Constant59': {'dim': 1, 'values': [2.0]},
#                'Constant60': {'dim': 1, 'values': [2.0]},
#                'Constant61': {'dim': 1, 'values': [2.0]},
#                'Constant62': {'dim': 1, 'values': [2.0]},
#                'Constant64': {'dim': 1, 'values': [2.0]},
#                'Constant65': {'dim': 1, 'values': [2.0]},
#                'Constant66': {'dim': 1, 'values': [2.0]},
#                'Constant67': {'dim': 1, 'values': [2.0]},
#                'Constant68': {'dim': 1, 'values': [2.0]},
#                'Constant69': {'dim': 1, 'values': [2.0]},
#                'Constant70': {'dim': 1, 'values': [2.0]},
#                'Constant71': {'dim': 1, 'values': [2.0]},
#                'Constant72': {'dim': 1, 'values': [2.0]},
#                'Constant73': {'dim': 1, 'values': [2.0]},
#                'Constant74': {'dim': 1, 'values': [2.0]},
#                'Constant75': {'dim': 1, 'values': [2.0]},
#                'Constant76': {'dim': 1, 'values': [2.0]},
#                'Constant77': {'dim': 1, 'values': [2.0]},
#                'Constant78': {'dim': 1, 'values': [2.0]},
#                'Constant79': {'dim': 1, 'values': [2.0]},
#                'Constant80': {'dim': 1, 'values': [2.0]},
#                'Constant81': {'dim': 1, 'values': [2.0]},
#                'Constant82': {'dim': 1, 'values': [2.0]},
#                'Constant83': {'dim': 1, 'values': [2.0]},
#                'Constant84': {'dim': 1, 'values': [2.0]},
#                'Constant85': {'dim': 1, 'values': [6.0]},
#                'Constant86': {'dim': 1, 'values': [2.0]},
#                'Constant87': {'dim': 1, 'values': [2.0]},
#                'Constant88': {'dim': 1, 'values': [6.0]},
#                'Constant89': {'dim': 1, 'values': [2.0]},
#                'Constant90': {'dim': 1, 'values': [2.0]},
#                'Constant91': {'dim': 1, 'values': [6.0]},
#                'Constant92': {'dim': 1, 'values': [2.0]},
#                'Constant93': {'dim': 1, 'values': [2.0]},
#                'Constant94': {'dim': 1, 'values': [6.0]},
#                'dt': {'dim': 1, 'values': [0.019999999552965164]},
#                'g': {'dim': 1, 'values': [9.8100004196167]},
#                'gear': {'dim': 1, 'values': [100.0]},
#                'sigma_omega': {'dim': 1, 'values': [0.0]},
#                'sigma_theta': {'dim': 1, 'values': [0.0]},
#                'sigma_v': {'dim': 1, 'values': [0.0]},
#                'sigma_x': {'dim': 1, 'values': [0.0]}},
#  'Functions': {},
#  'Info': {'SampleTime': 0.02,
#           'nnodely_version': '1.5.2',
#           'ns': [1, 0],
#           'ntot': 1,
#           'num_parameters': 206},
#  'Inputs': {'Xangle': {'closedLoop': 'Add574',
#                        'dim': 1,
#                        'local': 1,
#                        'ns': [1, 0],
#                        'ntot': 1,
#                        'sw': [-1, 0]},
#             'Xangular_velocity': {'closedLoop': 'Add560',
#                                   'dim': 1,
#                                   'local': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Xpos': {'closedLoop': 'Add546',
#                      'dim': 1,
#                      'local': 1,
#                      'ns': [1, 0],
#                      'ntot': 1,
#                      'sw': [-1, 0]},
#             'Xvelocity': {'closedLoop': 'Add532',
#                           'dim': 1,
#                           'local': 1,
#                           'ns': [1, 0],
#                           'ntot': 1,
#                           'sw': [-1, 0]},
#             'Yangle': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yangular_velocity': {'dim': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Ypos': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yvelocity': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'action': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise1': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise2': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise3': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise4': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]}},
#  'Minimizers': {'ang_vel_error': {'A': 'SamplePart580',
#                                   'B': 'Add560',
#                                   'loss': 'mse'},
#                 'angle_error': {'A': 'SamplePart582',
#                                 'B': 'Add574',
#                                 'loss': 'mse'},
#                 'pos_error': {'A': 'SamplePart586',
#                               'B': 'Add546',
#                               'loss': 'mse'},
#                 'vel_error': {'A': 'SamplePart584',
#                               'B': 'Add532',
#                               'loss': 'mse'}},
#  'Models': 'pendulum',
#  'Outputs': {'contr_theta': 'Select575',
#              'contr_thetadot': 'Select576',
#              'contr_x': 'Select578',
#              'contr_xdot': 'Select577',
#              'est_theta': 'Add574',
#              'est_thetadot': 'Add560',
#              'est_x': 'Add546',
#              'est_xdot': 'Add532'},
#  'Parameters': {'I': {'dim': 1, 'values': [0.07601392269134521]},
#                 'PLinear27W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[-0.00869770534336567,
#                                            0.00638507679104805,
#                                            0.003210035851225257,
#                                            0.006352710071951151,
#                                            0.000530886638443917,
#                                            0.005158124957233667,
#                                            0.0010753677925094962,
#                                            -0.0016517032636329532,
#                                            0.008639078587293625,
#                                            -0.003799901343882084]]},
#                 'PLinear29W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[-0.0038965512067079544,
#                                            0.007394349668174982,
#                                            -0.007424590177834034,
#                                            -0.008793101646006107,
#                                            0.0031364508904516697,
#                                            -0.0005372866289690137,
#                                            -0.006544576957821846,
#                                            -0.004281366243958473,
#                                            0.006668386049568653,
#                                            0.005434591788798571]]},
#                 'PLinear31W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[-0.0043343473225831985,
#                                            0.007480219006538391,
#                                            -0.008195712231099606,
#                                            0.005128732416778803,
#                                            -0.0032368283718824387,
#                                            -0.0010830258252099156,
#                                            0.002695991424843669,
#                                            -0.0004891763674095273,
#                                            0.0059421067126095295,
#                                            0.005818018689751625]]},
#                 'PLinear33W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[0.007489468902349472,
#                                            -0.0030282228253781796,
#                                            0.00602993369102478,
#                                            0.006138994358479977,
#                                            -0.00599884707480669,
#                                            -0.003091196995228529,
#                                            0.007608319167047739,
#                                            -9.221755135513376e-06,
#                                            0.0024316643830388784,
#                                            0.0040740822441875935]]},
#                 'PLinear35W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[-0.008397525176405907,
#                                            -0.006268790457397699,
#                                            0.004164554178714752,
#                                            -0.006511803716421127,
#                                            0.004984942264854908,
#                                            -0.001698038773611188,
#                                            -0.006211462430655956,
#                                            -0.0020472591277211905,
#                                            0.002269558608531952,
#                                            -0.004520269576460123]]},
#                 'PLinear37W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[0.006448206026107073,
#                                            0.0005071097402833402,
#                                            -0.005086095537990332,
#                                            0.0017759200418367982,
#                                            -0.0005956368404440582,
#                                            0.005107024218887091,
#                                            -0.005153392907232046,
#                                            -8.604705362813547e-05,
#                                            0.006314787082374096,
#                                            -0.003664198098704219]]},
#                 'PLinear39W': {'dim': [10, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[-0.00395909184589982,
#                                            -0.0022782054729759693,
#                                            0.006326490547508001,
#                                            0.004558152053505182,
#                                            -0.004553195089101791,
#                                            -0.0071602556854486465,
#                                            0.009519141167402267,
#                                            0.004698562901467085,
#                                            0.005516562610864639,
#                                            0.009898675605654716],
#                                           [0.0024084143806248903,
#                                            0.008489909581840038,
#                                            -0.00572320818901062,
#                                            -0.007584333885461092,
#                                            -0.006140540819615126,
#                                            -0.0008870808524079621,
#                                            0.003431275486946106,
#                                            0.007538207806646824,
#                                            -0.00605878746137023,
#                                            0.0024377189110964537],
#                                           [-0.005622348748147488,
#                                            -0.0016208942979574203,
#                                            0.008837422356009483,
#                                            0.009289625100791454,
#                                            0.00909960176795721,
#                                            -0.00011492515477584675,
#                                            0.004154108930379152,
#                                            0.0015442861476913095,
#                                            0.00023052167671266943,
#                                            0.006674544420093298],
#                                           [0.003440167987719178,
#                                            -0.0033499968703836203,
#                                            -0.005944118835031986,
#                                            0.002011570381000638,
#                                            -0.005846661049872637,
#                                            0.004363951738923788,
#                                            -0.00415433943271637,
#                                            -0.009944280609488487,
#                                            -0.004660711623728275,
#                                            -0.004188220947980881],
#                                           [0.008074771612882614,
#                                            -0.003121965564787388,
#                                            0.004519582260400057,
#                                            0.007281737867742777,
#                                            -0.003368101315572858,
#                                            0.004258370026946068,
#                                            -0.007982190698385239,
#                                            -0.001815942581743002,
#                                            0.0018802174599841237,
#                                            0.000606298039201647],
#                                           [-0.008207122795283794,
#                                            -0.0041228653863072395,
#                                            -0.007295813877135515,
#                                            -0.008434723131358624,
#                                            -0.002206289442256093,
#                                            -0.0013451710110530257,
#                                            -0.0013152883620932698,
#                                            0.009846079163253307,
#                                            0.0010365053312852979,
#                                            0.0028417978901416063],
#                                           [-0.004655978176742792,
#                                            0.002470905426889658,
#                                            0.002537802327424288,
#                                            0.0009311316534876823,
#                                            -0.006038389168679714,
#                                            -0.001044299453496933,
#                                            -0.006403271108865738,
#                                            0.005631319247186184,
#                                            0.00905177928507328,
#                                            0.007294727489352226],
#                                           [0.0002616810379549861,
#                                            -0.003230893984436989,
#                                            0.006790153216570616,
#                                            0.007435491308569908,
#                                            -0.003174371086061001,
#                                            -0.003635300323367119,
#                                            -0.00833142176270485,
#                                            0.008570699021220207,
#                                            -0.0010380761232227087,
#                                            -0.009064246900379658],
#                                           [0.001089887460693717,
#                                            -0.0012935502454638481,
#                                            0.0003120082837995142,
#                                            0.0069343396462500095,
#                                            0.008316721767187119,
#                                            0.008541741408407688,
#                                            -0.004006875678896904,
#                                            0.004161544144153595,
#                                            -0.004348560702055693,
#                                            -0.0021190065890550613],
#                                           [0.002003657165914774,
#                                            0.0016733754891902208,
#                                            -6.657528047071537e-06,
#                                            -0.0006492375396192074,
#                                            -0.0022000756580382586,
#                                            0.0043856012634932995,
#                                            -0.004136598203331232,
#                                            -0.0070426627062261105,
#                                            0.0006845920579507947,
#                                            0.0015673114685341716]]},
#                 'PLinear41W': {'dim': [10, 4],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[0.00284898211248219,
#                                            -0.0030454336665570736,
#                                            -0.00797986425459385,
#                                            0.007080556359142065],
#                                           [-0.006095935590565205,
#                                            0.0038660275749862194,
#                                            -0.009385895915329456,
#                                            0.009946539998054504],
#                                           [0.009638735093176365,
#                                            0.006569757591933012,
#                                            0.006661471910774708,
#                                            -0.00028913281857967377],
#                                           [0.0022423809859901667,
#                                            -0.006019303575158119,
#                                            -0.00932258553802967,
#                                            -0.004198046866804361],
#                                           [-0.009277847595512867,
#                                            0.0016588097205385566,
#                                            -0.008960353210568428,
#                                            -0.006882243324071169],
#                                           [-0.007994741201400757,
#                                            0.008960641920566559,
#                                            0.006346501410007477,
#                                            0.0003035464324057102],
#                                           [0.00968116894364357,
#                                            -0.008394845761358738,
#                                            0.0001961674279300496,
#                                            0.006920239422470331],
#                                           [0.007125783246010542,
#                                            0.007388942409306765,
#                                            0.0002994257665704936,
#                                            -0.008519786410033703],
#                                           [0.00549260014668107,
#                                            -0.0022583308164030313,
#                                            -0.005632195621728897,
#                                            -0.007025754079222679],
#                                           [0.0006980248144827783,
#                                            -0.009389974176883698,
#                                            0.0020347265526652336,
#                                            -0.0027033654041588306]]},
#                 'b': {'dim': 1, 'values': [0.9625828862190247]},
#                 'd': {'dim': 1, 'values': [0.4160938858985901]},
#                 'l': {'dim': 1, 'values': [0.2789917588233948]},
#                 'm1': {'dim': 1, 'values': [0.7723962068557739]},
#                 'm2': {'dim': 1, 'values': [0.4194328784942627]}},
#  'Relations': {'Add104': ['Add', ['Sub93', 'Mul103']],
#                'Add112': ['Add', ['Add104', 'Mul111']],
#                'Add13': ['Add', ['SamplePart8', 'Mul12']],
#                'Add148': ['Add', ['Sub140', 'Mul147']],
#                'Add150': ['Add', ['Add148', 'Mul149']],
#                'Add161': ['Add', ['Add13', 'Div160']],
#                'Add166': ['Add', ['Add27', 'Div165']],
#                'Add171': ['Add', ['Add20', 'Div170']],
#                'Add182': ['Add', ['I', 'Mul180']],
#                'Add185': ['Add', ['m1', 'm2']],
#                'Add20': ['Add', ['SamplePart15', 'Mul19']],
#                'Add201': ['Add', ['m1', 'm2']],
#                'Add221': ['Add', ['m1', 'm2']],
#                'Add229': ['Add', ['Sub218', 'Mul228']],
#                'Add237': ['Add', ['Add229', 'Mul236']],
#                'Add27': ['Add', ['SamplePart22', 'Mul26']],
#                'Add273': ['Add', ['Sub265', 'Mul272']],
#                'Add275': ['Add', ['Add273', 'Mul274']],
#                'Add286': ['Add', ['Add13', 'Div285']],
#                'Add291': ['Add', ['Add27', 'Div290']],
#                'Add296': ['Add', ['Add20', 'Div295']],
#                'Add307': ['Add', ['I', 'Mul305']],
#                'Add310': ['Add', ['m1', 'm2']],
#                'Add326': ['Add', ['m1', 'm2']],
#                'Add346': ['Add', ['m1', 'm2']],
#                'Add354': ['Add', ['Sub343', 'Mul353']],
#                'Add362': ['Add', ['Add354', 'Mul361']],
#                'Add38': ['Add', ['Linear28', 'Linear29']],
#                'Add39': ['Add', ['Add38', 'Linear31']],
#                'Add398': ['Add', ['Sub390', 'Mul397']],
#                'Add40': ['Add', ['Add39', 'Linear33']],
#                'Add400': ['Add', ['Add398', 'Mul399']],
#                'Add407': ['Add', ['Add13', 'Mul406']],
#                'Add41': ['Add', ['Add40', 'Linear34']],
#                'Add410': ['Add', ['Add27', 'Mul409']],
#                'Add413': ['Add', ['Add20', 'Mul412']],
#                'Add42': ['Add', ['Add41', 'Linear37']],
#                'Add424': ['Add', ['I', 'Mul422']],
#                'Add427': ['Add', ['m1', 'm2']],
#                'Add443': ['Add', ['m1', 'm2']],
#                'Add463': ['Add', ['m1', 'm2']],
#                'Add471': ['Add', ['Sub460', 'Mul470']],
#                'Add479': ['Add', ['Add471', 'Mul478']],
#                'Add515': ['Add', ['Sub507', 'Mul514']],
#                'Add517': ['Add', ['Add515', 'Mul516']],
#                'Add521': ['Add', ['Div151', 'Mul520']],
#                'Add524': ['Add', ['Add521', 'Mul523']],
#                'Add525': ['Add', ['Add524', 'Div518']],
#                'Add530': ['Add', ['Add13', 'Div529']],
#                'Add532': ['Add', ['Add530', 'Select531']],
#                'Add535': ['Add', ['Add13', 'Mul534']],
#                'Add538': ['Add', ['Add535', 'Mul537']],
#                'Add539': ['Add', ['Add538', 'Add407']],
#                'Add544': ['Add', ['Add6', 'Div543']],
#                'Add546': ['Add', ['Add544', 'Select545']],
#                'Add549': ['Add', ['Div119', 'Mul548']],
#                'Add552': ['Add', ['Add549', 'Mul551']],
#                'Add553': ['Add', ['Add552', 'Div486']],
#                'Add558': ['Add', ['Add20', 'Div557']],
#                'Add560': ['Add', ['Add558', 'Select559']],
#                'Add563': ['Add', ['Add20', 'Mul562']],
#                'Add566': ['Add', ['Add563', 'Mul565']],
#                'Add567': ['Add', ['Add566', 'Add413']],
#                'Add57': ['Add', ['I', 'Mul55']],
#                'Add572': ['Add', ['Add27', 'Div571']],
#                'Add574': ['Add', ['Add572', 'Select573']],
#                'Add6': ['Add', ['SamplePart1', 'Mul5']],
#                'Add60': ['Add', ['m1', 'm2']],
#                'Add76': ['Add', ['m1', 'm2']],
#                'Add96': ['Add', ['m1', 'm2']],
#                'Cos175': ['Cos', ['Add166']],
#                'Cos300': ['Cos', ['Add291']],
#                'Cos32': ['Cos', ['Add27']],
#                'Cos417': ['Cos', ['Add410']],
#                'Cos50': ['Cos', ['Add27']],
#                'Div119': ['Div', ['Sub118', 'Sub68']],
#                'Div151': ['Div', ['Add150', 'Sub68']],
#                'Div160': ['Div', ['Mul158', 'Constant52']],
#                'Div165': ['Div', ['Mul163', 'Constant53']],
#                'Div170': ['Div', ['Mul168', 'Constant54']],
#                'Div244': ['Div', ['Sub243', 'Sub193']],
#                'Div276': ['Div', ['Add275', 'Sub193']],
#                'Div285': ['Div', ['Mul283', 'Constant64']],
#                'Div290': ['Div', ['Mul288', 'Constant65']],
#                'Div295': ['Div', ['Mul293', 'Constant66']],
#                'Div369': ['Div', ['Sub368', 'Sub318']],
#                'Div401': ['Div', ['Add400', 'Sub318']],
#                'Div486': ['Div', ['Sub485', 'Sub435']],
#                'Div518': ['Div', ['Add517', 'Sub435']],
#                'Div529': ['Div', ['Mul527', 'Constant85']],
#                'Div543': ['Div', ['Mul541', 'Constant88']],
#                'Div557': ['Div', ['Mul555', 'Constant91']],
#                'Div571': ['Div', ['Mul569', 'Constant94']],
#                'Linear28': ['Linear', ['Add27'], 'PLinear27W', None, 0.0],
#                'Linear29': ['Linear', ['Add13'], 'PLinear29W', None, 0.0],
#                'Linear31': ['Linear', ['Sin30'], 'PLinear31W', None, 0.0],
#                'Linear33': ['Linear', ['Cos32'], 'PLinear33W', None, 0.0],
#                'Linear34': ['Linear', ['Add20'], 'PLinear35W', None, 0.0],
#                'Linear37': ['Linear',
#                             ['SamplePart36'],
#                             'PLinear37W',
#                             None,
#                             0.0],
#                'Linear44': ['Linear', ['Tanh43'], 'PLinear39W', None, 0.0],
#                'Linear46': ['Linear', ['Tanh45'], 'PLinear41W', None, 0],
#                'Mul100': ['Mul', ['Mul98', 'g']],
#                'Mul102': ['Mul', ['Mul100', 'l']],
#                'Mul103': ['Mul', ['Mul102', 'Sin49']],
#                'Mul107': ['Mul', ['m2', 'l']],
#                'Mul109': ['Mul', ['Mul107', 'b']],
#                'Mul110': ['Mul', ['Mul109', 'Add13']],
#                'Mul111': ['Mul', ['Mul110', 'Cos50']],
#                'Mul115': ['Mul', ['m2', 'l']],
#                'Mul116': ['Mul', ['Mul115', 'Cos50']],
#                'Mul117': ['Mul', ['Mul116', 'Mul70']],
#                'Mul12': ['Mul', ['SamplePart10', 'sigma_v']],
#                'Mul121': ['Mul', ['Add57', 'm2']],
#                'Mul123': ['Mul', ['Mul121', 'l']],
#                'Mul126': ['Mul', ['Mul123', 'Pow125']],
#                'Mul127': ['Mul', ['Mul126', 'Sin49']],
#                'Mul135': ['Mul', ['Pow131', 'Pow134']],
#                'Mul137': ['Mul', ['Mul135', 'g']],
#                'Mul138': ['Mul', ['Mul137', 'Sin49']],
#                'Mul139': ['Mul', ['Mul138', 'Cos50']],
#                'Mul143': ['Mul', ['m2', 'l']],
#                'Mul145': ['Mul', ['Mul143', 'd']],
#                'Mul146': ['Mul', ['Mul145', 'Add20']],
#                'Mul147': ['Mul', ['Mul146', 'Cos50']],
#                'Mul149': ['Mul', ['Mul70', 'Add57']],
#                'Mul158': ['Mul', ['Div151', 'dt']],
#                'Mul163': ['Mul', ['Add20', 'dt']],
#                'Mul168': ['Mul', ['Div119', 'dt']],
#                'Mul180': ['Mul', ['m2', 'Pow178']],
#                'Mul186': ['Mul', ['Add185', 'Add182']],
#                'Mul189': ['Mul', ['m2', 'l']],
#                'Mul19': ['Mul', ['SamplePart17', 'sigma_omega']],
#                'Mul190': ['Mul', ['Mul189', 'Cos175']],
#                'Mul195': ['Mul', ['gear', 'SamplePart173']],
#                'Mul197': ['Mul', ['Add182', 'b']],
#                'Mul198': ['Mul', ['Mul197', 'Add161']],
#                'Mul203': ['Mul', ['Add201', 'd']],
#                'Mul204': ['Mul', ['Mul203', 'Add171']],
#                'Mul212': ['Mul', ['Neg208', 'Pow211']],
#                'Mul215': ['Mul', ['Mul212', 'Pow214']],
#                'Mul216': ['Mul', ['Mul215', 'Sin174']],
#                'Mul217': ['Mul', ['Mul216', 'Cos175']],
#                'Mul223': ['Mul', ['Add221', 'm2']],
#                'Mul225': ['Mul', ['Mul223', 'g']],
#                'Mul227': ['Mul', ['Mul225', 'l']],
#                'Mul228': ['Mul', ['Mul227', 'Sin174']],
#                'Mul232': ['Mul', ['m2', 'l']],
#                'Mul234': ['Mul', ['Mul232', 'b']],
#                'Mul235': ['Mul', ['Mul234', 'Add161']],
#                'Mul236': ['Mul', ['Mul235', 'Cos175']],
#                'Mul240': ['Mul', ['m2', 'l']],
#                'Mul241': ['Mul', ['Mul240', 'Cos175']],
#                'Mul242': ['Mul', ['Mul241', 'Mul195']],
#                'Mul246': ['Mul', ['Add182', 'm2']],
#                'Mul248': ['Mul', ['Mul246', 'l']],
#                'Mul251': ['Mul', ['Mul248', 'Pow250']],
#                'Mul252': ['Mul', ['Mul251', 'Sin174']],
#                'Mul26': ['Mul', ['SamplePart24', 'sigma_theta']],
#                'Mul260': ['Mul', ['Pow256', 'Pow259']],
#                'Mul262': ['Mul', ['Mul260', 'g']],
#                'Mul263': ['Mul', ['Mul262', 'Sin174']],
#                'Mul264': ['Mul', ['Mul263', 'Cos175']],
#                'Mul268': ['Mul', ['m2', 'l']],
#                'Mul270': ['Mul', ['Mul268', 'd']],
#                'Mul271': ['Mul', ['Mul270', 'Add171']],
#                'Mul272': ['Mul', ['Mul271', 'Cos175']],
#                'Mul274': ['Mul', ['Mul195', 'Add182']],
#                'Mul283': ['Mul', ['Div276', 'dt']],
#                'Mul288': ['Mul', ['Add171', 'dt']],
#                'Mul293': ['Mul', ['Div244', 'dt']],
#                'Mul305': ['Mul', ['m2', 'Pow303']],
#                'Mul311': ['Mul', ['Add310', 'Add307']],
#                'Mul314': ['Mul', ['m2', 'l']],
#                'Mul315': ['Mul', ['Mul314', 'Cos300']],
#                'Mul320': ['Mul', ['gear', 'SamplePart298']],
#                'Mul322': ['Mul', ['Add307', 'b']],
#                'Mul323': ['Mul', ['Mul322', 'Add286']],
#                'Mul328': ['Mul', ['Add326', 'd']],
#                'Mul329': ['Mul', ['Mul328', 'Add296']],
#                'Mul337': ['Mul', ['Neg333', 'Pow336']],
#                'Mul340': ['Mul', ['Mul337', 'Pow339']],
#                'Mul341': ['Mul', ['Mul340', 'Sin299']],
#                'Mul342': ['Mul', ['Mul341', 'Cos300']],
#                'Mul348': ['Mul', ['Add346', 'm2']],
#                'Mul350': ['Mul', ['Mul348', 'g']],
#                'Mul352': ['Mul', ['Mul350', 'l']],
#                'Mul353': ['Mul', ['Mul352', 'Sin299']],
#                'Mul357': ['Mul', ['m2', 'l']],
#                'Mul359': ['Mul', ['Mul357', 'b']],
#                'Mul360': ['Mul', ['Mul359', 'Add286']],
#                'Mul361': ['Mul', ['Mul360', 'Cos300']],
#                'Mul365': ['Mul', ['m2', 'l']],
#                'Mul366': ['Mul', ['Mul365', 'Cos300']],
#                'Mul367': ['Mul', ['Mul366', 'Mul320']],
#                'Mul371': ['Mul', ['Add307', 'm2']],
#                'Mul373': ['Mul', ['Mul371', 'l']],
#                'Mul376': ['Mul', ['Mul373', 'Pow375']],
#                'Mul377': ['Mul', ['Mul376', 'Sin299']],
#                'Mul385': ['Mul', ['Pow381', 'Pow384']],
#                'Mul387': ['Mul', ['Mul385', 'g']],
#                'Mul388': ['Mul', ['Mul387', 'Sin299']],
#                'Mul389': ['Mul', ['Mul388', 'Cos300']],
#                'Mul393': ['Mul', ['m2', 'l']],
#                'Mul395': ['Mul', ['Mul393', 'd']],
#                'Mul396': ['Mul', ['Mul395', 'Add296']],
#                'Mul397': ['Mul', ['Mul396', 'Cos300']],
#                'Mul399': ['Mul', ['Mul320', 'Add307']],
#                'Mul406': ['Mul', ['Div401', 'dt']],
#                'Mul409': ['Mul', ['Add296', 'dt']],
#                'Mul412': ['Mul', ['Div369', 'dt']],
#                'Mul422': ['Mul', ['m2', 'Pow420']],
#                'Mul428': ['Mul', ['Add427', 'Add424']],
#                'Mul431': ['Mul', ['m2', 'l']],
#                'Mul432': ['Mul', ['Mul431', 'Cos417']],
#                'Mul437': ['Mul', ['gear', 'SamplePart415']],
#                'Mul439': ['Mul', ['Add424', 'b']],
#                'Mul440': ['Mul', ['Mul439', 'Add407']],
#                'Mul445': ['Mul', ['Add443', 'd']],
#                'Mul446': ['Mul', ['Mul445', 'Add413']],
#                'Mul454': ['Mul', ['Neg450', 'Pow453']],
#                'Mul457': ['Mul', ['Mul454', 'Pow456']],
#                'Mul458': ['Mul', ['Mul457', 'Sin416']],
#                'Mul459': ['Mul', ['Mul458', 'Cos417']],
#                'Mul465': ['Mul', ['Add463', 'm2']],
#                'Mul467': ['Mul', ['Mul465', 'g']],
#                'Mul469': ['Mul', ['Mul467', 'l']],
#                'Mul470': ['Mul', ['Mul469', 'Sin416']],
#                'Mul474': ['Mul', ['m2', 'l']],
#                'Mul476': ['Mul', ['Mul474', 'b']],
#                'Mul477': ['Mul', ['Mul476', 'Add407']],
#                'Mul478': ['Mul', ['Mul477', 'Cos417']],
#                'Mul482': ['Mul', ['m2', 'l']],
#                'Mul483': ['Mul', ['Mul482', 'Cos417']],
#                'Mul484': ['Mul', ['Mul483', 'Mul437']],
#                'Mul488': ['Mul', ['Add424', 'm2']],
#                'Mul490': ['Mul', ['Mul488', 'l']],
#                'Mul493': ['Mul', ['Mul490', 'Pow492']],
#                'Mul494': ['Mul', ['Mul493', 'Sin416']],
#                'Mul5': ['Mul', ['SamplePart3', 'sigma_x']],
#                'Mul502': ['Mul', ['Pow498', 'Pow501']],
#                'Mul504': ['Mul', ['Mul502', 'g']],
#                'Mul505': ['Mul', ['Mul504', 'Sin416']],
#                'Mul506': ['Mul', ['Mul505', 'Cos417']],
#                'Mul510': ['Mul', ['m2', 'l']],
#                'Mul512': ['Mul', ['Mul510', 'd']],
#                'Mul513': ['Mul', ['Mul512', 'Add413']],
#                'Mul514': ['Mul', ['Mul513', 'Cos417']],
#                'Mul516': ['Mul', ['Mul437', 'Add424']],
#                'Mul520': ['Mul', ['Constant83', 'Div276']],
#                'Mul523': ['Mul', ['Constant84', 'Div401']],
#                'Mul527': ['Mul', ['Add525', 'dt']],
#                'Mul534': ['Mul', ['Constant86', 'Add161']],
#                'Mul537': ['Mul', ['Constant87', 'Add286']],
#                'Mul541': ['Mul', ['Add539', 'dt']],
#                'Mul548': ['Mul', ['Constant89', 'Div244']],
#                'Mul55': ['Mul', ['m2', 'Pow53']],
#                'Mul551': ['Mul', ['Constant90', 'Div369']],
#                'Mul555': ['Mul', ['Add553', 'dt']],
#                'Mul562': ['Mul', ['Constant92', 'Add171']],
#                'Mul565': ['Mul', ['Constant93', 'Add296']],
#                'Mul569': ['Mul', ['Add567', 'dt']],
#                'Mul61': ['Mul', ['Add60', 'Add57']],
#                'Mul64': ['Mul', ['m2', 'l']],
#                'Mul65': ['Mul', ['Mul64', 'Cos50']],
#                'Mul70': ['Mul', ['gear', 'SamplePart48']],
#                'Mul72': ['Mul', ['Add57', 'b']],
#                'Mul73': ['Mul', ['Mul72', 'Add13']],
#                'Mul78': ['Mul', ['Add76', 'd']],
#                'Mul79': ['Mul', ['Mul78', 'Add20']],
#                'Mul87': ['Mul', ['Neg83', 'Pow86']],
#                'Mul90': ['Mul', ['Mul87', 'Pow89']],
#                'Mul91': ['Mul', ['Mul90', 'Sin49']],
#                'Mul92': ['Mul', ['Mul91', 'Cos50']],
#                'Mul98': ['Mul', ['Add96', 'm2']],
#                'Neg208': ['Neg', ['Pow207']],
#                'Neg333': ['Neg', ['Pow332']],
#                'Neg450': ['Neg', ['Pow449']],
#                'Neg83': ['Neg', ['Pow82']],
#                'Pow125': ['Pow', ['Add20', 'Constant48']],
#                'Pow131': ['Pow', ['m2', 'Constant49']],
#                'Pow134': ['Pow', ['l', 'Constant50']],
#                'Pow178': ['Pow', ['l', 'Constant55']],
#                'Pow192': ['Pow', ['Mul190', 'Constant56']],
#                'Pow207': ['Pow', ['m2', 'Constant57']],
#                'Pow211': ['Pow', ['l', 'Constant58']],
#                'Pow214': ['Pow', ['Add171', 'Constant59']],
#                'Pow250': ['Pow', ['Add171', 'Constant60']],
#                'Pow256': ['Pow', ['m2', 'Constant61']],
#                'Pow259': ['Pow', ['l', 'Constant62']],
#                'Pow303': ['Pow', ['l', 'Constant67']],
#                'Pow317': ['Pow', ['Mul315', 'Constant68']],
#                'Pow332': ['Pow', ['m2', 'Constant69']],
#                'Pow336': ['Pow', ['l', 'Constant70']],
#                'Pow339': ['Pow', ['Add296', 'Constant71']],
#                'Pow375': ['Pow', ['Add296', 'Constant72']],
#                'Pow381': ['Pow', ['m2', 'Constant73']],
#                'Pow384': ['Pow', ['l', 'Constant74']],
#                'Pow420': ['Pow', ['l', 'Constant75']],
#                'Pow434': ['Pow', ['Mul432', 'Constant76']],
#                'Pow449': ['Pow', ['m2', 'Constant77']],
#                'Pow453': ['Pow', ['l', 'Constant78']],
#                'Pow456': ['Pow', ['Add413', 'Constant79']],
#                'Pow492': ['Pow', ['Add413', 'Constant80']],
#                'Pow498': ['Pow', ['m2', 'Constant81']],
#                'Pow501': ['Pow', ['l', 'Constant82']],
#                'Pow53': ['Pow', ['l', 'Constant43']],
#                'Pow67': ['Pow', ['Mul65', 'Constant44']],
#                'Pow82': ['Pow', ['m2', 'Constant45']],
#                'Pow86': ['Pow', ['l', 'Constant46']],
#                'Pow89': ['Pow', ['Add20', 'Constant47']],
#                'SamplePart1': ['SamplePart', ['Xpos'], -1, [-1, 0]],
#                'SamplePart10': ['SamplePart', ['noise1'], -1, [-1, 0]],
#                'SamplePart15': ['SamplePart',
#                                 ['Xangular_velocity'],
#                                 -1,
#                                 [-1, 0]],
#                'SamplePart17': ['SamplePart', ['noise3'], -1, [-1, 0]],
#                'SamplePart173': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart22': ['SamplePart', ['Xangle'], -1, [-1, 0]],
#                'SamplePart24': ['SamplePart', ['noise2'], -1, [-1, 0]],
#                'SamplePart298': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart3': ['SamplePart', ['noise4'], -1, [-1, 0]],
#                'SamplePart36': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart415': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart48': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart580': ['SamplePart',
#                                  ['Yangular_velocity'],
#                                  -1,
#                                  [-1, 0]],
#                'SamplePart582': ['SamplePart', ['Yangle'], -1, [-1, 0]],
#                'SamplePart584': ['SamplePart', ['Yvelocity'], -1, [-1, 0]],
#                'SamplePart586': ['SamplePart', ['Ypos'], -1, [-1, 0]],
#                'SamplePart8': ['SamplePart', ['Xvelocity'], -1, [-1, 0]],
#                'Select531': ['Select', ['Linear46'], 4, 0],
#                'Select545': ['Select', ['Linear46'], 4, 1],
#                'Select559': ['Select', ['Linear46'], 4, 2],
#                'Select573': ['Select', ['Linear46'], 4, 3],
#                'Select575': ['Select', ['Linear46'], 4, 3],
#                'Select576': ['Select', ['Linear46'], 4, 2],
#                'Select577': ['Select', ['Linear46'], 4, 1],
#                'Select578': ['Select', ['Linear46'], 4, 0],
#                'Sin174': ['Sin', ['Add166']],
#                'Sin299': ['Sin', ['Add291']],
#                'Sin30': ['Sin', ['Add27']],
#                'Sin416': ['Sin', ['Add410']],
#                'Sin49': ['Sin', ['Add27']],
#                'Sub118': ['Sub', ['Add112', 'Mul117']],
#                'Sub128': ['Sub', ['Mul127', 'Mul73']],
#                'Sub140': ['Sub', ['Sub128', 'Mul139']],
#                'Sub193': ['Sub', ['Mul186', 'Pow192']],
#                'Sub218': ['Sub', ['Mul217', 'Mul204']],
#                'Sub243': ['Sub', ['Add237', 'Mul242']],
#                'Sub253': ['Sub', ['Mul252', 'Mul198']],
#                'Sub265': ['Sub', ['Sub253', 'Mul264']],
#                'Sub318': ['Sub', ['Mul311', 'Pow317']],
#                'Sub343': ['Sub', ['Mul342', 'Mul329']],
#                'Sub368': ['Sub', ['Add362', 'Mul367']],
#                'Sub378': ['Sub', ['Mul377', 'Mul323']],
#                'Sub390': ['Sub', ['Sub378', 'Mul389']],
#                'Sub435': ['Sub', ['Mul428', 'Pow434']],
#                'Sub460': ['Sub', ['Mul459', 'Mul446']],
#                'Sub485': ['Sub', ['Add479', 'Mul484']],
#                'Sub495': ['Sub', ['Mul494', 'Mul440']],
#                'Sub507': ['Sub', ['Sub495', 'Mul506']],
#                'Sub68': ['Sub', ['Mul61', 'Pow67']],
#                'Sub93': ['Sub', ['Mul92', 'Mul79']],
#                'Tanh43': ['Tanh', ['Add42']],
#                'Tanh45': ['Tanh', ['Linear44']]}}
# ================================================================================

# %%
# Training
data_struct = ['time', 'action', 'Xpos', 'Xangle', 'Xvelocity', 'Xangular_velocity', 'Ypos', 'Yangle', 'Yvelocity', 'Yangular_velocity', 'noise1', 'noise2', 'noise3', 'noise4']
data_folder = os.path.join(os.path.abspath(''), 'data')
inverted_pendulum.loadData(name='data', source=data_folder, format=data_struct, delimiter=',', header=0)

prediction_samples = None
step = None
early_stop_patience = 20
inverted_pendulum.exportPythonModel(name=model_name)
inverted_pendulum.importPythonModel(name=model_name)
inverted_pendulum.neuralizeModel(sample_time = 0.02)
params = {'train_batch_size':64, 'num_of_epochs':500, 'lr':1e-3}
inverted_pendulum.trainModel(splits=[100,0,0], optimizer='Adam', prediction_samples=prediction_samples, step=step, training_params=params, early_stopping=earlystopping.early_stop_patience,  
                                                            early_stopping_params={'patience':early_stop_patience, 'error':'ang_vel_error'})
inverted_pendulum.exportPythonModel(name=model_name)
inverted_pendulum.exportReport(name=model_name+'_report')
# Out:
# ============================ nnodely Model Dataset =============================
# Dataset Name:                 data
# Number of files:              200
# Total number of samples:      30000
# Shape of Xpos:                (30000, 1, 1)
# Shape of action:              (30000, 1, 1)
# Shape of noise3:              (30000, 1, 1)
# Shape of Xangular_velocity:   (30000, 1, 1)
# Shape of noise2:              (30000, 1, 1)
# Shape of Xangle:              (30000, 1, 1)
# Shape of noise1:              (30000, 1, 1)
# Shape of Xvelocity:           (30000, 1, 1)
# Shape of noise4:              (30000, 1, 1)
# Shape of Ypos:                (30000, 1, 1)
# Shape of Yvelocity:           (30000, 1, 1)
# Shape of Yangle:              (30000, 1, 1)
# Shape of Yangular_velocity:   (30000, 1, 1)
# ================================================================================
# =============================== Save JSON Model ================================
# Model saved in:               /home/baro/Desktop/inv_pend/saved_models/nn_physical_model.json
# ================================================================================
# ========================== Export Python Torch Model ===========================
# Model exported in:            /home/baro/Desktop/inv_pend/saved_models/nn_physical_model.py
# ================================================================================
# =============================== Load JSON Model ================================
# Model loaded from:            /home/baro/Desktop/inv_pend/saved_models/nn_physical_model.json
# ================================================================================
# [neuralizeModel] Closed loop on Xangle with sample in the future.
# [neuralizeModel] Closed loop on Xangular_velocity with sample in the future.
# [neuralizeModel] Closed loop on Xpos with sample in the future.
# [neuralizeModel] Closed loop on Xvelocity with sample in the future.
# ================================ nnodely Model =================================
# {'Constants': {'Constant43': {'dim': 1, 'values': [2.0]},
#                'Constant44': {'dim': 1, 'values': [2.0]},
#                'Constant45': {'dim': 1, 'values': [2.0]},
#                'Constant46': {'dim': 1, 'values': [2.0]},
#                'Constant47': {'dim': 1, 'values': [2.0]},
#                'Constant48': {'dim': 1, 'values': [2.0]},
#                'Constant49': {'dim': 1, 'values': [2.0]},
#                'Constant50': {'dim': 1, 'values': [2.0]},
#                'Constant52': {'dim': 1, 'values': [2.0]},
#                'Constant53': {'dim': 1, 'values': [2.0]},
#                'Constant54': {'dim': 1, 'values': [2.0]},
#                'Constant55': {'dim': 1, 'values': [2.0]},
#                'Constant56': {'dim': 1, 'values': [2.0]},
#                'Constant57': {'dim': 1, 'values': [2.0]},
#                'Constant58': {'dim': 1, 'values': [2.0]},
#                'Constant59': {'dim': 1, 'values': [2.0]},
#                'Constant60': {'dim': 1, 'values': [2.0]},
#                'Constant61': {'dim': 1, 'values': [2.0]},
#                'Constant62': {'dim': 1, 'values': [2.0]},
#                'Constant64': {'dim': 1, 'values': [2.0]},
#                'Constant65': {'dim': 1, 'values': [2.0]},
#                'Constant66': {'dim': 1, 'values': [2.0]},
#                'Constant67': {'dim': 1, 'values': [2.0]},
#                'Constant68': {'dim': 1, 'values': [2.0]},
#                'Constant69': {'dim': 1, 'values': [2.0]},
#                'Constant70': {'dim': 1, 'values': [2.0]},
#                'Constant71': {'dim': 1, 'values': [2.0]},
#                'Constant72': {'dim': 1, 'values': [2.0]},
#                'Constant73': {'dim': 1, 'values': [2.0]},
#                'Constant74': {'dim': 1, 'values': [2.0]},
#                'Constant75': {'dim': 1, 'values': [2.0]},
#                'Constant76': {'dim': 1, 'values': [2.0]},
#                'Constant77': {'dim': 1, 'values': [2.0]},
#                'Constant78': {'dim': 1, 'values': [2.0]},
#                'Constant79': {'dim': 1, 'values': [2.0]},
#                'Constant80': {'dim': 1, 'values': [2.0]},
#                'Constant81': {'dim': 1, 'values': [2.0]},
#                'Constant82': {'dim': 1, 'values': [2.0]},
#                'Constant83': {'dim': 1, 'values': [2.0]},
#                'Constant84': {'dim': 1, 'values': [2.0]},
#                'Constant85': {'dim': 1, 'values': [6.0]},
#                'Constant86': {'dim': 1, 'values': [2.0]},
#                'Constant87': {'dim': 1, 'values': [2.0]},
#                'Constant88': {'dim': 1, 'values': [6.0]},
#                'Constant89': {'dim': 1, 'values': [2.0]},
#                'Constant90': {'dim': 1, 'values': [2.0]},
#                'Constant91': {'dim': 1, 'values': [6.0]},
#                'Constant92': {'dim': 1, 'values': [2.0]},
#                'Constant93': {'dim': 1, 'values': [2.0]},
#                'Constant94': {'dim': 1, 'values': [6.0]},
#                'dt': {'dim': 1, 'values': [0.019999999552965164]},
#                'g': {'dim': 1, 'values': [9.8100004196167]},
#                'gear': {'dim': 1, 'values': [100.0]},
#                'sigma_omega': {'dim': 1, 'values': [0.0]},
#                'sigma_theta': {'dim': 1, 'values': [0.0]},
#                'sigma_v': {'dim': 1, 'values': [0.0]},
#                'sigma_x': {'dim': 1, 'values': [0.0]}},
#  'Functions': {},
#  'Info': {'SampleTime': 0.02,
#           'nnodely_version': '1.5.2',
#           'ns': [1, 0],
#           'ntot': 1,
#           'num_parameters': 206},
#  'Inputs': {'Xangle': {'closedLoop': 'Add574',
#                        'dim': 1,
#                        'local': 1,
#                        'ns': [1, 0],
#                        'ntot': 1,
#                        'sw': [-1, 0]},
#             'Xangular_velocity': {'closedLoop': 'Add560',
#                                   'dim': 1,
#                                   'local': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Xpos': {'closedLoop': 'Add546',
#                      'dim': 1,
#                      'local': 1,
#                      'ns': [1, 0],
#                      'ntot': 1,
#                      'sw': [-1, 0]},
#             'Xvelocity': {'closedLoop': 'Add532',
#                           'dim': 1,
#                           'local': 1,
#                           'ns': [1, 0],
#                           'ntot': 1,
#                           'sw': [-1, 0]},
#             'Yangle': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yangular_velocity': {'dim': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Ypos': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yvelocity': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'action': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise1': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise2': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise3': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise4': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]}},
#  'Minimizers': {'ang_vel_error': {'A': 'SamplePart580',
#                                   'B': 'Add560',
#                                   'loss': 'mse'},
#                 'angle_error': {'A': 'SamplePart582',
#                                 'B': 'Add574',
#                                 'loss': 'mse'},
#                 'pos_error': {'A': 'SamplePart586',
#                               'B': 'Add546',
#                               'loss': 'mse'},
#                 'vel_error': {'A': 'SamplePart584',
#                               'B': 'Add532',
#                               'loss': 'mse'}},
#  'Models': 'pendulum',
#  'Outputs': {'contr_theta': 'Select575',
#              'contr_thetadot': 'Select576',
#              'contr_x': 'Select578',
#              'contr_xdot': 'Select577',
#              'est_theta': 'Add574',
#              'est_thetadot': 'Add560',
#              'est_x': 'Add546',
#              'est_xdot': 'Add532'},
#  'Parameters': {'I': {'dim': 1, 'values': [0.07601392269134521]},
#                 'PLinear27W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[-0.00869770534336567,
#                                            0.00638507679104805,
#                                            0.003210035851225257,
#                                            0.006352710071951151,
#                                            0.000530886638443917,
#                                            0.005158124957233667,
#                                            0.0010753677925094962,
#                                            -0.0016517032636329532,
#                                            0.008639078587293625,
#                                            -0.003799901343882084]]},
#                 'PLinear29W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[-0.0038965512067079544,
#                                            0.007394349668174982,
#                                            -0.007424590177834034,
#                                            -0.008793101646006107,
#                                            0.0031364508904516697,
#                                            -0.0005372866289690137,
#                                            -0.006544576957821846,
#                                            -0.004281366243958473,
#                                            0.006668386049568653,
#                                            0.005434591788798571]]},
#                 'PLinear31W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[-0.0043343473225831985,
#                                            0.007480219006538391,
#                                            -0.008195712231099606,
#                                            0.005128732416778803,
#                                            -0.0032368283718824387,
#                                            -0.0010830258252099156,
#                                            0.002695991424843669,
#                                            -0.0004891763674095273,
#                                            0.0059421067126095295,
#                                            0.005818018689751625]]},
#                 'PLinear33W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[0.007489468902349472,
#                                            -0.0030282228253781796,
#                                            0.00602993369102478,
#                                            0.006138994358479977,
#                                            -0.00599884707480669,
#                                            -0.003091196995228529,
#                                            0.007608319167047739,
#                                            -9.221755135513376e-06,
#                                            0.0024316643830388784,
#                                            0.0040740822441875935]]},
#                 'PLinear35W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[-0.008397525176405907,
#                                            -0.006268790457397699,
#                                            0.004164554178714752,
#                                            -0.006511803716421127,
#                                            0.004984942264854908,
#                                            -0.001698038773611188,
#                                            -0.006211462430655956,
#                                            -0.0020472591277211905,
#                                            0.002269558608531952,
#                                            -0.004520269576460123]]},
#                 'PLinear37W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[0.006448206026107073,
#                                            0.0005071097402833402,
#                                            -0.005086095537990332,
#                                            0.0017759200418367982,
#                                            -0.0005956368404440582,
#                                            0.005107024218887091,
#                                            -0.005153392907232046,
#                                            -8.604705362813547e-05,
#                                            0.006314787082374096,
#                                            -0.003664198098704219]]},
#                 'PLinear39W': {'dim': [10, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[-0.00395909184589982,
#                                            -0.0022782054729759693,
#                                            0.006326490547508001,
#                                            0.004558152053505182,
#                                            -0.004553195089101791,
#                                            -0.0071602556854486465,
#                                            0.009519141167402267,
#                                            0.004698562901467085,
#                                            0.005516562610864639,
#                                            0.009898675605654716],
#                                           [0.0024084143806248903,
#                                            0.008489909581840038,
#                                            -0.00572320818901062,
#                                            -0.007584333885461092,
#                                            -0.006140540819615126,
#                                            -0.0008870808524079621,
#                                            0.003431275486946106,
#                                            0.007538207806646824,
#                                            -0.00605878746137023,
#                                            0.0024377189110964537],
#                                           [-0.005622348748147488,
#                                            -0.0016208942979574203,
#                                            0.008837422356009483,
#                                            0.009289625100791454,
#                                            0.00909960176795721,
#                                            -0.00011492515477584675,
#                                            0.004154108930379152,
#                                            0.0015442861476913095,
#                                            0.00023052167671266943,
#                                            0.006674544420093298],
#                                           [0.003440167987719178,
#                                            -0.0033499968703836203,
#                                            -0.005944118835031986,
#                                            0.002011570381000638,
#                                            -0.005846661049872637,
#                                            0.004363951738923788,
#                                            -0.00415433943271637,
#                                            -0.009944280609488487,
#                                            -0.004660711623728275,
#                                            -0.004188220947980881],
#                                           [0.008074771612882614,
#                                            -0.003121965564787388,
#                                            0.004519582260400057,
#                                            0.007281737867742777,
#                                            -0.003368101315572858,
#                                            0.004258370026946068,
#                                            -0.007982190698385239,
#                                            -0.001815942581743002,
#                                            0.0018802174599841237,
#                                            0.000606298039201647],
#                                           [-0.008207122795283794,
#                                            -0.0041228653863072395,
#                                            -0.007295813877135515,
#                                            -0.008434723131358624,
#                                            -0.002206289442256093,
#                                            -0.0013451710110530257,
#                                            -0.0013152883620932698,
#                                            0.009846079163253307,
#                                            0.0010365053312852979,
#                                            0.0028417978901416063],
#                                           [-0.004655978176742792,
#                                            0.002470905426889658,
#                                            0.002537802327424288,
#                                            0.0009311316534876823,
#                                            -0.006038389168679714,
#                                            -0.001044299453496933,
#                                            -0.006403271108865738,
#                                            0.005631319247186184,
#                                            0.00905177928507328,
#                                            0.007294727489352226],
#                                           [0.0002616810379549861,
#                                            -0.003230893984436989,
#                                            0.006790153216570616,
#                                            0.007435491308569908,
#                                            -0.003174371086061001,
#                                            -0.003635300323367119,
#                                            -0.00833142176270485,
#                                            0.008570699021220207,
#                                            -0.0010380761232227087,
#                                            -0.009064246900379658],
#                                           [0.001089887460693717,
#                                            -0.0012935502454638481,
#                                            0.0003120082837995142,
#                                            0.0069343396462500095,
#                                            0.008316721767187119,
#                                            0.008541741408407688,
#                                            -0.004006875678896904,
#                                            0.004161544144153595,
#                                            -0.004348560702055693,
#                                            -0.0021190065890550613],
#                                           [0.002003657165914774,
#                                            0.0016733754891902208,
#                                            -6.657528047071537e-06,
#                                            -0.0006492375396192074,
#                                            -0.0022000756580382586,
#                                            0.0043856012634932995,
#                                            -0.004136598203331232,
#                                            -0.0070426627062261105,
#                                            0.0006845920579507947,
#                                            0.0015673114685341716]]},
#                 'PLinear41W': {'dim': [10, 4],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[0.00284898211248219,
#                                            -0.0030454336665570736,
#                                            -0.00797986425459385,
#                                            0.007080556359142065],
#                                           [-0.006095935590565205,
#                                            0.0038660275749862194,
#                                            -0.009385895915329456,
#                                            0.009946539998054504],
#                                           [0.009638735093176365,
#                                            0.006569757591933012,
#                                            0.006661471910774708,
#                                            -0.00028913281857967377],
#                                           [0.0022423809859901667,
#                                            -0.006019303575158119,
#                                            -0.00932258553802967,
#                                            -0.004198046866804361],
#                                           [-0.009277847595512867,
#                                            0.0016588097205385566,
#                                            -0.008960353210568428,
#                                            -0.006882243324071169],
#                                           [-0.007994741201400757,
#                                            0.008960641920566559,
#                                            0.006346501410007477,
#                                            0.0003035464324057102],
#                                           [0.00968116894364357,
#                                            -0.008394845761358738,
#                                            0.0001961674279300496,
#                                            0.006920239422470331],
#                                           [0.007125783246010542,
#                                            0.007388942409306765,
#                                            0.0002994257665704936,
#                                            -0.008519786410033703],
#                                           [0.00549260014668107,
#                                            -0.0022583308164030313,
#                                            -0.005632195621728897,
#                                            -0.007025754079222679],
#                                           [0.0006980248144827783,
#                                            -0.009389974176883698,
#                                            0.0020347265526652336,
#                                            -0.0027033654041588306]]},
#                 'b': {'dim': 1, 'values': [0.9625828862190247]},
#                 'd': {'dim': 1, 'values': [0.4160938858985901]},
#                 'l': {'dim': 1, 'values': [0.2789917588233948]},
#                 'm1': {'dim': 1, 'values': [0.7723962068557739]},
#                 'm2': {'dim': 1, 'values': [0.4194328784942627]}},
#  'Relations': {'Add104': ['Add', ['Sub93', 'Mul103']],
#                'Add112': ['Add', ['Add104', 'Mul111']],
#                'Add13': ['Add', ['SamplePart8', 'Mul12']],
#                'Add148': ['Add', ['Sub140', 'Mul147']],
#                'Add150': ['Add', ['Add148', 'Mul149']],
#                'Add161': ['Add', ['Add13', 'Div160']],
#                'Add166': ['Add', ['Add27', 'Div165']],
#                'Add171': ['Add', ['Add20', 'Div170']],
#                'Add182': ['Add', ['I', 'Mul180']],
#                'Add185': ['Add', ['m1', 'm2']],
#                'Add20': ['Add', ['SamplePart15', 'Mul19']],
#                'Add201': ['Add', ['m1', 'm2']],
#                'Add221': ['Add', ['m1', 'm2']],
#                'Add229': ['Add', ['Sub218', 'Mul228']],
#                'Add237': ['Add', ['Add229', 'Mul236']],
#                'Add27': ['Add', ['SamplePart22', 'Mul26']],
#                'Add273': ['Add', ['Sub265', 'Mul272']],
#                'Add275': ['Add', ['Add273', 'Mul274']],
#                'Add286': ['Add', ['Add13', 'Div285']],
#                'Add291': ['Add', ['Add27', 'Div290']],
#                'Add296': ['Add', ['Add20', 'Div295']],
#                'Add307': ['Add', ['I', 'Mul305']],
#                'Add310': ['Add', ['m1', 'm2']],
#                'Add326': ['Add', ['m1', 'm2']],
#                'Add346': ['Add', ['m1', 'm2']],
#                'Add354': ['Add', ['Sub343', 'Mul353']],
#                'Add362': ['Add', ['Add354', 'Mul361']],
#                'Add38': ['Add', ['Linear28', 'Linear29']],
#                'Add39': ['Add', ['Add38', 'Linear31']],
#                'Add398': ['Add', ['Sub390', 'Mul397']],
#                'Add40': ['Add', ['Add39', 'Linear33']],
#                'Add400': ['Add', ['Add398', 'Mul399']],
#                'Add407': ['Add', ['Add13', 'Mul406']],
#                'Add41': ['Add', ['Add40', 'Linear34']],
#                'Add410': ['Add', ['Add27', 'Mul409']],
#                'Add413': ['Add', ['Add20', 'Mul412']],
#                'Add42': ['Add', ['Add41', 'Linear37']],
#                'Add424': ['Add', ['I', 'Mul422']],
#                'Add427': ['Add', ['m1', 'm2']],
#                'Add443': ['Add', ['m1', 'm2']],
#                'Add463': ['Add', ['m1', 'm2']],
#                'Add471': ['Add', ['Sub460', 'Mul470']],
#                'Add479': ['Add', ['Add471', 'Mul478']],
#                'Add515': ['Add', ['Sub507', 'Mul514']],
#                'Add517': ['Add', ['Add515', 'Mul516']],
#                'Add521': ['Add', ['Div151', 'Mul520']],
#                'Add524': ['Add', ['Add521', 'Mul523']],
#                'Add525': ['Add', ['Add524', 'Div518']],
#                'Add530': ['Add', ['Add13', 'Div529']],
#                'Add532': ['Add', ['Add530', 'Select531']],
#                'Add535': ['Add', ['Add13', 'Mul534']],
#                'Add538': ['Add', ['Add535', 'Mul537']],
#                'Add539': ['Add', ['Add538', 'Add407']],
#                'Add544': ['Add', ['Add6', 'Div543']],
#                'Add546': ['Add', ['Add544', 'Select545']],
#                'Add549': ['Add', ['Div119', 'Mul548']],
#                'Add552': ['Add', ['Add549', 'Mul551']],
#                'Add553': ['Add', ['Add552', 'Div486']],
#                'Add558': ['Add', ['Add20', 'Div557']],
#                'Add560': ['Add', ['Add558', 'Select559']],
#                'Add563': ['Add', ['Add20', 'Mul562']],
#                'Add566': ['Add', ['Add563', 'Mul565']],
#                'Add567': ['Add', ['Add566', 'Add413']],
#                'Add57': ['Add', ['I', 'Mul55']],
#                'Add572': ['Add', ['Add27', 'Div571']],
#                'Add574': ['Add', ['Add572', 'Select573']],
#                'Add6': ['Add', ['SamplePart1', 'Mul5']],
#                'Add60': ['Add', ['m1', 'm2']],
#                'Add76': ['Add', ['m1', 'm2']],
#                'Add96': ['Add', ['m1', 'm2']],
#                'Cos175': ['Cos', ['Add166']],
#                'Cos300': ['Cos', ['Add291']],
#                'Cos32': ['Cos', ['Add27']],
#                'Cos417': ['Cos', ['Add410']],
#                'Cos50': ['Cos', ['Add27']],
#                'Div119': ['Div', ['Sub118', 'Sub68']],
#                'Div151': ['Div', ['Add150', 'Sub68']],
#                'Div160': ['Div', ['Mul158', 'Constant52']],
#                'Div165': ['Div', ['Mul163', 'Constant53']],
#                'Div170': ['Div', ['Mul168', 'Constant54']],
#                'Div244': ['Div', ['Sub243', 'Sub193']],
#                'Div276': ['Div', ['Add275', 'Sub193']],
#                'Div285': ['Div', ['Mul283', 'Constant64']],
#                'Div290': ['Div', ['Mul288', 'Constant65']],
#                'Div295': ['Div', ['Mul293', 'Constant66']],
#                'Div369': ['Div', ['Sub368', 'Sub318']],
#                'Div401': ['Div', ['Add400', 'Sub318']],
#                'Div486': ['Div', ['Sub485', 'Sub435']],
#                'Div518': ['Div', ['Add517', 'Sub435']],
#                'Div529': ['Div', ['Mul527', 'Constant85']],
#                'Div543': ['Div', ['Mul541', 'Constant88']],
#                'Div557': ['Div', ['Mul555', 'Constant91']],
#                'Div571': ['Div', ['Mul569', 'Constant94']],
#                'Linear28': ['Linear', ['Add27'], 'PLinear27W', None, 0.0],
#                'Linear29': ['Linear', ['Add13'], 'PLinear29W', None, 0.0],
#                'Linear31': ['Linear', ['Sin30'], 'PLinear31W', None, 0.0],
#                'Linear33': ['Linear', ['Cos32'], 'PLinear33W', None, 0.0],
#                'Linear34': ['Linear', ['Add20'], 'PLinear35W', None, 0.0],
#                'Linear37': ['Linear',
#                             ['SamplePart36'],
#                             'PLinear37W',
#                             None,
#                             0.0],
#                'Linear44': ['Linear', ['Tanh43'], 'PLinear39W', None, 0.0],
#                'Linear46': ['Linear', ['Tanh45'], 'PLinear41W', None, 0],
#                'Mul100': ['Mul', ['Mul98', 'g']],
#                'Mul102': ['Mul', ['Mul100', 'l']],
#                'Mul103': ['Mul', ['Mul102', 'Sin49']],
#                'Mul107': ['Mul', ['m2', 'l']],
#                'Mul109': ['Mul', ['Mul107', 'b']],
#                'Mul110': ['Mul', ['Mul109', 'Add13']],
#                'Mul111': ['Mul', ['Mul110', 'Cos50']],
#                'Mul115': ['Mul', ['m2', 'l']],
#                'Mul116': ['Mul', ['Mul115', 'Cos50']],
#                'Mul117': ['Mul', ['Mul116', 'Mul70']],
#                'Mul12': ['Mul', ['SamplePart10', 'sigma_v']],
#                'Mul121': ['Mul', ['Add57', 'm2']],
#                'Mul123': ['Mul', ['Mul121', 'l']],
#                'Mul126': ['Mul', ['Mul123', 'Pow125']],
#                'Mul127': ['Mul', ['Mul126', 'Sin49']],
#                'Mul135': ['Mul', ['Pow131', 'Pow134']],
#                'Mul137': ['Mul', ['Mul135', 'g']],
#                'Mul138': ['Mul', ['Mul137', 'Sin49']],
#                'Mul139': ['Mul', ['Mul138', 'Cos50']],
#                'Mul143': ['Mul', ['m2', 'l']],
#                'Mul145': ['Mul', ['Mul143', 'd']],
#                'Mul146': ['Mul', ['Mul145', 'Add20']],
#                'Mul147': ['Mul', ['Mul146', 'Cos50']],
#                'Mul149': ['Mul', ['Mul70', 'Add57']],
#                'Mul158': ['Mul', ['Div151', 'dt']],
#                'Mul163': ['Mul', ['Add20', 'dt']],
#                'Mul168': ['Mul', ['Div119', 'dt']],
#                'Mul180': ['Mul', ['m2', 'Pow178']],
#                'Mul186': ['Mul', ['Add185', 'Add182']],
#                'Mul189': ['Mul', ['m2', 'l']],
#                'Mul19': ['Mul', ['SamplePart17', 'sigma_omega']],
#                'Mul190': ['Mul', ['Mul189', 'Cos175']],
#                'Mul195': ['Mul', ['gear', 'SamplePart173']],
#                'Mul197': ['Mul', ['Add182', 'b']],
#                'Mul198': ['Mul', ['Mul197', 'Add161']],
#                'Mul203': ['Mul', ['Add201', 'd']],
#                'Mul204': ['Mul', ['Mul203', 'Add171']],
#                'Mul212': ['Mul', ['Neg208', 'Pow211']],
#                'Mul215': ['Mul', ['Mul212', 'Pow214']],
#                'Mul216': ['Mul', ['Mul215', 'Sin174']],
#                'Mul217': ['Mul', ['Mul216', 'Cos175']],
#                'Mul223': ['Mul', ['Add221', 'm2']],
#                'Mul225': ['Mul', ['Mul223', 'g']],
#                'Mul227': ['Mul', ['Mul225', 'l']],
#                'Mul228': ['Mul', ['Mul227', 'Sin174']],
#                'Mul232': ['Mul', ['m2', 'l']],
#                'Mul234': ['Mul', ['Mul232', 'b']],
#                'Mul235': ['Mul', ['Mul234', 'Add161']],
#                'Mul236': ['Mul', ['Mul235', 'Cos175']],
#                'Mul240': ['Mul', ['m2', 'l']],
#                'Mul241': ['Mul', ['Mul240', 'Cos175']],
#                'Mul242': ['Mul', ['Mul241', 'Mul195']],
#                'Mul246': ['Mul', ['Add182', 'm2']],
#                'Mul248': ['Mul', ['Mul246', 'l']],
#                'Mul251': ['Mul', ['Mul248', 'Pow250']],
#                'Mul252': ['Mul', ['Mul251', 'Sin174']],
#                'Mul26': ['Mul', ['SamplePart24', 'sigma_theta']],
#                'Mul260': ['Mul', ['Pow256', 'Pow259']],
#                'Mul262': ['Mul', ['Mul260', 'g']],
#                'Mul263': ['Mul', ['Mul262', 'Sin174']],
#                'Mul264': ['Mul', ['Mul263', 'Cos175']],
#                'Mul268': ['Mul', ['m2', 'l']],
#                'Mul270': ['Mul', ['Mul268', 'd']],
#                'Mul271': ['Mul', ['Mul270', 'Add171']],
#                'Mul272': ['Mul', ['Mul271', 'Cos175']],
#                'Mul274': ['Mul', ['Mul195', 'Add182']],
#                'Mul283': ['Mul', ['Div276', 'dt']],
#                'Mul288': ['Mul', ['Add171', 'dt']],
#                'Mul293': ['Mul', ['Div244', 'dt']],
#                'Mul305': ['Mul', ['m2', 'Pow303']],
#                'Mul311': ['Mul', ['Add310', 'Add307']],
#                'Mul314': ['Mul', ['m2', 'l']],
#                'Mul315': ['Mul', ['Mul314', 'Cos300']],
#                'Mul320': ['Mul', ['gear', 'SamplePart298']],
#                'Mul322': ['Mul', ['Add307', 'b']],
#                'Mul323': ['Mul', ['Mul322', 'Add286']],
#                'Mul328': ['Mul', ['Add326', 'd']],
#                'Mul329': ['Mul', ['Mul328', 'Add296']],
#                'Mul337': ['Mul', ['Neg333', 'Pow336']],
#                'Mul340': ['Mul', ['Mul337', 'Pow339']],
#                'Mul341': ['Mul', ['Mul340', 'Sin299']],
#                'Mul342': ['Mul', ['Mul341', 'Cos300']],
#                'Mul348': ['Mul', ['Add346', 'm2']],
#                'Mul350': ['Mul', ['Mul348', 'g']],
#                'Mul352': ['Mul', ['Mul350', 'l']],
#                'Mul353': ['Mul', ['Mul352', 'Sin299']],
#                'Mul357': ['Mul', ['m2', 'l']],
#                'Mul359': ['Mul', ['Mul357', 'b']],
#                'Mul360': ['Mul', ['Mul359', 'Add286']],
#                'Mul361': ['Mul', ['Mul360', 'Cos300']],
#                'Mul365': ['Mul', ['m2', 'l']],
#                'Mul366': ['Mul', ['Mul365', 'Cos300']],
#                'Mul367': ['Mul', ['Mul366', 'Mul320']],
#                'Mul371': ['Mul', ['Add307', 'm2']],
#                'Mul373': ['Mul', ['Mul371', 'l']],
#                'Mul376': ['Mul', ['Mul373', 'Pow375']],
#                'Mul377': ['Mul', ['Mul376', 'Sin299']],
#                'Mul385': ['Mul', ['Pow381', 'Pow384']],
#                'Mul387': ['Mul', ['Mul385', 'g']],
#                'Mul388': ['Mul', ['Mul387', 'Sin299']],
#                'Mul389': ['Mul', ['Mul388', 'Cos300']],
#                'Mul393': ['Mul', ['m2', 'l']],
#                'Mul395': ['Mul', ['Mul393', 'd']],
#                'Mul396': ['Mul', ['Mul395', 'Add296']],
#                'Mul397': ['Mul', ['Mul396', 'Cos300']],
#                'Mul399': ['Mul', ['Mul320', 'Add307']],
#                'Mul406': ['Mul', ['Div401', 'dt']],
#                'Mul409': ['Mul', ['Add296', 'dt']],
#                'Mul412': ['Mul', ['Div369', 'dt']],
#                'Mul422': ['Mul', ['m2', 'Pow420']],
#                'Mul428': ['Mul', ['Add427', 'Add424']],
#                'Mul431': ['Mul', ['m2', 'l']],
#                'Mul432': ['Mul', ['Mul431', 'Cos417']],
#                'Mul437': ['Mul', ['gear', 'SamplePart415']],
#                'Mul439': ['Mul', ['Add424', 'b']],
#                'Mul440': ['Mul', ['Mul439', 'Add407']],
#                'Mul445': ['Mul', ['Add443', 'd']],
#                'Mul446': ['Mul', ['Mul445', 'Add413']],
#                'Mul454': ['Mul', ['Neg450', 'Pow453']],
#                'Mul457': ['Mul', ['Mul454', 'Pow456']],
#                'Mul458': ['Mul', ['Mul457', 'Sin416']],
#                'Mul459': ['Mul', ['Mul458', 'Cos417']],
#                'Mul465': ['Mul', ['Add463', 'm2']],
#                'Mul467': ['Mul', ['Mul465', 'g']],
#                'Mul469': ['Mul', ['Mul467', 'l']],
#                'Mul470': ['Mul', ['Mul469', 'Sin416']],
#                'Mul474': ['Mul', ['m2', 'l']],
#                'Mul476': ['Mul', ['Mul474', 'b']],
#                'Mul477': ['Mul', ['Mul476', 'Add407']],
#                'Mul478': ['Mul', ['Mul477', 'Cos417']],
#                'Mul482': ['Mul', ['m2', 'l']],
#                'Mul483': ['Mul', ['Mul482', 'Cos417']],
#                'Mul484': ['Mul', ['Mul483', 'Mul437']],
#                'Mul488': ['Mul', ['Add424', 'm2']],
#                'Mul490': ['Mul', ['Mul488', 'l']],
#                'Mul493': ['Mul', ['Mul490', 'Pow492']],
#                'Mul494': ['Mul', ['Mul493', 'Sin416']],
#                'Mul5': ['Mul', ['SamplePart3', 'sigma_x']],
#                'Mul502': ['Mul', ['Pow498', 'Pow501']],
#                'Mul504': ['Mul', ['Mul502', 'g']],
#                'Mul505': ['Mul', ['Mul504', 'Sin416']],
#                'Mul506': ['Mul', ['Mul505', 'Cos417']],
#                'Mul510': ['Mul', ['m2', 'l']],
#                'Mul512': ['Mul', ['Mul510', 'd']],
#                'Mul513': ['Mul', ['Mul512', 'Add413']],
#                'Mul514': ['Mul', ['Mul513', 'Cos417']],
#                'Mul516': ['Mul', ['Mul437', 'Add424']],
#                'Mul520': ['Mul', ['Constant83', 'Div276']],
#                'Mul523': ['Mul', ['Constant84', 'Div401']],
#                'Mul527': ['Mul', ['Add525', 'dt']],
#                'Mul534': ['Mul', ['Constant86', 'Add161']],
#                'Mul537': ['Mul', ['Constant87', 'Add286']],
#                'Mul541': ['Mul', ['Add539', 'dt']],
#                'Mul548': ['Mul', ['Constant89', 'Div244']],
#                'Mul55': ['Mul', ['m2', 'Pow53']],
#                'Mul551': ['Mul', ['Constant90', 'Div369']],
#                'Mul555': ['Mul', ['Add553', 'dt']],
#                'Mul562': ['Mul', ['Constant92', 'Add171']],
#                'Mul565': ['Mul', ['Constant93', 'Add296']],
#                'Mul569': ['Mul', ['Add567', 'dt']],
#                'Mul61': ['Mul', ['Add60', 'Add57']],
#                'Mul64': ['Mul', ['m2', 'l']],
#                'Mul65': ['Mul', ['Mul64', 'Cos50']],
#                'Mul70': ['Mul', ['gear', 'SamplePart48']],
#                'Mul72': ['Mul', ['Add57', 'b']],
#                'Mul73': ['Mul', ['Mul72', 'Add13']],
#                'Mul78': ['Mul', ['Add76', 'd']],
#                'Mul79': ['Mul', ['Mul78', 'Add20']],
#                'Mul87': ['Mul', ['Neg83', 'Pow86']],
#                'Mul90': ['Mul', ['Mul87', 'Pow89']],
#                'Mul91': ['Mul', ['Mul90', 'Sin49']],
#                'Mul92': ['Mul', ['Mul91', 'Cos50']],
#                'Mul98': ['Mul', ['Add96', 'm2']],
#                'Neg208': ['Neg', ['Pow207']],
#                'Neg333': ['Neg', ['Pow332']],
#                'Neg450': ['Neg', ['Pow449']],
#                'Neg83': ['Neg', ['Pow82']],
# ...
#                                 ['Xangular_velocity'],
#                                 -1,
#                                 [-1, 0]],
#                'SamplePart17': ['SamplePart', ['noise3'], -1, [-1, 0]],
#                'SamplePart173': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart22': ['SamplePart', ['Xangle'], -1, [-1, 0]],
#                'SamplePart24': ['SamplePart', ['noise2'], -1, [-1, 0]],
#                'SamplePart298': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart3': ['SamplePart', ['noise4'], -1, [-1, 0]],
#                'SamplePart36': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart415': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart48': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart580': ['SamplePart',
#                                  ['Yangular_velocity'],
#                                  -1,
#                                  [-1, 0]],
#                'SamplePart582': ['SamplePart', ['Yangle'], -1, [-1, 0]],
#                'SamplePart584': ['SamplePart', ['Yvelocity'], -1, [-1, 0]],
#                'SamplePart586': ['SamplePart', ['Ypos'], -1, [-1, 0]],
#                'SamplePart8': ['SamplePart', ['Xvelocity'], -1, [-1, 0]],
#                'Select531': ['Select', ['Linear46'], 4, 0],
#                'Select545': ['Select', ['Linear46'], 4, 1],
#                'Select559': ['Select', ['Linear46'], 4, 2],
#                'Select573': ['Select', ['Linear46'], 4, 3],
#                'Select575': ['Select', ['Linear46'], 4, 3],
#                'Select576': ['Select', ['Linear46'], 4, 2],
#                'Select577': ['Select', ['Linear46'], 4, 1],
#                'Select578': ['Select', ['Linear46'], 4, 0],
#                'Sin174': ['Sin', ['Add166']],
#                'Sin299': ['Sin', ['Add291']],
#                'Sin30': ['Sin', ['Add27']],
#                'Sin416': ['Sin', ['Add410']],
#                'Sin49': ['Sin', ['Add27']],
#                'Sub118': ['Sub', ['Add112', 'Mul117']],
#                'Sub128': ['Sub', ['Mul127', 'Mul73']],
#                'Sub140': ['Sub', ['Sub128', 'Mul139']],
#                'Sub193': ['Sub', ['Mul186', 'Pow192']],
#                'Sub218': ['Sub', ['Mul217', 'Mul204']],
#                'Sub243': ['Sub', ['Add237', 'Mul242']],
#                'Sub253': ['Sub', ['Mul252', 'Mul198']],
#                'Sub265': ['Sub', ['Sub253', 'Mul264']],
#                'Sub318': ['Sub', ['Mul311', 'Pow317']],
#                'Sub343': ['Sub', ['Mul342', 'Mul329']],
#                'Sub368': ['Sub', ['Add362', 'Mul367']],
#                'Sub378': ['Sub', ['Mul377', 'Mul323']],
#                'Sub390': ['Sub', ['Sub378', 'Mul389']],
#                'Sub435': ['Sub', ['Mul428', 'Pow434']],
#                'Sub460': ['Sub', ['Mul459', 'Mul446']],
#                'Sub485': ['Sub', ['Add479', 'Mul484']],
#                'Sub495': ['Sub', ['Mul494', 'Mul440']],
#                'Sub507': ['Sub', ['Sub495', 'Mul506']],
#                'Sub68': ['Sub', ['Mul61', 'Pow67']],
#                'Sub93': ['Sub', ['Mul92', 'Mul79']],
#                'Tanh43': ['Tanh', ['Add42']],
#                'Tanh45': ['Tanh', ['Linear44']]}}
# ================================================================================
# ======================== nnodely Model Train Parameters ========================
# models:                       ['pendulum']
# num of epochs:                500
# update per epochs:            468
# └>len(train_indexes)//(batch_size+step)
# shuffle data:                 True
# early stopping:               early_stop_patience
# early stopping params:        {'error': 'ang_vel_error', 'patience': 20}
# prediction samples:           0
# step:                         0
# closed loop:                  {}
# connect:                      {}
# train dataset:                data_train
# 	- batch size:                64
# 	- num of samples:            30000
# 	- num of first samples:      30000
# minimizers:                   {'ang_vel_error': {'A': 'SamplePart580',
#                                                  'B': 'Add560',
#                                                  'loss': 'mse'},
#                                'angle_error': {'A': 'SamplePart582',
#                                                'B': 'Add574',
#                                                'loss': 'mse'},
#                                'pos_error': {'A': 'SamplePart586',
#                                              'B': 'Add546',
#                                              'loss': 'mse'},
#                                'vel_error': {'A': 'SamplePart584',
#                                              'B': 'Add532',
#                                              'loss': 'mse'}}
# optimizer:                    Adam
# optimizer defaults:           {'lr': 0.001}
# optimizer params:             [{'params': 'I'},
#                                {'params': 'PLinear27W'},
#                                {'params': 'PLinear29W'},
#                                {'params': 'PLinear31W'},
#                                {'params': 'PLinear33W'},
#                                {'params': 'PLinear35W'},
#                                {'params': 'PLinear37W'},
#                                {'params': 'PLinear39W'},
#                                {'params': 'PLinear41W'},
#                                {'params': 'b'},
#                                {'params': 'd'},
#                                {'params': 'l'},
#                                {'params': 'm1'},
#                                {'params': 'm2'}]
# ================================================================================
# =============================================== nnodely Training ===============================================
# |  Epoch   |   ang_vel_error   |    angle_error    |     pos_error     |     vel_error     |       Total       |
# |          |        Loss       |        Loss       |        Loss       |        Loss       |        Loss       |
# |          |       train       |       train       |       train       |       train       |       train       |
# |--------------------------------------------------------------------------------------------------------------|
# |  5/500   |     9.291e-04     |     1.149e-07     |     1.448e-07     |     9.450e-04     |     4.686e-04     |
# |  10/500  |     7.243e-04     |     9.433e-08     |      7.91e-08     |      3.78e-04     |     2.756e-04     |
# |  15/500  |     4.934e-04     |     6.965e-08     |     4.222e-08     |      2.28e-04     |     1.804e-04     |
# |  20/500  |     1.915e-04     |     3.918e-08     |     2.733e-08     |     1.436e-04     |     8.381e-05     |
# |  25/500  |     1.630e-04     |     2.725e-08     |     2.034e-08     |     1.109e-04     |     6.849e-05     |
# |  30/500  |     1.392e-04     |     3.006e-08     |     2.489e-08     |     7.478e-05     |     5.351e-05     |
# |  35/500  |     1.077e-04     |     2.108e-08     |     1.516e-08     |      5.18e-05     |     3.988e-05     |
# |  40/500  |     7.787e-05     |     1.492e-08     |     1.065e-08     |     3.597e-05     |     2.847e-05     |
# |  45/500  |     5.675e-05     |     1.221e-08     |     1.251e-08     |     3.597e-05     |     2.319e-05     |
# |  50/500  |     4.133e-05     |     1.001e-08     |     1.033e-08     |     2.969e-05     |     1.776e-05     |
# |  55/500  |     2.946e-05     |     6.945e-09     |     7.364e-09     |     2.653e-05     |     1.400e-05     |
# |  60/500  |     2.239e-05     |     5.294e-09     |     5.940e-09     |     2.211e-05     |     1.113e-05     |
# |  65/500  |     1.798e-05     |     6.255e-09     |     6.280e-09     |     2.008e-05     |     9.519e-06     |
# |  70/500  |     1.437e-05     |     4.486e-09     |     6.217e-09     |     1.576e-05     |     7.535e-06     |
# |  75/500  |     1.249e-05     |     3.906e-09     |     3.975e-09     |     1.323e-05     |     6.432e-06     |
# |  80/500  |     1.059e-05     |     3.315e-09     |     3.358e-09     |     1.188e-05     |     5.619e-06     |
# |  85/500  |     8.018e-06     |     2.887e-09     |     3.436e-09     |     9.222e-06     |     4.312e-06     |
# |  90/500  |     7.119e-06     |     2.612e-09     |     3.817e-09     |     8.324e-06     |     3.862e-06     |
# |  95/500  |     6.163e-06     |     2.417e-09     |     3.899e-09     |     7.308e-06     |     3.369e-06     |
# | 100/500  |     5.415e-06     |     2.041e-09     |     2.096e-09     |     5.628e-06     |     2.762e-06     |
# | 105/500  |     5.046e-06     |     1.636e-09     |     2.582e-09     |     4.931e-06     |     2.495e-06     |
# | 110/500  |     4.712e-06     |     3.389e-09     |      2.37e-09     |     5.002e-06     |     2.430e-06     |
# | 115/500  |      4.33e-06     |     2.172e-09     |     2.285e-09     |     4.269e-06     |     2.151e-06     |
# | 120/500  |     3.816e-06     |     1.145e-09     |     2.135e-09     |     3.644e-06     |     1.866e-06     |
# | 125/500  |      3.71e-06     |     9.854e-10     |     1.607e-09     |     3.102e-06     |     1.704e-06     |
# | 130/500  |     3.446e-06     |      1.7e-09      |     1.649e-09     |     3.510e-06     |      1.74e-06     |
# | 135/500  |     3.261e-06     |     1.488e-09     |     8.115e-10     |     2.488e-06     |     1.438e-06     |
# | 140/500  |     2.976e-06     |     1.615e-09     |     1.373e-09     |     2.083e-06     |     1.265e-06     |
# | 145/500  |     2.853e-06     |     9.252e-10     |     1.784e-09     |     2.123e-06     |     1.245e-06     |
# | 150/500  |     2.707e-06     |     1.257e-09     |     1.559e-09     |     2.457e-06     |     1.292e-06     |
# | 155/500  |     2.519e-06     |     1.136e-09     |      1.1e-09      |     1.833e-06     |     1.089e-06     |
# | 160/500  |     2.298e-06     |     1.913e-09     |     1.230e-09     |     1.521e-06     |     9.555e-07     |
# | 165/500  |     2.094e-06     |     1.138e-09     |     1.505e-09     |     1.593e-06     |     9.223e-07     |
# | 170/500  |     1.853e-06     |     1.363e-09     |     5.595e-10     |     1.380e-06     |     8.089e-07     |
# | 175/500  |     1.729e-06     |     2.795e-09     |     1.198e-09     |     1.098e-06     |     7.079e-07     |
# | 180/500  |     1.521e-06     |     1.466e-09     |     8.708e-10     |     1.083e-06     |     6.517e-07     |
# | 185/500  |     1.402e-06     |     1.085e-09     |     1.310e-09     |     1.181e-06     |     6.464e-07     |
# | 190/500  |     1.239e-06     |     1.280e-09     |     1.071e-09     |     9.054e-07     |     5.366e-07     |
# | 195/500  |     1.135e-06     |     1.037e-09     |     1.015e-09     |     1.009e-06     |     5.366e-07     |
# | 200/500  |     1.026e-06     |     1.116e-09     |     1.121e-09     |     8.851e-07     |     4.784e-07     |
# | 205/500  |     9.121e-07     |     7.282e-10     |     1.073e-09     |     9.626e-07     |     4.691e-07     |
# | 210/500  |     7.507e-07     |     1.378e-09     |     1.917e-09     |     7.083e-07     |     3.656e-07     |
# | 215/500  |      6.52e-07     |     3.340e-10     |     5.934e-10     |     7.422e-07     |     3.488e-07     |
# | 220/500  |     5.519e-07     |     1.264e-09     |     1.689e-09     |     7.079e-07     |     3.157e-07     |
# | 225/500  |     4.557e-07     |     2.424e-10     |     6.014e-10     |     5.754e-07     |      2.58e-07     |
# | 230/500  |     3.574e-07     |     1.004e-09     |     7.021e-10     |     5.634e-07     |     2.306e-07     |
# | 235/500  |     2.943e-07     |     1.132e-09     |     1.576e-09     |     5.001e-07     |     1.993e-07     |
# | 240/500  |     2.494e-07     |     1.214e-09     |     7.849e-10     |     3.681e-07     |     1.549e-07     |
# | 245/500  |     2.652e-07     |     5.674e-10     |     6.922e-10     |     3.780e-07     |     1.611e-07     |
# | 250/500  |     1.994e-07     |     1.181e-09     |     1.319e-09     |     3.440e-07     |     1.365e-07     |
# | 255/500  |     1.817e-07     |     1.739e-09     |     6.727e-10     |     3.270e-07     |     1.278e-07     |
# | 260/500  |      1.75e-07     |     1.941e-09     |     1.849e-09     |     3.098e-07     |     1.221e-07     |
# | 265/500  |     1.527e-07     |      2.8e-10      |      7.57e-10     |     2.979e-07     |     1.129e-07     |
# | 270/500  |     1.379e-07     |     1.389e-09     |     7.994e-10     |     3.342e-07     |     1.186e-07     |
# | 275/500  |     1.363e-07     |     9.848e-10     |     6.846e-10     |     1.876e-07     |     8.139e-08     |
# | 280/500  |     1.419e-07     |     1.506e-09     |     2.799e-09     |     2.471e-07     |     9.832e-08     |
# | 285/500  |     1.223e-07     |     4.443e-10     |     2.571e-09     |     2.849e-07     |     1.026e-07     |
# | 290/500  |     1.463e-07     |     1.881e-10     |      1.03e-09     |     2.291e-07     |     9.417e-08     |
# | 295/500  |     1.125e-07     |     2.286e-10     |      2.41e-10     |     1.842e-07     |     7.428e-08     |
# | 300/500  |     1.104e-07     |     6.899e-10     |     8.499e-10     |     1.660e-07     |     6.949e-08     |
# | 305/500  |     1.001e-07     |     4.687e-10     |     6.496e-10     |     1.563e-07     |     6.438e-08     |
# | 310/500  |     1.049e-07     |     1.199e-10     |     1.687e-09     |     1.628e-07     |     6.738e-08     |
# | 315/500  |     9.998e-08     |     2.107e-10     |     1.168e-09     |     1.547e-07     |     6.401e-08     |
# | 320/500  |     1.003e-07     |     2.271e-09     |     1.498e-09     |     1.169e-07     |     5.524e-08     |
# | 325/500  |     8.947e-08     |     4.435e-10     |     2.563e-10     |      1.3e-07      |     5.503e-08     |
# | 330/500  |     8.227e-08     |     8.162e-10     |     1.582e-09     |     1.561e-07     |     6.019e-08     |
# | 335/500  |     7.276e-08     |     1.401e-09     |     1.031e-09     |     1.091e-07     |     4.606e-08     |
# | 340/500  |     7.583e-08     |     1.457e-09     |      1.43e-09     |     1.273e-07     |     5.151e-08     |
# | 345/500  |     7.942e-08     |     9.996e-10     |     1.291e-10     |     1.148e-07     |     4.884e-08     |
# | 350/500  |     8.328e-08     |     1.096e-09     |     8.642e-10     |     1.066e-07     |     4.795e-08     |
# | 355/500  |     6.593e-08     |     2.975e-09     |     1.147e-09     |     7.457e-08     |     3.615e-08     |
# | 360/500  |     6.911e-08     |     1.056e-09     |     5.583e-10     |     7.845e-08     |     3.729e-08     |
# | 365/500  |     7.655e-08     |     2.596e-10     |     8.098e-10     |     8.955e-08     |     4.179e-08     |
# | 370/500  |     7.411e-08     |     1.134e-09     |     4.968e-10     |     1.146e-07     |     4.758e-08     |
# | 375/500  |     7.235e-08     |     9.717e-10     |     3.376e-10     |     1.248e-07     |     4.962e-08     |
# | 380/500  |     6.828e-08     |     8.446e-10     |     7.711e-10     |     8.989e-08     |     3.995e-08     |
# | 382/500  |     6.584e-08     |     3.624e-11     |     2.969e-10     |     8.120e-08     |     3.684e-08     |Stopping the training at epoch 382 due to early stopping.
# ============================ nnodely Training Time =============================
# Total time of Training:       1401.3906073570251
# ================================================================================
# The selected model is the LAST model of the training.
# =============================== Save JSON Model ================================
# Model saved in:               /home/baro/Desktop/inv_pend/saved_models/nn_physical_model.json
# ================================================================================
# ========================== Export Python Torch Model ===========================
# Model exported in:            /home/baro/Desktop/inv_pend/saved_models/nn_physical_model.py
# ================================================================================
# ======================== Export Training Results Report ========================
# Report exported in:           /home/baro/Desktop/inv_pend/saved_models/nn_physical_model_report.pdf
# ================================================================================

# %%
# Closed-loop plot
data_struct = ['time', 'action', 'Xpos', 'Xangle', 'Xvelocity', 'Xangular_velocity', 'Ypos', 'Yangle', 'Yvelocity', 'Yangular_velocity', 'noise1', 'noise2', 'noise3', 'noise4']
inverted_pendulum.importPythonModel(name=model_name)
inverted_pendulum.neuralizeModel(sample_time = 0.02)
data_folder = os.path.join(os.path.abspath(''),'data')
inverted_pendulum.loadData(name='data_test', source=data_folder, format=data_struct, delimiter=',', header=0)
samples = inverted_pendulum.getSamples(dataset='data_test', window=150, index=0)

result = inverted_pendulum(samples, sampled=True, prediction_samples=150)

# Plotting
t = np.arange(len(result['est_theta'])) * 0.02
plt.figure(figsize=(14, 9))
plt.subplot(5, 1, 2)
plt.plot(t, result['est_theta'], label=r'Estimated $\theta$')
plt.plot(t, np.array(samples['Yangle']).squeeze(), '--', label=r'True $\theta$')
plt.title('Theta estimation')
plt.xlabel('Time [s]')
plt.ylabel(r'$\theta$ [rad]')
plt.grid()
plt.legend()
plt.subplot(5, 1, 1)
plt.plot(t, result['est_thetadot'], label=r'Estimated $\dot{\theta}$')
plt.plot(t, np.array(samples['Yangular_velocity']).squeeze(), '--', label=r'True $\dot{\theta}$')
plt.title('Angular velocity estimation')
plt.xlabel('Time [s]')
plt.ylabel(r'$\dot{\theta}$ [rad/s]')
plt.grid()
plt.legend()
plt.subplot(5, 1, 4)
plt.plot(t, result['est_x'], label='Estimated X')
plt.plot(t, np.array(samples['Ypos']).squeeze(), '--', label='True x')
plt.title('Position estimation')
plt.xlabel('Time [s]')
plt.ylabel('x [m]')
plt.grid()
plt.legend()
plt.subplot(5, 1, 3)
plt.plot(t, result['est_xdot'], label=r'Estimated $\dot{x}$')
plt.plot(t, np.array(samples['Yvelocity']).squeeze(), '--', label=r'True $\dot{x}$')
plt.title('Velocity estimation')
plt.xlabel('Time [s]')
plt.ylabel(r'$\dot{x}$ [m/s]')
plt.grid()
plt.legend()
plt.subplot(5, 1, 5)
plt.plot(t, np.array(samples['action']).squeeze(), label='F')
plt.title('Applied force')
plt.xlabel('Time [s]')
plt.ylabel('Force [N]')
plt.grid()
plt.legend()
plt.tight_layout()

img_name = model_name + '_closed_loop.png'
save_path = os.path.join(os.getcwd(), "results", "imgs", img_name)
#plt.savefig(save_path, dpi=300)
plt.show()
# Out:
# =============================== Load JSON Model ================================
# Model loaded from:            /home/baro/Desktop/inv_pend/saved_models/nn_physical_model.json
# ================================================================================
# [neuralizeModel] Closed loop on Xangle with sample in the future.
# [neuralizeModel] Closed loop on Xangular_velocity with sample in the future.
# [neuralizeModel] Closed loop on Xpos with sample in the future.
# [neuralizeModel] Closed loop on Xvelocity with sample in the future.
# ================================ nnodely Model =================================
# {'Constants': {'Constant43': {'dim': 1, 'values': [2.0]},
#                'Constant44': {'dim': 1, 'values': [2.0]},
#                'Constant45': {'dim': 1, 'values': [2.0]},
#                'Constant46': {'dim': 1, 'values': [2.0]},
#                'Constant47': {'dim': 1, 'values': [2.0]},
#                'Constant48': {'dim': 1, 'values': [2.0]},
#                'Constant49': {'dim': 1, 'values': [2.0]},
#                'Constant50': {'dim': 1, 'values': [2.0]},
#                'Constant52': {'dim': 1, 'values': [2.0]},
#                'Constant53': {'dim': 1, 'values': [2.0]},
#                'Constant54': {'dim': 1, 'values': [2.0]},
#                'Constant55': {'dim': 1, 'values': [2.0]},
#                'Constant56': {'dim': 1, 'values': [2.0]},
#                'Constant57': {'dim': 1, 'values': [2.0]},
#                'Constant58': {'dim': 1, 'values': [2.0]},
#                'Constant59': {'dim': 1, 'values': [2.0]},
#                'Constant60': {'dim': 1, 'values': [2.0]},
#                'Constant61': {'dim': 1, 'values': [2.0]},
#                'Constant62': {'dim': 1, 'values': [2.0]},
#                'Constant64': {'dim': 1, 'values': [2.0]},
#                'Constant65': {'dim': 1, 'values': [2.0]},
#                'Constant66': {'dim': 1, 'values': [2.0]},
#                'Constant67': {'dim': 1, 'values': [2.0]},
#                'Constant68': {'dim': 1, 'values': [2.0]},
#                'Constant69': {'dim': 1, 'values': [2.0]},
#                'Constant70': {'dim': 1, 'values': [2.0]},
#                'Constant71': {'dim': 1, 'values': [2.0]},
#                'Constant72': {'dim': 1, 'values': [2.0]},
#                'Constant73': {'dim': 1, 'values': [2.0]},
#                'Constant74': {'dim': 1, 'values': [2.0]},
#                'Constant75': {'dim': 1, 'values': [2.0]},
#                'Constant76': {'dim': 1, 'values': [2.0]},
#                'Constant77': {'dim': 1, 'values': [2.0]},
#                'Constant78': {'dim': 1, 'values': [2.0]},
#                'Constant79': {'dim': 1, 'values': [2.0]},
#                'Constant80': {'dim': 1, 'values': [2.0]},
#                'Constant81': {'dim': 1, 'values': [2.0]},
#                'Constant82': {'dim': 1, 'values': [2.0]},
#                'Constant83': {'dim': 1, 'values': [2.0]},
#                'Constant84': {'dim': 1, 'values': [2.0]},
#                'Constant85': {'dim': 1, 'values': [6.0]},
#                'Constant86': {'dim': 1, 'values': [2.0]},
#                'Constant87': {'dim': 1, 'values': [2.0]},
#                'Constant88': {'dim': 1, 'values': [6.0]},
#                'Constant89': {'dim': 1, 'values': [2.0]},
#                'Constant90': {'dim': 1, 'values': [2.0]},
#                'Constant91': {'dim': 1, 'values': [6.0]},
#                'Constant92': {'dim': 1, 'values': [2.0]},
#                'Constant93': {'dim': 1, 'values': [2.0]},
#                'Constant94': {'dim': 1, 'values': [6.0]},
#                'dt': {'dim': 1, 'values': [0.019999999552965164]},
#                'g': {'dim': 1, 'values': [9.8100004196167]},
#                'gear': {'dim': 1, 'values': [100.0]},
#                'sigma_omega': {'dim': 1, 'values': [0.0]},
#                'sigma_theta': {'dim': 1, 'values': [0.0]},
#                'sigma_v': {'dim': 1, 'values': [0.0]},
#                'sigma_x': {'dim': 1, 'values': [0.0]}},
#  'Functions': {},
#  'Info': {'SampleTime': 0.02,
#           'nnodely_version': '1.5.2',
#           'ns': [1, 0],
#           'ntot': 1,
#           'num_parameters': 206},
#  'Inputs': {'Xangle': {'closedLoop': 'Add574',
#                        'dim': 1,
#                        'local': 1,
#                        'ns': [1, 0],
#                        'ntot': 1,
#                        'sw': [-1, 0]},
#             'Xangular_velocity': {'closedLoop': 'Add560',
#                                   'dim': 1,
#                                   'local': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Xpos': {'closedLoop': 'Add546',
#                      'dim': 1,
#                      'local': 1,
#                      'ns': [1, 0],
#                      'ntot': 1,
#                      'sw': [-1, 0]},
#             'Xvelocity': {'closedLoop': 'Add532',
#                           'dim': 1,
#                           'local': 1,
#                           'ns': [1, 0],
#                           'ntot': 1,
#                           'sw': [-1, 0]},
#             'Yangle': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yangular_velocity': {'dim': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Ypos': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yvelocity': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'action': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise1': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise2': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise3': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise4': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]}},
#  'Minimizers': {'ang_vel_error': {'A': 'SamplePart580',
#                                   'B': 'Add560',
#                                   'loss': 'mse'},
#                 'angle_error': {'A': 'SamplePart582',
#                                 'B': 'Add574',
#                                 'loss': 'mse'},
#                 'pos_error': {'A': 'SamplePart586',
#                               'B': 'Add546',
#                               'loss': 'mse'},
#                 'vel_error': {'A': 'SamplePart584',
#                               'B': 'Add532',
#                               'loss': 'mse'}},
#  'Models': 'pendulum',
#  'Outputs': {'contr_theta': 'Select575',
#              'contr_thetadot': 'Select576',
#              'contr_x': 'Select578',
#              'contr_xdot': 'Select577',
#              'est_theta': 'Add574',
#              'est_thetadot': 'Add560',
#              'est_x': 'Add546',
#              'est_xdot': 'Add532'},
#  'Parameters': {'I': {'dim': 1, 'values': [0.39864471554756165]},
#                 'PLinear27W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[-0.0001880190393421799,
#                                            0.005893010180443525,
#                                            0.06466307491064072,
#                                            0.008933239616453648,
#                                            -0.009084898978471756,
#                                            0.017183907330036163,
#                                            -0.019742656499147415,
#                                            1.083087113329384e-06,
#                                            0.011865868233144283,
#                                            0.3578527569770813]]},
#                 'PLinear29W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[-0.0003215222095604986,
#                                            -0.0159317534416914,
#                                            0.0040748706087470055,
#                                            0.0024561698082834482,
#                                            0.0008748300024308264,
#                                            0.005368994083255529,
#                                            0.0011685825884342194,
#                                            4.917534897685982e-05,
#                                            -0.0023861457593739033,
#                                            0.004730813670903444]]},
#                 'PLinear31W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[-0.004730580374598503,
#                                            0.0158639308065176,
#                                            -0.24506770074367523,
#                                            -0.6142343282699585,
#                                            -0.41605210304260254,
#                                            0.3105451464653015,
#                                            -0.5566937327384949,
#                                            0.0005361298681236804,
#                                            0.7950761318206787,
#                                            -0.028897438198328018]]},
#                 'PLinear33W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[-0.022707810625433922,
#                                            -0.024240678176283836,
#                                            -6.05483292019926e-05,
#                                            0.0039931898936629295,
#                                            0.011852693744003773,
#                                            -0.024018894881010056,
#                                            0.017550267279148102,
#                                            0.0002702289493754506,
#                                            0.027396487072110176,
#                                            -0.0028888338711112738]]},
#                 'PLinear35W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[-0.0007065734243951738,
#                                            -0.004066101275384426,
#                                            -0.07811392843723297,
#                                            0.11103671789169312,
#                                            0.011188536882400513,
#                                            -0.03196336701512337,
#                                            -0.09168338775634766,
#                                            -4.609256939147599e-05,
#                                            -0.025937706232070923,
#                                            -0.10917679965496063]]},
#                 'PLinear37W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[0.02063254453241825,
#                                            0.0494617260992527,
#                                            0.04872281104326248,
#                                            -0.012855189852416515,
#                                            -0.10390949249267578,
#                                            -0.10877903550863266,
#                                            0.03513195738196373,
#                                            0.00023904282716102898,
#                                            0.009891501627862453,
#                                            0.034692347049713135]]},
#                 'PLinear39W': {'dim': [10, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[-0.014171193353831768,
#                                            0.15714071691036224,
#                                            0.1192670539021492,
#                                            0.22510765492916107,
#                                            -0.03281927481293678,
#                                            0.05098520964384079,
#                                            -0.19426411390304565,
#                                            -0.045756496489048004,
#                                            -0.04010786861181259,
#                                            -0.16718825697898865],
#                                           [-0.012721898965537548,
#                                            -0.047862086445093155,
#                                            0.10460641980171204,
#                                            0.07384853065013885,
#                                            0.11315490305423737,
#                                            0.09630806744098663,
#                                            -0.13797935843467712,
#                                            0.13106301426887512,
#                                            -0.08511984348297119,
#                                            -0.12640643119812012],
#                                           [0.09282247722148895,
#                                            0.15721435844898224,
#                                            -0.15941648185253143,
#                                            0.04045811668038368,
#                                            0.17485108971595764,
#                                            0.19064748287200928,
#                                            -0.3914415240287781,
#                                            -0.18088196218013763,
#                                            -0.20432069897651672,
#                                            -0.39218342304229736],
#                                           [0.020315401256084442,
#                                            0.17174473404884338,
#                                            -0.0941096842288971,
#                                            0.13578255474567413,
#                                            0.0036467043682932854,
#                                            0.03338479623198509,
#                                            -0.17292973399162292,
#                                            -0.002710219006985426,
#                                            -0.036179885268211365,
#                                            -0.168988436460495],
#                                           [-0.002569112228229642,
#                                            -0.0162314735352993,
#                                            -0.04215381294488907,
#                                            -0.08848243951797485,
#                                            -0.06981850415468216,
#                                            0.139090895652771,
#                                            -0.22295518219470978,
#                                            -0.25321006774902344,
#                                            -0.12679491937160492,
#                                            -0.22471360862255096],
#                                           [0.013126885518431664,
#                                            -0.23434196412563324,
#                                            -0.06248229742050171,
#                                            -0.31178855895996094,
#                                            0.18223148584365845,
#                                            -0.03691273182630539,
#                                            -0.03208531066775322,
#                                            0.07352177798748016,
#                                            0.03043670579791069,
#                                            0.007704177405685186],
#                                           [-0.04763412103056908,
#                                            0.0794190764427185,
#                                            0.002835692372173071,
#                                            0.2109101116657257,
#                                            -0.11395229399204254,
#                                            -0.10175381600856781,
#                                            0.025590883567929268,
#                                            0.14064401388168335,
#                                            0.10899025946855545,
#                                            0.03457411751151085],
#                                           [0.002361225662752986,
#                                            -0.005406251177191734,
#                                            0.04142311215400696,
#                                            0.00313198403455317,
#                                            0.0010670534102246165,
#                                            0.0003897600690834224,
#                                            0.01573532447218895,
#                                            0.02508380077779293,
#                                            -0.00209144689142704,
#                                            0.019812580198049545],
#                                           [0.006501292809844017,
#                                            -0.05561191588640213,
#                                            -0.2117011398077011,
#                                            -0.3178425431251526,
#                                            0.44138410687446594,
#                                            0.10796058923006058,
#                                            -0.5007132291793823,
#                                            -0.13645219802856445,
#                                            -0.10036168992519379,
#                                            -0.4539477229118347],
#                                           [-0.027732979506254196,
#                                            -0.04559260234236717,
#                                            0.07316332310438156,
#                                            0.07365732640028,
#                                            -0.11794889718294144,
#                                            -0.05489973723888397,
#                                            0.18127629160881042,
#                                            -0.07468268275260925,
#                                            0.05915010720491409,
#                                            0.1412903517484665]]},
#                 'PLinear41W': {'dim': [10, 4],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[0.0008763351361267269,
#                                            -0.00024157062580343336,
#                                            -0.00028882664628326893,
#                                            -0.0007237002719193697],
#                                           [-0.30842161178588867,
#                                            -0.0030950887594372034,
#                                            0.11811084300279617,
#                                            0.0013123834505677223],
#                                           [0.15039990842342377,
#                                            0.0014968308387324214,
#                                            0.03533568233251572,
#                                            0.0007502621156163514],
#                                           [-0.26984065771102905,
#                                            -0.0026179030537605286,
#                                            -0.05602499470114708,
#                                            -0.0010904406663030386],
#                                           [-0.5811452865600586,
#                                            -0.005795136094093323,
#                                            0.18178735673427582,
#                                            0.0014936721418052912],
#                                           [0.0006841715076006949,
#                                            0.0001788078952813521,
#                                            -0.0019367801724001765,
#                                            -0.0007646018057130277],
#                                           [-0.2240845263004303,
#                                            -0.0025831980165094137,
#                                            0.030911885201931,
#                                            0.0027259401977062225],
#                                           [0.004272507969290018,
#                                            -6.568706885445863e-05,
#                                            -0.065296471118927,
#                                            -0.00010297287371940911],
#                                           [-0.0007754236576147377,
#                                            -0.0004502884694375098,
#                                            0.002104794839397073,
#                                            -4.8566282202955335e-05],
#                                           [-0.15299534797668457,
#                                            -0.0011870090384036303,
#                                            0.014870685525238514,
#                                            -0.002811344340443611]]},
#                 'b': {'dim': 1, 'values': [0.9730616211891174]},
#                 'd': {'dim': 1, 'values': [1.1174551248550415]},
#                 'l': {'dim': 1, 'values': [0.21911874413490295]},
#                 'm1': {'dim': 1, 'values': [6.780579090118408]},
#                 'm2': {'dim': 1, 'values': [6.922131061553955]}},
#  'Relations': {'Add104': ['Add', ['Sub93', 'Mul103']],
#                'Add112': ['Add', ['Add104', 'Mul111']],
#                'Add13': ['Add', ['SamplePart8', 'Mul12']],
#                'Add148': ['Add', ['Sub140', 'Mul147']],
#                'Add150': ['Add', ['Add148', 'Mul149']],
#                'Add161': ['Add', ['Add13', 'Div160']],
#                'Add166': ['Add', ['Add27', 'Div165']],
#                'Add171': ['Add', ['Add20', 'Div170']],
#                'Add182': ['Add', ['I', 'Mul180']],
#                'Add185': ['Add', ['m1', 'm2']],
#                'Add20': ['Add', ['SamplePart15', 'Mul19']],
#                'Add201': ['Add', ['m1', 'm2']],
#                'Add221': ['Add', ['m1', 'm2']],
#                'Add229': ['Add', ['Sub218', 'Mul228']],
#                'Add237': ['Add', ['Add229', 'Mul236']],
#                'Add27': ['Add', ['SamplePart22', 'Mul26']],
#                'Add273': ['Add', ['Sub265', 'Mul272']],
#                'Add275': ['Add', ['Add273', 'Mul274']],
#                'Add286': ['Add', ['Add13', 'Div285']],
#                'Add291': ['Add', ['Add27', 'Div290']],
#                'Add296': ['Add', ['Add20', 'Div295']],
#                'Add307': ['Add', ['I', 'Mul305']],
#                'Add310': ['Add', ['m1', 'm2']],
#                'Add326': ['Add', ['m1', 'm2']],
#                'Add346': ['Add', ['m1', 'm2']],
#                'Add354': ['Add', ['Sub343', 'Mul353']],
#                'Add362': ['Add', ['Add354', 'Mul361']],
#                'Add38': ['Add', ['Linear28', 'Linear29']],
#                'Add39': ['Add', ['Add38', 'Linear31']],
#                'Add398': ['Add', ['Sub390', 'Mul397']],
#                'Add40': ['Add', ['Add39', 'Linear33']],
#                'Add400': ['Add', ['Add398', 'Mul399']],
#                'Add407': ['Add', ['Add13', 'Mul406']],
#                'Add41': ['Add', ['Add40', 'Linear34']],
#                'Add410': ['Add', ['Add27', 'Mul409']],
#                'Add413': ['Add', ['Add20', 'Mul412']],
#                'Add42': ['Add', ['Add41', 'Linear37']],
#                'Add424': ['Add', ['I', 'Mul422']],
#                'Add427': ['Add', ['m1', 'm2']],
#                'Add443': ['Add', ['m1', 'm2']],
#                'Add463': ['Add', ['m1', 'm2']],
#                'Add471': ['Add', ['Sub460', 'Mul470']],
#                'Add479': ['Add', ['Add471', 'Mul478']],
#                'Add515': ['Add', ['Sub507', 'Mul514']],
#                'Add517': ['Add', ['Add515', 'Mul516']],
#                'Add521': ['Add', ['Div151', 'Mul520']],
#                'Add524': ['Add', ['Add521', 'Mul523']],
#                'Add525': ['Add', ['Add524', 'Div518']],
#                'Add530': ['Add', ['Add13', 'Div529']],
#                'Add532': ['Add', ['Add530', 'Select531']],
#                'Add535': ['Add', ['Add13', 'Mul534']],
#                'Add538': ['Add', ['Add535', 'Mul537']],
#                'Add539': ['Add', ['Add538', 'Add407']],
#                'Add544': ['Add', ['Add6', 'Div543']],
#                'Add546': ['Add', ['Add544', 'Select545']],
#                'Add549': ['Add', ['Div119', 'Mul548']],
#                'Add552': ['Add', ['Add549', 'Mul551']],
#                'Add553': ['Add', ['Add552', 'Div486']],
#                'Add558': ['Add', ['Add20', 'Div557']],
#                'Add560': ['Add', ['Add558', 'Select559']],
#                'Add563': ['Add', ['Add20', 'Mul562']],
#                'Add566': ['Add', ['Add563', 'Mul565']],
#                'Add567': ['Add', ['Add566', 'Add413']],
#                'Add57': ['Add', ['I', 'Mul55']],
#                'Add572': ['Add', ['Add27', 'Div571']],
#                'Add574': ['Add', ['Add572', 'Select573']],
#                'Add6': ['Add', ['SamplePart1', 'Mul5']],
#                'Add60': ['Add', ['m1', 'm2']],
#                'Add76': ['Add', ['m1', 'm2']],
#                'Add96': ['Add', ['m1', 'm2']],
#                'Cos175': ['Cos', ['Add166']],
#                'Cos300': ['Cos', ['Add291']],
#                'Cos32': ['Cos', ['Add27']],
#                'Cos417': ['Cos', ['Add410']],
#                'Cos50': ['Cos', ['Add27']],
#                'Div119': ['Div', ['Sub118', 'Sub68']],
#                'Div151': ['Div', ['Add150', 'Sub68']],
#                'Div160': ['Div', ['Mul158', 'Constant52']],
#                'Div165': ['Div', ['Mul163', 'Constant53']],
#                'Div170': ['Div', ['Mul168', 'Constant54']],
#                'Div244': ['Div', ['Sub243', 'Sub193']],
#                'Div276': ['Div', ['Add275', 'Sub193']],
#                'Div285': ['Div', ['Mul283', 'Constant64']],
#                'Div290': ['Div', ['Mul288', 'Constant65']],
#                'Div295': ['Div', ['Mul293', 'Constant66']],
#                'Div369': ['Div', ['Sub368', 'Sub318']],
#                'Div401': ['Div', ['Add400', 'Sub318']],
#                'Div486': ['Div', ['Sub485', 'Sub435']],
#                'Div518': ['Div', ['Add517', 'Sub435']],
#                'Div529': ['Div', ['Mul527', 'Constant85']],
#                'Div543': ['Div', ['Mul541', 'Constant88']],
#                'Div557': ['Div', ['Mul555', 'Constant91']],
#                'Div571': ['Div', ['Mul569', 'Constant94']],
#                'Linear28': ['Linear', ['Add27'], 'PLinear27W', None, 0.0],
#                'Linear29': ['Linear', ['Add13'], 'PLinear29W', None, 0.0],
#                'Linear31': ['Linear', ['Sin30'], 'PLinear31W', None, 0.0],
#                'Linear33': ['Linear', ['Cos32'], 'PLinear33W', None, 0.0],
#                'Linear34': ['Linear', ['Add20'], 'PLinear35W', None, 0.0],
#                'Linear37': ['Linear',
#                             ['SamplePart36'],
#                             'PLinear37W',
#                             None,
#                             0.0],
#                'Linear44': ['Linear', ['Tanh43'], 'PLinear39W', None, 0.0],
#                'Linear46': ['Linear', ['Tanh45'], 'PLinear41W', None, 0],
#                'Mul100': ['Mul', ['Mul98', 'g']],
#                'Mul102': ['Mul', ['Mul100', 'l']],
#                'Mul103': ['Mul', ['Mul102', 'Sin49']],
#                'Mul107': ['Mul', ['m2', 'l']],
#                'Mul109': ['Mul', ['Mul107', 'b']],
#                'Mul110': ['Mul', ['Mul109', 'Add13']],
#                'Mul111': ['Mul', ['Mul110', 'Cos50']],
#                'Mul115': ['Mul', ['m2', 'l']],
#                'Mul116': ['Mul', ['Mul115', 'Cos50']],
#                'Mul117': ['Mul', ['Mul116', 'Mul70']],
#                'Mul12': ['Mul', ['SamplePart10', 'sigma_v']],
#                'Mul121': ['Mul', ['Add57', 'm2']],
#                'Mul123': ['Mul', ['Mul121', 'l']],
#                'Mul126': ['Mul', ['Mul123', 'Pow125']],
#                'Mul127': ['Mul', ['Mul126', 'Sin49']],
#                'Mul135': ['Mul', ['Pow131', 'Pow134']],
#                'Mul137': ['Mul', ['Mul135', 'g']],
#                'Mul138': ['Mul', ['Mul137', 'Sin49']],
#                'Mul139': ['Mul', ['Mul138', 'Cos50']],
#                'Mul143': ['Mul', ['m2', 'l']],
#                'Mul145': ['Mul', ['Mul143', 'd']],
#                'Mul146': ['Mul', ['Mul145', 'Add20']],
#                'Mul147': ['Mul', ['Mul146', 'Cos50']],
#                'Mul149': ['Mul', ['Mul70', 'Add57']],
#                'Mul158': ['Mul', ['Div151', 'dt']],
#                'Mul163': ['Mul', ['Add20', 'dt']],
#                'Mul168': ['Mul', ['Div119', 'dt']],
#                'Mul180': ['Mul', ['m2', 'Pow178']],
#                'Mul186': ['Mul', ['Add185', 'Add182']],
#                'Mul189': ['Mul', ['m2', 'l']],
#                'Mul19': ['Mul', ['SamplePart17', 'sigma_omega']],
#                'Mul190': ['Mul', ['Mul189', 'Cos175']],
#                'Mul195': ['Mul', ['gear', 'SamplePart173']],
#                'Mul197': ['Mul', ['Add182', 'b']],
#                'Mul198': ['Mul', ['Mul197', 'Add161']],
#                'Mul203': ['Mul', ['Add201', 'd']],
#                'Mul204': ['Mul', ['Mul203', 'Add171']],
#                'Mul212': ['Mul', ['Neg208', 'Pow211']],
#                'Mul215': ['Mul', ['Mul212', 'Pow214']],
#                'Mul216': ['Mul', ['Mul215', 'Sin174']],
#                'Mul217': ['Mul', ['Mul216', 'Cos175']],
#                'Mul223': ['Mul', ['Add221', 'm2']],
#                'Mul225': ['Mul', ['Mul223', 'g']],
#                'Mul227': ['Mul', ['Mul225', 'l']],
#                'Mul228': ['Mul', ['Mul227', 'Sin174']],
#                'Mul232': ['Mul', ['m2', 'l']],
#                'Mul234': ['Mul', ['Mul232', 'b']],
#                'Mul235': ['Mul', ['Mul234', 'Add161']],
#                'Mul236': ['Mul', ['Mul235', 'Cos175']],
#                'Mul240': ['Mul', ['m2', 'l']],
#                'Mul241': ['Mul', ['Mul240', 'Cos175']],
#                'Mul242': ['Mul', ['Mul241', 'Mul195']],
#                'Mul246': ['Mul', ['Add182', 'm2']],
#                'Mul248': ['Mul', ['Mul246', 'l']],
#                'Mul251': ['Mul', ['Mul248', 'Pow250']],
#                'Mul252': ['Mul', ['Mul251', 'Sin174']],
#                'Mul26': ['Mul', ['SamplePart24', 'sigma_theta']],
#                'Mul260': ['Mul', ['Pow256', 'Pow259']],
#                'Mul262': ['Mul', ['Mul260', 'g']],
#                'Mul263': ['Mul', ['Mul262', 'Sin174']],
#                'Mul264': ['Mul', ['Mul263', 'Cos175']],
#                'Mul268': ['Mul', ['m2', 'l']],
#                'Mul270': ['Mul', ['Mul268', 'd']],
#                'Mul271': ['Mul', ['Mul270', 'Add171']],
#                'Mul272': ['Mul', ['Mul271', 'Cos175']],
#                'Mul274': ['Mul', ['Mul195', 'Add182']],
#                'Mul283': ['Mul', ['Div276', 'dt']],
#                'Mul288': ['Mul', ['Add171', 'dt']],
#                'Mul293': ['Mul', ['Div244', 'dt']],
#                'Mul305': ['Mul', ['m2', 'Pow303']],
#                'Mul311': ['Mul', ['Add310', 'Add307']],
#                'Mul314': ['Mul', ['m2', 'l']],
#                'Mul315': ['Mul', ['Mul314', 'Cos300']],
#                'Mul320': ['Mul', ['gear', 'SamplePart298']],
#                'Mul322': ['Mul', ['Add307', 'b']],
#                'Mul323': ['Mul', ['Mul322', 'Add286']],
#                'Mul328': ['Mul', ['Add326', 'd']],
#                'Mul329': ['Mul', ['Mul328', 'Add296']],
#                'Mul337': ['Mul', ['Neg333', 'Pow336']],
#                'Mul340': ['Mul', ['Mul337', 'Pow339']],
#                'Mul341': ['Mul', ['Mul340', 'Sin299']],
#                'Mul342': ['Mul', ['Mul341', 'Cos300']],
#                'Mul348': ['Mul', ['Add346', 'm2']],
#                'Mul350': ['Mul', ['Mul348', 'g']],
#                'Mul352': ['Mul', ['Mul350', 'l']],
#                'Mul353': ['Mul', ['Mul352', 'Sin299']],
#                'Mul357': ['Mul', ['m2', 'l']],
#                'Mul359': ['Mul', ['Mul357', 'b']],
#                'Mul360': ['Mul', ['Mul359', 'Add286']],
#                'Mul361': ['Mul', ['Mul360', 'Cos300']],
#                'Mul365': ['Mul', ['m2', 'l']],
#                'Mul366': ['Mul', ['Mul365', 'Cos300']],
#                'Mul367': ['Mul', ['Mul366', 'Mul320']],
#                'Mul371': ['Mul', ['Add307', 'm2']],
#                'Mul373': ['Mul', ['Mul371', 'l']],
#                'Mul376': ['Mul', ['Mul373', 'Pow375']],
#                'Mul377': ['Mul', ['Mul376', 'Sin299']],
#                'Mul385': ['Mul', ['Pow381', 'Pow384']],
#                'Mul387': ['Mul', ['Mul385', 'g']],
#                'Mul388': ['Mul', ['Mul387', 'Sin299']],
#                'Mul389': ['Mul', ['Mul388', 'Cos300']],
#                'Mul393': ['Mul', ['m2', 'l']],
#                'Mul395': ['Mul', ['Mul393', 'd']],
#                'Mul396': ['Mul', ['Mul395', 'Add296']],
#                'Mul397': ['Mul', ['Mul396', 'Cos300']],
#                'Mul399': ['Mul', ['Mul320', 'Add307']],
#                'Mul406': ['Mul', ['Div401', 'dt']],
#                'Mul409': ['Mul', ['Add296', 'dt']],
#                'Mul412': ['Mul', ['Div369', 'dt']],
#                'Mul422': ['Mul', ['m2', 'Pow420']],
#                'Mul428': ['Mul', ['Add427', 'Add424']],
#                'Mul431': ['Mul', ['m2', 'l']],
#                'Mul432': ['Mul', ['Mul431', 'Cos417']],
#                'Mul437': ['Mul', ['gear', 'SamplePart415']],
#                'Mul439': ['Mul', ['Add424', 'b']],
#                'Mul440': ['Mul', ['Mul439', 'Add407']],
#                'Mul445': ['Mul', ['Add443', 'd']],
#                'Mul446': ['Mul', ['Mul445', 'Add413']],
#                'Mul454': ['Mul', ['Neg450', 'Pow453']],
#                'Mul457': ['Mul', ['Mul454', 'Pow456']],
#                'Mul458': ['Mul', ['Mul457', 'Sin416']],
#                'Mul459': ['Mul', ['Mul458', 'Cos417']],
#                'Mul465': ['Mul', ['Add463', 'm2']],
#                'Mul467': ['Mul', ['Mul465', 'g']],
#                'Mul469': ['Mul', ['Mul467', 'l']],
#                'Mul470': ['Mul', ['Mul469', 'Sin416']],
#                'Mul474': ['Mul', ['m2', 'l']],
#                'Mul476': ['Mul', ['Mul474', 'b']],
#                'Mul477': ['Mul', ['Mul476', 'Add407']],
#                'Mul478': ['Mul', ['Mul477', 'Cos417']],
#                'Mul482': ['Mul', ['m2', 'l']],
#                'Mul483': ['Mul', ['Mul482', 'Cos417']],
#                'Mul484': ['Mul', ['Mul483', 'Mul437']],
#                'Mul488': ['Mul', ['Add424', 'm2']],
#                'Mul490': ['Mul', ['Mul488', 'l']],
#                'Mul493': ['Mul', ['Mul490', 'Pow492']],
#                'Mul494': ['Mul', ['Mul493', 'Sin416']],
#                'Mul5': ['Mul', ['SamplePart3', 'sigma_x']],
#                'Mul502': ['Mul', ['Pow498', 'Pow501']],
#                'Mul504': ['Mul', ['Mul502', 'g']],
#                'Mul505': ['Mul', ['Mul504', 'Sin416']],
#                'Mul506': ['Mul', ['Mul505', 'Cos417']],
#                'Mul510': ['Mul', ['m2', 'l']],
#                'Mul512': ['Mul', ['Mul510', 'd']],
#                'Mul513': ['Mul', ['Mul512', 'Add413']],
#                'Mul514': ['Mul', ['Mul513', 'Cos417']],
#                'Mul516': ['Mul', ['Mul437', 'Add424']],
#                'Mul520': ['Mul', ['Constant83', 'Div276']],
#                'Mul523': ['Mul', ['Constant84', 'Div401']],
#                'Mul527': ['Mul', ['Add525', 'dt']],
#                'Mul534': ['Mul', ['Constant86', 'Add161']],
#                'Mul537': ['Mul', ['Constant87', 'Add286']],
#                'Mul541': ['Mul', ['Add539', 'dt']],
#                'Mul548': ['Mul', ['Constant89', 'Div244']],
#                'Mul55': ['Mul', ['m2', 'Pow53']],
#                'Mul551': ['Mul', ['Constant90', 'Div369']],
#                'Mul555': ['Mul', ['Add553', 'dt']],
#                'Mul562': ['Mul', ['Constant92', 'Add171']],
#                'Mul565': ['Mul', ['Constant93', 'Add296']],
#                'Mul569': ['Mul', ['Add567', 'dt']],
#                'Mul61': ['Mul', ['Add60', 'Add57']],
#                'Mul64': ['Mul', ['m2', 'l']],
#                'Mul65': ['Mul', ['Mul64', 'Cos50']],
#                'Mul70': ['Mul', ['gear', 'SamplePart48']],
#                'Mul72': ['Mul', ['Add57', 'b']],
#                'Mul73': ['Mul', ['Mul72', 'Add13']],
#                'Mul78': ['Mul', ['Add76', 'd']],
#                'Mul79': ['Mul', ['Mul78', 'Add20']],
#                'Mul87': ['Mul', ['Neg83', 'Pow86']],
#                'Mul90': ['Mul', ['Mul87', 'Pow89']],
#                'Mul91': ['Mul', ['Mul90', 'Sin49']],
#                'Mul92': ['Mul', ['Mul91', 'Cos50']],
#                'Mul98': ['Mul', ['Add96', 'm2']],
#                'Neg208': ['Neg', ['Pow207']],
#                'Neg333': ['Neg', ['Pow332']],
#                'Neg450': ['Neg', ['Pow449']],
#                'Neg83': ['Neg', ['Pow82']],
#                'Pow125': ['Pow', ['Add20', 'Constant48']],
#                'Pow131': ['Pow', ['m2', 'Constant49']],
#                'Pow134': ['Pow', ['l', 'Constant50']],
#                'Pow178': ['Pow', ['l', 'Constant55']],
#                'Pow192': ['Pow', ['Mul190', 'Constant56']],
#                'Pow207': ['Pow', ['m2', 'Constant57']],
#                'Pow211': ['Pow', ['l', 'Constant58']],
#                'Pow214': ['Pow', ['Add171', 'Constant59']],
#                'Pow250': ['Pow', ['Add171', 'Constant60']],
#                'Pow256': ['Pow', ['m2', 'Constant61']],
#                'Pow259': ['Pow', ['l', 'Constant62']],
#                'Pow303': ['Pow', ['l', 'Constant67']],
#                'Pow317': ['Pow', ['Mul315', 'Constant68']],
#                'Pow332': ['Pow', ['m2', 'Constant69']],
#                'Pow336': ['Pow', ['l', 'Constant70']],
#                'Pow339': ['Pow', ['Add296', 'Constant71']],
#                'Pow375': ['Pow', ['Add296', 'Constant72']],
#                'Pow381': ['Pow', ['m2', 'Constant73']],
#                'Pow384': ['Pow', ['l', 'Constant74']],
#                'Pow420': ['Pow', ['l', 'Constant75']],
#                'Pow434': ['Pow', ['Mul432', 'Constant76']],
#                'Pow449': ['Pow', ['m2', 'Constant77']],
#                'Pow453': ['Pow', ['l', 'Constant78']],
#                'Pow456': ['Pow', ['Add413', 'Constant79']],
#                'Pow492': ['Pow', ['Add413', 'Constant80']],
#                'Pow498': ['Pow', ['m2', 'Constant81']],
#                'Pow501': ['Pow', ['l', 'Constant82']],
# ...
#                'Linear37': ['Linear',
#                             ['SamplePart36'],
#                             'PLinear37W',
#                             None,
#                             0.0],
#                'Linear44': ['Linear', ['Tanh43'], 'PLinear39W', None, 0.0],
#                'Linear46': ['Linear', ['Tanh45'], 'PLinear41W', None, 0],
#                'Mul100': ['Mul', ['Mul98', 'g']],
#                'Mul102': ['Mul', ['Mul100', 'l']],
#                'Mul103': ['Mul', ['Mul102', 'Sin49']],
#                'Mul107': ['Mul', ['m2', 'l']],
#                'Mul109': ['Mul', ['Mul107', 'b']],
#                'Mul110': ['Mul', ['Mul109', 'Add13']],
#                'Mul111': ['Mul', ['Mul110', 'Cos50']],
#                'Mul115': ['Mul', ['m2', 'l']],
#                'Mul116': ['Mul', ['Mul115', 'Cos50']],
#                'Mul117': ['Mul', ['Mul116', 'Mul70']],
#                'Mul12': ['Mul', ['SamplePart10', 'sigma_v']],
#                'Mul121': ['Mul', ['Add57', 'm2']],
#                'Mul123': ['Mul', ['Mul121', 'l']],
#                'Mul126': ['Mul', ['Mul123', 'Pow125']],
#                'Mul127': ['Mul', ['Mul126', 'Sin49']],
#                'Mul135': ['Mul', ['Pow131', 'Pow134']],
#                'Mul137': ['Mul', ['Mul135', 'g']],
#                'Mul138': ['Mul', ['Mul137', 'Sin49']],
#                'Mul139': ['Mul', ['Mul138', 'Cos50']],
#                'Mul143': ['Mul', ['m2', 'l']],
#                'Mul145': ['Mul', ['Mul143', 'd']],
#                'Mul146': ['Mul', ['Mul145', 'Add20']],
#                'Mul147': ['Mul', ['Mul146', 'Cos50']],
#                'Mul149': ['Mul', ['Mul70', 'Add57']],
#                'Mul158': ['Mul', ['Div151', 'dt']],
#                'Mul163': ['Mul', ['Add20', 'dt']],
#                'Mul168': ['Mul', ['Div119', 'dt']],
#                'Mul180': ['Mul', ['m2', 'Pow178']],
#                'Mul186': ['Mul', ['Add185', 'Add182']],
#                'Mul189': ['Mul', ['m2', 'l']],
#                'Mul19': ['Mul', ['SamplePart17', 'sigma_omega']],
#                'Mul190': ['Mul', ['Mul189', 'Cos175']],
#                'Mul195': ['Mul', ['gear', 'SamplePart173']],
#                'Mul197': ['Mul', ['Add182', 'b']],
#                'Mul198': ['Mul', ['Mul197', 'Add161']],
#                'Mul203': ['Mul', ['Add201', 'd']],
#                'Mul204': ['Mul', ['Mul203', 'Add171']],
#                'Mul212': ['Mul', ['Neg208', 'Pow211']],
#                'Mul215': ['Mul', ['Mul212', 'Pow214']],
#                'Mul216': ['Mul', ['Mul215', 'Sin174']],
#                'Mul217': ['Mul', ['Mul216', 'Cos175']],
#                'Mul223': ['Mul', ['Add221', 'm2']],
#                'Mul225': ['Mul', ['Mul223', 'g']],
#                'Mul227': ['Mul', ['Mul225', 'l']],
#                'Mul228': ['Mul', ['Mul227', 'Sin174']],
#                'Mul232': ['Mul', ['m2', 'l']],
#                'Mul234': ['Mul', ['Mul232', 'b']],
#                'Mul235': ['Mul', ['Mul234', 'Add161']],
#                'Mul236': ['Mul', ['Mul235', 'Cos175']],
#                'Mul240': ['Mul', ['m2', 'l']],
#                'Mul241': ['Mul', ['Mul240', 'Cos175']],
#                'Mul242': ['Mul', ['Mul241', 'Mul195']],
#                'Mul246': ['Mul', ['Add182', 'm2']],
#                'Mul248': ['Mul', ['Mul246', 'l']],
#                'Mul251': ['Mul', ['Mul248', 'Pow250']],
#                'Mul252': ['Mul', ['Mul251', 'Sin174']],
#                'Mul26': ['Mul', ['SamplePart24', 'sigma_theta']],
#                'Mul260': ['Mul', ['Pow256', 'Pow259']],
#                'Mul262': ['Mul', ['Mul260', 'g']],
#                'Mul263': ['Mul', ['Mul262', 'Sin174']],
#                'Mul264': ['Mul', ['Mul263', 'Cos175']],
#                'Mul268': ['Mul', ['m2', 'l']],
#                'Mul270': ['Mul', ['Mul268', 'd']],
#                'Mul271': ['Mul', ['Mul270', 'Add171']],
#                'Mul272': ['Mul', ['Mul271', 'Cos175']],
#                'Mul274': ['Mul', ['Mul195', 'Add182']],
#                'Mul283': ['Mul', ['Div276', 'dt']],
#                'Mul288': ['Mul', ['Add171', 'dt']],
#                'Mul293': ['Mul', ['Div244', 'dt']],
#                'Mul305': ['Mul', ['m2', 'Pow303']],
#                'Mul311': ['Mul', ['Add310', 'Add307']],
#                'Mul314': ['Mul', ['m2', 'l']],
#                'Mul315': ['Mul', ['Mul314', 'Cos300']],
#                'Mul320': ['Mul', ['gear', 'SamplePart298']],
#                'Mul322': ['Mul', ['Add307', 'b']],
#                'Mul323': ['Mul', ['Mul322', 'Add286']],
#                'Mul328': ['Mul', ['Add326', 'd']],
#                'Mul329': ['Mul', ['Mul328', 'Add296']],
#                'Mul337': ['Mul', ['Neg333', 'Pow336']],
#                'Mul340': ['Mul', ['Mul337', 'Pow339']],
#                'Mul341': ['Mul', ['Mul340', 'Sin299']],
#                'Mul342': ['Mul', ['Mul341', 'Cos300']],
#                'Mul348': ['Mul', ['Add346', 'm2']],
#                'Mul350': ['Mul', ['Mul348', 'g']],
#                'Mul352': ['Mul', ['Mul350', 'l']],
#                'Mul353': ['Mul', ['Mul352', 'Sin299']],
#                'Mul357': ['Mul', ['m2', 'l']],
#                'Mul359': ['Mul', ['Mul357', 'b']],
#                'Mul360': ['Mul', ['Mul359', 'Add286']],
#                'Mul361': ['Mul', ['Mul360', 'Cos300']],
#                'Mul365': ['Mul', ['m2', 'l']],
#                'Mul366': ['Mul', ['Mul365', 'Cos300']],
#                'Mul367': ['Mul', ['Mul366', 'Mul320']],
#                'Mul371': ['Mul', ['Add307', 'm2']],
#                'Mul373': ['Mul', ['Mul371', 'l']],
#                'Mul376': ['Mul', ['Mul373', 'Pow375']],
#                'Mul377': ['Mul', ['Mul376', 'Sin299']],
#                'Mul385': ['Mul', ['Pow381', 'Pow384']],
#                'Mul387': ['Mul', ['Mul385', 'g']],
#                'Mul388': ['Mul', ['Mul387', 'Sin299']],
#                'Mul389': ['Mul', ['Mul388', 'Cos300']],
#                'Mul393': ['Mul', ['m2', 'l']],
#                'Mul395': ['Mul', ['Mul393', 'd']],
#                'Mul396': ['Mul', ['Mul395', 'Add296']],
#                'Mul397': ['Mul', ['Mul396', 'Cos300']],
#                'Mul399': ['Mul', ['Mul320', 'Add307']],
#                'Mul406': ['Mul', ['Div401', 'dt']],
#                'Mul409': ['Mul', ['Add296', 'dt']],
#                'Mul412': ['Mul', ['Div369', 'dt']],
#                'Mul422': ['Mul', ['m2', 'Pow420']],
#                'Mul428': ['Mul', ['Add427', 'Add424']],
#                'Mul431': ['Mul', ['m2', 'l']],
#                'Mul432': ['Mul', ['Mul431', 'Cos417']],
#                'Mul437': ['Mul', ['gear', 'SamplePart415']],
#                'Mul439': ['Mul', ['Add424', 'b']],
#                'Mul440': ['Mul', ['Mul439', 'Add407']],
#                'Mul445': ['Mul', ['Add443', 'd']],
#                'Mul446': ['Mul', ['Mul445', 'Add413']],
#                'Mul454': ['Mul', ['Neg450', 'Pow453']],
#                'Mul457': ['Mul', ['Mul454', 'Pow456']],
#                'Mul458': ['Mul', ['Mul457', 'Sin416']],
#                'Mul459': ['Mul', ['Mul458', 'Cos417']],
#                'Mul465': ['Mul', ['Add463', 'm2']],
#                'Mul467': ['Mul', ['Mul465', 'g']],
#                'Mul469': ['Mul', ['Mul467', 'l']],
#                'Mul470': ['Mul', ['Mul469', 'Sin416']],
#                'Mul474': ['Mul', ['m2', 'l']],
#                'Mul476': ['Mul', ['Mul474', 'b']],
#                'Mul477': ['Mul', ['Mul476', 'Add407']],
#                'Mul478': ['Mul', ['Mul477', 'Cos417']],
#                'Mul482': ['Mul', ['m2', 'l']],
#                'Mul483': ['Mul', ['Mul482', 'Cos417']],
#                'Mul484': ['Mul', ['Mul483', 'Mul437']],
#                'Mul488': ['Mul', ['Add424', 'm2']],
#                'Mul490': ['Mul', ['Mul488', 'l']],
#                'Mul493': ['Mul', ['Mul490', 'Pow492']],
#                'Mul494': ['Mul', ['Mul493', 'Sin416']],
#                'Mul5': ['Mul', ['SamplePart3', 'sigma_x']],
#                'Mul502': ['Mul', ['Pow498', 'Pow501']],
#                'Mul504': ['Mul', ['Mul502', 'g']],
#                'Mul505': ['Mul', ['Mul504', 'Sin416']],
#                'Mul506': ['Mul', ['Mul505', 'Cos417']],
#                'Mul510': ['Mul', ['m2', 'l']],
#                'Mul512': ['Mul', ['Mul510', 'd']],
#                'Mul513': ['Mul', ['Mul512', 'Add413']],
#                'Mul514': ['Mul', ['Mul513', 'Cos417']],
#                'Mul516': ['Mul', ['Mul437', 'Add424']],
#                'Mul520': ['Mul', ['Constant83', 'Div276']],
#                'Mul523': ['Mul', ['Constant84', 'Div401']],
#                'Mul527': ['Mul', ['Add525', 'dt']],
#                'Mul534': ['Mul', ['Constant86', 'Add161']],
#                'Mul537': ['Mul', ['Constant87', 'Add286']],
#                'Mul541': ['Mul', ['Add539', 'dt']],
#                'Mul548': ['Mul', ['Constant89', 'Div244']],
#                'Mul55': ['Mul', ['m2', 'Pow53']],
#                'Mul551': ['Mul', ['Constant90', 'Div369']],
#                'Mul555': ['Mul', ['Add553', 'dt']],
#                'Mul562': ['Mul', ['Constant92', 'Add171']],
#                'Mul565': ['Mul', ['Constant93', 'Add296']],
#                'Mul569': ['Mul', ['Add567', 'dt']],
#                'Mul61': ['Mul', ['Add60', 'Add57']],
#                'Mul64': ['Mul', ['m2', 'l']],
#                'Mul65': ['Mul', ['Mul64', 'Cos50']],
#                'Mul70': ['Mul', ['gear', 'SamplePart48']],
#                'Mul72': ['Mul', ['Add57', 'b']],
#                'Mul73': ['Mul', ['Mul72', 'Add13']],
#                'Mul78': ['Mul', ['Add76', 'd']],
#                'Mul79': ['Mul', ['Mul78', 'Add20']],
#                'Mul87': ['Mul', ['Neg83', 'Pow86']],
#                'Mul90': ['Mul', ['Mul87', 'Pow89']],
#                'Mul91': ['Mul', ['Mul90', 'Sin49']],
#                'Mul92': ['Mul', ['Mul91', 'Cos50']],
#                'Mul98': ['Mul', ['Add96', 'm2']],
#                'Neg208': ['Neg', ['Pow207']],
#                'Neg333': ['Neg', ['Pow332']],
#                'Neg450': ['Neg', ['Pow449']],
#                'Neg83': ['Neg', ['Pow82']],
#                'Pow125': ['Pow', ['Add20', 'Constant48']],
#                'Pow131': ['Pow', ['m2', 'Constant49']],
#                'Pow134': ['Pow', ['l', 'Constant50']],
#                'Pow178': ['Pow', ['l', 'Constant55']],
#                'Pow192': ['Pow', ['Mul190', 'Constant56']],
#                'Pow207': ['Pow', ['m2', 'Constant57']],
#                'Pow211': ['Pow', ['l', 'Constant58']],
#                'Pow214': ['Pow', ['Add171', 'Constant59']],
#                'Pow250': ['Pow', ['Add171', 'Constant60']],
#                'Pow256': ['Pow', ['m2', 'Constant61']],
#                'Pow259': ['Pow', ['l', 'Constant62']],
#                'Pow303': ['Pow', ['l', 'Constant67']],
#                'Pow317': ['Pow', ['Mul315', 'Constant68']],
#                'Pow332': ['Pow', ['m2', 'Constant69']],
#                'Pow336': ['Pow', ['l', 'Constant70']],
#                'Pow339': ['Pow', ['Add296', 'Constant71']],
#                'Pow375': ['Pow', ['Add296', 'Constant72']],
#                'Pow381': ['Pow', ['m2', 'Constant73']],
#                'Pow384': ['Pow', ['l', 'Constant74']],
#                'Pow420': ['Pow', ['l', 'Constant75']],
#                'Pow434': ['Pow', ['Mul432', 'Constant76']],
#                'Pow449': ['Pow', ['m2', 'Constant77']],
#                'Pow453': ['Pow', ['l', 'Constant78']],
#                'Pow456': ['Pow', ['Add413', 'Constant79']],
#                'Pow492': ['Pow', ['Add413', 'Constant80']],
#                'Pow498': ['Pow', ['m2', 'Constant81']],
#                'Pow501': ['Pow', ['l', 'Constant82']],
#                'Pow53': ['Pow', ['l', 'Constant43']],
#                'Pow67': ['Pow', ['Mul65', 'Constant44']],
#                'Pow82': ['Pow', ['m2', 'Constant45']],
#                'Pow86': ['Pow', ['l', 'Constant46']],
#                'Pow89': ['Pow', ['Add20', 'Constant47']],
#                'SamplePart1': ['SamplePart', ['Xpos'], -1, [-1, 0]],
#                'SamplePart10': ['SamplePart', ['noise1'], -1, [-1, 0]],
#                'SamplePart15': ['SamplePart',
#                                 ['Xangular_velocity'],
#                                 -1,
#                                 [-1, 0]],
#                'SamplePart17': ['SamplePart', ['noise3'], -1, [-1, 0]],
#                'SamplePart173': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart22': ['SamplePart', ['Xangle'], -1, [-1, 0]],
#                'SamplePart24': ['SamplePart', ['noise2'], -1, [-1, 0]],
#                'SamplePart298': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart3': ['SamplePart', ['noise4'], -1, [-1, 0]],
#                'SamplePart36': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart415': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart48': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart580': ['SamplePart',
#                                  ['Yangular_velocity'],
#                                  -1,
#                                  [-1, 0]],
#                'SamplePart582': ['SamplePart', ['Yangle'], -1, [-1, 0]],
#                'SamplePart584': ['SamplePart', ['Yvelocity'], -1, [-1, 0]],
#                'SamplePart586': ['SamplePart', ['Ypos'], -1, [-1, 0]],
#                'SamplePart8': ['SamplePart', ['Xvelocity'], -1, [-1, 0]],
#                'Select531': ['Select', ['Linear46'], 4, 0],
#                'Select545': ['Select', ['Linear46'], 4, 1],
#                'Select559': ['Select', ['Linear46'], 4, 2],
#                'Select573': ['Select', ['Linear46'], 4, 3],
#                'Select575': ['Select', ['Linear46'], 4, 3],
#                'Select576': ['Select', ['Linear46'], 4, 2],
#                'Select577': ['Select', ['Linear46'], 4, 1],
#                'Select578': ['Select', ['Linear46'], 4, 0],
#                'Sin174': ['Sin', ['Add166']],
#                'Sin299': ['Sin', ['Add291']],
#                'Sin30': ['Sin', ['Add27']],
#                'Sin416': ['Sin', ['Add410']],
#                'Sin49': ['Sin', ['Add27']],
#                'Sub118': ['Sub', ['Add112', 'Mul117']],
#                'Sub128': ['Sub', ['Mul127', 'Mul73']],
#                'Sub140': ['Sub', ['Sub128', 'Mul139']],
#                'Sub193': ['Sub', ['Mul186', 'Pow192']],
#                'Sub218': ['Sub', ['Mul217', 'Mul204']],
#                'Sub243': ['Sub', ['Add237', 'Mul242']],
#                'Sub253': ['Sub', ['Mul252', 'Mul198']],
#                'Sub265': ['Sub', ['Sub253', 'Mul264']],
#                'Sub318': ['Sub', ['Mul311', 'Pow317']],
#                'Sub343': ['Sub', ['Mul342', 'Mul329']],
#                'Sub368': ['Sub', ['Add362', 'Mul367']],
#                'Sub378': ['Sub', ['Mul377', 'Mul323']],
#                'Sub390': ['Sub', ['Sub378', 'Mul389']],
#                'Sub435': ['Sub', ['Mul428', 'Pow434']],
#                'Sub460': ['Sub', ['Mul459', 'Mul446']],
#                'Sub485': ['Sub', ['Add479', 'Mul484']],
#                'Sub495': ['Sub', ['Mul494', 'Mul440']],
#                'Sub507': ['Sub', ['Sub495', 'Mul506']],
#                'Sub68': ['Sub', ['Mul61', 'Pow67']],
#                'Sub93': ['Sub', ['Mul92', 'Mul79']],
#                'Tanh43': ['Tanh', ['Add42']],
#                'Tanh45': ['Tanh', ['Linear44']]}}
# ================================================================================
# ============================ nnodely Model Dataset =============================
# Dataset Name:                 data_test
# Number of files:              200
# Total number of samples:      30000
# Shape of Xangle:              (30000, 1, 1)
# Shape of Xangular_velocity:   (30000, 1, 1)
# Shape of Xpos:                (30000, 1, 1)
# Shape of Xvelocity:           (30000, 1, 1)
# Shape of Yangle:              (30000, 1, 1)
# Shape of Yangular_velocity:   (30000, 1, 1)
# Shape of Ypos:                (30000, 1, 1)
# Shape of Yvelocity:           (30000, 1, 1)
# Shape of action:              (30000, 1, 1)
# Shape of noise1:              (30000, 1, 1)
# Shape of noise2:              (30000, 1, 1)
# Shape of noise3:              (30000, 1, 1)
# Shape of noise4:              (30000, 1, 1)
# ================================================================================

# %%
# Plot percentage of contribution of the neural network
plt.figure(figsize=(14, 9))
plt.subplot(4, 1, 1)
plt.plot(t, 100*np.abs(np.array(result['contr_theta']))/np.abs(np.array(result['est_theta'])), label='NN contribute')
plt.title(r'NN contribution to $\theta$')
plt.xlabel('Time [s]')
plt.ylabel(r'$\theta$ contribution [%]')
plt.grid()
plt.legend()
plt.subplot(4, 1, 2)
plt.plot(t, 100*np.abs(np.array(result['contr_thetadot']))/np.abs(np.array(result['est_thetadot'])), label='NN contribute')
plt.title(r'NN contribution to $\dot{\theta}$')
plt.xlabel('Time [s]')
plt.ylabel(r'$\dot{\theta}$ contribution [%]')
plt.grid()
plt.legend()
plt.subplot(4, 1, 3)
plt.plot(t, 100*np.abs(np.array(result['contr_x']))/np.abs(np.array(result['est_x'])), label='NN contribute')
plt.title('NN contribution to x')
plt.xlabel('Time [s]')
plt.ylabel('x contribution [%]')
plt.grid()
plt.legend()
plt.subplot(4, 1, 4)
plt.plot(t, 100*np.abs(np.array(result['contr_xdot']))/np.abs(np.array(result['est_xdot'])), label='NN contribute')
plt.title(r'NN contribution to $\dot{x}$')
plt.xlabel('Time [s]')
plt.ylabel(r'$\dot{x}$ contribution [%]')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()
