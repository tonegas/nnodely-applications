# %%
from nnodely import *
from nnodely.support import earlystopping
import matplotlib.pyplot as plt
import numpy as np
import os

workspace = os.path.join(os.getcwd(), "saved_models")
inverted_pendulum = Modely(workspace=workspace)
# Out:
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>-- nnodely_v1.5.2 --<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

# %%
def init_random_range(indexes, params_size, dict_param={'min_value': 0.0, 'max_value': 1.0}):
    import numpy as np
    min_val = dict_param.get('min_value', 0.0)
    max_val = dict_param.get('max_value', 1.0)
    return np.random.uniform(low=min_val, high=max_val)

# %%
# Create neural model

model_name = 'physics_augmented_neural_network'
pos                 = Input('Xpos')
Ypos                = Input('Ypos')
velocity            = Input('Xvelocity')
Yvelocity           = Input('Yvelocity')
angle               = Input('Xangle')
Yangle              = Input('Yangle')
angular_velocity    = Input('Xangular_velocity')
Yangular_velocity   = Input('Yangular_velocity')
F                   = Input('action')

noise1          = Input('noise1')
noise2          = Input('noise2')
noise3          = Input('noise3')
noise4          = Input('noise4')
noise5          = Input('noise5')
sigma_x         = Constant('sigma_x', values=0.0)
sigma_v         = Constant('sigma_v', values=0.0)
sigma_theta     = Constant('sigma_theta', values=0.0)
sigma_omega     = Constant('sigma_omega', values=0.0)
sigma_force     = Constant('sigma_force', values=0.0)
g               = Constant('g', values=9.81)
dt              = Constant('dt', values=0.02)
gear            = Parameter('gear', values=100)
m1              = Parameter('m1')
m2              = Parameter('m2')
l               = Parameter('l')
b               = Parameter('b')
d               = Parameter('d')
I               = Parameter('I')

def inv_pend(p, v, alpha, omega, u):
    # Equations of motion for the inverted pendulum on a cart
    sin_theta = Sin(alpha)
    cos_theta = Cos(alpha)
    I_eff = I + m2 * l**2
    denom = (m1+m2)*I_eff - (m2*l*cos_theta)**2

    # Input force
    F = gear * u
    
    # Friction
    friction_cart = I_eff * b*v
    friction_pend = (m1+m2) * d*omega

    # Angular acceleration (omega_dot)
    omega_dot = (- m2**2*l**2*omega**2*sin_theta*cos_theta
                 - friction_pend
                 + (m1+m2)*m2*g*l*sin_theta
                 + m2*l*b*v*cos_theta
                 - m2*l*cos_theta*F
    )/ denom

    # Linear acceleration of the cart (v_dot)
    v_dot = (I_eff*m2*l*omega**2*sin_theta
             - friction_cart
             - m2**2*l**2*g*sin_theta*cos_theta
             + m2*l*d*omega*cos_theta
             + F*I_eff
    )/ denom

    p_dot = v
    alpha_dot = omega

    return [p_dot, v_dot, alpha_dot, omega_dot]

# Adding noise to the inputs
x_noisy = pos.last() + noise4.last()*sigma_x
vel_noisy = velocity.last() + noise1.last()*sigma_v
ang_vel_noisy = angular_velocity.last() + noise3.last()*sigma_omega
theta_noisy = angle.last() + noise2.last()*sigma_theta
F_noisy = F.last() + noise5.last() * sigma_force

# Residual neural network
hidden_size = 10
dropout = 0.0
init_value = 0.01
l1 = Linear(output_dimension = hidden_size, dropout=dropout, W_init=init_random_range, W_init_params={'min_value': -init_value, 'max_value': init_value})(theta_noisy)
l2 = Linear(output_dimension = hidden_size, dropout=dropout, W_init=init_random_range, W_init_params={'min_value': -init_value, 'max_value': init_value})(vel_noisy)
l3 = Linear(output_dimension = hidden_size, dropout=dropout, W_init=init_random_range, W_init_params={'min_value': -init_value, 'max_value': init_value})(ang_vel_noisy)
l4 = Linear(output_dimension = hidden_size, dropout=dropout, W_init=init_random_range, W_init_params={'min_value': -init_value, 'max_value': init_value})(F_noisy)
x1 = Tanh(l1 + l2 + l3 + l4)
x2 = Tanh(Linear(output_dimension = hidden_size, dropout=dropout, W_init=init_random_range, W_init_params={'min_value': -init_value, 'max_value': init_value})(x1))
nn_out = Linear(output_dimension = 4, W_init=init_random_range, W_init_params={'min_value': -init_value, 'max_value': init_value})(x2)

# Runge-Kutta 4th order method
k1 = inv_pend(x_noisy, vel_noisy, theta_noisy, ang_vel_noisy, F_noisy)
k2 = inv_pend(x_noisy + k1[0]*dt/2, vel_noisy + k1[1]*dt/2, theta_noisy + k1[2]*dt/2, ang_vel_noisy + k1[3]*dt/2, F_noisy)
k3 = inv_pend(x_noisy + k2[0]*dt/2, vel_noisy + k2[1]*dt/2, theta_noisy + k2[2]*dt/2, ang_vel_noisy + k2[3]*dt/2, F_noisy)
k4 = inv_pend(x_noisy + k3[0]*dt, vel_noisy + k3[1]*dt, theta_noisy + k3[2]*dt, ang_vel_noisy + k3[3]*dt, F_noisy)
# Update state variables
dt_xdot = (k1[1] + 2*k2[1] + 2*k3[1] + k4[1])*dt/6
xdot = vel_noisy + dt_xdot + Select(nn_out, 0)
xdot.closedLoop(velocity)

dt_x = (k1[0] + 2*k2[0] + 2*k3[0] + k4[0])*dt/6
x = x_noisy + dt_x + Select(nn_out, 1)
x.closedLoop(pos)

dt_thetadot = (k1[3] + 2*k2[3] + 2*k3[3] + k4[3])*dt/6
thetadot = ang_vel_noisy + dt_thetadot + Select(nn_out, 2)
thetadot.closedLoop(angular_velocity)

dt_theta = (k1[2] + 2*k2[2] + 2*k3[2] + k4[2])*dt/6
theta = theta_noisy + dt_theta + Select(nn_out, 3)
theta.closedLoop(angle)

# Remove noise on states in closed-loop predictions
zero = pos.last() * 0.0
noise1.closedLoop(zero)
noise2.closedLoop(zero)
noise3.closedLoop(zero)
noise4.closedLoop(zero)

# Output and loss
est_theta = Output('est_theta', theta)
contr_theta = Output('contr_theta', Select(nn_out, 3))
est_thetadot = Output('est_thetadot', thetadot)
contr_thetadot = Output('contr_thetadot', Select(nn_out, 2))
est_xdot = Output('est_xdot', xdot)
contr_xdot = Output('contr_xdot', Select(nn_out, 1))
est_x = Output('est_x', x)
contr_x = Output('contr_x', Select(nn_out, 0))

inverted_pendulum.addModel('pendulum', [est_thetadot, est_theta, est_xdot, est_x, contr_thetadot, contr_theta, contr_xdot, contr_x])
inverted_pendulum.addMinimize('ang_vel_error', Yangular_velocity.last(), thetadot, loss_function='mse')
inverted_pendulum.addMinimize('angle_error', Yangle.last(), theta, loss_function='mse')
inverted_pendulum.addMinimize('vel_error', Yvelocity.last(), xdot, loss_function='mse')
inverted_pendulum.addMinimize('pos_error', Ypos.last(), x, loss_function='mse')
inverted_pendulum.neuralizeModel(sample_time = 0.02)
# Out:
# [neuralizeModel] Closed loop on Xpos with sample in the future.
# [neuralizeModel] Closed loop on Xangular_velocity with sample in the future.
# [neuralizeModel] Closed loop on Xvelocity with sample in the future.
# [neuralizeModel] Closed loop on Xangle with sample in the future.
# ================================ nnodely Model =================================
# {'Constants': {'Constant41': {'dim': 1, 'values': [2.0]},
#                'Constant42': {'dim': 1, 'values': [2.0]},
#                'Constant43': {'dim': 1, 'values': [2.0]},
#                'Constant44': {'dim': 1, 'values': [2.0]},
#                'Constant45': {'dim': 1, 'values': [2.0]},
#                'Constant46': {'dim': 1, 'values': [2.0]},
#                'Constant47': {'dim': 1, 'values': [2.0]},
#                'Constant48': {'dim': 1, 'values': [2.0]},
#                'Constant50': {'dim': 1, 'values': [2.0]},
#                'Constant51': {'dim': 1, 'values': [2.0]},
#                'Constant52': {'dim': 1, 'values': [2.0]},
#                'Constant53': {'dim': 1, 'values': [2.0]},
#                'Constant54': {'dim': 1, 'values': [2.0]},
#                'Constant55': {'dim': 1, 'values': [2.0]},
#                'Constant56': {'dim': 1, 'values': [2.0]},
#                'Constant57': {'dim': 1, 'values': [2.0]},
#                'Constant58': {'dim': 1, 'values': [2.0]},
#                'Constant59': {'dim': 1, 'values': [2.0]},
#                'Constant60': {'dim': 1, 'values': [2.0]},
#                'Constant62': {'dim': 1, 'values': [2.0]},
#                'Constant63': {'dim': 1, 'values': [2.0]},
#                'Constant64': {'dim': 1, 'values': [2.0]},
#                'Constant65': {'dim': 1, 'values': [2.0]},
#                'Constant66': {'dim': 1, 'values': [2.0]},
#                'Constant67': {'dim': 1, 'values': [2.0]},
#                'Constant68': {'dim': 1, 'values': [2.0]},
#                'Constant69': {'dim': 1, 'values': [2.0]},
#                'Constant70': {'dim': 1, 'values': [2.0]},
#                'Constant71': {'dim': 1, 'values': [2.0]},
#                'Constant72': {'dim': 1, 'values': [2.0]},
#                'Constant73': {'dim': 1, 'values': [2.0]},
#                'Constant74': {'dim': 1, 'values': [2.0]},
#                'Constant75': {'dim': 1, 'values': [2.0]},
#                'Constant76': {'dim': 1, 'values': [2.0]},
#                'Constant77': {'dim': 1, 'values': [2.0]},
#                'Constant78': {'dim': 1, 'values': [2.0]},
#                'Constant79': {'dim': 1, 'values': [2.0]},
#                'Constant80': {'dim': 1, 'values': [2.0]},
#                'Constant81': {'dim': 1, 'values': [2.0]},
#                'Constant82': {'dim': 1, 'values': [2.0]},
#                'Constant83': {'dim': 1, 'values': [6.0]},
#                'Constant84': {'dim': 1, 'values': [2.0]},
#                'Constant85': {'dim': 1, 'values': [2.0]},
#                'Constant86': {'dim': 1, 'values': [6.0]},
#                'Constant87': {'dim': 1, 'values': [2.0]},
#                'Constant88': {'dim': 1, 'values': [2.0]},
#                'Constant89': {'dim': 1, 'values': [6.0]},
#                'Constant90': {'dim': 1, 'values': [2.0]},
#                'Constant91': {'dim': 1, 'values': [2.0]},
#                'Constant92': {'dim': 1, 'values': [6.0]},
#                'dt': {'dim': 1, 'values': [0.019999999552965164]},
#                'g': {'dim': 1, 'values': [9.8100004196167]},
#                'sigma_force': {'dim': 1, 'values': [0.0]},
#                'sigma_omega': {'dim': 1, 'values': [0.0]},
#                'sigma_theta': {'dim': 1, 'values': [0.0]},
#                'sigma_v': {'dim': 1, 'values': [0.0]},
#                'sigma_x': {'dim': 1, 'values': [0.0]}},
#  'Functions': {},
#  'Info': {'SampleTime': 0.02,
#           'nnodely_version': '1.5.2',
#           'ns': [1, 0],
#           'ntot': 1,
#           'num_parameters': 187},
#  'Inputs': {'Xangle': {'closedLoop': 'Add565',
#                        'dim': 1,
#                        'local': 1,
#                        'ns': [1, 0],
#                        'ntot': 1,
#                        'sw': [-1, 0]},
#             'Xangular_velocity': {'closedLoop': 'Add551',
#                                   'dim': 1,
#                                   'local': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Xpos': {'closedLoop': 'Add537',
#                      'dim': 1,
#                      'local': 1,
#                      'ns': [1, 0],
#                      'ntot': 1,
#                      'sw': [-1, 0]},
#             'Xvelocity': {'closedLoop': 'Add523',
#                           'dim': 1,
#                           'local': 1,
#                           'ns': [1, 0],
#                           'ntot': 1,
#                           'sw': [-1, 0]},
#             'Yangle': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yangular_velocity': {'dim': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Ypos': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yvelocity': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'action': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise1': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise2': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise3': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise4': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise5': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]}},
#  'Minimizers': {'ang_vel_error': {'A': 'SamplePart575',
#                                   'B': 'Add551',
#                                   'loss': 'mse'},
#                 'angle_error': {'A': 'SamplePart577',
#                                 'B': 'Add565',
#                                 'loss': 'mse'},
#                 'pos_error': {'A': 'SamplePart581',
#                               'B': 'Add537',
#                               'loss': 'mse'},
#                 'vel_error': {'A': 'SamplePart579',
#                               'B': 'Add523',
#                               'loss': 'mse'}},
#  'Models': 'pendulum',
#  'Outputs': {'contr_theta': 'Select570',
#              'contr_thetadot': 'Select571',
#              'contr_x': 'Select573',
#              'contr_xdot': 'Select572',
#              'est_theta': 'Add565',
#              'est_thetadot': 'Add551',
#              'est_x': 'Add537',
#              'est_xdot': 'Add523'},
#  'Parameters': {'I': {'dim': 1, 'values': [0.08596968650817871]},
#                 'PLinear29W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[0.00862917024642229,
#                                            0.005954026244580746,
#                                            0.0034692990593612194,
#                                            -0.008012236095964909,
#                                            -0.009324947372078896,
#                                            -0.0028474275022745132,
#                                            -0.009591856971383095,
#                                            -0.007630377542227507,
#                                            -0.009664718993008137,
#                                            -0.00782825704663992]]},
#                 'PLinear31W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[0.009540239349007607,
#                                            0.005351549480110407,
#                                            0.0064392248168587685,
#                                            -0.004799471702426672,
#                                            0.003084996249526739,
#                                            -0.003310707164928317,
#                                            -0.007349432446062565,
#                                            -0.006039717234671116,
#                                            -0.0003477595164440572,
#                                            0.0012962776236236095]]},
#                 'PLinear33W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[0.00233649299480021,
#                                            0.0074326638132333755,
#                                            -0.004911244381219149,
#                                            -0.0034891606774181128,
#                                            -0.006035403348505497,
#                                            -0.0020648580975830555,
#                                            0.006685217842459679,
#                                            -0.001657941029407084,
#                                            0.002153657842427492,
#                                            0.00957088265568018]]},
#                 'PLinear35W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[-0.0049531483091413975,
#                                            0.009745283983647823,
#                                            0.007102243602275848,
#                                            -0.007062169257551432,
#                                            0.0056283073499798775,
#                                            -0.005390378180891275,
#                                            0.004414922557771206,
#                                            0.006279173772782087,
#                                            -0.00758537370711565,
#                                            -0.007840566337108612]]},
#                 'PLinear37W': {'dim': [10, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[-0.0038577080704271793,
#                                            0.0029502962715923786,
#                                            -0.0019927257671952248,
#                                            -0.005561034195125103,
#                                            0.0005738583859056234,
#                                            0.0028034544084221125,
#                                            -0.005037210416048765,
#                                            0.0010835749562829733,
#                                            -0.008850771002471447,
#                                            -0.0009768689051270485],
#                                           [-0.0024999550078064203,
#                                            0.0045029581524431705,
#                                            0.0016870388062670827,
#                                            0.006177427247166634,
#                                            -0.007432155776768923,
#                                            -0.000485147291328758,
#                                            -0.004801611416041851,
#                                            -0.007377337198704481,
#                                            -0.00966364610940218,
#                                            0.004927748814225197],
#                                           [0.00323410308919847,
#                                            0.0066611263900995255,
#                                            0.002623969689011574,
#                                            0.009196612983942032,
#                                            -0.002917555859312415,
#                                            -0.008416476659476757,
#                                            -0.0009271559538319707,
#                                            0.0014648548094555736,
#                                            -0.00222536432556808,
#                                            0.004129489418119192],
#                                           [0.0007366703939624131,
#                                            -0.008859293535351753,
#                                            0.00607456685975194,
#                                            -0.008033600635826588,
#                                            0.0038675677496939898,
#                                            -0.004426576662808657,
#                                            -0.004777947440743446,
#                                            -0.000982199446298182,
#                                            -0.009982612915337086,
#                                            -0.009483972564339638],
#                                           [0.00864158384501934,
#                                            0.008242128416895866,
#                                            -0.006511523388326168,
#                                            -0.00216650846414268,
#                                            -0.0058360532857477665,
#                                            -0.0033446599263697863,
#                                            0.0054500955156981945,
#                                            -0.002501403447240591,
#                                            0.0049078622832894325,
#                                            -0.009082688950002193],
#                                           [0.00872798077762127,
#                                            0.0032998346723616123,
#                                            0.00713757099583745,
#                                            0.006752954330295324,
#                                            0.004230066668242216,
#                                            0.0012739029480144382,
#                                            -0.00496447179466486,
#                                            0.008322549983859062,
#                                            -0.007312469184398651,
#                                            0.003982589114457369],
#                                           [0.0004328021313995123,
#                                            0.0037332887295633554,
#                                            -0.005999973975121975,
#                                            0.004797106143087149,
#                                            -0.0046431333757936954,
#                                            0.007669955492019653,
#                                            -0.00013813185796607286,
#                                            -0.006943860556930304,
#                                            0.008309208787977695,
#                                            -0.009208728559315205],
#                                           [0.004004389513283968,
#                                            0.0021179530303925276,
#                                            -0.009520639665424824,
#                                            -0.0014408986316993833,
#                                            -0.006882254034280777,
#                                            0.0031735997181385756,
#                                            0.006317384075373411,
#                                            0.006088643800467253,
#                                            0.003651196835562587,
#                                            0.0044936444610357285],
#                                           [0.0033750920556485653,
#                                            0.006521283183246851,
#                                            -0.007438215892761946,
#                                            -0.0034539466723799706,
#                                            0.009188616648316383,
#                                            0.009798930957913399,
#                                            0.002856683684512973,
#                                            -0.0097341975197196,
#                                            -0.0032585503067821264,
#                                            -4.8349815187975764e-05],
#                                           [-0.008911856450140476,
#                                            -0.000315548968501389,
#                                            0.009985498152673244,
#                                            0.002759774448350072,
#                                            0.006162350997328758,
#                                            0.006114480085670948,
#                                            0.005944021046161652,
#                                            -0.0006714173941873014,
#                                            -0.003147680312395096,
#                                            0.005257792770862579]]},
#                 'PLinear39W': {'dim': [10, 4],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[0.002858562394976616,
#                                            0.0050081973895430565,
#                                            0.0070095607079565525,
#                                            -0.007027018815279007],
#                                           [-0.007900819182395935,
#                                            -0.00473769661039114,
#                                            -0.005646956618875265,
#                                            -0.0037184820976108313],
#                                           [0.006878015119582415,
#                                            -0.0001495163596700877,
#                                            0.0010510513093322515,
#                                            0.003963647875934839],
#                                           [0.002303577261045575,
#                                            -0.0013557530473917723,
#                                            0.004299320746213198,
#                                            0.008319425396621227],
#                                           [0.00536121241748333,
#                                            0.00039619876770302653,
#                                            0.009091472253203392,
#                                            -0.008780991658568382],
#                                           [-0.0016814988339319825,
#                                            0.009365090169012547,
#                                            -0.00041450184653513134,
#                                            -0.002072902163490653],
#                                           [-0.0032607652246952057,
#                                            -0.0059480187483131886,
#                                            0.005274489987641573,
#                                            0.0006020419532433152],
#                                           [0.006744254380464554,
#                                            0.00044724956387653947,
#                                            -3.8689282519044355e-05,
#                                            0.0020670436788350344],
#                                           [-0.009459995664656162,
#                                            0.009179556742310524,
#                                            -0.006985106505453587,
#                                            0.0055917054414749146],
#                                           [-0.009172145277261734,
#                                            0.009197155013680458,
#                                            -0.0024139867164194584,
#                                            -0.005545312538743019]]},
#                 'b': {'dim': 1, 'values': [0.7123878002166748]},
#                 'd': {'dim': 1, 'values': [0.08885741233825684]},
#                 'gear': {'dim': 1, 'init_values': [100.0], 'values': [100.0]},
#                 'l': {'dim': 1, 'values': [0.7918664813041687]},
#                 'm1': {'dim': 1, 'values': [0.8797435164451599]},
#                 'm2': {'dim': 1, 'values': [0.5581528544425964]}},
#  'Relations': {'Add101': ['Add', ['Sub90', 'Mul100']],
#                'Add109': ['Add', ['Add101', 'Mul108']],
#                'Add13': ['Add', ['SamplePart8', 'Mul12']],
#                'Add145': ['Add', ['Sub137', 'Mul144']],
#                'Add147': ['Add', ['Add145', 'Mul146']],
#                'Add158': ['Add', ['Add13', 'Div157']],
#                'Add163': ['Add', ['Add27', 'Div162']],
#                'Add168': ['Add', ['Add20', 'Div167']],
#                'Add177': ['Add', ['I', 'Mul175']],
#                'Add180': ['Add', ['m1', 'm2']],
#                'Add196': ['Add', ['m1', 'm2']],
#                'Add20': ['Add', ['SamplePart15', 'Mul19']],
#                'Add216': ['Add', ['m1', 'm2']],
#                'Add224': ['Add', ['Sub213', 'Mul223']],
#                'Add232': ['Add', ['Add224', 'Mul231']],
#                'Add268': ['Add', ['Sub260', 'Mul267']],
#                'Add27': ['Add', ['SamplePart22', 'Mul26']],
#                'Add270': ['Add', ['Add268', 'Mul269']],
#                'Add281': ['Add', ['Add13', 'Div280']],
#                'Add286': ['Add', ['Add27', 'Div285']],
#                'Add291': ['Add', ['Add20', 'Div290']],
#                'Add300': ['Add', ['I', 'Mul298']],
#                'Add303': ['Add', ['m1', 'm2']],
#                'Add319': ['Add', ['m1', 'm2']],
#                'Add339': ['Add', ['m1', 'm2']],
#                'Add34': ['Add', ['SamplePart29', 'Mul33']],
#                'Add347': ['Add', ['Sub336', 'Mul346']],
#                'Add355': ['Add', ['Add347', 'Mul354']],
#                'Add39': ['Add', ['Linear35', 'Linear36']],
#                'Add391': ['Add', ['Sub383', 'Mul390']],
#                'Add393': ['Add', ['Add391', 'Mul392']],
#                'Add40': ['Add', ['Add39', 'Linear37']],
#                'Add400': ['Add', ['Add13', 'Mul399']],
#                'Add403': ['Add', ['Add27', 'Mul402']],
#                'Add406': ['Add', ['Add20', 'Mul405']],
#                'Add41': ['Add', ['Add40', 'Linear38']],
#                'Add415': ['Add', ['I', 'Mul413']],
#                'Add418': ['Add', ['m1', 'm2']],
#                'Add434': ['Add', ['m1', 'm2']],
#                'Add454': ['Add', ['m1', 'm2']],
#                'Add462': ['Add', ['Sub451', 'Mul461']],
#                'Add470': ['Add', ['Add462', 'Mul469']],
#                'Add506': ['Add', ['Sub498', 'Mul505']],
#                'Add508': ['Add', ['Add506', 'Mul507']],
#                'Add512': ['Add', ['Div148', 'Mul511']],
#                'Add515': ['Add', ['Add512', 'Mul514']],
#                'Add516': ['Add', ['Add515', 'Div509']],
#                'Add521': ['Add', ['Add13', 'Div520']],
#                'Add523': ['Add', ['Add521', 'Select522']],
#                'Add526': ['Add', ['Add13', 'Mul525']],
#                'Add529': ['Add', ['Add526', 'Mul528']],
#                'Add530': ['Add', ['Add529', 'Add400']],
#                'Add535': ['Add', ['Add6', 'Div534']],
#                'Add537': ['Add', ['Add535', 'Select536']],
#                'Add54': ['Add', ['I', 'Mul52']],
#                'Add540': ['Add', ['Div116', 'Mul539']],
#                'Add543': ['Add', ['Add540', 'Mul542']],
#                'Add544': ['Add', ['Add543', 'Div477']],
#                'Add549': ['Add', ['Add20', 'Div548']],
#                'Add551': ['Add', ['Add549', 'Select550']],
#                'Add554': ['Add', ['Add20', 'Mul553']],
#                'Add557': ['Add', ['Add554', 'Mul556']],
#                'Add558': ['Add', ['Add557', 'Add406']],
#                'Add563': ['Add', ['Add27', 'Div562']],
#                'Add565': ['Add', ['Add563', 'Select564']],
#                'Add57': ['Add', ['m1', 'm2']],
#                'Add6': ['Add', ['SamplePart1', 'Mul5']],
#                'Add73': ['Add', ['m1', 'm2']],
#                'Add93': ['Add', ['m1', 'm2']],
#                'Cos170': ['Cos', ['Add163']],
#                'Cos293': ['Cos', ['Add286']],
#                'Cos408': ['Cos', ['Add403']],
#                'Cos47': ['Cos', ['Add27']],
#                'Div116': ['Div', ['Sub115', 'Sub65']],
#                'Div148': ['Div', ['Add147', 'Sub65']],
#                'Div157': ['Div', ['Mul155', 'Constant50']],
#                'Div162': ['Div', ['Mul160', 'Constant51']],
#                'Div167': ['Div', ['Mul165', 'Constant52']],
#                'Div239': ['Div', ['Sub238', 'Sub188']],
#                'Div271': ['Div', ['Add270', 'Sub188']],
#                'Div280': ['Div', ['Mul278', 'Constant62']],
#                'Div285': ['Div', ['Mul283', 'Constant63']],
#                'Div290': ['Div', ['Mul288', 'Constant64']],
#                'Div362': ['Div', ['Sub361', 'Sub311']],
#                'Div394': ['Div', ['Add393', 'Sub311']],
#                'Div477': ['Div', ['Sub476', 'Sub426']],
#                'Div509': ['Div', ['Add508', 'Sub426']],
#                'Div520': ['Div', ['Mul518', 'Constant83']],
#                'Div534': ['Div', ['Mul532', 'Constant86']],
#                'Div548': ['Div', ['Mul546', 'Constant89']],
#                'Div562': ['Div', ['Mul560', 'Constant92']],
#                'Linear35': ['Linear', ['Add27'], 'PLinear29W', None, 0.0],
#                'Linear36': ['Linear', ['Add13'], 'PLinear31W', None, 0.0],
#                'Linear37': ['Linear', ['Add20'], 'PLinear33W', None, 0.0],
#                'Linear38': ['Linear', ['Add34'], 'PLinear35W', None, 0.0],
#                'Linear43': ['Linear', ['Tanh42'], 'PLinear37W', None, 0.0],
#                'Linear45': ['Linear', ['Tanh44'], 'PLinear39W', None, 0],
#                'Mul100': ['Mul', ['Mul99', 'Sin46']],
#                'Mul104': ['Mul', ['m2', 'l']],
#                'Mul106': ['Mul', ['Mul104', 'b']],
#                'Mul107': ['Mul', ['Mul106', 'Add13']],
#                'Mul108': ['Mul', ['Mul107', 'Cos47']],
#                'Mul112': ['Mul', ['m2', 'l']],
#                'Mul113': ['Mul', ['Mul112', 'Cos47']],
#                'Mul114': ['Mul', ['Mul113', 'Mul67']],
#                'Mul118': ['Mul', ['Add54', 'm2']],
#                'Mul12': ['Mul', ['SamplePart10', 'sigma_v']],
#                'Mul120': ['Mul', ['Mul118', 'l']],
#                'Mul123': ['Mul', ['Mul120', 'Pow122']],
#                'Mul124': ['Mul', ['Mul123', 'Sin46']],
#                'Mul132': ['Mul', ['Pow128', 'Pow131']],
#                'Mul134': ['Mul', ['Mul132', 'g']],
#                'Mul135': ['Mul', ['Mul134', 'Sin46']],
#                'Mul136': ['Mul', ['Mul135', 'Cos47']],
#                'Mul140': ['Mul', ['m2', 'l']],
#                'Mul142': ['Mul', ['Mul140', 'd']],
#                'Mul143': ['Mul', ['Mul142', 'Add20']],
#                'Mul144': ['Mul', ['Mul143', 'Cos47']],
#                'Mul146': ['Mul', ['Mul67', 'Add54']],
#                'Mul155': ['Mul', ['Div148', 'dt']],
#                'Mul160': ['Mul', ['Add20', 'dt']],
#                'Mul165': ['Mul', ['Div116', 'dt']],
#                'Mul175': ['Mul', ['m2', 'Pow173']],
#                'Mul181': ['Mul', ['Add180', 'Add177']],
#                'Mul184': ['Mul', ['m2', 'l']],
#                'Mul185': ['Mul', ['Mul184', 'Cos170']],
#                'Mul19': ['Mul', ['SamplePart17', 'sigma_omega']],
#                'Mul190': ['Mul', ['gear', 'Add34']],
#                'Mul192': ['Mul', ['Add177', 'b']],
#                'Mul193': ['Mul', ['Mul192', 'Add158']],
#                'Mul198': ['Mul', ['Add196', 'd']],
#                'Mul199': ['Mul', ['Mul198', 'Add168']],
#                'Mul207': ['Mul', ['Neg203', 'Pow206']],
#                'Mul210': ['Mul', ['Mul207', 'Pow209']],
#                'Mul211': ['Mul', ['Mul210', 'Sin169']],
#                'Mul212': ['Mul', ['Mul211', 'Cos170']],
#                'Mul218': ['Mul', ['Add216', 'm2']],
#                'Mul220': ['Mul', ['Mul218', 'g']],
#                'Mul222': ['Mul', ['Mul220', 'l']],
#                'Mul223': ['Mul', ['Mul222', 'Sin169']],
#                'Mul227': ['Mul', ['m2', 'l']],
#                'Mul229': ['Mul', ['Mul227', 'b']],
#                'Mul230': ['Mul', ['Mul229', 'Add158']],
#                'Mul231': ['Mul', ['Mul230', 'Cos170']],
#                'Mul235': ['Mul', ['m2', 'l']],
#                'Mul236': ['Mul', ['Mul235', 'Cos170']],
#                'Mul237': ['Mul', ['Mul236', 'Mul190']],
#                'Mul241': ['Mul', ['Add177', 'm2']],
#                'Mul243': ['Mul', ['Mul241', 'l']],
#                'Mul246': ['Mul', ['Mul243', 'Pow245']],
#                'Mul247': ['Mul', ['Mul246', 'Sin169']],
#                'Mul255': ['Mul', ['Pow251', 'Pow254']],
#                'Mul257': ['Mul', ['Mul255', 'g']],
#                'Mul258': ['Mul', ['Mul257', 'Sin169']],
#                'Mul259': ['Mul', ['Mul258', 'Cos170']],
#                'Mul26': ['Mul', ['SamplePart24', 'sigma_theta']],
#                'Mul263': ['Mul', ['m2', 'l']],
#                'Mul265': ['Mul', ['Mul263', 'd']],
#                'Mul266': ['Mul', ['Mul265', 'Add168']],
#                'Mul267': ['Mul', ['Mul266', 'Cos170']],
#                'Mul269': ['Mul', ['Mul190', 'Add177']],
#                'Mul278': ['Mul', ['Div271', 'dt']],
#                'Mul283': ['Mul', ['Add168', 'dt']],
#                'Mul288': ['Mul', ['Div239', 'dt']],
#                'Mul298': ['Mul', ['m2', 'Pow296']],
#                'Mul304': ['Mul', ['Add303', 'Add300']],
#                'Mul307': ['Mul', ['m2', 'l']],
#                'Mul308': ['Mul', ['Mul307', 'Cos293']],
#                'Mul313': ['Mul', ['gear', 'Add34']],
#                'Mul315': ['Mul', ['Add300', 'b']],
#                'Mul316': ['Mul', ['Mul315', 'Add281']],
#                'Mul321': ['Mul', ['Add319', 'd']],
#                'Mul322': ['Mul', ['Mul321', 'Add291']],
#                'Mul33': ['Mul', ['SamplePart31', 'sigma_force']],
#                'Mul330': ['Mul', ['Neg326', 'Pow329']],
#                'Mul333': ['Mul', ['Mul330', 'Pow332']],
#                'Mul334': ['Mul', ['Mul333', 'Sin292']],
#                'Mul335': ['Mul', ['Mul334', 'Cos293']],
#                'Mul341': ['Mul', ['Add339', 'm2']],
#                'Mul343': ['Mul', ['Mul341', 'g']],
#                'Mul345': ['Mul', ['Mul343', 'l']],
#                'Mul346': ['Mul', ['Mul345', 'Sin292']],
#                'Mul350': ['Mul', ['m2', 'l']],
#                'Mul352': ['Mul', ['Mul350', 'b']],
#                'Mul353': ['Mul', ['Mul352', 'Add281']],
#                'Mul354': ['Mul', ['Mul353', 'Cos293']],
#                'Mul358': ['Mul', ['m2', 'l']],
#                'Mul359': ['Mul', ['Mul358', 'Cos293']],
#                'Mul360': ['Mul', ['Mul359', 'Mul313']],
#                'Mul364': ['Mul', ['Add300', 'm2']],
#                'Mul366': ['Mul', ['Mul364', 'l']],
#                'Mul369': ['Mul', ['Mul366', 'Pow368']],
#                'Mul370': ['Mul', ['Mul369', 'Sin292']],
#                'Mul378': ['Mul', ['Pow374', 'Pow377']],
#                'Mul380': ['Mul', ['Mul378', 'g']],
#                'Mul381': ['Mul', ['Mul380', 'Sin292']],
#                'Mul382': ['Mul', ['Mul381', 'Cos293']],
#                'Mul386': ['Mul', ['m2', 'l']],
#                'Mul388': ['Mul', ['Mul386', 'd']],
#                'Mul389': ['Mul', ['Mul388', 'Add291']],
#                'Mul390': ['Mul', ['Mul389', 'Cos293']],
#                'Mul392': ['Mul', ['Mul313', 'Add300']],
#                'Mul399': ['Mul', ['Div394', 'dt']],
#                'Mul402': ['Mul', ['Add291', 'dt']],
#                'Mul405': ['Mul', ['Div362', 'dt']],
#                'Mul413': ['Mul', ['m2', 'Pow411']],
#                'Mul419': ['Mul', ['Add418', 'Add415']],
#                'Mul422': ['Mul', ['m2', 'l']],
#                'Mul423': ['Mul', ['Mul422', 'Cos408']],
#                'Mul428': ['Mul', ['gear', 'Add34']],
#                'Mul430': ['Mul', ['Add415', 'b']],
#                'Mul431': ['Mul', ['Mul430', 'Add400']],
#                'Mul436': ['Mul', ['Add434', 'd']],
#                'Mul437': ['Mul', ['Mul436', 'Add406']],
#                'Mul445': ['Mul', ['Neg441', 'Pow444']],
#                'Mul448': ['Mul', ['Mul445', 'Pow447']],
#                'Mul449': ['Mul', ['Mul448', 'Sin407']],
#                'Mul450': ['Mul', ['Mul449', 'Cos408']],
#                'Mul456': ['Mul', ['Add454', 'm2']],
#                'Mul458': ['Mul', ['Mul456', 'g']],
#                'Mul460': ['Mul', ['Mul458', 'l']],
#                'Mul461': ['Mul', ['Mul460', 'Sin407']],
#                'Mul465': ['Mul', ['m2', 'l']],
#                'Mul467': ['Mul', ['Mul465', 'b']],
#                'Mul468': ['Mul', ['Mul467', 'Add400']],
#                'Mul469': ['Mul', ['Mul468', 'Cos408']],
#                'Mul473': ['Mul', ['m2', 'l']],
#                'Mul474': ['Mul', ['Mul473', 'Cos408']],
#                'Mul475': ['Mul', ['Mul474', 'Mul428']],
#                'Mul479': ['Mul', ['Add415', 'm2']],
#                'Mul481': ['Mul', ['Mul479', 'l']],
#                'Mul484': ['Mul', ['Mul481', 'Pow483']],
#                'Mul485': ['Mul', ['Mul484', 'Sin407']],
#                'Mul493': ['Mul', ['Pow489', 'Pow492']],
#                'Mul495': ['Mul', ['Mul493', 'g']],
#                'Mul496': ['Mul', ['Mul495', 'Sin407']],
#                'Mul497': ['Mul', ['Mul496', 'Cos408']],
#                'Mul5': ['Mul', ['SamplePart3', 'sigma_x']],
#                'Mul501': ['Mul', ['m2', 'l']],
#                'Mul503': ['Mul', ['Mul501', 'd']],
#                'Mul504': ['Mul', ['Mul503', 'Add406']],
#                'Mul505': ['Mul', ['Mul504', 'Cos408']],
#                'Mul507': ['Mul', ['Mul428', 'Add415']],
#                'Mul511': ['Mul', ['Constant81', 'Div271']],
#                'Mul514': ['Mul', ['Constant82', 'Div394']],
#                'Mul518': ['Mul', ['Add516', 'dt']],
#                'Mul52': ['Mul', ['m2', 'Pow50']],
#                'Mul525': ['Mul', ['Constant84', 'Add158']],
#                'Mul528': ['Mul', ['Constant85', 'Add281']],
#                'Mul532': ['Mul', ['Add530', 'dt']],
#                'Mul539': ['Mul', ['Constant87', 'Div239']],
#                'Mul542': ['Mul', ['Constant88', 'Div362']],
#                'Mul546': ['Mul', ['Add544', 'dt']],
#                'Mul553': ['Mul', ['Constant90', 'Add168']],
#                'Mul556': ['Mul', ['Constant91', 'Add291']],
#                'Mul560': ['Mul', ['Add558', 'dt']],
#                'Mul58': ['Mul', ['Add57', 'Add54']],
#                'Mul61': ['Mul', ['m2', 'l']],
#                'Mul62': ['Mul', ['Mul61', 'Cos47']],
#                'Mul67': ['Mul', ['gear', 'Add34']],
#                'Mul69': ['Mul', ['Add54', 'b']],
#                'Mul70': ['Mul', ['Mul69', 'Add13']],
#                'Mul75': ['Mul', ['Add73', 'd']],
#                'Mul76': ['Mul', ['Mul75', 'Add20']],
#                'Mul84': ['Mul', ['Neg80', 'Pow83']],
#                'Mul87': ['Mul', ['Mul84', 'Pow86']],
#                'Mul88': ['Mul', ['Mul87', 'Sin46']],
#                'Mul89': ['Mul', ['Mul88', 'Cos47']],
#                'Mul95': ['Mul', ['Add93', 'm2']],
#                'Mul97': ['Mul', ['Mul95', 'g']],
#                'Mul99': ['Mul', ['Mul97', 'l']],
#                'Neg203': ['Neg', ['Pow202']],
#                'Neg326': ['Neg', ['Pow325']],
#                'Neg441': ['Neg', ['Pow440']],
#                'Neg80': ['Neg', ['Pow79']],
#                'Pow122': ['Pow', ['Add20', 'Constant46']],
#                'Pow128': ['Pow', ['m2', 'Constant47']],
#                'Pow131': ['Pow', ['l', 'Constant48']],
#                'Pow173': ['Pow', ['l', 'Constant53']],
#                'Pow187': ['Pow', ['Mul185', 'Constant54']],
#                'Pow202': ['Pow', ['m2', 'Constant55']],
#                'Pow206': ['Pow', ['l', 'Constant56']],
#                'Pow209': ['Pow', ['Add168', 'Constant57']],
#                'Pow245': ['Pow', ['Add168', 'Constant58']],
#                'Pow251': ['Pow', ['m2', 'Constant59']],
#                'Pow254': ['Pow', ['l', 'Constant60']],
#                'Pow296': ['Pow', ['l', 'Constant65']],
#                'Pow310': ['Pow', ['Mul308', 'Constant66']],
#                'Pow325': ['Pow', ['m2', 'Constant67']],
#                'Pow329': ['Pow', ['l', 'Constant68']],
#                'Pow332': ['Pow', ['Add291', 'Constant69']],
#                'Pow368': ['Pow', ['Add291', 'Constant70']],
#                'Pow374': ['Pow', ['m2', 'Constant71']],
#                'Pow377': ['Pow', ['l', 'Constant72']],
#                'Pow411': ['Pow', ['l', 'Constant73']],
#                'Pow425': ['Pow', ['Mul423', 'Constant74']],
#                'Pow440': ['Pow', ['m2', 'Constant75']],
#                'Pow444': ['Pow', ['l', 'Constant76']],
#                'Pow447': ['Pow', ['Add406', 'Constant77']],
#                'Pow483': ['Pow', ['Add406', 'Constant78']],
#                'Pow489': ['Pow', ['m2', 'Constant79']],
#                'Pow492': ['Pow', ['l', 'Constant80']],
#                'Pow50': ['Pow', ['l', 'Constant41']],
#                'Pow64': ['Pow', ['Mul62', 'Constant42']],
#                'Pow79': ['Pow', ['m2', 'Constant43']],
#                'Pow83': ['Pow', ['l', 'Constant44']],
#                'Pow86': ['Pow', ['Add20', 'Constant45']],
#                'SamplePart1': ['SamplePart', ['Xpos'], -1, [-1, 0]],
#                'SamplePart10': ['SamplePart', ['noise1'], -1, [-1, 0]],
#                'SamplePart15': ['SamplePart',
#                                 ['Xangular_velocity'],
#                                 -1,
#                                 [-1, 0]],
#                'SamplePart17': ['SamplePart', ['noise3'], -1, [-1, 0]],
#                'SamplePart22': ['SamplePart', ['Xangle'], -1, [-1, 0]],
#                'SamplePart24': ['SamplePart', ['noise2'], -1, [-1, 0]],
#                'SamplePart29': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart3': ['SamplePart', ['noise4'], -1, [-1, 0]],
#                'SamplePart31': ['SamplePart', ['noise5'], -1, [-1, 0]],
#                'SamplePart575': ['SamplePart',
#                                  ['Yangular_velocity'],
#                                  -1,
#                                  [-1, 0]],
#                'SamplePart577': ['SamplePart', ['Yangle'], -1, [-1, 0]],
#                'SamplePart579': ['SamplePart', ['Yvelocity'], -1, [-1, 0]],
#                'SamplePart581': ['SamplePart', ['Ypos'], -1, [-1, 0]],
#                'SamplePart8': ['SamplePart', ['Xvelocity'], -1, [-1, 0]],
#                'Select522': ['Select', ['Linear45'], 4, 0],
#                'Select536': ['Select', ['Linear45'], 4, 1],
#                'Select550': ['Select', ['Linear45'], 4, 2],
#                'Select564': ['Select', ['Linear45'], 4, 3],
#                'Select570': ['Select', ['Linear45'], 4, 3],
#                'Select571': ['Select', ['Linear45'], 4, 2],
#                'Select572': ['Select', ['Linear45'], 4, 1],
#                'Select573': ['Select', ['Linear45'], 4, 0],
#                'Sin169': ['Sin', ['Add163']],
#                'Sin292': ['Sin', ['Add286']],
#                'Sin407': ['Sin', ['Add403']],
#                'Sin46': ['Sin', ['Add27']],
#                'Sub115': ['Sub', ['Add109', 'Mul114']],
#                'Sub125': ['Sub', ['Mul124', 'Mul70']],
#                'Sub137': ['Sub', ['Sub125', 'Mul136']],
#                'Sub188': ['Sub', ['Mul181', 'Pow187']],
#                'Sub213': ['Sub', ['Mul212', 'Mul199']],
#                'Sub238': ['Sub', ['Add232', 'Mul237']],
#                'Sub248': ['Sub', ['Mul247', 'Mul193']],
#                'Sub260': ['Sub', ['Sub248', 'Mul259']],
#                'Sub311': ['Sub', ['Mul304', 'Pow310']],
#                'Sub336': ['Sub', ['Mul335', 'Mul322']],
#                'Sub361': ['Sub', ['Add355', 'Mul360']],
#                'Sub371': ['Sub', ['Mul370', 'Mul316']],
#                'Sub383': ['Sub', ['Sub371', 'Mul382']],
#                'Sub426': ['Sub', ['Mul419', 'Pow425']],
#                'Sub451': ['Sub', ['Mul450', 'Mul437']],
#                'Sub476': ['Sub', ['Add470', 'Mul475']],
#                'Sub486': ['Sub', ['Mul485', 'Mul431']],
#                'Sub498': ['Sub', ['Sub486', 'Mul497']],
#                'Sub65': ['Sub', ['Mul58', 'Pow64']],
#                'Sub90': ['Sub', ['Mul89', 'Mul76']],
#                'Tanh42': ['Tanh', ['Add41']],
#                'Tanh44': ['Tanh', ['Linear43']]}}
# ================================================================================

# %%
# Data loading
import torch
torch.set_num_threads(4)
data_struct = ['time', 'action', 'Xpos', 'Xangle', 'Xvelocity', 'Xangular_velocity', 'Ypos', 'Yangle', 'Yvelocity', 'Yangular_velocity', 'noise1', 'noise2', 'noise3', 'noise4', 'noise5', 'acc', 'ang_acc']
data_folder = os.path.join(os.path.abspath(''), 'data')
inverted_pendulum.loadData(name='data', source=data_folder, format=data_struct, delimiter=',', header=0)
data_folder = os.path.join(os.path.abspath(''), 'data_val')
inverted_pendulum.loadData(name='data_val', source=data_folder, format=data_struct, delimiter=',', header=0)
data_folder = os.path.join(os.path.abspath(''),'data_test')
inverted_pendulum.loadData(name='data_test', source=data_folder, format=data_struct, delimiter=',', header=0)
# Out:
# ============================ nnodely Model Dataset =============================
# Dataset Name:                 data
# Number of files:              150
# Total number of samples:      22500
# Shape of Xpos:                (22500, 1, 1)
# Shape of noise5:              (22500, 1, 1)
# Shape of action:              (22500, 1, 1)
# Shape of noise3:              (22500, 1, 1)
# Shape of Xangular_velocity:   (22500, 1, 1)
# Shape of noise1:              (22500, 1, 1)
# Shape of Xvelocity:           (22500, 1, 1)
# Shape of noise2:              (22500, 1, 1)
# Shape of Xangle:              (22500, 1, 1)
# Shape of noise4:              (22500, 1, 1)
# Shape of Ypos:                (22500, 1, 1)
# Shape of Yvelocity:           (22500, 1, 1)
# Shape of Yangle:              (22500, 1, 1)
# Shape of Yangular_velocity:   (22500, 1, 1)
# ================================================================================
# ============================ nnodely Model Dataset =============================
# Dataset Name:                 data_val
# Number of files:              100
# Total number of samples:      15000
# Shape of Xpos:                (15000, 1, 1)
# Shape of noise5:              (15000, 1, 1)
# Shape of action:              (15000, 1, 1)
# Shape of noise3:              (15000, 1, 1)
# Shape of Xangular_velocity:   (15000, 1, 1)
# Shape of noise1:              (15000, 1, 1)
# Shape of Xvelocity:           (15000, 1, 1)
# Shape of noise2:              (15000, 1, 1)
# Shape of Xangle:              (15000, 1, 1)
# Shape of noise4:              (15000, 1, 1)
# Shape of Ypos:                (15000, 1, 1)
# Shape of Yvelocity:           (15000, 1, 1)
# Shape of Yangle:              (15000, 1, 1)
# Shape of Yangular_velocity:   (15000, 1, 1)
# ================================================================================
# ============================ nnodely Model Dataset =============================
# Dataset Name:                 data_test
# Number of files:              150
# Total number of samples:      22500
# Shape of Xpos:                (22500, 1, 1)
# Shape of noise5:              (22500, 1, 1)
# Shape of action:              (22500, 1, 1)
# Shape of noise3:              (22500, 1, 1)
# Shape of Xangular_velocity:   (22500, 1, 1)
# Shape of noise1:              (22500, 1, 1)
# Shape of Xvelocity:           (22500, 1, 1)
# Shape of noise2:              (22500, 1, 1)
# Shape of Xangle:              (22500, 1, 1)
# Shape of noise4:              (22500, 1, 1)
# Shape of Ypos:                (22500, 1, 1)
# Shape of Yvelocity:           (22500, 1, 1)
# Shape of Yangle:              (22500, 1, 1)
# Shape of Yangular_velocity:   (22500, 1, 1)
# ================================================================================

# %%
# Training
prediction_samples = None
step = None
early_stop_patience = 10
inverted_pendulum.exportPythonModel(name=model_name)
inverted_pendulum.importPythonModel(name=model_name)
inverted_pendulum.neuralizeModel(sample_time = 0.02)
params = {'train_batch_size':64, 'num_of_epochs':200}
inverted_pendulum.trainModel(train_dataset='data', validation_dataset='data_val', optimizer='Adam', prediction_samples=prediction_samples, step=step, training_params=params, early_stopping=earlystopping.early_stop_patience,  
                                                            early_stopping_params={'patience':early_stop_patience}, select_model=earlystopping.select_best_model, lr=1e-3)
inverted_pendulum.exportPythonModel(name=model_name)
# Out:
# =============================== Save JSON Model ================================
# Model saved in:               /home/baro/Desktop/inv_pend/rk4_models/saved_models/physics_augmented_neural_network.json
# ================================================================================
# ========================== Export Python Torch Model ===========================
# Model exported in:            /home/baro/Desktop/inv_pend/rk4_models/saved_models/physics_augmented_neural_network.py
# ================================================================================
# =============================== Load JSON Model ================================
# Model loaded from:            /home/baro/Desktop/inv_pend/rk4_models/saved_models/physics_augmented_neural_network.json
# ================================================================================
# [neuralizeModel] Closed loop on Xangle with sample in the future.
# [neuralizeModel] Closed loop on Xangular_velocity with sample in the future.
# [neuralizeModel] Closed loop on Xpos with sample in the future.
# [neuralizeModel] Closed loop on Xvelocity with sample in the future.
# ================================ nnodely Model =================================
# {'Constants': {'Constant41': {'dim': 1, 'values': [2.0]},
#                'Constant42': {'dim': 1, 'values': [2.0]},
#                'Constant43': {'dim': 1, 'values': [2.0]},
#                'Constant44': {'dim': 1, 'values': [2.0]},
#                'Constant45': {'dim': 1, 'values': [2.0]},
#                'Constant46': {'dim': 1, 'values': [2.0]},
#                'Constant47': {'dim': 1, 'values': [2.0]},
#                'Constant48': {'dim': 1, 'values': [2.0]},
#                'Constant50': {'dim': 1, 'values': [2.0]},
#                'Constant51': {'dim': 1, 'values': [2.0]},
#                'Constant52': {'dim': 1, 'values': [2.0]},
#                'Constant53': {'dim': 1, 'values': [2.0]},
#                'Constant54': {'dim': 1, 'values': [2.0]},
#                'Constant55': {'dim': 1, 'values': [2.0]},
#                'Constant56': {'dim': 1, 'values': [2.0]},
#                'Constant57': {'dim': 1, 'values': [2.0]},
#                'Constant58': {'dim': 1, 'values': [2.0]},
#                'Constant59': {'dim': 1, 'values': [2.0]},
#                'Constant60': {'dim': 1, 'values': [2.0]},
#                'Constant62': {'dim': 1, 'values': [2.0]},
#                'Constant63': {'dim': 1, 'values': [2.0]},
#                'Constant64': {'dim': 1, 'values': [2.0]},
#                'Constant65': {'dim': 1, 'values': [2.0]},
#                'Constant66': {'dim': 1, 'values': [2.0]},
#                'Constant67': {'dim': 1, 'values': [2.0]},
#                'Constant68': {'dim': 1, 'values': [2.0]},
#                'Constant69': {'dim': 1, 'values': [2.0]},
#                'Constant70': {'dim': 1, 'values': [2.0]},
#                'Constant71': {'dim': 1, 'values': [2.0]},
#                'Constant72': {'dim': 1, 'values': [2.0]},
#                'Constant73': {'dim': 1, 'values': [2.0]},
#                'Constant74': {'dim': 1, 'values': [2.0]},
#                'Constant75': {'dim': 1, 'values': [2.0]},
#                'Constant76': {'dim': 1, 'values': [2.0]},
#                'Constant77': {'dim': 1, 'values': [2.0]},
#                'Constant78': {'dim': 1, 'values': [2.0]},
#                'Constant79': {'dim': 1, 'values': [2.0]},
#                'Constant80': {'dim': 1, 'values': [2.0]},
#                'Constant81': {'dim': 1, 'values': [2.0]},
#                'Constant82': {'dim': 1, 'values': [2.0]},
#                'Constant83': {'dim': 1, 'values': [6.0]},
#                'Constant84': {'dim': 1, 'values': [2.0]},
#                'Constant85': {'dim': 1, 'values': [2.0]},
#                'Constant86': {'dim': 1, 'values': [6.0]},
#                'Constant87': {'dim': 1, 'values': [2.0]},
#                'Constant88': {'dim': 1, 'values': [2.0]},
#                'Constant89': {'dim': 1, 'values': [6.0]},
#                'Constant90': {'dim': 1, 'values': [2.0]},
#                'Constant91': {'dim': 1, 'values': [2.0]},
#                'Constant92': {'dim': 1, 'values': [6.0]},
#                'dt': {'dim': 1, 'values': [0.019999999552965164]},
#                'g': {'dim': 1, 'values': [9.8100004196167]},
#                'sigma_force': {'dim': 1, 'values': [0.0]},
#                'sigma_omega': {'dim': 1, 'values': [0.0]},
#                'sigma_theta': {'dim': 1, 'values': [0.0]},
#                'sigma_v': {'dim': 1, 'values': [0.0]},
#                'sigma_x': {'dim': 1, 'values': [0.0]}},
#  'Functions': {},
#  'Info': {'SampleTime': 0.02,
#           'nnodely_version': '1.5.2',
#           'ns': [1, 0],
#           'ntot': 1,
#           'num_parameters': 187},
#  'Inputs': {'Xangle': {'closedLoop': 'Add565',
#                        'dim': 1,
#                        'local': 1,
#                        'ns': [1, 0],
#                        'ntot': 1,
#                        'sw': [-1, 0]},
#             'Xangular_velocity': {'closedLoop': 'Add551',
#                                   'dim': 1,
#                                   'local': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Xpos': {'closedLoop': 'Add537',
#                      'dim': 1,
#                      'local': 1,
#                      'ns': [1, 0],
#                      'ntot': 1,
#                      'sw': [-1, 0]},
#             'Xvelocity': {'closedLoop': 'Add523',
#                           'dim': 1,
#                           'local': 1,
#                           'ns': [1, 0],
#                           'ntot': 1,
#                           'sw': [-1, 0]},
#             'Yangle': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yangular_velocity': {'dim': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Ypos': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yvelocity': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'action': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise1': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise2': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise3': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise4': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise5': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]}},
#  'Minimizers': {'ang_vel_error': {'A': 'SamplePart575',
#                                   'B': 'Add551',
#                                   'loss': 'mse'},
#                 'angle_error': {'A': 'SamplePart577',
#                                 'B': 'Add565',
#                                 'loss': 'mse'},
#                 'pos_error': {'A': 'SamplePart581',
#                               'B': 'Add537',
#                               'loss': 'mse'},
#                 'vel_error': {'A': 'SamplePart579',
#                               'B': 'Add523',
#                               'loss': 'mse'}},
#  'Models': 'pendulum',
#  'Outputs': {'contr_theta': 'Select570',
#              'contr_thetadot': 'Select571',
#              'contr_x': 'Select573',
#              'contr_xdot': 'Select572',
#              'est_theta': 'Add565',
#              'est_thetadot': 'Add551',
#              'est_x': 'Add537',
#              'est_xdot': 'Add523'},
#  'Parameters': {'I': {'dim': 1, 'values': [0.08596968650817871]},
#                 'PLinear29W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[0.00862917024642229,
#                                            0.005954026244580746,
#                                            0.0034692990593612194,
#                                            -0.008012236095964909,
#                                            -0.009324947372078896,
#                                            -0.0028474275022745132,
#                                            -0.009591856971383095,
#                                            -0.007630377542227507,
#                                            -0.009664718993008137,
#                                            -0.00782825704663992]]},
#                 'PLinear31W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[0.009540239349007607,
#                                            0.005351549480110407,
#                                            0.0064392248168587685,
#                                            -0.004799471702426672,
#                                            0.003084996249526739,
#                                            -0.003310707164928317,
#                                            -0.007349432446062565,
#                                            -0.006039717234671116,
#                                            -0.0003477595164440572,
#                                            0.0012962776236236095]]},
#                 'PLinear33W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[0.00233649299480021,
#                                            0.0074326638132333755,
#                                            -0.004911244381219149,
#                                            -0.0034891606774181128,
#                                            -0.006035403348505497,
#                                            -0.0020648580975830555,
#                                            0.006685217842459679,
#                                            -0.001657941029407084,
#                                            0.002153657842427492,
#                                            0.00957088265568018]]},
#                 'PLinear35W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[-0.0049531483091413975,
#                                            0.009745283983647823,
#                                            0.007102243602275848,
#                                            -0.007062169257551432,
#                                            0.0056283073499798775,
#                                            -0.005390378180891275,
#                                            0.004414922557771206,
#                                            0.006279173772782087,
#                                            -0.00758537370711565,
#                                            -0.007840566337108612]]},
#                 'PLinear37W': {'dim': [10, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[-0.0038577080704271793,
#                                            0.0029502962715923786,
#                                            -0.0019927257671952248,
#                                            -0.005561034195125103,
#                                            0.0005738583859056234,
#                                            0.0028034544084221125,
#                                            -0.005037210416048765,
#                                            0.0010835749562829733,
#                                            -0.008850771002471447,
#                                            -0.0009768689051270485],
#                                           [-0.0024999550078064203,
#                                            0.0045029581524431705,
#                                            0.0016870388062670827,
#                                            0.006177427247166634,
#                                            -0.007432155776768923,
#                                            -0.000485147291328758,
#                                            -0.004801611416041851,
#                                            -0.007377337198704481,
#                                            -0.00966364610940218,
#                                            0.004927748814225197],
#                                           [0.00323410308919847,
#                                            0.0066611263900995255,
#                                            0.002623969689011574,
#                                            0.009196612983942032,
#                                            -0.002917555859312415,
#                                            -0.008416476659476757,
#                                            -0.0009271559538319707,
#                                            0.0014648548094555736,
#                                            -0.00222536432556808,
#                                            0.004129489418119192],
#                                           [0.0007366703939624131,
#                                            -0.008859293535351753,
#                                            0.00607456685975194,
#                                            -0.008033600635826588,
#                                            0.0038675677496939898,
#                                            -0.004426576662808657,
#                                            -0.004777947440743446,
#                                            -0.000982199446298182,
#                                            -0.009982612915337086,
#                                            -0.009483972564339638],
#                                           [0.00864158384501934,
#                                            0.008242128416895866,
#                                            -0.006511523388326168,
#                                            -0.00216650846414268,
#                                            -0.0058360532857477665,
#                                            -0.0033446599263697863,
#                                            0.0054500955156981945,
#                                            -0.002501403447240591,
#                                            0.0049078622832894325,
#                                            -0.009082688950002193],
#                                           [0.00872798077762127,
#                                            0.0032998346723616123,
#                                            0.00713757099583745,
#                                            0.006752954330295324,
#                                            0.004230066668242216,
#                                            0.0012739029480144382,
#                                            -0.00496447179466486,
#                                            0.008322549983859062,
#                                            -0.007312469184398651,
#                                            0.003982589114457369],
#                                           [0.0004328021313995123,
#                                            0.0037332887295633554,
#                                            -0.005999973975121975,
#                                            0.004797106143087149,
#                                            -0.0046431333757936954,
#                                            0.007669955492019653,
#                                            -0.00013813185796607286,
#                                            -0.006943860556930304,
#                                            0.008309208787977695,
#                                            -0.009208728559315205],
#                                           [0.004004389513283968,
#                                            0.0021179530303925276,
#                                            -0.009520639665424824,
#                                            -0.0014408986316993833,
#                                            -0.006882254034280777,
#                                            0.0031735997181385756,
#                                            0.006317384075373411,
#                                            0.006088643800467253,
#                                            0.003651196835562587,
#                                            0.0044936444610357285],
#                                           [0.0033750920556485653,
#                                            0.006521283183246851,
#                                            -0.007438215892761946,
#                                            -0.0034539466723799706,
#                                            0.009188616648316383,
#                                            0.009798930957913399,
#                                            0.002856683684512973,
#                                            -0.0097341975197196,
#                                            -0.0032585503067821264,
#                                            -4.8349815187975764e-05],
#                                           [-0.008911856450140476,
#                                            -0.000315548968501389,
#                                            0.009985498152673244,
#                                            0.002759774448350072,
#                                            0.006162350997328758,
#                                            0.006114480085670948,
#                                            0.005944021046161652,
#                                            -0.0006714173941873014,
#                                            -0.003147680312395096,
#                                            0.005257792770862579]]},
#                 'PLinear39W': {'dim': [10, 4],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[0.002858562394976616,
#                                            0.0050081973895430565,
#                                            0.0070095607079565525,
#                                            -0.007027018815279007],
#                                           [-0.007900819182395935,
#                                            -0.00473769661039114,
#                                            -0.005646956618875265,
#                                            -0.0037184820976108313],
#                                           [0.006878015119582415,
#                                            -0.0001495163596700877,
#                                            0.0010510513093322515,
#                                            0.003963647875934839],
#                                           [0.002303577261045575,
#                                            -0.0013557530473917723,
#                                            0.004299320746213198,
#                                            0.008319425396621227],
#                                           [0.00536121241748333,
#                                            0.00039619876770302653,
#                                            0.009091472253203392,
#                                            -0.008780991658568382],
#                                           [-0.0016814988339319825,
#                                            0.009365090169012547,
#                                            -0.00041450184653513134,
#                                            -0.002072902163490653],
#                                           [-0.0032607652246952057,
#                                            -0.0059480187483131886,
#                                            0.005274489987641573,
#                                            0.0006020419532433152],
#                                           [0.006744254380464554,
#                                            0.00044724956387653947,
#                                            -3.8689282519044355e-05,
#                                            0.0020670436788350344],
#                                           [-0.009459995664656162,
#                                            0.009179556742310524,
#                                            -0.006985106505453587,
#                                            0.0055917054414749146],
#                                           [-0.009172145277261734,
#                                            0.009197155013680458,
#                                            -0.0024139867164194584,
#                                            -0.005545312538743019]]},
#                 'b': {'dim': 1, 'values': [0.7123878002166748]},
#                 'd': {'dim': 1, 'values': [0.08885741233825684]},
#                 'gear': {'dim': 1, 'init_values': [100.0], 'values': [100.0]},
#                 'l': {'dim': 1, 'values': [0.7918664813041687]},
#                 'm1': {'dim': 1, 'values': [0.8797435164451599]},
#                 'm2': {'dim': 1, 'values': [0.5581528544425964]}},
#  'Relations': {'Add101': ['Add', ['Sub90', 'Mul100']],
#                'Add109': ['Add', ['Add101', 'Mul108']],
#                'Add13': ['Add', ['SamplePart8', 'Mul12']],
#                'Add145': ['Add', ['Sub137', 'Mul144']],
#                'Add147': ['Add', ['Add145', 'Mul146']],
#                'Add158': ['Add', ['Add13', 'Div157']],
#                'Add163': ['Add', ['Add27', 'Div162']],
#                'Add168': ['Add', ['Add20', 'Div167']],
#                'Add177': ['Add', ['I', 'Mul175']],
#                'Add180': ['Add', ['m1', 'm2']],
#                'Add196': ['Add', ['m1', 'm2']],
#                'Add20': ['Add', ['SamplePart15', 'Mul19']],
#                'Add216': ['Add', ['m1', 'm2']],
#                'Add224': ['Add', ['Sub213', 'Mul223']],
#                'Add232': ['Add', ['Add224', 'Mul231']],
#                'Add268': ['Add', ['Sub260', 'Mul267']],
#                'Add27': ['Add', ['SamplePart22', 'Mul26']],
#                'Add270': ['Add', ['Add268', 'Mul269']],
#                'Add281': ['Add', ['Add13', 'Div280']],
#                'Add286': ['Add', ['Add27', 'Div285']],
#                'Add291': ['Add', ['Add20', 'Div290']],
#                'Add300': ['Add', ['I', 'Mul298']],
#                'Add303': ['Add', ['m1', 'm2']],
#                'Add319': ['Add', ['m1', 'm2']],
#                'Add339': ['Add', ['m1', 'm2']],
#                'Add34': ['Add', ['SamplePart29', 'Mul33']],
#                'Add347': ['Add', ['Sub336', 'Mul346']],
#                'Add355': ['Add', ['Add347', 'Mul354']],
#                'Add39': ['Add', ['Linear35', 'Linear36']],
#                'Add391': ['Add', ['Sub383', 'Mul390']],
#                'Add393': ['Add', ['Add391', 'Mul392']],
#                'Add40': ['Add', ['Add39', 'Linear37']],
#                'Add400': ['Add', ['Add13', 'Mul399']],
#                'Add403': ['Add', ['Add27', 'Mul402']],
#                'Add406': ['Add', ['Add20', 'Mul405']],
#                'Add41': ['Add', ['Add40', 'Linear38']],
#                'Add415': ['Add', ['I', 'Mul413']],
#                'Add418': ['Add', ['m1', 'm2']],
#                'Add434': ['Add', ['m1', 'm2']],
#                'Add454': ['Add', ['m1', 'm2']],
#                'Add462': ['Add', ['Sub451', 'Mul461']],
#                'Add470': ['Add', ['Add462', 'Mul469']],
#                'Add506': ['Add', ['Sub498', 'Mul505']],
#                'Add508': ['Add', ['Add506', 'Mul507']],
#                'Add512': ['Add', ['Div148', 'Mul511']],
#                'Add515': ['Add', ['Add512', 'Mul514']],
#                'Add516': ['Add', ['Add515', 'Div509']],
#                'Add521': ['Add', ['Add13', 'Div520']],
#                'Add523': ['Add', ['Add521', 'Select522']],
#                'Add526': ['Add', ['Add13', 'Mul525']],
#                'Add529': ['Add', ['Add526', 'Mul528']],
#                'Add530': ['Add', ['Add529', 'Add400']],
#                'Add535': ['Add', ['Add6', 'Div534']],
#                'Add537': ['Add', ['Add535', 'Select536']],
#                'Add54': ['Add', ['I', 'Mul52']],
#                'Add540': ['Add', ['Div116', 'Mul539']],
#                'Add543': ['Add', ['Add540', 'Mul542']],
#                'Add544': ['Add', ['Add543', 'Div477']],
#                'Add549': ['Add', ['Add20', 'Div548']],
#                'Add551': ['Add', ['Add549', 'Select550']],
#                'Add554': ['Add', ['Add20', 'Mul553']],
#                'Add557': ['Add', ['Add554', 'Mul556']],
#                'Add558': ['Add', ['Add557', 'Add406']],
#                'Add563': ['Add', ['Add27', 'Div562']],
#                'Add565': ['Add', ['Add563', 'Select564']],
#                'Add57': ['Add', ['m1', 'm2']],
#                'Add6': ['Add', ['SamplePart1', 'Mul5']],
#                'Add73': ['Add', ['m1', 'm2']],
#                'Add93': ['Add', ['m1', 'm2']],
#                'Cos170': ['Cos', ['Add163']],
#                'Cos293': ['Cos', ['Add286']],
#                'Cos408': ['Cos', ['Add403']],
#                'Cos47': ['Cos', ['Add27']],
#                'Div116': ['Div', ['Sub115', 'Sub65']],
#                'Div148': ['Div', ['Add147', 'Sub65']],
#                'Div157': ['Div', ['Mul155', 'Constant50']],
#                'Div162': ['Div', ['Mul160', 'Constant51']],
#                'Div167': ['Div', ['Mul165', 'Constant52']],
#                'Div239': ['Div', ['Sub238', 'Sub188']],
#                'Div271': ['Div', ['Add270', 'Sub188']],
#                'Div280': ['Div', ['Mul278', 'Constant62']],
#                'Div285': ['Div', ['Mul283', 'Constant63']],
#                'Div290': ['Div', ['Mul288', 'Constant64']],
#                'Div362': ['Div', ['Sub361', 'Sub311']],
#                'Div394': ['Div', ['Add393', 'Sub311']],
#                'Div477': ['Div', ['Sub476', 'Sub426']],
#                'Div509': ['Div', ['Add508', 'Sub426']],
#                'Div520': ['Div', ['Mul518', 'Constant83']],
#                'Div534': ['Div', ['Mul532', 'Constant86']],
#                'Div548': ['Div', ['Mul546', 'Constant89']],
#                'Div562': ['Div', ['Mul560', 'Constant92']],
#                'Linear35': ['Linear', ['Add27'], 'PLinear29W', None, 0.0],
#                'Linear36': ['Linear', ['Add13'], 'PLinear31W', None, 0.0],
#                'Linear37': ['Linear', ['Add20'], 'PLinear33W', None, 0.0],
#                'Linear38': ['Linear', ['Add34'], 'PLinear35W', None, 0.0],
#                'Linear43': ['Linear', ['Tanh42'], 'PLinear37W', None, 0.0],
#                'Linear45': ['Linear', ['Tanh44'], 'PLinear39W', None, 0],
#                'Mul100': ['Mul', ['Mul99', 'Sin46']],
#                'Mul104': ['Mul', ['m2', 'l']],
#                'Mul106': ['Mul', ['Mul104', 'b']],
#                'Mul107': ['Mul', ['Mul106', 'Add13']],
#                'Mul108': ['Mul', ['Mul107', 'Cos47']],
#                'Mul112': ['Mul', ['m2', 'l']],
#                'Mul113': ['Mul', ['Mul112', 'Cos47']],
#                'Mul114': ['Mul', ['Mul113', 'Mul67']],
#                'Mul118': ['Mul', ['Add54', 'm2']],
#                'Mul12': ['Mul', ['SamplePart10', 'sigma_v']],
#                'Mul120': ['Mul', ['Mul118', 'l']],
#                'Mul123': ['Mul', ['Mul120', 'Pow122']],
#                'Mul124': ['Mul', ['Mul123', 'Sin46']],
#                'Mul132': ['Mul', ['Pow128', 'Pow131']],
#                'Mul134': ['Mul', ['Mul132', 'g']],
#                'Mul135': ['Mul', ['Mul134', 'Sin46']],
#                'Mul136': ['Mul', ['Mul135', 'Cos47']],
#                'Mul140': ['Mul', ['m2', 'l']],
#                'Mul142': ['Mul', ['Mul140', 'd']],
#                'Mul143': ['Mul', ['Mul142', 'Add20']],
#                'Mul144': ['Mul', ['Mul143', 'Cos47']],
#                'Mul146': ['Mul', ['Mul67', 'Add54']],
#                'Mul155': ['Mul', ['Div148', 'dt']],
#                'Mul160': ['Mul', ['Add20', 'dt']],
#                'Mul165': ['Mul', ['Div116', 'dt']],
#                'Mul175': ['Mul', ['m2', 'Pow173']],
#                'Mul181': ['Mul', ['Add180', 'Add177']],
#                'Mul184': ['Mul', ['m2', 'l']],
#                'Mul185': ['Mul', ['Mul184', 'Cos170']],
#                'Mul19': ['Mul', ['SamplePart17', 'sigma_omega']],
#                'Mul190': ['Mul', ['gear', 'Add34']],
#                'Mul192': ['Mul', ['Add177', 'b']],
#                'Mul193': ['Mul', ['Mul192', 'Add158']],
#                'Mul198': ['Mul', ['Add196', 'd']],
#                'Mul199': ['Mul', ['Mul198', 'Add168']],
#                'Mul207': ['Mul', ['Neg203', 'Pow206']],
#                'Mul210': ['Mul', ['Mul207', 'Pow209']],
#                'Mul211': ['Mul', ['Mul210', 'Sin169']],
#                'Mul212': ['Mul', ['Mul211', 'Cos170']],
#                'Mul218': ['Mul', ['Add216', 'm2']],
#                'Mul220': ['Mul', ['Mul218', 'g']],
#                'Mul222': ['Mul', ['Mul220', 'l']],
#                'Mul223': ['Mul', ['Mul222', 'Sin169']],
#                'Mul227': ['Mul', ['m2', 'l']],
#                'Mul229': ['Mul', ['Mul227', 'b']],
#                'Mul230': ['Mul', ['Mul229', 'Add158']],
#                'Mul231': ['Mul', ['Mul230', 'Cos170']],
#                'Mul235': ['Mul', ['m2', 'l']],
#                'Mul236': ['Mul', ['Mul235', 'Cos170']],
#                'Mul237': ['Mul', ['Mul236', 'Mul190']],
#                'Mul241': ['Mul', ['Add177', 'm2']],
#                'Mul243': ['Mul', ['Mul241', 'l']],
#                'Mul246': ['Mul', ['Mul243', 'Pow245']],
#                'Mul247': ['Mul', ['Mul246', 'Sin169']],
#                'Mul255': ['Mul', ['Pow251', 'Pow254']],
#                'Mul257': ['Mul', ['Mul255', 'g']],
#                'Mul258': ['Mul', ['Mul257', 'Sin169']],
#                'Mul259': ['Mul', ['Mul258', 'Cos170']],
#                'Mul26': ['Mul', ['SamplePart24', 'sigma_theta']],
#                'Mul263': ['Mul', ['m2', 'l']],
#                'Mul265': ['Mul', ['Mul263', 'd']],
#                'Mul266': ['Mul', ['Mul265', 'Add168']],
#                'Mul267': ['Mul', ['Mul266', 'Cos170']],
#                'Mul269': ['Mul', ['Mul190', 'Add177']],
#                'Mul278': ['Mul', ['Div271', 'dt']],
#                'Mul283': ['Mul', ['Add168', 'dt']],
#                'Mul288': ['Mul', ['Div239', 'dt']],
#                'Mul298': ['Mul', ['m2', 'Pow296']],
#                'Mul304': ['Mul', ['Add303', 'Add300']],
#                'Mul307': ['Mul', ['m2', 'l']],
#                'Mul308': ['Mul', ['Mul307', 'Cos293']],
#                'Mul313': ['Mul', ['gear', 'Add34']],
#                'Mul315': ['Mul', ['Add300', 'b']],
#                'Mul316': ['Mul', ['Mul315', 'Add281']],
#                'Mul321': ['Mul', ['Add319', 'd']],
#                'Mul322': ['Mul', ['Mul321', 'Add291']],
#                'Mul33': ['Mul', ['SamplePart31', 'sigma_force']],
#                'Mul330': ['Mul', ['Neg326', 'Pow329']],
#                'Mul333': ['Mul', ['Mul330', 'Pow332']],
#                'Mul334': ['Mul', ['Mul333', 'Sin292']],
#                'Mul335': ['Mul', ['Mul334', 'Cos293']],
#                'Mul341': ['Mul', ['Add339', 'm2']],
#                'Mul343': ['Mul', ['Mul341', 'g']],
#                'Mul345': ['Mul', ['Mul343', 'l']],
#                'Mul346': ['Mul', ['Mul345', 'Sin292']],
#                'Mul350': ['Mul', ['m2', 'l']],
#                'Mul352': ['Mul', ['Mul350', 'b']],
#                'Mul353': ['Mul', ['Mul352', 'Add281']],
#                'Mul354': ['Mul', ['Mul353', 'Cos293']],
#                'Mul358': ['Mul', ['m2', 'l']],
#                'Mul359': ['Mul', ['Mul358', 'Cos293']],
#                'Mul360': ['Mul', ['Mul359', 'Mul313']],
#                'Mul364': ['Mul', ['Add300', 'm2']],
#                'Mul366': ['Mul', ['Mul364', 'l']],
#                'Mul369': ['Mul', ['Mul366', 'Pow368']],
#                'Mul370': ['Mul', ['Mul369', 'Sin292']],
#                'Mul378': ['Mul', ['Pow374', 'Pow377']],
#                'Mul380': ['Mul', ['Mul378', 'g']],
#                'Mul381': ['Mul', ['Mul380', 'Sin292']],
#                'Mul382': ['Mul', ['Mul381', 'Cos293']],
#                'Mul386': ['Mul', ['m2', 'l']],
#                'Mul388': ['Mul', ['Mul386', 'd']],
#                'Mul389': ['Mul', ['Mul388', 'Add291']],
#                'Mul390': ['Mul', ['Mul389', 'Cos293']],
#                'Mul392': ['Mul', ['Mul313', 'Add300']],
#                'Mul399': ['Mul', ['Div394', 'dt']],
#                'Mul402': ['Mul', ['Add291', 'dt']],
#                'Mul405': ['Mul', ['Div362', 'dt']],
#                'Mul413': ['Mul', ['m2', 'Pow411']],
#                'Mul419': ['Mul', ['Add418', 'Add415']],
#                'Mul422': ['Mul', ['m2', 'l']],
#                'Mul423': ['Mul', ['Mul422', 'Cos408']],
#                'Mul428': ['Mul', ['gear', 'Add34']],
#                'Mul430': ['Mul', ['Add415', 'b']],
#                'Mul431': ['Mul', ['Mul430', 'Add400']],
#                'Mul436': ['Mul', ['Add434', 'd']],
#                'Mul437': ['Mul', ['Mul436', 'Add406']],
#                'Mul445': ['Mul', ['Neg441', 'Pow444']],
#                'Mul448': ['Mul', ['Mul445', 'Pow447']],
#                'Mul449': ['Mul', ['Mul448', 'Sin407']],
#                'Mul450': ['Mul', ['Mul449', 'Cos408']],
#                'Mul456': ['Mul', ['Add454', 'm2']],
#                'Mul458': ['Mul', ['Mul456', 'g']],
#                'Mul460': ['Mul', ['Mul458', 'l']],
#                'Mul461': ['Mul', ['Mul460', 'Sin407']],
#                'Mul465': ['Mul', ['m2', 'l']],
#                'Mul467': ['Mul', ['Mul465', 'b']],
#                'Mul468': ['Mul', ['Mul467', 'Add400']],
#                'Mul469': ['Mul', ['Mul468', 'Cos408']],
#                'Mul473': ['Mul', ['m2', 'l']],
#                'Mul474': ['Mul', ['Mul473', 'Cos408']],
#                'Mul475': ['Mul', ['Mul474', 'Mul428']],
#                'Mul479': ['Mul', ['Add415', 'm2']],
#                'Mul481': ['Mul', ['Mul479', 'l']],
#                'Mul484': ['Mul', ['Mul481', 'Pow483']],
#                'Mul485': ['Mul', ['Mul484', 'Sin407']],
#                'Mul493': ['Mul', ['Pow489', 'Pow492']],
#                'Mul495': ['Mul', ['Mul493', 'g']],
#                'Mul496': ['Mul', ['Mul495', 'Sin407']],
#                'Mul497': ['Mul', ['Mul496', 'Cos408']],
#                'Mul5': ['Mul', ['SamplePart3', 'sigma_x']],
#                'Mul501': ['Mul', ['m2', 'l']],
#                'Mul503': ['Mul', ['Mul501', 'd']],
#                'Mul504': ['Mul', ['Mul503', 'Add406']],
#                'Mul505': ['Mul', ['Mul504', 'Cos408']],
#                'Mul507': ['Mul', ['Mul428', 'Add415']],
#                'Mul511': ['Mul', ['Constant81', 'Div271']],
#                'Mul514': ['Mul', ['Constant82', 'Div394']],
#                'Mul518': ['Mul', ['Add516', 'dt']],
#                'Mul52': ['Mul', ['m2', 'Pow50']],
#                'Mul525': ['Mul', ['Constant84', 'Add158']],
#                'Mul528': ['Mul', ['Constant85', 'Add281']],
#                'Mul532': ['Mul', ['Add530', 'dt']],
#                'Mul539': ['Mul', ['Constant87', 'Div239']],
#                'Mul542': ['Mul', ['Constant88', 'Div362']],
#                'Mul546': ['Mul', ['Add544', 'dt']],
#                'Mul553': ['Mul', ['Constant90', 'Add168']],
#                'Mul556': ['Mul', ['Constant91', 'Add291']],
#                'Mul560': ['Mul', ['Add558', 'dt']],
#                'Mul58': ['Mul', ['Add57', 'Add54']],
#                'Mul61': ['Mul', ['m2', 'l']],
#                'Mul62': ['Mul', ['Mul61', 'Cos47']],
#                'Mul67': ['Mul', ['gear', 'Add34']],
#                'Mul69': ['Mul', ['Add54', 'b']],
#                'Mul70': ['Mul', ['Mul69', 'Add13']],
#                'Mul75': ['Mul', ['Add73', 'd']],
#                'Mul76': ['Mul', ['Mul75', 'Add20']],
#                'Mul84': ['Mul', ['Neg80', 'Pow83']],
#                'Mul87': ['Mul', ['Mul84', 'Pow86']],
#                'Mul88': ['Mul', ['Mul87', 'Sin46']],
#                'Mul89': ['Mul', ['Mul88', 'Cos47']],
#                'Mul95': ['Mul', ['Add93', 'm2']],
#                'Mul97': ['Mul', ['Mul95', 'g']],
#                'Mul99': ['Mul', ['Mul97', 'l']],
#                'Neg203': ['Neg', ['Pow202']],
#                'Neg326': ['Neg', ['Pow325']],
#                'Neg441': ['Neg', ['Pow440']],
#                'Neg80': ['Neg', ['Pow79']],
#                'Pow122': ['Pow', ['Add20', 'Constant46']],
#                'Pow128': ['Pow', ['m2', 'Constant47']],
#                'Pow131': ['Pow', ['l', 'Constant48']],
#                'Pow173': ['Pow', ['l', 'Constant53']],
#                'Pow187': ['Pow', ['Mul185', 'Constant54']],
#                'Pow202': ['Pow', ['m2', 'Constant55']],
#                'Pow206': ['Pow', ['l', 'Constant56']],
#                'Pow209': ['Pow', ['Add168', 'Constant57']],
#                'Pow245': ['Pow', ['Add168', 'Constant58']],
#                'Pow251': ['Pow', ['m2', 'Constant59']],
#                'Pow254': ['Pow', ['l', 'Constant60']],
#                'Pow296': ['Pow', ['l', 'Constant65']],
#                'Pow310': ['Pow', ['Mul308', 'Constant66']],
#                'Pow325': ['Pow', ['m2', 'Constant67']],
#                'Pow329': ['Pow', ['l', 'Constant68']],
#                'Pow332': ['Pow', ['Add291', 'Constant69']],
#                'Pow368': ['Pow', ['Add291', 'Constant70']],
#                'Pow374': ['Pow', ['m2', 'Constant71']],
#                'Pow377': ['Pow', ['l', 'Constant72']],
#                'Pow411': ['Pow', ['l', 'Constant73']],
#                'Pow425': ['Pow', ['Mul423', 'Constant74']],
#                'Pow440': ['Pow', ['m2', 'Constant75']],
#                'Pow444': ['Pow', ['l', 'Constant76']],
#                'Pow447': ['Pow', ['Add406', 'Constant77']],
#                'Pow483': ['Pow', ['Add406', 'Constant78']],
#                'Pow489': ['Pow', ['m2', 'Constant79']],
#                'Pow492': ['Pow', ['l', 'Constant80']],
#                'Pow50': ['Pow', ['l', 'Constant41']],
#                'Pow64': ['Pow', ['Mul62', 'Constant42']],
#                'Pow79': ['Pow', ['m2', 'Constant43']],
#                'Pow83': ['Pow', ['l', 'Constant44']],
#                'Pow86': ['Pow', ['Add20', 'Constant45']],
#                'SamplePart1': ['SamplePart', ['Xpos'], -1, [-1, 0]],
#                'SamplePart10': ['SamplePart', ['noise1'], -1, [-1, 0]],
#                'SamplePart15': ['SamplePart',
#                                 ['Xangular_velocity'],
#                                 -1,
#                                 [-1, 0]],
#                'SamplePart17': ['SamplePart', ['noise3'], -1, [-1, 0]],
#                'SamplePart22': ['SamplePart', ['Xangle'], -1, [-1, 0]],
#                'SamplePart24': ['SamplePart', ['noise2'], -1, [-1, 0]],
#                'SamplePart29': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart3': ['SamplePart', ['noise4'], -1, [-1, 0]],
#                'SamplePart31': ['SamplePart', ['noise5'], -1, [-1, 0]],
#                'SamplePart575': ['SamplePart',
#                                  ['Yangular_velocity'],
#                                  -1,
#                                  [-1, 0]],
#                'SamplePart577': ['SamplePart', ['Yangle'], -1, [-1, 0]],
#                'SamplePart579': ['SamplePart', ['Yvelocity'], -1, [-1, 0]],
#                'SamplePart581': ['SamplePart', ['Ypos'], -1, [-1, 0]],
#                'SamplePart8': ['SamplePart', ['Xvelocity'], -1, [-1, 0]],
#                'Select522': ['Select', ['Linear45'], 4, 0],
#                'Select536': ['Select', ['Linear45'], 4, 1],
#                'Select550': ['Select', ['Linear45'], 4, 2],
#                'Select564': ['Select', ['Linear45'], 4, 3],
#                'Select570': ['Select', ['Linear45'], 4, 3],
#                'Select571': ['Select', ['Linear45'], 4, 2],
#                'Select572': ['Select', ['Linear45'], 4, 1],
#                'Select573': ['Select', ['Linear45'], 4, 0],
#                'Sin169': ['Sin', ['Add163']],
#                'Sin292': ['Sin', ['Add286']],
#                'Sin407': ['Sin', ['Add403']],
#                'Sin46': ['Sin', ['Add27']],
#                'Sub115': ['Sub', ['Add109', 'Mul114']],
#                'Sub125': ['Sub', ['Mul124', 'Mul70']],
#                'Sub137': ['Sub', ['Sub125', 'Mul136']],
#                'Sub188': ['Sub', ['Mul181', 'Pow187']],
#                'Sub213': ['Sub', ['Mul212', 'Mul199']],
#                'Sub238': ['Sub', ['Add232', 'Mul237']],
#                'Sub248': ['Sub', ['Mul247', 'Mul193']],
#                'Sub260': ['Sub', ['Sub248', 'Mul259']],
#                'Sub311': ['Sub', ['Mul304', 'Pow310']],
#                'Sub336': ['Sub', ['Mul335', 'Mul322']],
#                'Sub361': ['Sub', ['Add355', 'Mul360']],
#                'Sub371': ['Sub', ['Mul370', 'Mul316']],
#                'Sub383': ['Sub', ['Sub371', 'Mul382']],
#                'Sub426': ['Sub', ['Mul419', 'Pow425']],
#                'Sub451': ['Sub', ['Mul450', 'Mul437']],
#                'Sub476': ['Sub', ['Add470', 'Mul475']],
#                'Sub486': ['Sub', ['Mul485', 'Mul431']],
#                'Sub498': ['Sub', ['Sub486', 'Mul497']],
#                'Sub65': ['Sub', ['Mul58', 'Pow64']],
#                'Sub90': ['Sub', ['Mul89', 'Mul76']],
#                'Tanh42': ['Tanh', ['Add41']],
#                'Tanh44': ['Tanh', ['Linear43']]}}
# ================================================================================
# ...
#                'Mul89': ['Mul', ['Mul88', 'Cos47']],
#                'Mul95': ['Mul', ['Add93', 'm2']],
#                'Mul97': ['Mul', ['Mul95', 'g']],
#                'Mul99': ['Mul', ['Mul97', 'l']],
#                'Neg203': ['Neg', ['Pow202']],
#                'Neg326': ['Neg', ['Pow325']],
#                'Neg441': ['Neg', ['Pow440']],
#                'Neg80': ['Neg', ['Pow79']],
#                'Pow122': ['Pow', ['Add20', 'Constant46']],
#                'Pow128': ['Pow', ['m2', 'Constant47']],
#                'Pow131': ['Pow', ['l', 'Constant48']],
#                'Pow173': ['Pow', ['l', 'Constant53']],
#                'Pow187': ['Pow', ['Mul185', 'Constant54']],
#                'Pow202': ['Pow', ['m2', 'Constant55']],
#                'Pow206': ['Pow', ['l', 'Constant56']],
#                'Pow209': ['Pow', ['Add168', 'Constant57']],
#                'Pow245': ['Pow', ['Add168', 'Constant58']],
#                'Pow251': ['Pow', ['m2', 'Constant59']],
#                'Pow254': ['Pow', ['l', 'Constant60']],
#                'Pow296': ['Pow', ['l', 'Constant65']],
#                'Pow310': ['Pow', ['Mul308', 'Constant66']],
#                'Pow325': ['Pow', ['m2', 'Constant67']],
#                'Pow329': ['Pow', ['l', 'Constant68']],
#                'Pow332': ['Pow', ['Add291', 'Constant69']],
#                'Pow368': ['Pow', ['Add291', 'Constant70']],
#                'Pow374': ['Pow', ['m2', 'Constant71']],
#                'Pow377': ['Pow', ['l', 'Constant72']],
#                'Pow411': ['Pow', ['l', 'Constant73']],
#                'Pow425': ['Pow', ['Mul423', 'Constant74']],
#                'Pow440': ['Pow', ['m2', 'Constant75']],
#                'Pow444': ['Pow', ['l', 'Constant76']],
#                'Pow447': ['Pow', ['Add406', 'Constant77']],
#                'Pow483': ['Pow', ['Add406', 'Constant78']],
#                'Pow489': ['Pow', ['m2', 'Constant79']],
#                'Pow492': ['Pow', ['l', 'Constant80']],
#                'Pow50': ['Pow', ['l', 'Constant41']],
#                'Pow64': ['Pow', ['Mul62', 'Constant42']],
#                'Pow79': ['Pow', ['m2', 'Constant43']],
#                'Pow83': ['Pow', ['l', 'Constant44']],
#                'Pow86': ['Pow', ['Add20', 'Constant45']],
#                'SamplePart1': ['SamplePart', ['Xpos'], -1, [-1, 0]],
#                'SamplePart10': ['SamplePart', ['noise1'], -1, [-1, 0]],
#                'SamplePart15': ['SamplePart',
#                                 ['Xangular_velocity'],
#                                 -1,
#                                 [-1, 0]],
#                'SamplePart17': ['SamplePart', ['noise3'], -1, [-1, 0]],
#                'SamplePart22': ['SamplePart', ['Xangle'], -1, [-1, 0]],
#                'SamplePart24': ['SamplePart', ['noise2'], -1, [-1, 0]],
#                'SamplePart29': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart3': ['SamplePart', ['noise4'], -1, [-1, 0]],
#                'SamplePart31': ['SamplePart', ['noise5'], -1, [-1, 0]],
#                'SamplePart575': ['SamplePart',
#                                  ['Yangular_velocity'],
#                                  -1,
#                                  [-1, 0]],
#                'SamplePart577': ['SamplePart', ['Yangle'], -1, [-1, 0]],
#                'SamplePart579': ['SamplePart', ['Yvelocity'], -1, [-1, 0]],
#                'SamplePart581': ['SamplePart', ['Ypos'], -1, [-1, 0]],
#                'SamplePart8': ['SamplePart', ['Xvelocity'], -1, [-1, 0]],
#                'Select522': ['Select', ['Linear45'], 4, 0],
#                'Select536': ['Select', ['Linear45'], 4, 1],
#                'Select550': ['Select', ['Linear45'], 4, 2],
#                'Select564': ['Select', ['Linear45'], 4, 3],
#                'Select570': ['Select', ['Linear45'], 4, 3],
#                'Select571': ['Select', ['Linear45'], 4, 2],
#                'Select572': ['Select', ['Linear45'], 4, 1],
#                'Select573': ['Select', ['Linear45'], 4, 0],
#                'Sin169': ['Sin', ['Add163']],
#                'Sin292': ['Sin', ['Add286']],
#                'Sin407': ['Sin', ['Add403']],
#                'Sin46': ['Sin', ['Add27']],
#                'Sub115': ['Sub', ['Add109', 'Mul114']],
#                'Sub125': ['Sub', ['Mul124', 'Mul70']],
#                'Sub137': ['Sub', ['Sub125', 'Mul136']],
#                'Sub188': ['Sub', ['Mul181', 'Pow187']],
#                'Sub213': ['Sub', ['Mul212', 'Mul199']],
#                'Sub238': ['Sub', ['Add232', 'Mul237']],
#                'Sub248': ['Sub', ['Mul247', 'Mul193']],
#                'Sub260': ['Sub', ['Sub248', 'Mul259']],
#                'Sub311': ['Sub', ['Mul304', 'Pow310']],
#                'Sub336': ['Sub', ['Mul335', 'Mul322']],
#                'Sub361': ['Sub', ['Add355', 'Mul360']],
#                'Sub371': ['Sub', ['Mul370', 'Mul316']],
#                'Sub383': ['Sub', ['Sub371', 'Mul382']],
#                'Sub426': ['Sub', ['Mul419', 'Pow425']],
#                'Sub451': ['Sub', ['Mul450', 'Mul437']],
#                'Sub476': ['Sub', ['Add470', 'Mul475']],
#                'Sub486': ['Sub', ['Mul485', 'Mul431']],
#                'Sub498': ['Sub', ['Sub486', 'Mul497']],
#                'Sub65': ['Sub', ['Mul58', 'Pow64']],
#                'Sub90': ['Sub', ['Mul89', 'Mul76']],
#                'Tanh42': ['Tanh', ['Add41']],
#                'Tanh44': ['Tanh', ['Linear43']]}}
# ================================================================================
# ======================== nnodely Model Train Parameters ========================
# models:                       ['pendulum']
# num of epochs:                200
# update per epochs:            351
# └>len(train_indexes)//(batch_size+step)
# shuffle data:                 True
# early stopping:               early_stop_patience
# early stopping params:        {'patience': 10}
# prediction samples:           0
# step:                         0
# closed loop:                  {}
# connect:                      {}
# train dataset:                data
# 	- batch size:                64
# 	- num of samples:            22500
# 	- num of first samples:      22500
# validation dataset:           data_val
# 	- batch size:                128
# 	- num of samples:            15000
# 	- num of first samples:      15000
# minimizers:                   {'ang_vel_error': {'A': 'SamplePart575',
#                                                  'B': 'Add551',
#                                                  'loss': 'mse'},
#                                'angle_error': {'A': 'SamplePart577',
#                                                'B': 'Add565',
#                                                'loss': 'mse'},
#                                'pos_error': {'A': 'SamplePart581',
#                                              'B': 'Add537',
#                                              'loss': 'mse'},
#                                'vel_error': {'A': 'SamplePart579',
#                                              'B': 'Add523',
#                                              'loss': 'mse'}}
# optimizer:                    Adam
# optimizer defaults:           {'lr': 0.001}
# optimizer params:             [{'params': 'I'},
#                                {'params': 'PLinear29W'},
#                                {'params': 'PLinear31W'},
#                                {'params': 'PLinear33W'},
#                                {'params': 'PLinear35W'},
#                                {'params': 'PLinear37W'},
#                                {'params': 'PLinear39W'},
#                                {'params': 'b'},
#                                {'params': 'd'},
#                                {'params': 'gear'},
#                                {'params': 'l'},
#                                {'params': 'm1'},
#                                {'params': 'm2'}]
# ================================================================================
# =============================================== nnodely Training ===============================================
# |  Epoch   |   ang_vel_error   |    angle_error    |     pos_error     |     vel_error     |       Total       |
# |          |        Loss       |        Loss       |        Loss       |        Loss       |        Loss       |
# |          |  train  |   val   |  train  |   val   |  train  |   val   |  train  |   val   |  train  |   val   |
# |--------------------------------------------------------------------------------------------------------------|
# |  2/200   |5.702e-02|4.731e-02|6.136e-06|4.754e-06|1.295e-06|1.045e-06|5.930e-03|3.284e-03|1.574e-02|1.265e-02|
# |  4/200   |4.244e-02|4.104e-02| 4.36e-06|4.804e-06|2.247e-07|1.209e-07|1.759e-03|1.179e-03|1.105e-02|1.056e-02|
# |  6/200   |3.891e-02|3.823e-02|4.026e-06|3.891e-06|1.659e-07| 1.16e-07|9.177e-04|5.966e-04|9.959e-03|9.707e-03|
# |  8/200   |3.678e-02|3.576e-02|3.886e-06|3.688e-06|8.341e-08|3.788e-08|5.249e-04|3.709e-04|9.327e-03|9.033e-03|
# |  10/200  |3.409e-02|3.287e-02|3.576e-06|3.485e-06|4.622e-08|3.518e-08|3.251e-04|2.292e-04|8.606e-03|8.276e-03|
# |  12/200  |3.089e-02|2.952e-02|3.175e-06|3.072e-06|3.329e-08|2.665e-08|2.171e-04| 1.33e-04|7.776e-03|7.414e-03|
# |  14/200  |2.734e-02|2.581e-02|2.958e-06|2.989e-06| 3.8e-08 |2.317e-08|1.652e-04|1.587e-04|6.876e-03|6.493e-03|
# |  16/200  |2.349e-02| 2.17e-02|2.453e-06|2.437e-06|3.166e-08|9.286e-08|1.434e-04|1.264e-04|5.909e-03|5.456e-03|
# |  18/200  |1.965e-02|1.809e-02| 2.07e-06|1.825e-06|2.715e-08|1.746e-08|1.545e-04|1.112e-04|4.952e-03|4.551e-03|
# |  20/200  |1.605e-02|1.442e-02|1.702e-06|1.455e-06|2.357e-08|2.743e-08|1.524e-04|1.514e-04|4.050e-03|3.643e-03|
# |  22/200  |1.273e-02|1.142e-02|1.403e-06|1.282e-06|2.289e-08|3.019e-08|1.381e-04|1.211e-04|3.217e-03|2.886e-03|
# |  24/200  |7.387e-03|4.376e-03|8.098e-07|4.525e-07|9.400e-08|1.101e-07|7.346e-04|1.099e-03|2.031e-03|1.369e-03|
# |  26/200  |8.250e-04|9.019e-04|1.003e-07|1.144e-07|6.208e-09|5.100e-09|7.933e-05|5.446e-05|2.261e-04|2.391e-04|
# |  28/200  |5.989e-04|5.764e-04|7.993e-08|9.993e-08|4.901e-09|4.016e-09|3.908e-05| 4.19e-05|1.595e-04|1.546e-04|
# |  30/200  | 4.7e-04 |4.536e-04|6.246e-08|8.411e-08|5.362e-09|4.636e-09|3.761e-05|3.608e-05|1.269e-04|1.224e-04|
# |  32/200  |3.827e-04|3.584e-04|5.588e-08|5.059e-08|7.509e-09|6.062e-09|4.805e-05|4.132e-05|1.077e-04|9.994e-05|
# |  34/200  |3.187e-04|3.162e-04|4.543e-08|3.353e-08|9.337e-09| 1.4e-08 |5.409e-05|5.216e-05|9.321e-05|9.210e-05|
# |  36/200  |2.634e-04|2.668e-04|3.659e-08|3.206e-08|1.218e-08|5.948e-09|6.084e-05|5.143e-05|8.107e-05|7.956e-05|
# |  38/200  | 2.34e-04|2.248e-04| 4.15e-08| 2.59e-08|1.067e-08|1.803e-08|6.327e-05|5.414e-05|7.432e-05|6.974e-05|
# |  40/200  |2.007e-04|2.057e-04|3.511e-08|4.968e-08|1.179e-08|8.466e-09|5.931e-05|5.384e-05|6.501e-05| 6.49e-05|
# |  42/200  |1.694e-04|1.717e-04|3.054e-08|3.283e-08|1.194e-08|5.521e-09|5.702e-05|5.277e-05|5.662e-05|5.613e-05|
# |  44/200  |1.423e-04|1.327e-04|2.681e-08|1.860e-08|9.139e-09|1.518e-08|5.008e-05|5.083e-05|4.809e-05|4.588e-05|
# |  46/200  |1.190e-04|1.223e-04|2.335e-08|2.695e-08|7.057e-09|3.919e-09|4.221e-05|3.651e-05|4.032e-05|3.971e-05|
# |  48/200  |9.782e-05|8.565e-05|2.499e-08|2.601e-08|6.899e-09|7.708e-09|3.712e-05|3.340e-05|3.374e-05|2.977e-05|
# |  50/200  |7.874e-05|7.535e-05|1.738e-08|1.478e-08|5.111e-09|1.170e-08|2.960e-05| 2.78e-05|2.709e-05|2.579e-05|
# |  52/200  |6.325e-05|6.411e-05|1.136e-08|8.647e-09|5.394e-09|4.229e-09|2.604e-05|2.809e-05|2.232e-05|2.305e-05|
# |  54/200  |5.111e-05|4.930e-05|9.201e-09|9.891e-09|3.821e-09|2.576e-09|2.201e-05|2.111e-05|1.828e-05|1.761e-05|
# |  56/200  |4.151e-05|3.807e-05|7.931e-09|8.966e-09|3.417e-09|1.985e-09|1.808e-05|1.626e-05| 1.49e-05|1.358e-05|
# |  58/200  |3.397e-05|3.193e-05|6.263e-09|6.765e-09| 2.93e-09|2.717e-09|1.465e-05|1.302e-05|1.216e-05|1.124e-05|
# |  60/200  |2.715e-05|2.451e-05|5.308e-09|2.596e-09|2.402e-09|3.004e-09|1.238e-05| 1.36e-05|9.887e-06|9.529e-06|
# |  62/200  |2.216e-05|2.024e-05|4.224e-09|6.106e-09|2.234e-09|3.155e-09|9.782e-06|7.804e-06|7.986e-06|7.012e-06|
# |  64/200  |1.683e-05|1.576e-05|3.979e-09|5.009e-09|1.607e-09|1.474e-09|8.069e-06|8.432e-06|6.225e-06|6.051e-06|
# |  66/200  |1.351e-05|1.483e-05|2.914e-09|2.289e-09|1.508e-09|1.354e-09|6.309e-06|5.272e-06|4.955e-06|5.026e-06|
# |  68/200  |1.041e-05|1.216e-05| 2.35e-09|2.315e-09|1.570e-09|6.492e-10|5.119e-06|4.948e-06|3.883e-06|4.277e-06|
# |  70/200  |8.571e-06|7.259e-06|2.647e-09| 1.99e-09|1.056e-09|4.865e-10|3.993e-06|3.367e-06|3.142e-06|2.657e-06|
# |  72/200  |6.307e-06|6.006e-06|1.799e-09|3.082e-09|1.208e-09|5.195e-10|3.074e-06|3.066e-06|2.346e-06|2.269e-06|
# |  74/200  |5.207e-06|4.303e-06|1.732e-09|1.927e-09|1.289e-09|6.901e-09|2.235e-06|2.231e-06|1.861e-06|1.636e-06|
# |  76/200  |4.188e-06|3.535e-06|2.165e-09|5.729e-10|8.264e-10| 2.38e-09|1.805e-06|1.556e-06|1.499e-06|1.273e-06|
# |  78/200  |3.198e-06|2.727e-06|1.802e-09|3.094e-10|5.909e-10|3.154e-10|1.356e-06|1.711e-06|1.139e-06| 1.11e-06|
# |  80/200  |2.718e-06|3.084e-06|1.324e-09|7.955e-10|7.883e-10|1.073e-09|1.004e-06|7.736e-07|9.311e-07|9.648e-07|
# |  82/200  |2.103e-06| 2.7e-06 |1.149e-09|4.377e-10|4.298e-10|5.910e-10|8.109e-07|7.115e-07|7.289e-07|8.530e-07|
# |  84/200  |1.833e-06|1.694e-06|1.325e-09|5.247e-10| 7.66e-10| 2.01e-10|5.367e-07|7.877e-07| 5.93e-07|6.206e-07|
# |  86/200  |1.577e-06|1.296e-06|1.436e-09|2.107e-10|4.795e-10|2.384e-10|4.140e-07|3.422e-07|4.981e-07|4.098e-07|
# |  88/200  |1.377e-06|1.702e-06|7.512e-10|2.811e-09|4.604e-10|7.014e-11|2.989e-07|3.115e-07|4.194e-07|5.041e-07|
# |  90/200  |1.246e-06|1.201e-06|8.269e-10|2.039e-09|4.295e-10|1.044e-10|2.511e-07|2.369e-07|3.747e-07| 3.6e-07 |
# |  92/200  |1.171e-06|1.146e-06|1.321e-09|1.872e-09|1.125e-09|1.060e-10|1.681e-07|2.093e-07|3.353e-07|3.392e-07|
# |  94/200  | 1.09e-06|1.152e-06|6.210e-10|9.912e-11|1.113e-09|1.039e-10|1.309e-07| 1.99e-07|3.056e-07|3.378e-07|
# |  96/200  |1.162e-06|9.416e-07|7.449e-10|7.660e-10|7.827e-10|1.528e-09|1.236e-07|6.052e-08|3.218e-07|2.511e-07|
# |  98/200  |1.011e-06|7.786e-07|3.517e-10|9.837e-11|7.122e-10|4.509e-10|1.125e-07|7.170e-08|2.811e-07|2.127e-07|
# | 100/200  |9.346e-07|7.791e-07|5.185e-10|1.378e-10|9.935e-10|7.127e-10|1.064e-07|5.615e-08|2.606e-07|2.090e-07|
# | 102/200  |9.799e-07|7.566e-07|5.553e-10|3.892e-10|5.904e-09|9.444e-10|1.084e-07|1.127e-07|2.737e-07|2.177e-07|
# | 104/200  |9.339e-07|8.115e-07|5.130e-10|9.645e-11|1.247e-09|6.740e-11|8.323e-08|4.375e-08|2.547e-07|2.138e-07|
# | 106/200  |9.237e-07|1.008e-06|4.665e-10|4.584e-10|1.893e-09|2.230e-10|7.129e-08|3.509e-08|2.493e-07| 2.61e-07|
# | 108/200  |8.779e-07|8.462e-07|5.091e-10|3.704e-10|8.368e-10|1.983e-11|5.698e-08|3.543e-08|2.340e-07|2.205e-07|
# | 110/200  |9.090e-07|7.039e-07|6.079e-10|9.936e-11|1.282e-09|4.552e-11|7.376e-08|4.703e-08|2.462e-07|1.878e-07|
# | 112/200  |8.721e-07|7.377e-07|6.672e-10|1.425e-10|1.401e-09|1.333e-09|6.454e-08|9.178e-08|2.347e-07|2.077e-07|
# | 114/200  |8.719e-07|8.286e-07|4.399e-10|7.691e-10|1.641e-09|3.537e-10|5.191e-08|3.783e-08|2.315e-07|2.169e-07|
# | 116/200  |8.640e-07|7.966e-07|7.099e-10|2.700e-10|1.558e-09|3.969e-11|5.982e-08|4.469e-08|2.315e-07|2.104e-07|
# | 118/200  |8.099e-07|8.552e-07|1.183e-09|2.462e-09|7.311e-10|1.297e-10|3.358e-08|8.047e-08|2.113e-07|2.346e-07|
# | 119/200  |8.979e-07|9.032e-07|5.511e-09|5.092e-09|2.228e-09|3.578e-09|7.132e-08|3.579e-08|2.442e-07|2.369e-07|Stopping the training at epoch 119 due to early stopping.
# ============================ nnodely Training Time =============================
# Total time of Training:       396.75781869888306
# ================================================================================
# Selected the model at the epoch 110.
# =============================== Save JSON Model ================================
# Model saved in:               /home/baro/Desktop/inv_pend/rk4_models/saved_models/physics_augmented_neural_network.json
# ================================================================================
# ========================== Export Python Torch Model ===========================
# Model exported in:            /home/baro/Desktop/inv_pend/rk4_models/saved_models/physics_augmented_neural_network.py
# ================================================================================

# %%
# Model analysis
inverted_pendulum.analyzeModel('data_test', prediction_samples=50, batch_size=128)
# Out:
# =================== nnodely Model Results for data_test ===================
# |     Loss    |        mse        |        FVU        |        AIC        |
# |             |    small better   |    small better   |    lower better   |
# |-------------------------------------------------------------------------|
# |ang_vel_error|     4.111e-04     |     3.466e-05     |     7.662e+05     |
# | angle_error |     3.337e-05     |     3.579e-06     |     7.643e+05     |
# |  pos_error  |     4.822e-06     |     1.953e-05     |     7.641e+05     |
# |  vel_error  |     3.026e-05     |     1.457e-04     |     7.661e+05     |
# |-------------------------------------------------------------------------|
# |    Total    |     1.199e-04     |     5.088e-05     |     7.652e+05     |
# |-------------------------------------------------------------------------|

# %%
prediction_samples = 50
step = 48
inverted_pendulum.trainModel(train_dataset='data', validation_dataset='data_val', optimizer='Adam', prediction_samples=prediction_samples, step=step, training_params=params, early_stopping=earlystopping.early_stop_patience,  
                                                            early_stopping_params={'patience':early_stop_patience}, select_model=earlystopping.select_best_model, lr=1e-3)
inverted_pendulum.exportPythonModel(name=model_name)
# Out:
# ======================== nnodely Model Train Parameters ========================
# models:                       ['pendulum']
# num of epochs:                200
# update per epochs:            133
# └>len(train_indexes)//(batch_size+step)
# shuffle data:                 True
# early stopping:               early_stop_patience
# early stopping params:        {'patience': 10}
# prediction samples:           50
# step:                         48
# closed loop:                  {}
# connect:                      {}
# train dataset:                data
# 	- batch size:                64
# 	- num of samples:            22500
# 	- num of first samples:      15000
# validation dataset:           data_val
# 	- batch size:                128
# 	- num of samples:            15000
# 	- num of first samples:      10000
# minimizers:                   {'ang_vel_error': {'A': 'SamplePart575',
#                                                  'B': 'Add551',
#                                                  'loss': 'mse'},
#                                'angle_error': {'A': 'SamplePart577',
#                                                'B': 'Add565',
#                                                'loss': 'mse'},
#                                'pos_error': {'A': 'SamplePart581',
#                                              'B': 'Add537',
#                                              'loss': 'mse'},
#                                'vel_error': {'A': 'SamplePart579',
#                                              'B': 'Add523',
#                                              'loss': 'mse'}}
# optimizer:                    Adam
# optimizer defaults:           {'lr': 0.001}
# optimizer params:             [{'params': 'I'},
#                                {'params': 'PLinear29W'},
#                                {'params': 'PLinear31W'},
#                                {'params': 'PLinear33W'},
#                                {'params': 'PLinear35W'},
#                                {'params': 'PLinear37W'},
#                                {'params': 'PLinear39W'},
#                                {'params': 'b'},
#                                {'params': 'd'},
#                                {'params': 'gear'},
#                                {'params': 'l'},
#                                {'params': 'm1'},
#                                {'params': 'm2'}]
# ================================================================================
# =============================================== nnodely Training ===============================================
# |  Epoch   |   ang_vel_error   |    angle_error    |     pos_error     |     vel_error     |       Total       |
# |          |        Loss       |        Loss       |        Loss       |        Loss       |        Loss       |
# |          |  train  |   val   |  train  |   val   |  train  |   val   |  train  |   val   |  train  |   val   |
# |--------------------------------------------------------------------------------------------------------------|
# |  2/200   |3.869e-04|5.120e-04|3.242e-05| 3.96e-05|1.334e-06|7.871e-07|1.139e-05|9.415e-06|1.080e-04|1.405e-04|
# |  4/200   |3.847e-04|7.057e-04|3.143e-05|5.246e-05|9.156e-07|1.706e-06|9.255e-06|1.762e-05|1.066e-04|1.944e-04|
# |  6/200   |3.633e-04|5.853e-04|3.115e-05|4.678e-05|1.448e-06|3.662e-06|1.227e-05|2.592e-05|1.020e-04|1.654e-04|
# |  8/200   |4.545e-04|5.844e-04|3.610e-05|4.434e-05| 2.19e-06|1.153e-06|1.485e-05|1.266e-05|1.269e-04|1.606e-04|
# |  10/200  |3.955e-04|5.393e-04|3.318e-05|4.193e-05|2.166e-06|1.813e-06|1.453e-05| 1.26e-05|1.113e-04|1.489e-04|
# Stopping the training at epoch 10 due to early stopping.
# ============================ nnodely Training Time =============================
# Total time of Training:       624.1826720237732
# ================================================================================
# Selected the model at the epoch 1.
# =============================== Save JSON Model ================================
# Model saved in:               /home/baro/Desktop/inv_pend/rk4_models/saved_models/physics_augmented_neural_network.json
# ================================================================================
# ========================== Export Python Torch Model ===========================
# Model exported in:            /home/baro/Desktop/inv_pend/rk4_models/saved_models/physics_augmented_neural_network.py
# ================================================================================

# %%
# Closed-loop plot
inverted_pendulum.importPythonModel(name=model_name)
inverted_pendulum.neuralizeModel(sample_time = 0.02)
samples = inverted_pendulum.getSamples(dataset='data_test', window=150, index=0)
result = inverted_pendulum(samples, sampled=True, prediction_samples=150)

#region Plotting
t = np.arange(len(result['est_theta'])) * 0.02
plt.figure(figsize=(14, 9))
plt.subplot(5, 1, 2)
plt.plot(t, result['est_theta'], label=r'Estimated $\theta$')
plt.plot(t, np.array(samples['Yangle']).squeeze(), '--', label=r'True $\theta$')
plt.title('Theta estimation')
plt.xlabel('Time [s]')
plt.ylabel(r'$\theta$ [rad]')
plt.grid()
plt.legend()
plt.subplot(5, 1, 1)
plt.plot(t, result['est_thetadot'], label=r'Estimated $\dot{\theta}$')
plt.plot(t, np.array(samples['Yangular_velocity']).squeeze(), '--', label=r'True $\dot{\theta}$')
plt.title('Angular velocity estimation')
plt.xlabel('Time [s]')
plt.ylabel(r'$\dot{\theta}$ [rad/s]')
plt.grid()
plt.legend()
plt.subplot(5, 1, 4)
plt.plot(t, result['est_x'], label='Estimated X')
plt.plot(t, np.array(samples['Ypos']).squeeze(), '--', label='True x')
plt.title('Position estimation')
plt.xlabel('Time [s]')
plt.ylabel('x [m]')
plt.grid()
plt.legend()
plt.subplot(5, 1, 3)
plt.plot(t, result['est_xdot'], label=r'Estimated $\dot{x}$')
plt.plot(t, np.array(samples['Yvelocity']).squeeze(), '--', label=r'True $\dot{x}$')
plt.title('Velocity estimation')
plt.xlabel('Time [s]')
plt.ylabel(r'$\dot{x}$ [m/s]')
plt.grid()
plt.legend()
plt.subplot(5, 1, 5)
plt.plot(t, np.array(samples['action']).squeeze(), label='F')
plt.title('Applied force')
plt.xlabel('Time [s]')
plt.ylabel('Force [N]')
plt.grid()
plt.legend()
plt.tight_layout()
#endregion

plt.show()
# Out:
# =============================== Load JSON Model ================================
# Model loaded from:            /home/baro/Desktop/inv_pend/rk4_models/saved_models/physics_augmented_neural_network.json
# ================================================================================
# [neuralizeModel] Closed loop on Xangle with sample in the future.
# [neuralizeModel] Closed loop on Xangular_velocity with sample in the future.
# [neuralizeModel] Closed loop on Xpos with sample in the future.
# [neuralizeModel] Closed loop on Xvelocity with sample in the future.
# ================================ nnodely Model =================================
# {'Constants': {'Constant41': {'dim': 1, 'values': [2.0]},
#                'Constant42': {'dim': 1, 'values': [2.0]},
#                'Constant43': {'dim': 1, 'values': [2.0]},
#                'Constant44': {'dim': 1, 'values': [2.0]},
#                'Constant45': {'dim': 1, 'values': [2.0]},
#                'Constant46': {'dim': 1, 'values': [2.0]},
#                'Constant47': {'dim': 1, 'values': [2.0]},
#                'Constant48': {'dim': 1, 'values': [2.0]},
#                'Constant50': {'dim': 1, 'values': [2.0]},
#                'Constant51': {'dim': 1, 'values': [2.0]},
#                'Constant52': {'dim': 1, 'values': [2.0]},
#                'Constant53': {'dim': 1, 'values': [2.0]},
#                'Constant54': {'dim': 1, 'values': [2.0]},
#                'Constant55': {'dim': 1, 'values': [2.0]},
#                'Constant56': {'dim': 1, 'values': [2.0]},
#                'Constant57': {'dim': 1, 'values': [2.0]},
#                'Constant58': {'dim': 1, 'values': [2.0]},
#                'Constant59': {'dim': 1, 'values': [2.0]},
#                'Constant60': {'dim': 1, 'values': [2.0]},
#                'Constant62': {'dim': 1, 'values': [2.0]},
#                'Constant63': {'dim': 1, 'values': [2.0]},
#                'Constant64': {'dim': 1, 'values': [2.0]},
#                'Constant65': {'dim': 1, 'values': [2.0]},
#                'Constant66': {'dim': 1, 'values': [2.0]},
#                'Constant67': {'dim': 1, 'values': [2.0]},
#                'Constant68': {'dim': 1, 'values': [2.0]},
#                'Constant69': {'dim': 1, 'values': [2.0]},
#                'Constant70': {'dim': 1, 'values': [2.0]},
#                'Constant71': {'dim': 1, 'values': [2.0]},
#                'Constant72': {'dim': 1, 'values': [2.0]},
#                'Constant73': {'dim': 1, 'values': [2.0]},
#                'Constant74': {'dim': 1, 'values': [2.0]},
#                'Constant75': {'dim': 1, 'values': [2.0]},
#                'Constant76': {'dim': 1, 'values': [2.0]},
#                'Constant77': {'dim': 1, 'values': [2.0]},
#                'Constant78': {'dim': 1, 'values': [2.0]},
#                'Constant79': {'dim': 1, 'values': [2.0]},
#                'Constant80': {'dim': 1, 'values': [2.0]},
#                'Constant81': {'dim': 1, 'values': [2.0]},
#                'Constant82': {'dim': 1, 'values': [2.0]},
#                'Constant83': {'dim': 1, 'values': [6.0]},
#                'Constant84': {'dim': 1, 'values': [2.0]},
#                'Constant85': {'dim': 1, 'values': [2.0]},
#                'Constant86': {'dim': 1, 'values': [6.0]},
#                'Constant87': {'dim': 1, 'values': [2.0]},
#                'Constant88': {'dim': 1, 'values': [2.0]},
#                'Constant89': {'dim': 1, 'values': [6.0]},
#                'Constant90': {'dim': 1, 'values': [2.0]},
#                'Constant91': {'dim': 1, 'values': [2.0]},
#                'Constant92': {'dim': 1, 'values': [6.0]},
#                'dt': {'dim': 1, 'values': [0.019999999552965164]},
#                'g': {'dim': 1, 'values': [9.8100004196167]},
#                'sigma_force': {'dim': 1, 'values': [0.0]},
#                'sigma_omega': {'dim': 1, 'values': [0.0]},
#                'sigma_theta': {'dim': 1, 'values': [0.0]},
#                'sigma_v': {'dim': 1, 'values': [0.0]},
#                'sigma_x': {'dim': 1, 'values': [0.0]}},
#  'Functions': {},
#  'Info': {'SampleTime': 0.02,
#           'nnodely_version': '1.5.2',
#           'ns': [1, 0],
#           'ntot': 1,
#           'num_parameters': 187},
#  'Inputs': {'Xangle': {'closedLoop': 'Add565',
#                        'dim': 1,
#                        'local': 1,
#                        'ns': [1, 0],
#                        'ntot': 1,
#                        'sw': [-1, 0]},
#             'Xangular_velocity': {'closedLoop': 'Add551',
#                                   'dim': 1,
#                                   'local': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Xpos': {'closedLoop': 'Add537',
#                      'dim': 1,
#                      'local': 1,
#                      'ns': [1, 0],
#                      'ntot': 1,
#                      'sw': [-1, 0]},
#             'Xvelocity': {'closedLoop': 'Add523',
#                           'dim': 1,
#                           'local': 1,
#                           'ns': [1, 0],
#                           'ntot': 1,
#                           'sw': [-1, 0]},
#             'Yangle': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yangular_velocity': {'dim': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Ypos': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yvelocity': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'action': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise1': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise2': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise3': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise4': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise5': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]}},
#  'Minimizers': {'ang_vel_error': {'A': 'SamplePart575',
#                                   'B': 'Add551',
#                                   'loss': 'mse'},
#                 'angle_error': {'A': 'SamplePart577',
#                                 'B': 'Add565',
#                                 'loss': 'mse'},
#                 'pos_error': {'A': 'SamplePart581',
#                               'B': 'Add537',
#                               'loss': 'mse'},
#                 'vel_error': {'A': 'SamplePart579',
#                               'B': 'Add523',
#                               'loss': 'mse'}},
#  'Models': 'pendulum',
#  'Outputs': {'contr_theta': 'Select570',
#              'contr_thetadot': 'Select571',
#              'contr_x': 'Select573',
#              'contr_xdot': 'Select572',
#              'est_theta': 'Add565',
#              'est_thetadot': 'Add551',
#              'est_x': 'Add537',
#              'est_xdot': 'Add523'},
#  'Parameters': {'I': {'dim': 1, 'values': [0.3665934205055237]},
#                 'PLinear29W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[0.1339799165725708,
#                                            0.029055997729301453,
#                                            0.0901598408818245,
#                                            0.02187737263739109,
#                                            -0.40687552094459534,
#                                            -0.061862513422966,
#                                            0.073885478079319,
#                                            0.24921028316020966,
#                                            -0.34111401438713074,
#                                            -0.0335845872759819]]},
#                 'PLinear31W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[-0.015274163335561752,
#                                            0.037064600735902786,
#                                            -0.032421763986349106,
#                                            0.02278393879532814,
#                                            0.0911608561873436,
#                                            0.06094522401690483,
#                                            -0.012738989666104317,
#                                            -0.07245787233114243,
#                                            0.07643961161375046,
#                                            -0.00038468706770800054]]},
#                 'PLinear33W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[-0.0014596972614526749,
#                                            -0.05327482149004936,
#                                            0.005350697319954634,
#                                            -0.04364042729139328,
#                                            0.005023951176553965,
#                                            0.0021279947832226753,
#                                            -0.013751748017966747,
#                                            -0.005382625386118889,
#                                            0.003641919931396842,
#                                            -0.0063543543219566345]]},
#                 'PLinear35W': {'dim': [1, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[-0.028899969533085823,
#                                            0.024189023301005363,
#                                            0.0731528252363205,
#                                            0.028463633731007576,
#                                            -0.06439018994569778,
#                                            -0.03797878697514534,
#                                            0.02911299467086792,
#                                            0.07108074426651001,
#                                            -0.05557240545749664,
#                                            0.0163437332957983]]},
#                 'PLinear37W': {'dim': [10, 10],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[0.1158600002527237,
#                                            -0.113904669880867,
#                                            0.1473758965730667,
#                                            -0.1297556310892105,
#                                            0.13717201352119446,
#                                            -0.07345994561910629,
#                                            -0.36757394671440125,
#                                            0.13015739619731903,
#                                            -0.10960540920495987,
#                                            -0.14561152458190918],
#                                           [-0.04158630222082138,
#                                            -0.012368869036436081,
#                                            -0.03945964202284813,
#                                            0.18343447148799896,
#                                            -0.03848446160554886,
#                                            0.4302118122577667,
#                                            0.10172691941261292,
#                                            -0.03693754971027374,
#                                            -0.027750207111239433,
#                                            -0.0008555480162613094],
#                                           [-0.15900832414627075,
#                                            0.07811800390481949,
#                                            0.007560492493212223,
#                                            0.05739264190196991,
#                                            -0.12242865562438965,
#                                            0.09293336421251297,
#                                            0.33929768204689026,
#                                            -0.03630021587014198,
#                                            0.054978467524051666,
#                                            0.09337621927261353],
#                                           [0.052688438445329666,
#                                            -0.011684111319482327,
#                                            0.06339462846517563,
#                                            -0.23552720248699188,
#                                            0.02603539451956749,
#                                            -0.42918533086776733,
#                                            -0.038638196885585785,
#                                            0.007741205394268036,
#                                            -0.0010974914766848087,
#                                            -0.026332108303904533],
#                                           [-0.4360366761684418,
#                                            0.39213937520980835,
#                                            -0.257805198431015,
#                                            0.04064437374472618,
#                                            -0.4452415108680725,
#                                            -0.26700687408447266,
#                                            0.14069314301013947,
#                                            -0.3390043377876282,
#                                            0.37585732340812683,
#                                            0.41765275597572327],
#                                           [0.12035846710205078,
#                                            0.005024496931582689,
#                                            -0.01806093007326126,
#                                            -0.07486511021852493,
#                                            0.06955859065055847,
#                                            -0.18568632006645203,
#                                            -0.27796950936317444,
#                                            0.00625486159697175,
#                                            0.0037590747233480215,
#                                            -0.009188300929963589],
#                                           [-0.15588638186454773,
#                                            0.06122367084026337,
#                                            0.023844039067626,
#                                            -0.009529123082756996,
#                                            -0.13166674971580505,
#                                            -0.026931453496217728,
#                                            0.531968355178833,
#                                            -0.04087487608194351,
#                                            0.05037373676896095,
#                                            0.07474790513515472],
#                                           [-0.23034074902534485,
#                                            0.17068135738372803,
#                                            -0.006437335163354874,
#                                            -0.09281938523054123,
#                                            -0.2116357982158661,
#                                            -0.22263112664222717,
#                                            0.5551456809043884,
#                                            -0.08514589816331863,
#                                            0.15762844681739807,
#                                            0.198935866355896],
#                                           [0.33641570806503296,
#                                            -0.2992698550224304,
#                                            0.17985613644123077,
#                                            -0.0917915552854538,
#                                            0.31408196687698364,
#                                            0.07099668681621552,
#                                            0.6257125735282898,
#                                            0.2504812479019165,
#                                            -0.3045444190502167,
#                                            -0.30458828806877136],
#                                           [0.10669057816267014,
#                                            0.010860339738428593,
#                                            0.0019190269522368908,
#                                            -0.12608498334884644,
#                                            0.07611685246229172,
#                                            -0.21446296572685242,
#                                            -0.29395750164985657,
#                                            0.004336431156843901,
#                                            0.022175382822752,
#                                            -0.0031059144530445337]]},
#                 'PLinear39W': {'dim': [10, 4],
#                                'init_fun': {'code': 'def '
#                                                     'init_random_range(indexes, '
#                                                     'params_size, '
#                                                     "dict_param={'min_value': "
#                                                     "0.0, 'max_value': 1.0}):\n"
#                                                     '    import numpy as np\n'
#                                                     '    min_val = '
#                                                     "dict_param.get('min_value', "
#                                                     '0.0)\n'
#                                                     '    max_val = '
#                                                     "dict_param.get('max_value', "
#                                                     '1.0)\n'
#                                                     '    return '
#                                                     'np.random.uniform(low=min_val, '
#                                                     'high=max_val)\n',
#                                             'name': 'init_random_range',
#                                             'params': {'max_value': 0.01,
#                                                        'min_value': -0.01}},
#                                'values': [[0.01584816537797451,
#                                            0.002101324964314699,
#                                            0.22798039019107819,
#                                            0.001093197613954544],
#                                           [-0.030034629628062248,
#                                            -0.00028604682302102447,
#                                            0.07001148164272308,
#                                            0.009054356254637241],
#                                           [0.12718172371387482,
#                                            0.006596095860004425,
#                                            0.16990353167057037,
#                                            0.0014446963323280215],
#                                           [-0.03711821883916855,
#                                            0.0014384817332029343,
#                                            -0.032344426959753036,
#                                            0.0014871311141178012],
#                                           [0.00883575715124607,
#                                            0.00472089322283864,
#                                            0.15384739637374878,
#                                            0.004416007548570633],
#                                           [-0.2058391571044922,
#                                            -0.00212186761200428,
#                                            0.09624464064836502,
#                                            0.0031838121358305216],
#                                           [0.024641338735818863,
#                                            0.0005291750421747565,
#                                            0.12437859177589417,
#                                            -0.0004970211302861571],
#                                           [0.0329015776515007,
#                                            -0.004327105823904276,
#                                            0.13789543509483337,
#                                            -0.0029533361084759235],
#                                           [-0.0411948524415493,
#                                            0.009191468358039856,
#                                            0.0880482941865921,
#                                            0.006490145344287157],
#                                           [-0.01957927644252777,
#                                            -4.4422609789762646e-05,
#                                            0.061949461698532104,
#                                            -0.00206306716427207]]},
#                 'b': {'dim': 1, 'values': [1.1572990417480469]},
#                 'd': {'dim': 1, 'values': [0.9200180768966675]},
#                 'gear': {'dim': 1,
#                          'init_values': [100.0],
#                          'values': [92.17991638183594]},
#                 'l': {'dim': 1, 'values': [0.16484428942203522]},
#                 'm1': {'dim': 1, 'values': [5.707699298858643]},
#                 'm2': {'dim': 1, 'values': [8.428751945495605]}},
#  'Relations': {'Add101': ['Add', ['Sub90', 'Mul100']],
#                'Add109': ['Add', ['Add101', 'Mul108']],
#                'Add13': ['Add', ['SamplePart8', 'Mul12']],
#                'Add145': ['Add', ['Sub137', 'Mul144']],
#                'Add147': ['Add', ['Add145', 'Mul146']],
#                'Add158': ['Add', ['Add13', 'Div157']],
#                'Add163': ['Add', ['Add27', 'Div162']],
#                'Add168': ['Add', ['Add20', 'Div167']],
#                'Add177': ['Add', ['I', 'Mul175']],
#                'Add180': ['Add', ['m1', 'm2']],
#                'Add196': ['Add', ['m1', 'm2']],
#                'Add20': ['Add', ['SamplePart15', 'Mul19']],
#                'Add216': ['Add', ['m1', 'm2']],
#                'Add224': ['Add', ['Sub213', 'Mul223']],
#                'Add232': ['Add', ['Add224', 'Mul231']],
#                'Add268': ['Add', ['Sub260', 'Mul267']],
#                'Add27': ['Add', ['SamplePart22', 'Mul26']],
#                'Add270': ['Add', ['Add268', 'Mul269']],
#                'Add281': ['Add', ['Add13', 'Div280']],
#                'Add286': ['Add', ['Add27', 'Div285']],
#                'Add291': ['Add', ['Add20', 'Div290']],
#                'Add300': ['Add', ['I', 'Mul298']],
#                'Add303': ['Add', ['m1', 'm2']],
#                'Add319': ['Add', ['m1', 'm2']],
#                'Add339': ['Add', ['m1', 'm2']],
#                'Add34': ['Add', ['SamplePart29', 'Mul33']],
#                'Add347': ['Add', ['Sub336', 'Mul346']],
#                'Add355': ['Add', ['Add347', 'Mul354']],
#                'Add39': ['Add', ['Linear35', 'Linear36']],
#                'Add391': ['Add', ['Sub383', 'Mul390']],
#                'Add393': ['Add', ['Add391', 'Mul392']],
#                'Add40': ['Add', ['Add39', 'Linear37']],
#                'Add400': ['Add', ['Add13', 'Mul399']],
#                'Add403': ['Add', ['Add27', 'Mul402']],
#                'Add406': ['Add', ['Add20', 'Mul405']],
#                'Add41': ['Add', ['Add40', 'Linear38']],
#                'Add415': ['Add', ['I', 'Mul413']],
#                'Add418': ['Add', ['m1', 'm2']],
#                'Add434': ['Add', ['m1', 'm2']],
#                'Add454': ['Add', ['m1', 'm2']],
#                'Add462': ['Add', ['Sub451', 'Mul461']],
#                'Add470': ['Add', ['Add462', 'Mul469']],
#                'Add506': ['Add', ['Sub498', 'Mul505']],
#                'Add508': ['Add', ['Add506', 'Mul507']],
#                'Add512': ['Add', ['Div148', 'Mul511']],
#                'Add515': ['Add', ['Add512', 'Mul514']],
#                'Add516': ['Add', ['Add515', 'Div509']],
#                'Add521': ['Add', ['Add13', 'Div520']],
#                'Add523': ['Add', ['Add521', 'Select522']],
#                'Add526': ['Add', ['Add13', 'Mul525']],
#                'Add529': ['Add', ['Add526', 'Mul528']],
#                'Add530': ['Add', ['Add529', 'Add400']],
#                'Add535': ['Add', ['Add6', 'Div534']],
#                'Add537': ['Add', ['Add535', 'Select536']],
#                'Add54': ['Add', ['I', 'Mul52']],
#                'Add540': ['Add', ['Div116', 'Mul539']],
#                'Add543': ['Add', ['Add540', 'Mul542']],
#                'Add544': ['Add', ['Add543', 'Div477']],
#                'Add549': ['Add', ['Add20', 'Div548']],
#                'Add551': ['Add', ['Add549', 'Select550']],
#                'Add554': ['Add', ['Add20', 'Mul553']],
#                'Add557': ['Add', ['Add554', 'Mul556']],
#                'Add558': ['Add', ['Add557', 'Add406']],
#                'Add563': ['Add', ['Add27', 'Div562']],
#                'Add565': ['Add', ['Add563', 'Select564']],
#                'Add57': ['Add', ['m1', 'm2']],
#                'Add6': ['Add', ['SamplePart1', 'Mul5']],
#                'Add73': ['Add', ['m1', 'm2']],
#                'Add93': ['Add', ['m1', 'm2']],
#                'Cos170': ['Cos', ['Add163']],
#                'Cos293': ['Cos', ['Add286']],
#                'Cos408': ['Cos', ['Add403']],
#                'Cos47': ['Cos', ['Add27']],
#                'Div116': ['Div', ['Sub115', 'Sub65']],
#                'Div148': ['Div', ['Add147', 'Sub65']],
#                'Div157': ['Div', ['Mul155', 'Constant50']],
#                'Div162': ['Div', ['Mul160', 'Constant51']],
#                'Div167': ['Div', ['Mul165', 'Constant52']],
#                'Div239': ['Div', ['Sub238', 'Sub188']],
#                'Div271': ['Div', ['Add270', 'Sub188']],
#                'Div280': ['Div', ['Mul278', 'Constant62']],
#                'Div285': ['Div', ['Mul283', 'Constant63']],
#                'Div290': ['Div', ['Mul288', 'Constant64']],
#                'Div362': ['Div', ['Sub361', 'Sub311']],
#                'Div394': ['Div', ['Add393', 'Sub311']],
#                'Div477': ['Div', ['Sub476', 'Sub426']],
#                'Div509': ['Div', ['Add508', 'Sub426']],
#                'Div520': ['Div', ['Mul518', 'Constant83']],
#                'Div534': ['Div', ['Mul532', 'Constant86']],
#                'Div548': ['Div', ['Mul546', 'Constant89']],
#                'Div562': ['Div', ['Mul560', 'Constant92']],
#                'Linear35': ['Linear', ['Add27'], 'PLinear29W', None, 0.0],
#                'Linear36': ['Linear', ['Add13'], 'PLinear31W', None, 0.0],
#                'Linear37': ['Linear', ['Add20'], 'PLinear33W', None, 0.0],
#                'Linear38': ['Linear', ['Add34'], 'PLinear35W', None, 0.0],
#                'Linear43': ['Linear', ['Tanh42'], 'PLinear37W', None, 0.0],
#                'Linear45': ['Linear', ['Tanh44'], 'PLinear39W', None, 0],
#                'Mul100': ['Mul', ['Mul99', 'Sin46']],
#                'Mul104': ['Mul', ['m2', 'l']],
#                'Mul106': ['Mul', ['Mul104', 'b']],
#                'Mul107': ['Mul', ['Mul106', 'Add13']],
#                'Mul108': ['Mul', ['Mul107', 'Cos47']],
#                'Mul112': ['Mul', ['m2', 'l']],
#                'Mul113': ['Mul', ['Mul112', 'Cos47']],
#                'Mul114': ['Mul', ['Mul113', 'Mul67']],
#                'Mul118': ['Mul', ['Add54', 'm2']],
#                'Mul12': ['Mul', ['SamplePart10', 'sigma_v']],
#                'Mul120': ['Mul', ['Mul118', 'l']],
#                'Mul123': ['Mul', ['Mul120', 'Pow122']],
#                'Mul124': ['Mul', ['Mul123', 'Sin46']],
#                'Mul132': ['Mul', ['Pow128', 'Pow131']],
#                'Mul134': ['Mul', ['Mul132', 'g']],
#                'Mul135': ['Mul', ['Mul134', 'Sin46']],
#                'Mul136': ['Mul', ['Mul135', 'Cos47']],
#                'Mul140': ['Mul', ['m2', 'l']],
#                'Mul142': ['Mul', ['Mul140', 'd']],
#                'Mul143': ['Mul', ['Mul142', 'Add20']],
#                'Mul144': ['Mul', ['Mul143', 'Cos47']],
#                'Mul146': ['Mul', ['Mul67', 'Add54']],
#                'Mul155': ['Mul', ['Div148', 'dt']],
#                'Mul160': ['Mul', ['Add20', 'dt']],
#                'Mul165': ['Mul', ['Div116', 'dt']],
#                'Mul175': ['Mul', ['m2', 'Pow173']],
#                'Mul181': ['Mul', ['Add180', 'Add177']],
#                'Mul184': ['Mul', ['m2', 'l']],
#                'Mul185': ['Mul', ['Mul184', 'Cos170']],
#                'Mul19': ['Mul', ['SamplePart17', 'sigma_omega']],
#                'Mul190': ['Mul', ['gear', 'Add34']],
#                'Mul192': ['Mul', ['Add177', 'b']],
#                'Mul193': ['Mul', ['Mul192', 'Add158']],
#                'Mul198': ['Mul', ['Add196', 'd']],
#                'Mul199': ['Mul', ['Mul198', 'Add168']],
#                'Mul207': ['Mul', ['Neg203', 'Pow206']],
#                'Mul210': ['Mul', ['Mul207', 'Pow209']],
#                'Mul211': ['Mul', ['Mul210', 'Sin169']],
#                'Mul212': ['Mul', ['Mul211', 'Cos170']],
#                'Mul218': ['Mul', ['Add216', 'm2']],
#                'Mul220': ['Mul', ['Mul218', 'g']],
#                'Mul222': ['Mul', ['Mul220', 'l']],
#                'Mul223': ['Mul', ['Mul222', 'Sin169']],
#                'Mul227': ['Mul', ['m2', 'l']],
#                'Mul229': ['Mul', ['Mul227', 'b']],
#                'Mul230': ['Mul', ['Mul229', 'Add158']],
#                'Mul231': ['Mul', ['Mul230', 'Cos170']],
#                'Mul235': ['Mul', ['m2', 'l']],
#                'Mul236': ['Mul', ['Mul235', 'Cos170']],
#                'Mul237': ['Mul', ['Mul236', 'Mul190']],
#                'Mul241': ['Mul', ['Add177', 'm2']],
#                'Mul243': ['Mul', ['Mul241', 'l']],
#                'Mul246': ['Mul', ['Mul243', 'Pow245']],
#                'Mul247': ['Mul', ['Mul246', 'Sin169']],
#                'Mul255': ['Mul', ['Pow251', 'Pow254']],
#                'Mul257': ['Mul', ['Mul255', 'g']],
#                'Mul258': ['Mul', ['Mul257', 'Sin169']],
#                'Mul259': ['Mul', ['Mul258', 'Cos170']],
#                'Mul26': ['Mul', ['SamplePart24', 'sigma_theta']],
#                'Mul263': ['Mul', ['m2', 'l']],
#                'Mul265': ['Mul', ['Mul263', 'd']],
#                'Mul266': ['Mul', ['Mul265', 'Add168']],
#                'Mul267': ['Mul', ['Mul266', 'Cos170']],
#                'Mul269': ['Mul', ['Mul190', 'Add177']],
#                'Mul278': ['Mul', ['Div271', 'dt']],
#                'Mul283': ['Mul', ['Add168', 'dt']],
#                'Mul288': ['Mul', ['Div239', 'dt']],
#                'Mul298': ['Mul', ['m2', 'Pow296']],
#                'Mul304': ['Mul', ['Add303', 'Add300']],
#                'Mul307': ['Mul', ['m2', 'l']],
#                'Mul308': ['Mul', ['Mul307', 'Cos293']],
#                'Mul313': ['Mul', ['gear', 'Add34']],
#                'Mul315': ['Mul', ['Add300', 'b']],
#                'Mul316': ['Mul', ['Mul315', 'Add281']],
#                'Mul321': ['Mul', ['Add319', 'd']],
#                'Mul322': ['Mul', ['Mul321', 'Add291']],
#                'Mul33': ['Mul', ['SamplePart31', 'sigma_force']],
#                'Mul330': ['Mul', ['Neg326', 'Pow329']],
#                'Mul333': ['Mul', ['Mul330', 'Pow332']],
#                'Mul334': ['Mul', ['Mul333', 'Sin292']],
#                'Mul335': ['Mul', ['Mul334', 'Cos293']],
#                'Mul341': ['Mul', ['Add339', 'm2']],
#                'Mul343': ['Mul', ['Mul341', 'g']],
#                'Mul345': ['Mul', ['Mul343', 'l']],
#                'Mul346': ['Mul', ['Mul345', 'Sin292']],
#                'Mul350': ['Mul', ['m2', 'l']],
#                'Mul352': ['Mul', ['Mul350', 'b']],
#                'Mul353': ['Mul', ['Mul352', 'Add281']],
#                'Mul354': ['Mul', ['Mul353', 'Cos293']],
#                'Mul358': ['Mul', ['m2', 'l']],
#                'Mul359': ['Mul', ['Mul358', 'Cos293']],
#                'Mul360': ['Mul', ['Mul359', 'Mul313']],
#                'Mul364': ['Mul', ['Add300', 'm2']],
#                'Mul366': ['Mul', ['Mul364', 'l']],
#                'Mul369': ['Mul', ['Mul366', 'Pow368']],
#                'Mul370': ['Mul', ['Mul369', 'Sin292']],
#                'Mul378': ['Mul', ['Pow374', 'Pow377']],
#                'Mul380': ['Mul', ['Mul378', 'g']],
#                'Mul381': ['Mul', ['Mul380', 'Sin292']],
#                'Mul382': ['Mul', ['Mul381', 'Cos293']],
#                'Mul386': ['Mul', ['m2', 'l']],
#                'Mul388': ['Mul', ['Mul386', 'd']],
#                'Mul389': ['Mul', ['Mul388', 'Add291']],
#                'Mul390': ['Mul', ['Mul389', 'Cos293']],
#                'Mul392': ['Mul', ['Mul313', 'Add300']],
#                'Mul399': ['Mul', ['Div394', 'dt']],
#                'Mul402': ['Mul', ['Add291', 'dt']],
#                'Mul405': ['Mul', ['Div362', 'dt']],
#                'Mul413': ['Mul', ['m2', 'Pow411']],
#                'Mul419': ['Mul', ['Add418', 'Add415']],
#                'Mul422': ['Mul', ['m2', 'l']],
#                'Mul423': ['Mul', ['Mul422', 'Cos408']],
#                'Mul428': ['Mul', ['gear', 'Add34']],
#                'Mul430': ['Mul', ['Add415', 'b']],
#                'Mul431': ['Mul', ['Mul430', 'Add400']],
#                'Mul436': ['Mul', ['Add434', 'd']],
#                'Mul437': ['Mul', ['Mul436', 'Add406']],
#                'Mul445': ['Mul', ['Neg441', 'Pow444']],
#                'Mul448': ['Mul', ['Mul445', 'Pow447']],
#                'Mul449': ['Mul', ['Mul448', 'Sin407']],
#                'Mul450': ['Mul', ['Mul449', 'Cos408']],
#                'Mul456': ['Mul', ['Add454', 'm2']],
#                'Mul458': ['Mul', ['Mul456', 'g']],
#                'Mul460': ['Mul', ['Mul458', 'l']],
#                'Mul461': ['Mul', ['Mul460', 'Sin407']],
#                'Mul465': ['Mul', ['m2', 'l']],
#                'Mul467': ['Mul', ['Mul465', 'b']],
#                'Mul468': ['Mul', ['Mul467', 'Add400']],
#                'Mul469': ['Mul', ['Mul468', 'Cos408']],
#                'Mul473': ['Mul', ['m2', 'l']],
#                'Mul474': ['Mul', ['Mul473', 'Cos408']],
#                'Mul475': ['Mul', ['Mul474', 'Mul428']],
#                'Mul479': ['Mul', ['Add415', 'm2']],
#                'Mul481': ['Mul', ['Mul479', 'l']],
#                'Mul484': ['Mul', ['Mul481', 'Pow483']],
#                'Mul485': ['Mul', ['Mul484', 'Sin407']],
#                'Mul493': ['Mul', ['Pow489', 'Pow492']],
#                'Mul495': ['Mul', ['Mul493', 'g']],
#                'Mul496': ['Mul', ['Mul495', 'Sin407']],
#                'Mul497': ['Mul', ['Mul496', 'Cos408']],
#                'Mul5': ['Mul', ['SamplePart3', 'sigma_x']],
#                'Mul501': ['Mul', ['m2', 'l']],
#                'Mul503': ['Mul', ['Mul501', 'd']],
#                'Mul504': ['Mul', ['Mul503', 'Add406']],
#                'Mul505': ['Mul', ['Mul504', 'Cos408']],
#                'Mul507': ['Mul', ['Mul428', 'Add415']],
#                'Mul511': ['Mul', ['Constant81', 'Div271']],
#                'Mul514': ['Mul', ['Constant82', 'Div394']],
#                'Mul518': ['Mul', ['Add516', 'dt']],
#                'Mul52': ['Mul', ['m2', 'Pow50']],
#                'Mul525': ['Mul', ['Constant84', 'Add158']],
#                'Mul528': ['Mul', ['Constant85', 'Add281']],
#                'Mul532': ['Mul', ['Add530', 'dt']],
#                'Mul539': ['Mul', ['Constant87', 'Div239']],
#                'Mul542': ['Mul', ['Constant88', 'Div362']],
#                'Mul546': ['Mul', ['Add544', 'dt']],
#                'Mul553': ['Mul', ['Constant90', 'Add168']],
#                'Mul556': ['Mul', ['Constant91', 'Add291']],
#                'Mul560': ['Mul', ['Add558', 'dt']],
#                'Mul58': ['Mul', ['Add57', 'Add54']],
#                'Mul61': ['Mul', ['m2', 'l']],
#                'Mul62': ['Mul', ['Mul61', 'Cos47']],
#                'Mul67': ['Mul', ['gear', 'Add34']],
#                'Mul69': ['Mul', ['Add54', 'b']],
#                'Mul70': ['Mul', ['Mul69', 'Add13']],
#                'Mul75': ['Mul', ['Add73', 'd']],
#                'Mul76': ['Mul', ['Mul75', 'Add20']],
#                'Mul84': ['Mul', ['Neg80', 'Pow83']],
#                'Mul87': ['Mul', ['Mul84', 'Pow86']],
#                'Mul88': ['Mul', ['Mul87', 'Sin46']],
#                'Mul89': ['Mul', ['Mul88', 'Cos47']],
#                'Mul95': ['Mul', ['Add93', 'm2']],
#                'Mul97': ['Mul', ['Mul95', 'g']],
#                'Mul99': ['Mul', ['Mul97', 'l']],
#                'Neg203': ['Neg', ['Pow202']],
#                'Neg326': ['Neg', ['Pow325']],
#                'Neg441': ['Neg', ['Pow440']],
#                'Neg80': ['Neg', ['Pow79']],
#                'Pow122': ['Pow', ['Add20', 'Constant46']],
#                'Pow128': ['Pow', ['m2', 'Constant47']],
#                'Pow131': ['Pow', ['l', 'Constant48']],
#                'Pow173': ['Pow', ['l', 'Constant53']],
#                'Pow187': ['Pow', ['Mul185', 'Constant54']],
#                'Pow202': ['Pow', ['m2', 'Constant55']],
#                'Pow206': ['Pow', ['l', 'Constant56']],
#                'Pow209': ['Pow', ['Add168', 'Constant57']],
#                'Pow245': ['Pow', ['Add168', 'Constant58']],
#                'Pow251': ['Pow', ['m2', 'Constant59']],
#                'Pow254': ['Pow', ['l', 'Constant60']],
#                'Pow296': ['Pow', ['l', 'Constant65']],
#                'Pow310': ['Pow', ['Mul308', 'Constant66']],
#                'Pow325': ['Pow', ['m2', 'Constant67']],
#                'Pow329': ['Pow', ['l', 'Constant68']],
#                'Pow332': ['Pow', ['Add291', 'Constant69']],
#                'Pow368': ['Pow', ['Add291', 'Constant70']],
#                'Pow374': ['Pow', ['m2', 'Constant71']],
#                'Pow377': ['Pow', ['l', 'Constant72']],
#                'Pow411': ['Pow', ['l', 'Constant73']],
#                'Pow425': ['Pow', ['Mul423', 'Constant74']],
#                'Pow440': ['Pow', ['m2', 'Constant75']],
#                'Pow444': ['Pow', ['l', 'Constant76']],
#                'Pow447': ['Pow', ['Add406', 'Constant77']],
#                'Pow483': ['Pow', ['Add406', 'Constant78']],
#                'Pow489': ['Pow', ['m2', 'Constant79']],
#                'Pow492': ['Pow', ['l', 'Constant80']],
#                'Pow50': ['Pow', ['l', 'Constant41']],
#                'Pow64': ['Pow', ['Mul62', 'Constant42']],
#                'Pow79': ['Pow', ['m2', 'Constant43']],
#                'Pow83': ['Pow', ['l', 'Constant44']],
#                'Pow86': ['Pow', ['Add20', 'Constant45']],
#                'SamplePart1': ['SamplePart', ['Xpos'], -1, [-1, 0]],
#                'SamplePart10': ['SamplePart', ['noise1'], -1, [-1, 0]],
#                'SamplePart15': ['SamplePart',
#                                 ['Xangular_velocity'],
#                                 -1,
#                                 [-1, 0]],
#                'SamplePart17': ['SamplePart', ['noise3'], -1, [-1, 0]],
#                'SamplePart22': ['SamplePart', ['Xangle'], -1, [-1, 0]],
#                'SamplePart24': ['SamplePart', ['noise2'], -1, [-1, 0]],
#                'SamplePart29': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart3': ['SamplePart', ['noise4'], -1, [-1, 0]],
#                'SamplePart31': ['SamplePart', ['noise5'], -1, [-1, 0]],
#                'SamplePart575': ['SamplePart',
#                                  ['Yangular_velocity'],
#                                  -1,
#                                  [-1, 0]],
#                'SamplePart577': ['SamplePart', ['Yangle'], -1, [-1, 0]],
#                'SamplePart579': ['SamplePart', ['Yvelocity'], -1, [-1, 0]],
#                'SamplePart581': ['SamplePart', ['Ypos'], -1, [-1, 0]],
#                'SamplePart8': ['SamplePart', ['Xvelocity'], -1, [-1, 0]],
#                'Select522': ['Select', ['Linear45'], 4, 0],
#                'Select536': ['Select', ['Linear45'], 4, 1],
#                'Select550': ['Select', ['Linear45'], 4, 2],
#                'Select564': ['Select', ['Linear45'], 4, 3],
#                'Select570': ['Select', ['Linear45'], 4, 3],
#                'Select571': ['Select', ['Linear45'], 4, 2],
#                'Select572': ['Select', ['Linear45'], 4, 1],
#                'Select573': ['Select', ['Linear45'], 4, 0],
#                'Sin169': ['Sin', ['Add163']],
#                'Sin292': ['Sin', ['Add286']],
#                'Sin407': ['Sin', ['Add403']],
#                'Sin46': ['Sin', ['Add27']],
#                'Sub115': ['Sub', ['Add109', 'Mul114']],
#                'Sub125': ['Sub', ['Mul124', 'Mul70']],
#                'Sub137': ['Sub', ['Sub125', 'Mul136']],
#                'Sub188': ['Sub', ['Mul181', 'Pow187']],
#                'Sub213': ['Sub', ['Mul212', 'Mul199']],
#                'Sub238': ['Sub', ['Add232', 'Mul237']],
#                'Sub248': ['Sub', ['Mul247', 'Mul193']],
#                'Sub260': ['Sub', ['Sub248', 'Mul259']],
#                'Sub311': ['Sub', ['Mul304', 'Pow310']],
#                'Sub336': ['Sub', ['Mul335', 'Mul322']],
#                'Sub361': ['Sub', ['Add355', 'Mul360']],
#                'Sub371': ['Sub', ['Mul370', 'Mul316']],
#                'Sub383': ['Sub', ['Sub371', 'Mul382']],
#                'Sub426': ['Sub', ['Mul419', 'Pow425']],
#                'Sub451': ['Sub', ['Mul450', 'Mul437']],
#                'Sub476': ['Sub', ['Add470', 'Mul475']],
#                'Sub486': ['Sub', ['Mul485', 'Mul431']],
#                'Sub498': ['Sub', ['Sub486', 'Mul497']],
#                'Sub65': ['Sub', ['Mul58', 'Pow64']],
#                'Sub90': ['Sub', ['Mul89', 'Mul76']],
#                'Tanh42': ['Tanh', ['Add41']],
#                'Tanh44': ['Tanh', ['Linear43']]}}
# ================================================================================
# ========================== Import Python Torch Model ===========================
# Model imported from:          /home/baro/Desktop/inv_pend/rk4_models/saved_models/physics_augmented_neural_network.py
# ================================================================================
# [neuralizeModel] Closed loop on Xangle with sample in the future.
# [neuralizeModel] Closed loop on Xangular_velocity with sample in the future.
# [neuralizeModel] Closed loop on Xpos with sample in the future.
# [neuralizeModel] Closed loop on Xvelocity with sample in the future.
# ================================ nnodely Model =================================
# {'Constants': {'Constant41': {'dim': 1, 'values': [2.0]},
# ...
#                'Div148': ['Div', ['Add147', 'Sub65']],
#                'Div157': ['Div', ['Mul155', 'Constant50']],
#                'Div162': ['Div', ['Mul160', 'Constant51']],
#                'Div167': ['Div', ['Mul165', 'Constant52']],
#                'Div239': ['Div', ['Sub238', 'Sub188']],
#                'Div271': ['Div', ['Add270', 'Sub188']],
#                'Div280': ['Div', ['Mul278', 'Constant62']],
#                'Div285': ['Div', ['Mul283', 'Constant63']],
#                'Div290': ['Div', ['Mul288', 'Constant64']],
#                'Div362': ['Div', ['Sub361', 'Sub311']],
#                'Div394': ['Div', ['Add393', 'Sub311']],
#                'Div477': ['Div', ['Sub476', 'Sub426']],
#                'Div509': ['Div', ['Add508', 'Sub426']],
#                'Div520': ['Div', ['Mul518', 'Constant83']],
#                'Div534': ['Div', ['Mul532', 'Constant86']],
#                'Div548': ['Div', ['Mul546', 'Constant89']],
#                'Div562': ['Div', ['Mul560', 'Constant92']],
#                'Linear35': ['Linear', ['Add27'], 'PLinear29W', None, 0.0],
#                'Linear36': ['Linear', ['Add13'], 'PLinear31W', None, 0.0],
#                'Linear37': ['Linear', ['Add20'], 'PLinear33W', None, 0.0],
#                'Linear38': ['Linear', ['Add34'], 'PLinear35W', None, 0.0],
#                'Linear43': ['Linear', ['Tanh42'], 'PLinear37W', None, 0.0],
#                'Linear45': ['Linear', ['Tanh44'], 'PLinear39W', None, 0],
#                'Mul100': ['Mul', ['Mul99', 'Sin46']],
#                'Mul104': ['Mul', ['m2', 'l']],
#                'Mul106': ['Mul', ['Mul104', 'b']],
#                'Mul107': ['Mul', ['Mul106', 'Add13']],
#                'Mul108': ['Mul', ['Mul107', 'Cos47']],
#                'Mul112': ['Mul', ['m2', 'l']],
#                'Mul113': ['Mul', ['Mul112', 'Cos47']],
#                'Mul114': ['Mul', ['Mul113', 'Mul67']],
#                'Mul118': ['Mul', ['Add54', 'm2']],
#                'Mul12': ['Mul', ['SamplePart10', 'sigma_v']],
#                'Mul120': ['Mul', ['Mul118', 'l']],
#                'Mul123': ['Mul', ['Mul120', 'Pow122']],
#                'Mul124': ['Mul', ['Mul123', 'Sin46']],
#                'Mul132': ['Mul', ['Pow128', 'Pow131']],
#                'Mul134': ['Mul', ['Mul132', 'g']],
#                'Mul135': ['Mul', ['Mul134', 'Sin46']],
#                'Mul136': ['Mul', ['Mul135', 'Cos47']],
#                'Mul140': ['Mul', ['m2', 'l']],
#                'Mul142': ['Mul', ['Mul140', 'd']],
#                'Mul143': ['Mul', ['Mul142', 'Add20']],
#                'Mul144': ['Mul', ['Mul143', 'Cos47']],
#                'Mul146': ['Mul', ['Mul67', 'Add54']],
#                'Mul155': ['Mul', ['Div148', 'dt']],
#                'Mul160': ['Mul', ['Add20', 'dt']],
#                'Mul165': ['Mul', ['Div116', 'dt']],
#                'Mul175': ['Mul', ['m2', 'Pow173']],
#                'Mul181': ['Mul', ['Add180', 'Add177']],
#                'Mul184': ['Mul', ['m2', 'l']],
#                'Mul185': ['Mul', ['Mul184', 'Cos170']],
#                'Mul19': ['Mul', ['SamplePart17', 'sigma_omega']],
#                'Mul190': ['Mul', ['gear', 'Add34']],
#                'Mul192': ['Mul', ['Add177', 'b']],
#                'Mul193': ['Mul', ['Mul192', 'Add158']],
#                'Mul198': ['Mul', ['Add196', 'd']],
#                'Mul199': ['Mul', ['Mul198', 'Add168']],
#                'Mul207': ['Mul', ['Neg203', 'Pow206']],
#                'Mul210': ['Mul', ['Mul207', 'Pow209']],
#                'Mul211': ['Mul', ['Mul210', 'Sin169']],
#                'Mul212': ['Mul', ['Mul211', 'Cos170']],
#                'Mul218': ['Mul', ['Add216', 'm2']],
#                'Mul220': ['Mul', ['Mul218', 'g']],
#                'Mul222': ['Mul', ['Mul220', 'l']],
#                'Mul223': ['Mul', ['Mul222', 'Sin169']],
#                'Mul227': ['Mul', ['m2', 'l']],
#                'Mul229': ['Mul', ['Mul227', 'b']],
#                'Mul230': ['Mul', ['Mul229', 'Add158']],
#                'Mul231': ['Mul', ['Mul230', 'Cos170']],
#                'Mul235': ['Mul', ['m2', 'l']],
#                'Mul236': ['Mul', ['Mul235', 'Cos170']],
#                'Mul237': ['Mul', ['Mul236', 'Mul190']],
#                'Mul241': ['Mul', ['Add177', 'm2']],
#                'Mul243': ['Mul', ['Mul241', 'l']],
#                'Mul246': ['Mul', ['Mul243', 'Pow245']],
#                'Mul247': ['Mul', ['Mul246', 'Sin169']],
#                'Mul255': ['Mul', ['Pow251', 'Pow254']],
#                'Mul257': ['Mul', ['Mul255', 'g']],
#                'Mul258': ['Mul', ['Mul257', 'Sin169']],
#                'Mul259': ['Mul', ['Mul258', 'Cos170']],
#                'Mul26': ['Mul', ['SamplePart24', 'sigma_theta']],
#                'Mul263': ['Mul', ['m2', 'l']],
#                'Mul265': ['Mul', ['Mul263', 'd']],
#                'Mul266': ['Mul', ['Mul265', 'Add168']],
#                'Mul267': ['Mul', ['Mul266', 'Cos170']],
#                'Mul269': ['Mul', ['Mul190', 'Add177']],
#                'Mul278': ['Mul', ['Div271', 'dt']],
#                'Mul283': ['Mul', ['Add168', 'dt']],
#                'Mul288': ['Mul', ['Div239', 'dt']],
#                'Mul298': ['Mul', ['m2', 'Pow296']],
#                'Mul304': ['Mul', ['Add303', 'Add300']],
#                'Mul307': ['Mul', ['m2', 'l']],
#                'Mul308': ['Mul', ['Mul307', 'Cos293']],
#                'Mul313': ['Mul', ['gear', 'Add34']],
#                'Mul315': ['Mul', ['Add300', 'b']],
#                'Mul316': ['Mul', ['Mul315', 'Add281']],
#                'Mul321': ['Mul', ['Add319', 'd']],
#                'Mul322': ['Mul', ['Mul321', 'Add291']],
#                'Mul33': ['Mul', ['SamplePart31', 'sigma_force']],
#                'Mul330': ['Mul', ['Neg326', 'Pow329']],
#                'Mul333': ['Mul', ['Mul330', 'Pow332']],
#                'Mul334': ['Mul', ['Mul333', 'Sin292']],
#                'Mul335': ['Mul', ['Mul334', 'Cos293']],
#                'Mul341': ['Mul', ['Add339', 'm2']],
#                'Mul343': ['Mul', ['Mul341', 'g']],
#                'Mul345': ['Mul', ['Mul343', 'l']],
#                'Mul346': ['Mul', ['Mul345', 'Sin292']],
#                'Mul350': ['Mul', ['m2', 'l']],
#                'Mul352': ['Mul', ['Mul350', 'b']],
#                'Mul353': ['Mul', ['Mul352', 'Add281']],
#                'Mul354': ['Mul', ['Mul353', 'Cos293']],
#                'Mul358': ['Mul', ['m2', 'l']],
#                'Mul359': ['Mul', ['Mul358', 'Cos293']],
#                'Mul360': ['Mul', ['Mul359', 'Mul313']],
#                'Mul364': ['Mul', ['Add300', 'm2']],
#                'Mul366': ['Mul', ['Mul364', 'l']],
#                'Mul369': ['Mul', ['Mul366', 'Pow368']],
#                'Mul370': ['Mul', ['Mul369', 'Sin292']],
#                'Mul378': ['Mul', ['Pow374', 'Pow377']],
#                'Mul380': ['Mul', ['Mul378', 'g']],
#                'Mul381': ['Mul', ['Mul380', 'Sin292']],
#                'Mul382': ['Mul', ['Mul381', 'Cos293']],
#                'Mul386': ['Mul', ['m2', 'l']],
#                'Mul388': ['Mul', ['Mul386', 'd']],
#                'Mul389': ['Mul', ['Mul388', 'Add291']],
#                'Mul390': ['Mul', ['Mul389', 'Cos293']],
#                'Mul392': ['Mul', ['Mul313', 'Add300']],
#                'Mul399': ['Mul', ['Div394', 'dt']],
#                'Mul402': ['Mul', ['Add291', 'dt']],
#                'Mul405': ['Mul', ['Div362', 'dt']],
#                'Mul413': ['Mul', ['m2', 'Pow411']],
#                'Mul419': ['Mul', ['Add418', 'Add415']],
#                'Mul422': ['Mul', ['m2', 'l']],
#                'Mul423': ['Mul', ['Mul422', 'Cos408']],
#                'Mul428': ['Mul', ['gear', 'Add34']],
#                'Mul430': ['Mul', ['Add415', 'b']],
#                'Mul431': ['Mul', ['Mul430', 'Add400']],
#                'Mul436': ['Mul', ['Add434', 'd']],
#                'Mul437': ['Mul', ['Mul436', 'Add406']],
#                'Mul445': ['Mul', ['Neg441', 'Pow444']],
#                'Mul448': ['Mul', ['Mul445', 'Pow447']],
#                'Mul449': ['Mul', ['Mul448', 'Sin407']],
#                'Mul450': ['Mul', ['Mul449', 'Cos408']],
#                'Mul456': ['Mul', ['Add454', 'm2']],
#                'Mul458': ['Mul', ['Mul456', 'g']],
#                'Mul460': ['Mul', ['Mul458', 'l']],
#                'Mul461': ['Mul', ['Mul460', 'Sin407']],
#                'Mul465': ['Mul', ['m2', 'l']],
#                'Mul467': ['Mul', ['Mul465', 'b']],
#                'Mul468': ['Mul', ['Mul467', 'Add400']],
#                'Mul469': ['Mul', ['Mul468', 'Cos408']],
#                'Mul473': ['Mul', ['m2', 'l']],
#                'Mul474': ['Mul', ['Mul473', 'Cos408']],
#                'Mul475': ['Mul', ['Mul474', 'Mul428']],
#                'Mul479': ['Mul', ['Add415', 'm2']],
#                'Mul481': ['Mul', ['Mul479', 'l']],
#                'Mul484': ['Mul', ['Mul481', 'Pow483']],
#                'Mul485': ['Mul', ['Mul484', 'Sin407']],
#                'Mul493': ['Mul', ['Pow489', 'Pow492']],
#                'Mul495': ['Mul', ['Mul493', 'g']],
#                'Mul496': ['Mul', ['Mul495', 'Sin407']],
#                'Mul497': ['Mul', ['Mul496', 'Cos408']],
#                'Mul5': ['Mul', ['SamplePart3', 'sigma_x']],
#                'Mul501': ['Mul', ['m2', 'l']],
#                'Mul503': ['Mul', ['Mul501', 'd']],
#                'Mul504': ['Mul', ['Mul503', 'Add406']],
#                'Mul505': ['Mul', ['Mul504', 'Cos408']],
#                'Mul507': ['Mul', ['Mul428', 'Add415']],
#                'Mul511': ['Mul', ['Constant81', 'Div271']],
#                'Mul514': ['Mul', ['Constant82', 'Div394']],
#                'Mul518': ['Mul', ['Add516', 'dt']],
#                'Mul52': ['Mul', ['m2', 'Pow50']],
#                'Mul525': ['Mul', ['Constant84', 'Add158']],
#                'Mul528': ['Mul', ['Constant85', 'Add281']],
#                'Mul532': ['Mul', ['Add530', 'dt']],
#                'Mul539': ['Mul', ['Constant87', 'Div239']],
#                'Mul542': ['Mul', ['Constant88', 'Div362']],
#                'Mul546': ['Mul', ['Add544', 'dt']],
#                'Mul553': ['Mul', ['Constant90', 'Add168']],
#                'Mul556': ['Mul', ['Constant91', 'Add291']],
#                'Mul560': ['Mul', ['Add558', 'dt']],
#                'Mul58': ['Mul', ['Add57', 'Add54']],
#                'Mul61': ['Mul', ['m2', 'l']],
#                'Mul62': ['Mul', ['Mul61', 'Cos47']],
#                'Mul67': ['Mul', ['gear', 'Add34']],
#                'Mul69': ['Mul', ['Add54', 'b']],
#                'Mul70': ['Mul', ['Mul69', 'Add13']],
#                'Mul75': ['Mul', ['Add73', 'd']],
#                'Mul76': ['Mul', ['Mul75', 'Add20']],
#                'Mul84': ['Mul', ['Neg80', 'Pow83']],
#                'Mul87': ['Mul', ['Mul84', 'Pow86']],
#                'Mul88': ['Mul', ['Mul87', 'Sin46']],
#                'Mul89': ['Mul', ['Mul88', 'Cos47']],
#                'Mul95': ['Mul', ['Add93', 'm2']],
#                'Mul97': ['Mul', ['Mul95', 'g']],
#                'Mul99': ['Mul', ['Mul97', 'l']],
#                'Neg203': ['Neg', ['Pow202']],
#                'Neg326': ['Neg', ['Pow325']],
#                'Neg441': ['Neg', ['Pow440']],
#                'Neg80': ['Neg', ['Pow79']],
#                'Pow122': ['Pow', ['Add20', 'Constant46']],
#                'Pow128': ['Pow', ['m2', 'Constant47']],
#                'Pow131': ['Pow', ['l', 'Constant48']],
#                'Pow173': ['Pow', ['l', 'Constant53']],
#                'Pow187': ['Pow', ['Mul185', 'Constant54']],
#                'Pow202': ['Pow', ['m2', 'Constant55']],
#                'Pow206': ['Pow', ['l', 'Constant56']],
#                'Pow209': ['Pow', ['Add168', 'Constant57']],
#                'Pow245': ['Pow', ['Add168', 'Constant58']],
#                'Pow251': ['Pow', ['m2', 'Constant59']],
#                'Pow254': ['Pow', ['l', 'Constant60']],
#                'Pow296': ['Pow', ['l', 'Constant65']],
#                'Pow310': ['Pow', ['Mul308', 'Constant66']],
#                'Pow325': ['Pow', ['m2', 'Constant67']],
#                'Pow329': ['Pow', ['l', 'Constant68']],
#                'Pow332': ['Pow', ['Add291', 'Constant69']],
#                'Pow368': ['Pow', ['Add291', 'Constant70']],
#                'Pow374': ['Pow', ['m2', 'Constant71']],
#                'Pow377': ['Pow', ['l', 'Constant72']],
#                'Pow411': ['Pow', ['l', 'Constant73']],
#                'Pow425': ['Pow', ['Mul423', 'Constant74']],
#                'Pow440': ['Pow', ['m2', 'Constant75']],
#                'Pow444': ['Pow', ['l', 'Constant76']],
#                'Pow447': ['Pow', ['Add406', 'Constant77']],
#                'Pow483': ['Pow', ['Add406', 'Constant78']],
#                'Pow489': ['Pow', ['m2', 'Constant79']],
#                'Pow492': ['Pow', ['l', 'Constant80']],
#                'Pow50': ['Pow', ['l', 'Constant41']],
#                'Pow64': ['Pow', ['Mul62', 'Constant42']],
#                'Pow79': ['Pow', ['m2', 'Constant43']],
#                'Pow83': ['Pow', ['l', 'Constant44']],
#                'Pow86': ['Pow', ['Add20', 'Constant45']],
#                'SamplePart1': ['SamplePart', ['Xpos'], -1, [-1, 0]],
#                'SamplePart10': ['SamplePart', ['noise1'], -1, [-1, 0]],
#                'SamplePart15': ['SamplePart',
#                                 ['Xangular_velocity'],
#                                 -1,
#                                 [-1, 0]],
#                'SamplePart17': ['SamplePart', ['noise3'], -1, [-1, 0]],
#                'SamplePart22': ['SamplePart', ['Xangle'], -1, [-1, 0]],
#                'SamplePart24': ['SamplePart', ['noise2'], -1, [-1, 0]],
#                'SamplePart29': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart3': ['SamplePart', ['noise4'], -1, [-1, 0]],
#                'SamplePart31': ['SamplePart', ['noise5'], -1, [-1, 0]],
#                'SamplePart575': ['SamplePart',
#                                  ['Yangular_velocity'],
#                                  -1,
#                                  [-1, 0]],
#                'SamplePart577': ['SamplePart', ['Yangle'], -1, [-1, 0]],
#                'SamplePart579': ['SamplePart', ['Yvelocity'], -1, [-1, 0]],
#                'SamplePart581': ['SamplePart', ['Ypos'], -1, [-1, 0]],
#                'SamplePart8': ['SamplePart', ['Xvelocity'], -1, [-1, 0]],
#                'Select522': ['Select', ['Linear45'], 4, 0],
#                'Select536': ['Select', ['Linear45'], 4, 1],
#                'Select550': ['Select', ['Linear45'], 4, 2],
#                'Select564': ['Select', ['Linear45'], 4, 3],
#                'Select570': ['Select', ['Linear45'], 4, 3],
#                'Select571': ['Select', ['Linear45'], 4, 2],
#                'Select572': ['Select', ['Linear45'], 4, 1],
#                'Select573': ['Select', ['Linear45'], 4, 0],
#                'Sin169': ['Sin', ['Add163']],
#                'Sin292': ['Sin', ['Add286']],
#                'Sin407': ['Sin', ['Add403']],
#                'Sin46': ['Sin', ['Add27']],
#                'Sub115': ['Sub', ['Add109', 'Mul114']],
#                'Sub125': ['Sub', ['Mul124', 'Mul70']],
#                'Sub137': ['Sub', ['Sub125', 'Mul136']],
#                'Sub188': ['Sub', ['Mul181', 'Pow187']],
#                'Sub213': ['Sub', ['Mul212', 'Mul199']],
#                'Sub238': ['Sub', ['Add232', 'Mul237']],
#                'Sub248': ['Sub', ['Mul247', 'Mul193']],
#                'Sub260': ['Sub', ['Sub248', 'Mul259']],
#                'Sub311': ['Sub', ['Mul304', 'Pow310']],
#                'Sub336': ['Sub', ['Mul335', 'Mul322']],
#                'Sub361': ['Sub', ['Add355', 'Mul360']],
#                'Sub371': ['Sub', ['Mul370', 'Mul316']],
#                'Sub383': ['Sub', ['Sub371', 'Mul382']],
#                'Sub426': ['Sub', ['Mul419', 'Pow425']],
#                'Sub451': ['Sub', ['Mul450', 'Mul437']],
#                'Sub476': ['Sub', ['Add470', 'Mul475']],
#                'Sub486': ['Sub', ['Mul485', 'Mul431']],
#                'Sub498': ['Sub', ['Sub486', 'Mul497']],
#                'Sub65': ['Sub', ['Mul58', 'Pow64']],
#                'Sub90': ['Sub', ['Mul89', 'Mul76']],
#                'Tanh42': ['Tanh', ['Add41']],
#                'Tanh44': ['Tanh', ['Linear43']]}}
# ================================================================================

# %%
# Plot percentage of contribution of the neural network
plt.figure(figsize=(14, 9))
plt.subplot(4, 1, 1)
plt.plot(t, 100*np.abs(np.array(result['contr_theta']))/np.abs(np.array(result['est_theta'])), label='NN contribute')
plt.title(r'NN contribution to $\theta$')
plt.xlabel('Time [s]')
plt.ylabel(r'$\theta$ contribution [%]')
plt.grid()
plt.legend()
plt.subplot(4, 1, 2)
plt.plot(t, 100*np.abs(np.array(result['contr_thetadot']))/np.abs(np.array(result['est_thetadot'])), label='NN contribute')
plt.title(r'NN contribution to $\dot{\theta}$')
plt.xlabel('Time [s]')
plt.ylabel(r'$\dot{\theta}$ contribution [%]')
plt.grid()
plt.legend()
plt.subplot(4, 1, 3)
plt.plot(t, 100*np.abs(np.array(result['contr_x']))/np.abs(np.array(result['est_x'])), label='NN contribute')
plt.title('NN contribution to x')
plt.xlabel('Time [s]')
plt.ylabel('x contribution [%]')
plt.grid()
plt.legend()
plt.subplot(4, 1, 4)
plt.plot(t, 100*np.abs(np.array(result['contr_xdot']))/np.abs(np.array(result['est_xdot'])), label='NN contribute')
plt.title(r'NN contribution to $\dot{x}$')
plt.xlabel('Time [s]')
plt.ylabel(r'$\dot{x}$ contribution [%]')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Model analysis
inverted_pendulum.analyzeModel('data_test', prediction_samples=50, batch_size=128)
# Out:
# =================== nnodely Model Results for data_test ===================
# |     Loss    |        mse        |        FVU        |        AIC        |
# |             |    small better   |    small better   |    lower better   |
# |-------------------------------------------------------------------------|
# |ang_vel_error|     3.951e-04     |     3.336e-05     |     7.651e+05     |
# | angle_error |     3.168e-05     |     3.400e-06     |     7.637e+05     |
# |  pos_error  |     1.305e-06     |     5.108e-06     |     7.902e+05     |
# |  vel_error  |     9.071e-06     |     4.338e-05     |     7.713e+05     |
# |-------------------------------------------------------------------------|
# |    Total    |     1.093e-04     |     2.131e-05     |     7.726e+05     |
# |-------------------------------------------------------------------------|
