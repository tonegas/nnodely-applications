# %%
from nnodely import *
from nnodely.support import earlystopping
import matplotlib.pyplot as plt
import os
import numpy as np

workspace = os.path.join(os.getcwd(), "saved_models")
inverted_pendulum = Modely(workspace=workspace)
# Out:
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>-- nnodely_v1.5.2 --<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

# %%
# Create neural model

model_name = 'partially_neuralized'
pos                 = Input('Xpos')
Ypos                = Input('Ypos')
velocity            = Input('Xvelocity')
Yvelocity           = Input('Yvelocity')
angle               = Input('Xangle')
Yangle              = Input('Yangle')
angular_velocity    = Input('Xangular_velocity')
Yangular_velocity   = Input('Yangular_velocity')
F                   = Input('action')

noise1          = Input('noise1')
noise2          = Input('noise2')
noise3          = Input('noise3')
noise4          = Input('noise4')
noise5          = Input('noise5')
sigma_x         = Constant('sigma_x', values=0.0)
sigma_v         = Constant('sigma_v', values=0.0)
sigma_theta     = Constant('sigma_theta', values=0.0)
sigma_omega     = Constant('sigma_omega', values=0.0)
sigma_force     = Constant('sigma_force', values=0.0)
# sigma_x         = Constant('sigma_x', values=0.01)
# sigma_v         = Constant('sigma_v', values=0.02)
# sigma_theta     = Constant('sigma_theta', values=0.01)
# sigma_omega     = Constant('sigma_omega', values=0.1)
# sigma_force     = Constant('sigma_force', values=0.06)
g               = Constant('g', values=9.81)
dt              = Constant('dt', values=0.02)
a1              = Parameter('a1')#, values=0.9)
a2              = Parameter('a2')#, values=0.6)
a4              = Parameter('a4')#, values=2.25)
a5              = Parameter('a5')#, values=1.5)
a6              = Parameter('a6')#, values=50)
a7              = Parameter('a7')#, values=2.25)
a8              = Parameter('a8')#, values=15.5)
a10             = Parameter('a10')#, values=23.25)
a11             = Parameter('a11')#, values=1.5)
a12             = Parameter('a12')#, values=150)
a13             = Parameter('a13')#, values=9.3)
a14             = Parameter('a14')#, values=2.25)

def inv_pend(p, v, alpha, omega, u):
    # Equations of motion for the inverted pendulum on a cart
    sin_theta = Sin(alpha)
    cos_theta = Cos(alpha)
    sigma = a13-(a14*cos_theta)**2
    
    # Friction
    friction_cart = a2*v
    friction_pend = a8*omega

    # Linear acceleration of the cart (v_dot)
    v_dot = (a1*omega**2*sin_theta
             - friction_cart
             - a4*g*cos_theta*sin_theta
             + a5*omega*cos_theta
             + a6*u
    )/ sigma

    # Angular acceleration (omega_dot)
    omega_dot = (- a7*omega**2*cos_theta*sin_theta
                 - friction_pend
                 + a10*g*sin_theta
                 + a11*v*cos_theta
                 - a12*cos_theta*u
    )/ sigma

    p_dot = v
    alpha_dot = omega

    return [p_dot, v_dot, alpha_dot, omega_dot]

# Adding noise to the inputs
x_noisy = pos.last() + noise4.last()*sigma_x
vel_noisy = velocity.last() + noise1.last()*sigma_v
ang_vel_noisy = angular_velocity.last() + noise3.last()*sigma_omega
theta_noisy = angle.last() + noise2.last()*sigma_theta
F_noisy = F.last() + noise5.last() * sigma_force

# Runge-Kutta 4th order method
k1 = inv_pend(x_noisy, vel_noisy, theta_noisy, ang_vel_noisy, F_noisy)
k2 = inv_pend(x_noisy + k1[0]*dt/2, vel_noisy + k1[1]*dt/2, theta_noisy + k1[2]*dt/2, ang_vel_noisy + k1[3]*dt/2, F_noisy)
k3 = inv_pend(x_noisy + k2[0]*dt/2, vel_noisy + k2[1]*dt/2, theta_noisy + k2[2]*dt/2, ang_vel_noisy + k2[3]*dt/2, F_noisy)
k4 = inv_pend(x_noisy + k3[0]*dt, vel_noisy + k3[1]*dt, theta_noisy + k3[2]*dt, ang_vel_noisy + k3[3]*dt, F_noisy)

# Update state variables
dt_xdot = (k1[1] + 2*k2[1] + 2*k3[1] + k4[1])*dt/6
xdot = vel_noisy + dt_xdot
xdot.closedLoop(velocity)

dt_x = (k1[0] + 2*k2[0] + 2*k3[0] + k4[0])*dt/6
x = x_noisy + dt_x
x.closedLoop(pos)

dt_thetadot = (k1[3] + 2*k2[3] + 2*k3[3] + k4[3])*dt/6
thetadot = ang_vel_noisy + dt_thetadot
thetadot.closedLoop(angular_velocity)

dt_theta = (k1[2] + 2*k2[2] + 2*k3[2] + k4[2])*dt/6
theta = theta_noisy + dt_theta
theta.closedLoop(angle)

# Remove noise on states in closed-loop predictions
zero = pos.last() * 0.0
noise1.closedLoop(zero)
noise2.closedLoop(zero)
noise3.closedLoop(zero)
noise4.closedLoop(zero)

# Output and loss
est_theta = Output('est_theta', theta)
est_thetadot = Output('est_thetadot', thetadot)
est_xdot = Output('est_xdot', xdot)
est_x = Output('est_x', x)

inverted_pendulum.addModel('pendulum', [est_thetadot, est_theta, est_xdot, est_x])
inverted_pendulum.addMinimize('ang_vel_error', Yangular_velocity.last(), thetadot, loss_function='mse')
inverted_pendulum.addMinimize('angle_error', Yangle.last(), theta, loss_function='mse')
inverted_pendulum.addMinimize('vel_error', Yvelocity.last(), xdot, loss_function='mse')
inverted_pendulum.addMinimize('pos_error', Ypos.last(), x, loss_function='mse')
inverted_pendulum.neuralizeModel(sample_time = 0.02)
# Out:
# [neuralizeModel] Closed loop on Xpos with sample in the future.
# [neuralizeModel] Closed loop on Xangle with sample in the future.
# [neuralizeModel] Closed loop on Xvelocity with sample in the future.
# [neuralizeModel] Closed loop on Xangular_velocity with sample in the future.
# ================================ nnodely Model =================================
# {'Constants': {'Constant34': {'dim': 1, 'values': [2.0]},
#                'Constant35': {'dim': 1, 'values': [2.0]},
#                'Constant36': {'dim': 1, 'values': [2.0]},
#                'Constant38': {'dim': 1, 'values': [2.0]},
#                'Constant39': {'dim': 1, 'values': [2.0]},
#                'Constant40': {'dim': 1, 'values': [2.0]},
#                'Constant41': {'dim': 1, 'values': [2.0]},
#                'Constant42': {'dim': 1, 'values': [2.0]},
#                'Constant43': {'dim': 1, 'values': [2.0]},
#                'Constant45': {'dim': 1, 'values': [2.0]},
#                'Constant46': {'dim': 1, 'values': [2.0]},
#                'Constant47': {'dim': 1, 'values': [2.0]},
#                'Constant48': {'dim': 1, 'values': [2.0]},
#                'Constant49': {'dim': 1, 'values': [2.0]},
#                'Constant50': {'dim': 1, 'values': [2.0]},
#                'Constant51': {'dim': 1, 'values': [2.0]},
#                'Constant52': {'dim': 1, 'values': [2.0]},
#                'Constant53': {'dim': 1, 'values': [2.0]},
#                'Constant54': {'dim': 1, 'values': [2.0]},
#                'Constant55': {'dim': 1, 'values': [2.0]},
#                'Constant56': {'dim': 1, 'values': [6.0]},
#                'Constant57': {'dim': 1, 'values': [2.0]},
#                'Constant58': {'dim': 1, 'values': [2.0]},
#                'Constant59': {'dim': 1, 'values': [6.0]},
#                'Constant60': {'dim': 1, 'values': [2.0]},
#                'Constant61': {'dim': 1, 'values': [2.0]},
#                'Constant62': {'dim': 1, 'values': [6.0]},
#                'Constant63': {'dim': 1, 'values': [2.0]},
#                'Constant64': {'dim': 1, 'values': [2.0]},
#                'Constant65': {'dim': 1, 'values': [6.0]},
#                'dt': {'dim': 1, 'values': [0.019999999552965164]},
#                'g': {'dim': 1, 'values': [9.8100004196167]},
#                'sigma_force': {'dim': 1, 'values': [0.0]},
#                'sigma_omega': {'dim': 1, 'values': [0.0]},
#                'sigma_theta': {'dim': 1, 'values': [0.0]},
#                'sigma_v': {'dim': 1, 'values': [0.0]},
#                'sigma_x': {'dim': 1, 'values': [0.0]}},
#  'Functions': {},
#  'Info': {'SampleTime': 0.02,
#           'nnodely_version': '1.5.2',
#           'ns': [1, 0],
#           'ntot': 1,
#           'num_parameters': 12},
#  'Inputs': {'Xangle': {'closedLoop': 'Add350',
#                        'dim': 1,
#                        'local': 1,
#                        'ns': [1, 0],
#                        'ntot': 1,
#                        'sw': [-1, 0]},
#             'Xangular_velocity': {'closedLoop': 'Add338',
#                                   'dim': 1,
#                                   'local': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Xpos': {'closedLoop': 'Add326',
#                      'dim': 1,
#                      'local': 1,
#                      'ns': [1, 0],
#                      'ntot': 1,
#                      'sw': [-1, 0]},
#             'Xvelocity': {'closedLoop': 'Add314',
#                           'dim': 1,
#                           'local': 1,
#                           'ns': [1, 0],
#                           'ntot': 1,
#                           'sw': [-1, 0]},
#             'Yangle': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yangular_velocity': {'dim': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Ypos': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yvelocity': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'action': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise1': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise2': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise3': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise4': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise5': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]}},
#  'Minimizers': {'ang_vel_error': {'A': 'SamplePart356',
#                                   'B': 'Add338',
#                                   'loss': 'mse'},
#                 'angle_error': {'A': 'SamplePart358',
#                                 'B': 'Add350',
#                                 'loss': 'mse'},
#                 'pos_error': {'A': 'SamplePart362',
#                               'B': 'Add326',
#                               'loss': 'mse'},
#                 'vel_error': {'A': 'SamplePart360',
#                               'B': 'Add314',
#                               'loss': 'mse'}},
#  'Models': 'pendulum',
#  'Outputs': {'est_theta': 'Add350',
#              'est_thetadot': 'Add338',
#              'est_x': 'Add326',
#              'est_xdot': 'Add314'},
#  'Parameters': {'a1': {'dim': 1, 'values': [0.3394845724105835]},
#                 'a10': {'dim': 1, 'values': [0.8054096102714539]},
#                 'a11': {'dim': 1, 'values': [0.24077892303466797]},
#                 'a12': {'dim': 1, 'values': [0.134421706199646]},
#                 'a13': {'dim': 1, 'values': [0.8833909034729004]},
#                 'a14': {'dim': 1, 'values': [0.7369095087051392]},
#                 'a2': {'dim': 1, 'values': [0.5252781510353088]},
#                 'a4': {'dim': 1, 'values': [0.020892798900604248]},
#                 'a5': {'dim': 1, 'values': [0.9828428030014038]},
#                 'a6': {'dim': 1, 'values': [0.5858309864997864]},
#                 'a7': {'dim': 1, 'values': [0.9259058237075806]},
#                 'a8': {'dim': 1, 'values': [0.8528372049331665]}},
#  'Relations': {'Add103': ['Add', ['Add27', 'Div102']],
#                'Add108': ['Add', ['Add20', 'Div107']],
#                'Add13': ['Add', ['SamplePart8', 'Mul12']],
#                'Add136': ['Add', ['Sub132', 'Mul135']],
#                'Add139': ['Add', ['Add136', 'Mul138']],
#                'Add153': ['Add', ['Sub148', 'Mul152']],
#                'Add157': ['Add', ['Add153', 'Mul156']],
#                'Add172': ['Add', ['Add13', 'Div171']],
#                'Add177': ['Add', ['Add27', 'Div176']],
#                'Add182': ['Add', ['Add20', 'Div181']],
#                'Add20': ['Add', ['SamplePart15', 'Mul19']],
#                'Add210': ['Add', ['Sub206', 'Mul209']],
#                'Add213': ['Add', ['Add210', 'Mul212']],
#                'Add227': ['Add', ['Sub222', 'Mul226']],
#                'Add231': ['Add', ['Add227', 'Mul230']],
#                'Add242': ['Add', ['Add13', 'Mul241']],
#                'Add245': ['Add', ['Add27', 'Mul244']],
#                'Add248': ['Add', ['Add20', 'Mul247']],
#                'Add27': ['Add', ['SamplePart22', 'Mul26']],
#                'Add276': ['Add', ['Sub272', 'Mul275']],
#                'Add279': ['Add', ['Add276', 'Mul278']],
#                'Add293': ['Add', ['Sub288', 'Mul292']],
#                'Add297': ['Add', ['Add293', 'Mul296']],
#                'Add305': ['Add', ['Div66', 'Mul304']],
#                'Add308': ['Add', ['Add305', 'Mul307']],
#                'Add309': ['Add', ['Add308', 'Div280']],
#                'Add314': ['Add', ['Add13', 'Div313']],
#                'Add317': ['Add', ['Add13', 'Mul316']],
#                'Add320': ['Add', ['Add317', 'Mul319']],
#                'Add321': ['Add', ['Add320', 'Add242']],
#                'Add326': ['Add', ['Add6', 'Div325']],
#                'Add329': ['Add', ['Div88', 'Mul328']],
#                'Add332': ['Add', ['Add329', 'Mul331']],
#                'Add333': ['Add', ['Add332', 'Div302']],
#                'Add338': ['Add', ['Add20', 'Div337']],
#                'Add34': ['Add', ['SamplePart29', 'Mul33']],
#                'Add341': ['Add', ['Add20', 'Mul340']],
#                'Add344': ['Add', ['Add341', 'Mul343']],
#                'Add345': ['Add', ['Add344', 'Add248']],
#                'Add350': ['Add', ['Add27', 'Div349']],
#                'Add6': ['Add', ['SamplePart1', 'Mul5']],
#                'Add62': ['Add', ['Sub58', 'Mul61']],
#                'Add65': ['Add', ['Add62', 'Mul64']],
#                'Add79': ['Add', ['Sub74', 'Mul78']],
#                'Add83': ['Add', ['Add79', 'Mul82']],
#                'Add98': ['Add', ['Add13', 'Div97']],
#                'Cos110': ['Cos', ['Add103']],
#                'Cos184': ['Cos', ['Add177']],
#                'Cos250': ['Cos', ['Add245']],
#                'Cos36': ['Cos', ['Add27']],
#                'Div102': ['Div', ['Mul100', 'Constant39']],
#                'Div107': ['Div', ['Mul105', 'Constant40']],
#                'Div140': ['Div', ['Add139', 'Sub116']],
#                'Div162': ['Div', ['Sub161', 'Sub116']],
#                'Div171': ['Div', ['Mul169', 'Constant45']],
#                'Div176': ['Div', ['Mul174', 'Constant46']],
#                'Div181': ['Div', ['Mul179', 'Constant47']],
#                'Div214': ['Div', ['Add213', 'Sub190']],
#                'Div236': ['Div', ['Sub235', 'Sub190']],
#                'Div280': ['Div', ['Add279', 'Sub256']],
#                'Div302': ['Div', ['Sub301', 'Sub256']],
#                'Div313': ['Div', ['Mul311', 'Constant56']],
#                'Div325': ['Div', ['Mul323', 'Constant59']],
#                'Div337': ['Div', ['Mul335', 'Constant62']],
#                'Div349': ['Div', ['Mul347', 'Constant65']],
#                'Div66': ['Div', ['Add65', 'Sub42']],
#                'Div88': ['Div', ['Sub87', 'Sub42']],
#                'Div97': ['Div', ['Mul95', 'Constant38']],
#                'Mul100': ['Mul', ['Add20', 'dt']],
#                'Mul105': ['Mul', ['Div88', 'dt']],
#                'Mul112': ['Mul', ['a14', 'Cos110']],
#                'Mul118': ['Mul', ['a2', 'Add98']],
#                'Mul12': ['Mul', ['SamplePart10', 'sigma_v']],
#                'Mul120': ['Mul', ['a8', 'Add108']],
#                'Mul124': ['Mul', ['a1', 'Pow122']],
#                'Mul125': ['Mul', ['Mul124', 'Sin109']],
#                'Mul129': ['Mul', ['a4', 'g']],
#                'Mul130': ['Mul', ['Mul129', 'Cos110']],
#                'Mul131': ['Mul', ['Mul130', 'Sin109']],
#                'Mul134': ['Mul', ['a5', 'Add108']],
#                'Mul135': ['Mul', ['Mul134', 'Cos110']],
#                'Mul138': ['Mul', ['a6', 'Add34']],
#                'Mul145': ['Mul', ['Neg142', 'Pow144']],
#                'Mul146': ['Mul', ['Mul145', 'Cos110']],
#                'Mul147': ['Mul', ['Mul146', 'Sin109']],
#                'Mul151': ['Mul', ['a10', 'g']],
#                'Mul152': ['Mul', ['Mul151', 'Sin109']],
#                'Mul155': ['Mul', ['a11', 'Add98']],
#                'Mul156': ['Mul', ['Mul155', 'Cos110']],
#                'Mul159': ['Mul', ['a12', 'Cos110']],
#                'Mul160': ['Mul', ['Mul159', 'Add34']],
#                'Mul169': ['Mul', ['Div140', 'dt']],
#                'Mul174': ['Mul', ['Add108', 'dt']],
#                'Mul179': ['Mul', ['Div162', 'dt']],
#                'Mul186': ['Mul', ['a14', 'Cos184']],
#                'Mul19': ['Mul', ['SamplePart17', 'sigma_omega']],
#                'Mul192': ['Mul', ['a2', 'Add172']],
#                'Mul194': ['Mul', ['a8', 'Add182']],
#                'Mul198': ['Mul', ['a1', 'Pow196']],
#                'Mul199': ['Mul', ['Mul198', 'Sin183']],
#                'Mul203': ['Mul', ['a4', 'g']],
#                'Mul204': ['Mul', ['Mul203', 'Cos184']],
#                'Mul205': ['Mul', ['Mul204', 'Sin183']],
#                'Mul208': ['Mul', ['a5', 'Add182']],
#                'Mul209': ['Mul', ['Mul208', 'Cos184']],
#                'Mul212': ['Mul', ['a6', 'Add34']],
#                'Mul219': ['Mul', ['Neg216', 'Pow218']],
#                'Mul220': ['Mul', ['Mul219', 'Cos184']],
#                'Mul221': ['Mul', ['Mul220', 'Sin183']],
#                'Mul225': ['Mul', ['a10', 'g']],
#                'Mul226': ['Mul', ['Mul225', 'Sin183']],
#                'Mul229': ['Mul', ['a11', 'Add172']],
#                'Mul230': ['Mul', ['Mul229', 'Cos184']],
#                'Mul233': ['Mul', ['a12', 'Cos184']],
#                'Mul234': ['Mul', ['Mul233', 'Add34']],
#                'Mul241': ['Mul', ['Div214', 'dt']],
#                'Mul244': ['Mul', ['Add182', 'dt']],
#                'Mul247': ['Mul', ['Div236', 'dt']],
#                'Mul252': ['Mul', ['a14', 'Cos250']],
#                'Mul258': ['Mul', ['a2', 'Add242']],
#                'Mul26': ['Mul', ['SamplePart24', 'sigma_theta']],
#                'Mul260': ['Mul', ['a8', 'Add248']],
#                'Mul264': ['Mul', ['a1', 'Pow262']],
#                'Mul265': ['Mul', ['Mul264', 'Sin249']],
#                'Mul269': ['Mul', ['a4', 'g']],
#                'Mul270': ['Mul', ['Mul269', 'Cos250']],
#                'Mul271': ['Mul', ['Mul270', 'Sin249']],
#                'Mul274': ['Mul', ['a5', 'Add248']],
#                'Mul275': ['Mul', ['Mul274', 'Cos250']],
#                'Mul278': ['Mul', ['a6', 'Add34']],
#                'Mul285': ['Mul', ['Neg282', 'Pow284']],
#                'Mul286': ['Mul', ['Mul285', 'Cos250']],
#                'Mul287': ['Mul', ['Mul286', 'Sin249']],
#                'Mul291': ['Mul', ['a10', 'g']],
#                'Mul292': ['Mul', ['Mul291', 'Sin249']],
#                'Mul295': ['Mul', ['a11', 'Add242']],
#                'Mul296': ['Mul', ['Mul295', 'Cos250']],
#                'Mul299': ['Mul', ['a12', 'Cos250']],
#                'Mul300': ['Mul', ['Mul299', 'Add34']],
#                'Mul304': ['Mul', ['Constant54', 'Div140']],
#                'Mul307': ['Mul', ['Constant55', 'Div214']],
#                'Mul311': ['Mul', ['Add309', 'dt']],
#                'Mul316': ['Mul', ['Constant57', 'Add98']],
#                'Mul319': ['Mul', ['Constant58', 'Add172']],
#                'Mul323': ['Mul', ['Add321', 'dt']],
#                'Mul328': ['Mul', ['Constant60', 'Div162']],
#                'Mul33': ['Mul', ['SamplePart31', 'sigma_force']],
#                'Mul331': ['Mul', ['Constant61', 'Div236']],
#                'Mul335': ['Mul', ['Add333', 'dt']],
#                'Mul340': ['Mul', ['Constant63', 'Add108']],
#                'Mul343': ['Mul', ['Constant64', 'Add182']],
#                'Mul347': ['Mul', ['Add345', 'dt']],
#                'Mul38': ['Mul', ['a14', 'Cos36']],
#                'Mul44': ['Mul', ['a2', 'Add13']],
#                'Mul46': ['Mul', ['a8', 'Add20']],
#                'Mul5': ['Mul', ['SamplePart3', 'sigma_x']],
#                'Mul50': ['Mul', ['a1', 'Pow48']],
#                'Mul51': ['Mul', ['Mul50', 'Sin35']],
#                'Mul55': ['Mul', ['a4', 'g']],
#                'Mul56': ['Mul', ['Mul55', 'Cos36']],
#                'Mul57': ['Mul', ['Mul56', 'Sin35']],
#                'Mul60': ['Mul', ['a5', 'Add20']],
#                'Mul61': ['Mul', ['Mul60', 'Cos36']],
#                'Mul64': ['Mul', ['a6', 'Add34']],
#                'Mul71': ['Mul', ['Neg68', 'Pow70']],
#                'Mul72': ['Mul', ['Mul71', 'Cos36']],
#                'Mul73': ['Mul', ['Mul72', 'Sin35']],
#                'Mul77': ['Mul', ['a10', 'g']],
#                'Mul78': ['Mul', ['Mul77', 'Sin35']],
#                'Mul81': ['Mul', ['a11', 'Add13']],
#                'Mul82': ['Mul', ['Mul81', 'Cos36']],
#                'Mul85': ['Mul', ['a12', 'Cos36']],
#                'Mul86': ['Mul', ['Mul85', 'Add34']],
#                'Mul95': ['Mul', ['Div66', 'dt']],
#                'Neg142': ['Neg', ['a7']],
#                'Neg216': ['Neg', ['a7']],
#                'Neg282': ['Neg', ['a7']],
#                'Neg68': ['Neg', ['a7']],
#                'Pow114': ['Pow', ['Mul112', 'Constant41']],
#                'Pow122': ['Pow', ['Add108', 'Constant42']],
#                'Pow144': ['Pow', ['Add108', 'Constant43']],
#                'Pow188': ['Pow', ['Mul186', 'Constant48']],
#                'Pow196': ['Pow', ['Add182', 'Constant49']],
#                'Pow218': ['Pow', ['Add182', 'Constant50']],
#                'Pow254': ['Pow', ['Mul252', 'Constant51']],
#                'Pow262': ['Pow', ['Add248', 'Constant52']],
#                'Pow284': ['Pow', ['Add248', 'Constant53']],
#                'Pow40': ['Pow', ['Mul38', 'Constant34']],
#                'Pow48': ['Pow', ['Add20', 'Constant35']],
#                'Pow70': ['Pow', ['Add20', 'Constant36']],
#                'SamplePart1': ['SamplePart', ['Xpos'], -1, [-1, 0]],
#                'SamplePart10': ['SamplePart', ['noise1'], -1, [-1, 0]],
#                'SamplePart15': ['SamplePart',
#                                 ['Xangular_velocity'],
#                                 -1,
#                                 [-1, 0]],
#                'SamplePart17': ['SamplePart', ['noise3'], -1, [-1, 0]],
#                'SamplePart22': ['SamplePart', ['Xangle'], -1, [-1, 0]],
#                'SamplePart24': ['SamplePart', ['noise2'], -1, [-1, 0]],
#                'SamplePart29': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart3': ['SamplePart', ['noise4'], -1, [-1, 0]],
#                'SamplePart31': ['SamplePart', ['noise5'], -1, [-1, 0]],
#                'SamplePart356': ['SamplePart',
#                                  ['Yangular_velocity'],
#                                  -1,
#                                  [-1, 0]],
#                'SamplePart358': ['SamplePart', ['Yangle'], -1, [-1, 0]],
#                'SamplePart360': ['SamplePart', ['Yvelocity'], -1, [-1, 0]],
#                'SamplePart362': ['SamplePart', ['Ypos'], -1, [-1, 0]],
#                'SamplePart8': ['SamplePart', ['Xvelocity'], -1, [-1, 0]],
#                'Sin109': ['Sin', ['Add103']],
#                'Sin183': ['Sin', ['Add177']],
#                'Sin249': ['Sin', ['Add245']],
#                'Sin35': ['Sin', ['Add27']],
#                'Sub116': ['Sub', ['a13', 'Pow114']],
#                'Sub126': ['Sub', ['Mul125', 'Mul118']],
#                'Sub132': ['Sub', ['Sub126', 'Mul131']],
#                'Sub148': ['Sub', ['Mul147', 'Mul120']],
#                'Sub161': ['Sub', ['Add157', 'Mul160']],
#                'Sub190': ['Sub', ['a13', 'Pow188']],
#                'Sub200': ['Sub', ['Mul199', 'Mul192']],
#                'Sub206': ['Sub', ['Sub200', 'Mul205']],
#                'Sub222': ['Sub', ['Mul221', 'Mul194']],
#                'Sub235': ['Sub', ['Add231', 'Mul234']],
#                'Sub256': ['Sub', ['a13', 'Pow254']],
#                'Sub266': ['Sub', ['Mul265', 'Mul258']],
#                'Sub272': ['Sub', ['Sub266', 'Mul271']],
#                'Sub288': ['Sub', ['Mul287', 'Mul260']],
#                'Sub301': ['Sub', ['Add297', 'Mul300']],
#                'Sub42': ['Sub', ['a13', 'Pow40']],
#                'Sub52': ['Sub', ['Mul51', 'Mul44']],
#                'Sub58': ['Sub', ['Sub52', 'Mul57']],
#                'Sub74': ['Sub', ['Mul73', 'Mul46']],
#                'Sub87': ['Sub', ['Add83', 'Mul86']]}}
# ================================================================================

# %%
# Data loading
import torch
torch.set_num_threads(4)
data_struct = ['time', 'action', 'Xpos', 'Xangle', 'Xvelocity', 'Xangular_velocity', 'Ypos', 'Yangle', 'Yvelocity', 'Yangular_velocity', 'noise1', 'noise2', 'noise3', 'noise4', 'noise5', 'acc', 'ang_acc']
data_folder = os.path.join(os.path.abspath(''), 'data')
inverted_pendulum.loadData(name='data', source=data_folder, format=data_struct, delimiter=',', header=0)
data_folder = os.path.join(os.path.abspath(''), 'data_val')
inverted_pendulum.loadData(name='data_val', source=data_folder, format=data_struct, delimiter=',', header=0)
data_folder = os.path.join(os.path.abspath(''),'data_test')
inverted_pendulum.loadData(name='data_test', source=data_folder, format=data_struct, delimiter=',', header=0)
# Out:
# ============================ nnodely Model Dataset =============================
# Dataset Name:                 data
# Number of files:              150
# Total number of samples:      22500
# Shape of Xpos:                (22500, 1, 1)
# Shape of noise2:              (22500, 1, 1)
# Shape of Xangle:              (22500, 1, 1)
# Shape of noise5:              (22500, 1, 1)
# Shape of action:              (22500, 1, 1)
# Shape of noise1:              (22500, 1, 1)
# Shape of Xvelocity:           (22500, 1, 1)
# Shape of noise3:              (22500, 1, 1)
# Shape of Xangular_velocity:   (22500, 1, 1)
# Shape of noise4:              (22500, 1, 1)
# Shape of Ypos:                (22500, 1, 1)
# Shape of Yvelocity:           (22500, 1, 1)
# Shape of Yangle:              (22500, 1, 1)
# Shape of Yangular_velocity:   (22500, 1, 1)
# ================================================================================
# ============================ nnodely Model Dataset =============================
# Dataset Name:                 data_val
# Number of files:              100
# Total number of samples:      15000
# Shape of Xpos:                (15000, 1, 1)
# Shape of noise2:              (15000, 1, 1)
# Shape of Xangle:              (15000, 1, 1)
# Shape of noise5:              (15000, 1, 1)
# Shape of action:              (15000, 1, 1)
# Shape of noise1:              (15000, 1, 1)
# Shape of Xvelocity:           (15000, 1, 1)
# Shape of noise3:              (15000, 1, 1)
# Shape of Xangular_velocity:   (15000, 1, 1)
# Shape of noise4:              (15000, 1, 1)
# Shape of Ypos:                (15000, 1, 1)
# Shape of Yvelocity:           (15000, 1, 1)
# Shape of Yangle:              (15000, 1, 1)
# Shape of Yangular_velocity:   (15000, 1, 1)
# ================================================================================
# ============================ nnodely Model Dataset =============================
# Dataset Name:                 data_test
# Number of files:              150
# Total number of samples:      22500
# Shape of Xpos:                (22500, 1, 1)
# Shape of noise2:              (22500, 1, 1)
# Shape of Xangle:              (22500, 1, 1)
# Shape of noise5:              (22500, 1, 1)
# Shape of action:              (22500, 1, 1)
# Shape of noise1:              (22500, 1, 1)
# Shape of Xvelocity:           (22500, 1, 1)
# Shape of noise3:              (22500, 1, 1)
# Shape of Xangular_velocity:   (22500, 1, 1)
# Shape of noise4:              (22500, 1, 1)
# Shape of Ypos:                (22500, 1, 1)
# Shape of Yvelocity:           (22500, 1, 1)
# Shape of Yangle:              (22500, 1, 1)
# Shape of Yangular_velocity:   (22500, 1, 1)
# ================================================================================

# %%
# Training
prediction_samples = None
step = None
early_stop_patience = 10
inverted_pendulum.exportPythonModel(name=model_name)
inverted_pendulum.importPythonModel(name=model_name)
inverted_pendulum.neuralizeModel(sample_time = 0.02)
params = {'train_batch_size':64, 'num_of_epochs':200}
inverted_pendulum.trainModel(train_dataset='data', validation_dataset='data_val', optimizer='Adam', prediction_samples=prediction_samples, step=step, training_params=params, early_stopping=earlystopping.early_stop_patience,  
                                                            early_stopping_params={'patience':early_stop_patience}, select_model=earlystopping.select_best_model, lr=1e-3)
inverted_pendulum.exportPythonModel(name=model_name)
# Out:
# =============================== Save JSON Model ================================
# Model saved in:               /home/baro/Desktop/inv_pend/rk4_models/saved_models/partially_neuralized.json
# ================================================================================
# ========================== Export Python Torch Model ===========================
# Model exported in:            /home/baro/Desktop/inv_pend/rk4_models/saved_models/partially_neuralized.py
# ================================================================================
# =============================== Load JSON Model ================================
# Model loaded from:            /home/baro/Desktop/inv_pend/rk4_models/saved_models/partially_neuralized.json
# ================================================================================
# [neuralizeModel] Closed loop on Xangle with sample in the future.
# [neuralizeModel] Closed loop on Xangular_velocity with sample in the future.
# [neuralizeModel] Closed loop on Xpos with sample in the future.
# [neuralizeModel] Closed loop on Xvelocity with sample in the future.
# ================================ nnodely Model =================================
# {'Constants': {'Constant34': {'dim': 1, 'values': [2.0]},
#                'Constant35': {'dim': 1, 'values': [2.0]},
#                'Constant36': {'dim': 1, 'values': [2.0]},
#                'Constant38': {'dim': 1, 'values': [2.0]},
#                'Constant39': {'dim': 1, 'values': [2.0]},
#                'Constant40': {'dim': 1, 'values': [2.0]},
#                'Constant41': {'dim': 1, 'values': [2.0]},
#                'Constant42': {'dim': 1, 'values': [2.0]},
#                'Constant43': {'dim': 1, 'values': [2.0]},
#                'Constant45': {'dim': 1, 'values': [2.0]},
#                'Constant46': {'dim': 1, 'values': [2.0]},
#                'Constant47': {'dim': 1, 'values': [2.0]},
#                'Constant48': {'dim': 1, 'values': [2.0]},
#                'Constant49': {'dim': 1, 'values': [2.0]},
#                'Constant50': {'dim': 1, 'values': [2.0]},
#                'Constant51': {'dim': 1, 'values': [2.0]},
#                'Constant52': {'dim': 1, 'values': [2.0]},
#                'Constant53': {'dim': 1, 'values': [2.0]},
#                'Constant54': {'dim': 1, 'values': [2.0]},
#                'Constant55': {'dim': 1, 'values': [2.0]},
#                'Constant56': {'dim': 1, 'values': [6.0]},
#                'Constant57': {'dim': 1, 'values': [2.0]},
#                'Constant58': {'dim': 1, 'values': [2.0]},
#                'Constant59': {'dim': 1, 'values': [6.0]},
#                'Constant60': {'dim': 1, 'values': [2.0]},
#                'Constant61': {'dim': 1, 'values': [2.0]},
#                'Constant62': {'dim': 1, 'values': [6.0]},
#                'Constant63': {'dim': 1, 'values': [2.0]},
#                'Constant64': {'dim': 1, 'values': [2.0]},
#                'Constant65': {'dim': 1, 'values': [6.0]},
#                'dt': {'dim': 1, 'values': [0.019999999552965164]},
#                'g': {'dim': 1, 'values': [9.8100004196167]},
#                'sigma_force': {'dim': 1, 'values': [0.0]},
#                'sigma_omega': {'dim': 1, 'values': [0.0]},
#                'sigma_theta': {'dim': 1, 'values': [0.0]},
#                'sigma_v': {'dim': 1, 'values': [0.0]},
#                'sigma_x': {'dim': 1, 'values': [0.0]}},
#  'Functions': {},
#  'Info': {'SampleTime': 0.02,
#           'nnodely_version': '1.5.2',
#           'ns': [1, 0],
#           'ntot': 1,
#           'num_parameters': 12},
#  'Inputs': {'Xangle': {'closedLoop': 'Add350',
#                        'dim': 1,
#                        'local': 1,
#                        'ns': [1, 0],
#                        'ntot': 1,
#                        'sw': [-1, 0]},
#             'Xangular_velocity': {'closedLoop': 'Add338',
#                                   'dim': 1,
#                                   'local': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Xpos': {'closedLoop': 'Add326',
#                      'dim': 1,
#                      'local': 1,
#                      'ns': [1, 0],
#                      'ntot': 1,
#                      'sw': [-1, 0]},
#             'Xvelocity': {'closedLoop': 'Add314',
#                           'dim': 1,
#                           'local': 1,
#                           'ns': [1, 0],
#                           'ntot': 1,
#                           'sw': [-1, 0]},
#             'Yangle': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yangular_velocity': {'dim': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Ypos': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yvelocity': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'action': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise1': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise2': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise3': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise4': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise5': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]}},
#  'Minimizers': {'ang_vel_error': {'A': 'SamplePart356',
#                                   'B': 'Add338',
#                                   'loss': 'mse'},
#                 'angle_error': {'A': 'SamplePart358',
#                                 'B': 'Add350',
#                                 'loss': 'mse'},
#                 'pos_error': {'A': 'SamplePart362',
#                               'B': 'Add326',
#                               'loss': 'mse'},
#                 'vel_error': {'A': 'SamplePart360',
#                               'B': 'Add314',
#                               'loss': 'mse'}},
#  'Models': 'pendulum',
#  'Outputs': {'est_theta': 'Add350',
#              'est_thetadot': 'Add338',
#              'est_x': 'Add326',
#              'est_xdot': 'Add314'},
#  'Parameters': {'a1': {'dim': 1, 'values': [0.3394845724105835]},
#                 'a10': {'dim': 1, 'values': [0.8054096102714539]},
#                 'a11': {'dim': 1, 'values': [0.24077892303466797]},
#                 'a12': {'dim': 1, 'values': [0.134421706199646]},
#                 'a13': {'dim': 1, 'values': [0.8833909034729004]},
#                 'a14': {'dim': 1, 'values': [0.7369095087051392]},
#                 'a2': {'dim': 1, 'values': [0.5252781510353088]},
#                 'a4': {'dim': 1, 'values': [0.020892798900604248]},
#                 'a5': {'dim': 1, 'values': [0.9828428030014038]},
#                 'a6': {'dim': 1, 'values': [0.5858309864997864]},
#                 'a7': {'dim': 1, 'values': [0.9259058237075806]},
#                 'a8': {'dim': 1, 'values': [0.8528372049331665]}},
#  'Relations': {'Add103': ['Add', ['Add27', 'Div102']],
#                'Add108': ['Add', ['Add20', 'Div107']],
#                'Add13': ['Add', ['SamplePart8', 'Mul12']],
#                'Add136': ['Add', ['Sub132', 'Mul135']],
#                'Add139': ['Add', ['Add136', 'Mul138']],
#                'Add153': ['Add', ['Sub148', 'Mul152']],
#                'Add157': ['Add', ['Add153', 'Mul156']],
#                'Add172': ['Add', ['Add13', 'Div171']],
#                'Add177': ['Add', ['Add27', 'Div176']],
#                'Add182': ['Add', ['Add20', 'Div181']],
#                'Add20': ['Add', ['SamplePart15', 'Mul19']],
#                'Add210': ['Add', ['Sub206', 'Mul209']],
#                'Add213': ['Add', ['Add210', 'Mul212']],
#                'Add227': ['Add', ['Sub222', 'Mul226']],
#                'Add231': ['Add', ['Add227', 'Mul230']],
#                'Add242': ['Add', ['Add13', 'Mul241']],
#                'Add245': ['Add', ['Add27', 'Mul244']],
#                'Add248': ['Add', ['Add20', 'Mul247']],
#                'Add27': ['Add', ['SamplePart22', 'Mul26']],
#                'Add276': ['Add', ['Sub272', 'Mul275']],
#                'Add279': ['Add', ['Add276', 'Mul278']],
#                'Add293': ['Add', ['Sub288', 'Mul292']],
#                'Add297': ['Add', ['Add293', 'Mul296']],
#                'Add305': ['Add', ['Div66', 'Mul304']],
#                'Add308': ['Add', ['Add305', 'Mul307']],
#                'Add309': ['Add', ['Add308', 'Div280']],
#                'Add314': ['Add', ['Add13', 'Div313']],
#                'Add317': ['Add', ['Add13', 'Mul316']],
#                'Add320': ['Add', ['Add317', 'Mul319']],
#                'Add321': ['Add', ['Add320', 'Add242']],
#                'Add326': ['Add', ['Add6', 'Div325']],
#                'Add329': ['Add', ['Div88', 'Mul328']],
#                'Add332': ['Add', ['Add329', 'Mul331']],
#                'Add333': ['Add', ['Add332', 'Div302']],
#                'Add338': ['Add', ['Add20', 'Div337']],
#                'Add34': ['Add', ['SamplePart29', 'Mul33']],
#                'Add341': ['Add', ['Add20', 'Mul340']],
#                'Add344': ['Add', ['Add341', 'Mul343']],
#                'Add345': ['Add', ['Add344', 'Add248']],
#                'Add350': ['Add', ['Add27', 'Div349']],
#                'Add6': ['Add', ['SamplePart1', 'Mul5']],
#                'Add62': ['Add', ['Sub58', 'Mul61']],
#                'Add65': ['Add', ['Add62', 'Mul64']],
#                'Add79': ['Add', ['Sub74', 'Mul78']],
#                'Add83': ['Add', ['Add79', 'Mul82']],
#                'Add98': ['Add', ['Add13', 'Div97']],
#                'Cos110': ['Cos', ['Add103']],
#                'Cos184': ['Cos', ['Add177']],
#                'Cos250': ['Cos', ['Add245']],
#                'Cos36': ['Cos', ['Add27']],
#                'Div102': ['Div', ['Mul100', 'Constant39']],
#                'Div107': ['Div', ['Mul105', 'Constant40']],
#                'Div140': ['Div', ['Add139', 'Sub116']],
#                'Div162': ['Div', ['Sub161', 'Sub116']],
#                'Div171': ['Div', ['Mul169', 'Constant45']],
#                'Div176': ['Div', ['Mul174', 'Constant46']],
#                'Div181': ['Div', ['Mul179', 'Constant47']],
#                'Div214': ['Div', ['Add213', 'Sub190']],
#                'Div236': ['Div', ['Sub235', 'Sub190']],
#                'Div280': ['Div', ['Add279', 'Sub256']],
#                'Div302': ['Div', ['Sub301', 'Sub256']],
#                'Div313': ['Div', ['Mul311', 'Constant56']],
#                'Div325': ['Div', ['Mul323', 'Constant59']],
#                'Div337': ['Div', ['Mul335', 'Constant62']],
#                'Div349': ['Div', ['Mul347', 'Constant65']],
#                'Div66': ['Div', ['Add65', 'Sub42']],
#                'Div88': ['Div', ['Sub87', 'Sub42']],
#                'Div97': ['Div', ['Mul95', 'Constant38']],
#                'Mul100': ['Mul', ['Add20', 'dt']],
#                'Mul105': ['Mul', ['Div88', 'dt']],
#                'Mul112': ['Mul', ['a14', 'Cos110']],
#                'Mul118': ['Mul', ['a2', 'Add98']],
#                'Mul12': ['Mul', ['SamplePart10', 'sigma_v']],
#                'Mul120': ['Mul', ['a8', 'Add108']],
#                'Mul124': ['Mul', ['a1', 'Pow122']],
#                'Mul125': ['Mul', ['Mul124', 'Sin109']],
#                'Mul129': ['Mul', ['a4', 'g']],
#                'Mul130': ['Mul', ['Mul129', 'Cos110']],
#                'Mul131': ['Mul', ['Mul130', 'Sin109']],
#                'Mul134': ['Mul', ['a5', 'Add108']],
#                'Mul135': ['Mul', ['Mul134', 'Cos110']],
#                'Mul138': ['Mul', ['a6', 'Add34']],
#                'Mul145': ['Mul', ['Neg142', 'Pow144']],
#                'Mul146': ['Mul', ['Mul145', 'Cos110']],
#                'Mul147': ['Mul', ['Mul146', 'Sin109']],
#                'Mul151': ['Mul', ['a10', 'g']],
#                'Mul152': ['Mul', ['Mul151', 'Sin109']],
#                'Mul155': ['Mul', ['a11', 'Add98']],
#                'Mul156': ['Mul', ['Mul155', 'Cos110']],
#                'Mul159': ['Mul', ['a12', 'Cos110']],
#                'Mul160': ['Mul', ['Mul159', 'Add34']],
#                'Mul169': ['Mul', ['Div140', 'dt']],
#                'Mul174': ['Mul', ['Add108', 'dt']],
#                'Mul179': ['Mul', ['Div162', 'dt']],
#                'Mul186': ['Mul', ['a14', 'Cos184']],
#                'Mul19': ['Mul', ['SamplePart17', 'sigma_omega']],
#                'Mul192': ['Mul', ['a2', 'Add172']],
#                'Mul194': ['Mul', ['a8', 'Add182']],
#                'Mul198': ['Mul', ['a1', 'Pow196']],
#                'Mul199': ['Mul', ['Mul198', 'Sin183']],
#                'Mul203': ['Mul', ['a4', 'g']],
#                'Mul204': ['Mul', ['Mul203', 'Cos184']],
#                'Mul205': ['Mul', ['Mul204', 'Sin183']],
#                'Mul208': ['Mul', ['a5', 'Add182']],
#                'Mul209': ['Mul', ['Mul208', 'Cos184']],
#                'Mul212': ['Mul', ['a6', 'Add34']],
#                'Mul219': ['Mul', ['Neg216', 'Pow218']],
#                'Mul220': ['Mul', ['Mul219', 'Cos184']],
#                'Mul221': ['Mul', ['Mul220', 'Sin183']],
#                'Mul225': ['Mul', ['a10', 'g']],
#                'Mul226': ['Mul', ['Mul225', 'Sin183']],
#                'Mul229': ['Mul', ['a11', 'Add172']],
#                'Mul230': ['Mul', ['Mul229', 'Cos184']],
#                'Mul233': ['Mul', ['a12', 'Cos184']],
#                'Mul234': ['Mul', ['Mul233', 'Add34']],
#                'Mul241': ['Mul', ['Div214', 'dt']],
#                'Mul244': ['Mul', ['Add182', 'dt']],
#                'Mul247': ['Mul', ['Div236', 'dt']],
#                'Mul252': ['Mul', ['a14', 'Cos250']],
#                'Mul258': ['Mul', ['a2', 'Add242']],
#                'Mul26': ['Mul', ['SamplePart24', 'sigma_theta']],
#                'Mul260': ['Mul', ['a8', 'Add248']],
#                'Mul264': ['Mul', ['a1', 'Pow262']],
#                'Mul265': ['Mul', ['Mul264', 'Sin249']],
#                'Mul269': ['Mul', ['a4', 'g']],
#                'Mul270': ['Mul', ['Mul269', 'Cos250']],
#                'Mul271': ['Mul', ['Mul270', 'Sin249']],
#                'Mul274': ['Mul', ['a5', 'Add248']],
#                'Mul275': ['Mul', ['Mul274', 'Cos250']],
#                'Mul278': ['Mul', ['a6', 'Add34']],
#                'Mul285': ['Mul', ['Neg282', 'Pow284']],
#                'Mul286': ['Mul', ['Mul285', 'Cos250']],
#                'Mul287': ['Mul', ['Mul286', 'Sin249']],
#                'Mul291': ['Mul', ['a10', 'g']],
#                'Mul292': ['Mul', ['Mul291', 'Sin249']],
#                'Mul295': ['Mul', ['a11', 'Add242']],
#                'Mul296': ['Mul', ['Mul295', 'Cos250']],
#                'Mul299': ['Mul', ['a12', 'Cos250']],
#                'Mul300': ['Mul', ['Mul299', 'Add34']],
#                'Mul304': ['Mul', ['Constant54', 'Div140']],
#                'Mul307': ['Mul', ['Constant55', 'Div214']],
#                'Mul311': ['Mul', ['Add309', 'dt']],
#                'Mul316': ['Mul', ['Constant57', 'Add98']],
#                'Mul319': ['Mul', ['Constant58', 'Add172']],
#                'Mul323': ['Mul', ['Add321', 'dt']],
#                'Mul328': ['Mul', ['Constant60', 'Div162']],
#                'Mul33': ['Mul', ['SamplePart31', 'sigma_force']],
#                'Mul331': ['Mul', ['Constant61', 'Div236']],
#                'Mul335': ['Mul', ['Add333', 'dt']],
#                'Mul340': ['Mul', ['Constant63', 'Add108']],
#                'Mul343': ['Mul', ['Constant64', 'Add182']],
#                'Mul347': ['Mul', ['Add345', 'dt']],
#                'Mul38': ['Mul', ['a14', 'Cos36']],
#                'Mul44': ['Mul', ['a2', 'Add13']],
#                'Mul46': ['Mul', ['a8', 'Add20']],
#                'Mul5': ['Mul', ['SamplePart3', 'sigma_x']],
#                'Mul50': ['Mul', ['a1', 'Pow48']],
#                'Mul51': ['Mul', ['Mul50', 'Sin35']],
#                'Mul55': ['Mul', ['a4', 'g']],
#                'Mul56': ['Mul', ['Mul55', 'Cos36']],
#                'Mul57': ['Mul', ['Mul56', 'Sin35']],
#                'Mul60': ['Mul', ['a5', 'Add20']],
#                'Mul61': ['Mul', ['Mul60', 'Cos36']],
#                'Mul64': ['Mul', ['a6', 'Add34']],
#                'Mul71': ['Mul', ['Neg68', 'Pow70']],
#                'Mul72': ['Mul', ['Mul71', 'Cos36']],
#                'Mul73': ['Mul', ['Mul72', 'Sin35']],
#                'Mul77': ['Mul', ['a10', 'g']],
#                'Mul78': ['Mul', ['Mul77', 'Sin35']],
#                'Mul81': ['Mul', ['a11', 'Add13']],
#                'Mul82': ['Mul', ['Mul81', 'Cos36']],
#                'Mul85': ['Mul', ['a12', 'Cos36']],
#                'Mul86': ['Mul', ['Mul85', 'Add34']],
#                'Mul95': ['Mul', ['Div66', 'dt']],
#                'Neg142': ['Neg', ['a7']],
#                'Neg216': ['Neg', ['a7']],
#                'Neg282': ['Neg', ['a7']],
#                'Neg68': ['Neg', ['a7']],
#                'Pow114': ['Pow', ['Mul112', 'Constant41']],
#                'Pow122': ['Pow', ['Add108', 'Constant42']],
#                'Pow144': ['Pow', ['Add108', 'Constant43']],
#                'Pow188': ['Pow', ['Mul186', 'Constant48']],
#                'Pow196': ['Pow', ['Add182', 'Constant49']],
#                'Pow218': ['Pow', ['Add182', 'Constant50']],
#                'Pow254': ['Pow', ['Mul252', 'Constant51']],
#                'Pow262': ['Pow', ['Add248', 'Constant52']],
#                'Pow284': ['Pow', ['Add248', 'Constant53']],
#                'Pow40': ['Pow', ['Mul38', 'Constant34']],
#                'Pow48': ['Pow', ['Add20', 'Constant35']],
#                'Pow70': ['Pow', ['Add20', 'Constant36']],
#                'SamplePart1': ['SamplePart', ['Xpos'], -1, [-1, 0]],
#                'SamplePart10': ['SamplePart', ['noise1'], -1, [-1, 0]],
#                'SamplePart15': ['SamplePart',
#                                 ['Xangular_velocity'],
#                                 -1,
#                                 [-1, 0]],
#                'SamplePart17': ['SamplePart', ['noise3'], -1, [-1, 0]],
#                'SamplePart22': ['SamplePart', ['Xangle'], -1, [-1, 0]],
#                'SamplePart24': ['SamplePart', ['noise2'], -1, [-1, 0]],
#                'SamplePart29': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart3': ['SamplePart', ['noise4'], -1, [-1, 0]],
#                'SamplePart31': ['SamplePart', ['noise5'], -1, [-1, 0]],
#                'SamplePart356': ['SamplePart',
#                                  ['Yangular_velocity'],
#                                  -1,
#                                  [-1, 0]],
#                'SamplePart358': ['SamplePart', ['Yangle'], -1, [-1, 0]],
#                'SamplePart360': ['SamplePart', ['Yvelocity'], -1, [-1, 0]],
#                'SamplePart362': ['SamplePart', ['Ypos'], -1, [-1, 0]],
#                'SamplePart8': ['SamplePart', ['Xvelocity'], -1, [-1, 0]],
#                'Sin109': ['Sin', ['Add103']],
#                'Sin183': ['Sin', ['Add177']],
#                'Sin249': ['Sin', ['Add245']],
#                'Sin35': ['Sin', ['Add27']],
#                'Sub116': ['Sub', ['a13', 'Pow114']],
#                'Sub126': ['Sub', ['Mul125', 'Mul118']],
#                'Sub132': ['Sub', ['Sub126', 'Mul131']],
#                'Sub148': ['Sub', ['Mul147', 'Mul120']],
#                'Sub161': ['Sub', ['Add157', 'Mul160']],
#                'Sub190': ['Sub', ['a13', 'Pow188']],
#                'Sub200': ['Sub', ['Mul199', 'Mul192']],
#                'Sub206': ['Sub', ['Sub200', 'Mul205']],
#                'Sub222': ['Sub', ['Mul221', 'Mul194']],
#                'Sub235': ['Sub', ['Add231', 'Mul234']],
#                'Sub256': ['Sub', ['a13', 'Pow254']],
#                'Sub266': ['Sub', ['Mul265', 'Mul258']],
#                'Sub272': ['Sub', ['Sub266', 'Mul271']],
#                'Sub288': ['Sub', ['Mul287', 'Mul260']],
#                'Sub301': ['Sub', ['Add297', 'Mul300']],
#                'Sub42': ['Sub', ['a13', 'Pow40']],
#                'Sub52': ['Sub', ['Mul51', 'Mul44']],
#                'Sub58': ['Sub', ['Sub52', 'Mul57']],
#                'Sub74': ['Sub', ['Mul73', 'Mul46']],
#                'Sub87': ['Sub', ['Add83', 'Mul86']]}}
# ================================================================================
# ========================== Import Python Torch Model ===========================
# Model imported from:          /home/baro/Desktop/inv_pend/rk4_models/saved_models/partially_neuralized.py
# ================================================================================
# [neuralizeModel] Closed loop on Xangle with sample in the future.
# [neuralizeModel] Closed loop on Xangular_velocity with sample in the future.
# [neuralizeModel] Closed loop on Xpos with sample in the future.
# [neuralizeModel] Closed loop on Xvelocity with sample in the future.
# ================================ nnodely Model =================================
# {'Constants': {'Constant34': {'dim': 1, 'values': [2.0]},
#                'Constant35': {'dim': 1, 'values': [2.0]},
#                'Constant36': {'dim': 1, 'values': [2.0]},
#                'Constant38': {'dim': 1, 'values': [2.0]},
#                'Constant39': {'dim': 1, 'values': [2.0]},
#                'Constant40': {'dim': 1, 'values': [2.0]},
#                'Constant41': {'dim': 1, 'values': [2.0]},
#                'Constant42': {'dim': 1, 'values': [2.0]},
#                'Constant43': {'dim': 1, 'values': [2.0]},
#                'Constant45': {'dim': 1, 'values': [2.0]},
#                'Constant46': {'dim': 1, 'values': [2.0]},
#                'Constant47': {'dim': 1, 'values': [2.0]},
#                'Constant48': {'dim': 1, 'values': [2.0]},
#                'Constant49': {'dim': 1, 'values': [2.0]},
#                'Constant50': {'dim': 1, 'values': [2.0]},
#                'Constant51': {'dim': 1, 'values': [2.0]},
#                'Constant52': {'dim': 1, 'values': [2.0]},
#                'Constant53': {'dim': 1, 'values': [2.0]},
#                'Constant54': {'dim': 1, 'values': [2.0]},
#                'Constant55': {'dim': 1, 'values': [2.0]},
#                'Constant56': {'dim': 1, 'values': [6.0]},
#                'Constant57': {'dim': 1, 'values': [2.0]},
#                'Constant58': {'dim': 1, 'values': [2.0]},
#                'Constant59': {'dim': 1, 'values': [6.0]},
#                'Constant60': {'dim': 1, 'values': [2.0]},
#                'Constant61': {'dim': 1, 'values': [2.0]},
#                'Constant62': {'dim': 1, 'values': [6.0]},
#                'Constant63': {'dim': 1, 'values': [2.0]},
#                'Constant64': {'dim': 1, 'values': [2.0]},
#                'Constant65': {'dim': 1, 'values': [6.0]},
#                'dt': {'dim': 1, 'values': [0.019999999552965164]},
#                'g': {'dim': 1, 'values': [9.8100004196167]},
#                'sigma_force': {'dim': 1, 'values': [0.0]},
#                'sigma_omega': {'dim': 1, 'values': [0.0]},
#                'sigma_theta': {'dim': 1, 'values': [0.0]},
#                'sigma_v': {'dim': 1, 'values': [0.0]},
#                'sigma_x': {'dim': 1, 'values': [0.0]}},
#  'Functions': {},
#  'Info': {'SampleTime': 0.02,
#           'nnodely_version': '1.5.2',
#           'ns': [1, 0],
#           'ntot': 1,
#           'num_parameters': 12},
#  'Inputs': {'Xangle': {'closedLoop': 'Add350',
#                        'dim': 1,
#                        'local': 1,
#                        'ns': [1, 0],
#                        'ntot': 1,
#                        'sw': [-1, 0]},
#             'Xangular_velocity': {'closedLoop': 'Add338',
#                                   'dim': 1,
#                                   'local': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Xpos': {'closedLoop': 'Add326',
#                      'dim': 1,
#                      'local': 1,
#                      'ns': [1, 0],
#                      'ntot': 1,
#                      'sw': [-1, 0]},
#             'Xvelocity': {'closedLoop': 'Add314',
#                           'dim': 1,
#                           'local': 1,
#                           'ns': [1, 0],
#                           'ntot': 1,
#                           'sw': [-1, 0]},
#             'Yangle': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yangular_velocity': {'dim': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Ypos': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yvelocity': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'action': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise1': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise2': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise3': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise4': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise5': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]}},
#  'Minimizers': {'ang_vel_error': {'A': 'SamplePart356',
#                                   'B': 'Add338',
#                                   'loss': 'mse'},
#                 'angle_error': {'A': 'SamplePart358',
#                                 'B': 'Add350',
#                                 'loss': 'mse'},
#                 'pos_error': {'A': 'SamplePart362',
#                               'B': 'Add326',
#                               'loss': 'mse'},
#                 'vel_error': {'A': 'SamplePart360',
#                               'B': 'Add314',
#                               'loss': 'mse'}},
#  'Models': 'pendulum',
#  'Outputs': {'est_theta': 'Add350',
#              'est_thetadot': 'Add338',
#              'est_x': 'Add326',
#              'est_xdot': 'Add314'},
#  'Parameters': {'a1': {'dim': 1, 'values': [0.3394845724105835]},
#                 'a10': {'dim': 1, 'values': [0.8054096102714539]},
#                 'a11': {'dim': 1, 'values': [0.24077892303466797]},
#                 'a12': {'dim': 1, 'values': [0.134421706199646]},
#                 'a13': {'dim': 1, 'values': [0.8833909034729004]},
#                 'a14': {'dim': 1, 'values': [0.7369095087051392]},
#                 'a2': {'dim': 1, 'values': [0.5252781510353088]},
#                 'a4': {'dim': 1, 'values': [0.020892798900604248]},
#                 'a5': {'dim': 1, 'values': [0.9828428030014038]},
#                 'a6': {'dim': 1, 'values': [0.5858309864997864]},
#                 'a7': {'dim': 1, 'values': [0.9259058237075806]},
#                 'a8': {'dim': 1, 'values': [0.8528372049331665]}},
#  'Relations': {'Add103': ['Add', ['Add27', 'Div102']],
#                'Add108': ['Add', ['Add20', 'Div107']],
#                'Add13': ['Add', ['SamplePart8', 'Mul12']],
#                'Add136': ['Add', ['Sub132', 'Mul135']],
#                'Add139': ['Add', ['Add136', 'Mul138']],
#                'Add153': ['Add', ['Sub148', 'Mul152']],
#                'Add157': ['Add', ['Add153', 'Mul156']],
#                'Add172': ['Add', ['Add13', 'Div171']],
#                'Add177': ['Add', ['Add27', 'Div176']],
#                'Add182': ['Add', ['Add20', 'Div181']],
#                'Add20': ['Add', ['SamplePart15', 'Mul19']],
#                'Add210': ['Add', ['Sub206', 'Mul209']],
#                'Add213': ['Add', ['Add210', 'Mul212']],
#                'Add227': ['Add', ['Sub222', 'Mul226']],
#                'Add231': ['Add', ['Add227', 'Mul230']],
#                'Add242': ['Add', ['Add13', 'Mul241']],
#                'Add245': ['Add', ['Add27', 'Mul244']],
#                'Add248': ['Add', ['Add20', 'Mul247']],
#                'Add27': ['Add', ['SamplePart22', 'Mul26']],
#                'Add276': ['Add', ['Sub272', 'Mul275']],
#                'Add279': ['Add', ['Add276', 'Mul278']],
#                'Add293': ['Add', ['Sub288', 'Mul292']],
#                'Add297': ['Add', ['Add293', 'Mul296']],
#                'Add305': ['Add', ['Div66', 'Mul304']],
#                'Add308': ['Add', ['Add305', 'Mul307']],
#                'Add309': ['Add', ['Add308', 'Div280']],
#                'Add314': ['Add', ['Add13', 'Div313']],
#                'Add317': ['Add', ['Add13', 'Mul316']],
#                'Add320': ['Add', ['Add317', 'Mul319']],
#                'Add321': ['Add', ['Add320', 'Add242']],
#                'Add326': ['Add', ['Add6', 'Div325']],
#                'Add329': ['Add', ['Div88', 'Mul328']],
#                'Add332': ['Add', ['Add329', 'Mul331']],
#                'Add333': ['Add', ['Add332', 'Div302']],
#                'Add338': ['Add', ['Add20', 'Div337']],
#                'Add34': ['Add', ['SamplePart29', 'Mul33']],
#                'Add341': ['Add', ['Add20', 'Mul340']],
#                'Add344': ['Add', ['Add341', 'Mul343']],
#                'Add345': ['Add', ['Add344', 'Add248']],
#                'Add350': ['Add', ['Add27', 'Div349']],
#                'Add6': ['Add', ['SamplePart1', 'Mul5']],
#                'Add62': ['Add', ['Sub58', 'Mul61']],
#                'Add65': ['Add', ['Add62', 'Mul64']],
#                'Add79': ['Add', ['Sub74', 'Mul78']],
#                'Add83': ['Add', ['Add79', 'Mul82']],
#                'Add98': ['Add', ['Add13', 'Div97']],
#                'Cos110': ['Cos', ['Add103']],
#                'Cos184': ['Cos', ['Add177']],
#                'Cos250': ['Cos', ['Add245']],
#                'Cos36': ['Cos', ['Add27']],
#                'Div102': ['Div', ['Mul100', 'Constant39']],
#                'Div107': ['Div', ['Mul105', 'Constant40']],
#                'Div140': ['Div', ['Add139', 'Sub116']],
#                'Div162': ['Div', ['Sub161', 'Sub116']],
#                'Div171': ['Div', ['Mul169', 'Constant45']],
#                'Div176': ['Div', ['Mul174', 'Constant46']],
#                'Div181': ['Div', ['Mul179', 'Constant47']],
#                'Div214': ['Div', ['Add213', 'Sub190']],
#                'Div236': ['Div', ['Sub235', 'Sub190']],
#                'Div280': ['Div', ['Add279', 'Sub256']],
#                'Div302': ['Div', ['Sub301', 'Sub256']],
#                'Div313': ['Div', ['Mul311', 'Constant56']],
#                'Div325': ['Div', ['Mul323', 'Constant59']],
#                'Div337': ['Div', ['Mul335', 'Constant62']],
#                'Div349': ['Div', ['Mul347', 'Constant65']],
#                'Div66': ['Div', ['Add65', 'Sub42']],
#                'Div88': ['Div', ['Sub87', 'Sub42']],
#                'Div97': ['Div', ['Mul95', 'Constant38']],
#                'Mul100': ['Mul', ['Add20', 'dt']],
#                'Mul105': ['Mul', ['Div88', 'dt']],
#                'Mul112': ['Mul', ['a14', 'Cos110']],
#                'Mul118': ['Mul', ['a2', 'Add98']],
#                'Mul12': ['Mul', ['SamplePart10', 'sigma_v']],
#                'Mul120': ['Mul', ['a8', 'Add108']],
#                'Mul124': ['Mul', ['a1', 'Pow122']],
#                'Mul125': ['Mul', ['Mul124', 'Sin109']],
#                'Mul129': ['Mul', ['a4', 'g']],
#                'Mul130': ['Mul', ['Mul129', 'Cos110']],
#                'Mul131': ['Mul', ['Mul130', 'Sin109']],
#                'Mul134': ['Mul', ['a5', 'Add108']],
#                'Mul135': ['Mul', ['Mul134', 'Cos110']],
#                'Mul138': ['Mul', ['a6', 'Add34']],
#                'Mul145': ['Mul', ['Neg142', 'Pow144']],
#                'Mul146': ['Mul', ['Mul145', 'Cos110']],
#                'Mul147': ['Mul', ['Mul146', 'Sin109']],
#                'Mul151': ['Mul', ['a10', 'g']],
#                'Mul152': ['Mul', ['Mul151', 'Sin109']],
#                'Mul155': ['Mul', ['a11', 'Add98']],
#                'Mul156': ['Mul', ['Mul155', 'Cos110']],
#                'Mul159': ['Mul', ['a12', 'Cos110']],
#                'Mul160': ['Mul', ['Mul159', 'Add34']],
#                'Mul169': ['Mul', ['Div140', 'dt']],
#                'Mul174': ['Mul', ['Add108', 'dt']],
#                'Mul179': ['Mul', ['Div162', 'dt']],
#                'Mul186': ['Mul', ['a14', 'Cos184']],
#                'Mul19': ['Mul', ['SamplePart17', 'sigma_omega']],
#                'Mul192': ['Mul', ['a2', 'Add172']],
#                'Mul194': ['Mul', ['a8', 'Add182']],
#                'Mul198': ['Mul', ['a1', 'Pow196']],
#                'Mul199': ['Mul', ['Mul198', 'Sin183']],
#                'Mul203': ['Mul', ['a4', 'g']],
#                'Mul204': ['Mul', ['Mul203', 'Cos184']],
#                'Mul205': ['Mul', ['Mul204', 'Sin183']],
#                'Mul208': ['Mul', ['a5', 'Add182']],
#                'Mul209': ['Mul', ['Mul208', 'Cos184']],
#                'Mul212': ['Mul', ['a6', 'Add34']],
#                'Mul219': ['Mul', ['Neg216', 'Pow218']],
#                'Mul220': ['Mul', ['Mul219', 'Cos184']],
#                'Mul221': ['Mul', ['Mul220', 'Sin183']],
#                'Mul225': ['Mul', ['a10', 'g']],
#                'Mul226': ['Mul', ['Mul225', 'Sin183']],
#                'Mul229': ['Mul', ['a11', 'Add172']],
#                'Mul230': ['Mul', ['Mul229', 'Cos184']],
#                'Mul233': ['Mul', ['a12', 'Cos184']],
#                'Mul234': ['Mul', ['Mul233', 'Add34']],
#                'Mul241': ['Mul', ['Div214', 'dt']],
#                'Mul244': ['Mul', ['Add182', 'dt']],
#                'Mul247': ['Mul', ['Div236', 'dt']],
#                'Mul252': ['Mul', ['a14', 'Cos250']],
#                'Mul258': ['Mul', ['a2', 'Add242']],
#                'Mul26': ['Mul', ['SamplePart24', 'sigma_theta']],
#                'Mul260': ['Mul', ['a8', 'Add248']],
#                'Mul264': ['Mul', ['a1', 'Pow262']],
#                'Mul265': ['Mul', ['Mul264', 'Sin249']],
#                'Mul269': ['Mul', ['a4', 'g']],
#                'Mul270': ['Mul', ['Mul269', 'Cos250']],
#                'Mul271': ['Mul', ['Mul270', 'Sin249']],
#                'Mul274': ['Mul', ['a5', 'Add248']],
#                'Mul275': ['Mul', ['Mul274', 'Cos250']],
#                'Mul278': ['Mul', ['a6', 'Add34']],
#                'Mul285': ['Mul', ['Neg282', 'Pow284']],
#                'Mul286': ['Mul', ['Mul285', 'Cos250']],
#                'Mul287': ['Mul', ['Mul286', 'Sin249']],
#                'Mul291': ['Mul', ['a10', 'g']],
#                'Mul292': ['Mul', ['Mul291', 'Sin249']],
#                'Mul295': ['Mul', ['a11', 'Add242']],
#                'Mul296': ['Mul', ['Mul295', 'Cos250']],
#                'Mul299': ['Mul', ['a12', 'Cos250']],
#                'Mul300': ['Mul', ['Mul299', 'Add34']],
#                'Mul304': ['Mul', ['Constant54', 'Div140']],
#                'Mul307': ['Mul', ['Constant55', 'Div214']],
#                'Mul311': ['Mul', ['Add309', 'dt']],
#                'Mul316': ['Mul', ['Constant57', 'Add98']],
#                'Mul319': ['Mul', ['Constant58', 'Add172']],
#                'Mul323': ['Mul', ['Add321', 'dt']],
#                'Mul328': ['Mul', ['Constant60', 'Div162']],
#                'Mul33': ['Mul', ['SamplePart31', 'sigma_force']],
#                'Mul331': ['Mul', ['Constant61', 'Div236']],
#                'Mul335': ['Mul', ['Add333', 'dt']],
#                'Mul340': ['Mul', ['Constant63', 'Add108']],
#                'Mul343': ['Mul', ['Constant64', 'Add182']],
#                'Mul347': ['Mul', ['Add345', 'dt']],
#                'Mul38': ['Mul', ['a14', 'Cos36']],
#                'Mul44': ['Mul', ['a2', 'Add13']],
#                'Mul46': ['Mul', ['a8', 'Add20']],
#                'Mul5': ['Mul', ['SamplePart3', 'sigma_x']],
#                'Mul50': ['Mul', ['a1', 'Pow48']],
#                'Mul51': ['Mul', ['Mul50', 'Sin35']],
#                'Mul55': ['Mul', ['a4', 'g']],
#                'Mul56': ['Mul', ['Mul55', 'Cos36']],
#                'Mul57': ['Mul', ['Mul56', 'Sin35']],
#                'Mul60': ['Mul', ['a5', 'Add20']],
#                'Mul61': ['Mul', ['Mul60', 'Cos36']],
#                'Mul64': ['Mul', ['a6', 'Add34']],
#                'Mul71': ['Mul', ['Neg68', 'Pow70']],
#                'Mul72': ['Mul', ['Mul71', 'Cos36']],
#                'Mul73': ['Mul', ['Mul72', 'Sin35']],
#                'Mul77': ['Mul', ['a10', 'g']],
#                'Mul78': ['Mul', ['Mul77', 'Sin35']],
#                'Mul81': ['Mul', ['a11', 'Add13']],
#                'Mul82': ['Mul', ['Mul81', 'Cos36']],
#                'Mul85': ['Mul', ['a12', 'Cos36']],
#                'Mul86': ['Mul', ['Mul85', 'Add34']],
#                'Mul95': ['Mul', ['Div66', 'dt']],
#                'Neg142': ['Neg', ['a7']],
#                'Neg216': ['Neg', ['a7']],
#                'Neg282': ['Neg', ['a7']],
#                'Neg68': ['Neg', ['a7']],
#                'Pow114': ['Pow', ['Mul112', 'Constant41']],
#                'Pow122': ['Pow', ['Add108', 'Constant42']],
#                'Pow144': ['Pow', ['Add108', 'Constant43']],
#                'Pow188': ['Pow', ['Mul186', 'Constant48']],
#                'Pow196': ['Pow', ['Add182', 'Constant49']],
#                'Pow218': ['Pow', ['Add182', 'Constant50']],
#                'Pow254': ['Pow', ['Mul252', 'Constant51']],
#                'Pow262': ['Pow', ['Add248', 'Constant52']],
#                'Pow284': ['Pow', ['Add248', 'Constant53']],
#                'Pow40': ['Pow', ['Mul38', 'Constant34']],
#                'Pow48': ['Pow', ['Add20', 'Constant35']],
#                'Pow70': ['Pow', ['Add20', 'Constant36']],
#                'SamplePart1': ['SamplePart', ['Xpos'], -1, [-1, 0]],
#                'SamplePart10': ['SamplePart', ['noise1'], -1, [-1, 0]],
#                'SamplePart15': ['SamplePart',
#                                 ['Xangular_velocity'],
#                                 -1,
#                                 [-1, 0]],
#                'SamplePart17': ['SamplePart', ['noise3'], -1, [-1, 0]],
#                'SamplePart22': ['SamplePart', ['Xangle'], -1, [-1, 0]],
#                'SamplePart24': ['SamplePart', ['noise2'], -1, [-1, 0]],
#                'SamplePart29': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart3': ['SamplePart', ['noise4'], -1, [-1, 0]],
#                'SamplePart31': ['SamplePart', ['noise5'], -1, [-1, 0]],
#                'SamplePart356': ['SamplePart',
#                                  ['Yangular_velocity'],
#                                  -1,
#                                  [-1, 0]],
#                'SamplePart358': ['SamplePart', ['Yangle'], -1, [-1, 0]],
#                'SamplePart360': ['SamplePart', ['Yvelocity'], -1, [-1, 0]],
#                'SamplePart362': ['SamplePart', ['Ypos'], -1, [-1, 0]],
#                'SamplePart8': ['SamplePart', ['Xvelocity'], -1, [-1, 0]],
#                'Sin109': ['Sin', ['Add103']],
#                'Sin183': ['Sin', ['Add177']],
#                'Sin249': ['Sin', ['Add245']],
#                'Sin35': ['Sin', ['Add27']],
#                'Sub116': ['Sub', ['a13', 'Pow114']],
#                'Sub126': ['Sub', ['Mul125', 'Mul118']],
#                'Sub132': ['Sub', ['Sub126', 'Mul131']],
#                'Sub148': ['Sub', ['Mul147', 'Mul120']],
#                'Sub161': ['Sub', ['Add157', 'Mul160']],
#                'Sub190': ['Sub', ['a13', 'Pow188']],
#                'Sub200': ['Sub', ['Mul199', 'Mul192']],
#                'Sub206': ['Sub', ['Sub200', 'Mul205']],
#                'Sub222': ['Sub', ['Mul221', 'Mul194']],
#                'Sub235': ['Sub', ['Add231', 'Mul234']],
#                'Sub256': ['Sub', ['a13', 'Pow254']],
#                'Sub266': ['Sub', ['Mul265', 'Mul258']],
#                'Sub272': ['Sub', ['Sub266', 'Mul271']],
#                'Sub288': ['Sub', ['Mul287', 'Mul260']],
#                'Sub301': ['Sub', ['Add297', 'Mul300']],
#                'Sub42': ['Sub', ['a13', 'Pow40']],
#                'Sub52': ['Sub', ['Mul51', 'Mul44']],
#                'Sub58': ['Sub', ['Sub52', 'Mul57']],
#                'Sub74': ['Sub', ['Mul73', 'Mul46']],
#                'Sub87': ['Sub', ['Add83', 'Mul86']]}}
# ================================================================================
# ======================== nnodely Model Train Parameters ========================
# models:                       ['pendulum']
# num of epochs:                200
# update per epochs:            351
# └>len(train_indexes)//(batch_size+step)
# shuffle data:                 True
# early stopping:               early_stop_patience
# early stopping params:        {'patience': 10}
# prediction samples:           0
# step:                         0
# closed loop:                  {}
# connect:                      {}
# train dataset:                data
# 	- batch size:                64
# 	- num of samples:            22500
# 	- num of first samples:      22500
# validation dataset:           data_val
# 	- batch size:                128
# 	- num of samples:            15000
# 	- num of first samples:      15000
# minimizers:                   {'ang_vel_error': {'A': 'SamplePart356',
#                                                  'B': 'Add338',
#                                                  'loss': 'mse'},
#                                'angle_error': {'A': 'SamplePart358',
#                                                'B': 'Add350',
#                                                'loss': 'mse'},
#                                'pos_error': {'A': 'SamplePart362',
#                                              'B': 'Add326',
#                                              'loss': 'mse'},
#                                'vel_error': {'A': 'SamplePart360',
#                                              'B': 'Add314',
#                                              'loss': 'mse'}}
# optimizer:                    Adam
# optimizer defaults:           {'lr': 0.001}
# optimizer params:             [{'params': 'a1'},
#                                {'params': 'a10'},
#                                {'params': 'a11'},
#                                {'params': 'a12'},
#                                {'params': 'a13'},
#                                {'params': 'a14'},
#                                {'params': 'a2'},
#                                {'params': 'a4'},
#                                {'params': 'a5'},
#                                {'params': 'a6'},
#                                {'params': 'a7'},
#                                {'params': 'a8'}]
# ================================================================================
# =============================================== nnodely Training ===============================================
# |  Epoch   |   ang_vel_error   |    angle_error    |     pos_error     |     vel_error     |       Total       |
# |          |        Loss       |        Loss       |        Loss       |        Loss       |        Loss       |
# |          |  train  |   val   |  train  |   val   |  train  |   val   |  train  |   val   |  train  |   val   |
# |--------------------------------------------------------------------------------------------------------------|
# |  2/200   |2.250e-02|1.645e-02|2.275e-06|1.665e-06|3.824e-07|2.808e-07|3.807e-03|2.798e-03|6.578e-03|4.812e-03|
# |  4/200   |1.278e-02|9.896e-03|1.297e-06|1.004e-06|1.659e-07|1.197e-07|1.651e-03|1.191e-03|3.609e-03|2.772e-03|
# |  6/200   |1.027e-02| 8.18e-03|1.042e-06|8.297e-07|8.391e-08|5.616e-08|8.333e-04|5.575e-04|2.775e-03|2.185e-03|
# |  8/200   |7.934e-03|6.038e-03|8.054e-07|6.129e-07|2.452e-08|1.265e-08| 2.43e-04|1.254e-04|2.044e-03|1.541e-03|
# |  10/200  |4.498e-03|3.084e-03|4.574e-07|3.136e-07|9.946e-09|1.017e-08|9.966e-05|1.018e-04|1.149e-03|7.964e-04|
# |  12/200  |1.280e-03|6.673e-04|1.303e-07|6.784e-08|1.255e-08|8.243e-09|1.251e-04|8.216e-05|3.514e-04|1.874e-04|
# |  14/200  |9.812e-05| 3.41e-05|9.976e-09|3.463e-09|1.746e-09|5.816e-10|1.739e-05|5.782e-06|2.888e-05|9.971e-06|
# |  16/200  |2.602e-06|1.090e-06|2.645e-10|1.108e-10|2.806e-11|6.009e-12|2.776e-07|5.823e-08|7.200e-07|2.872e-07|
# |  18/200  |6.918e-07|6.846e-07|7.037e-11|6.964e-11|1.347e-12|1.300e-12|1.172e-08|1.129e-08|1.759e-07| 1.74e-07|
# |  20/200  |6.876e-07|6.718e-07|6.993e-11|6.834e-11|1.396e-12|1.509e-12|1.227e-08|1.337e-08| 1.75e-07|1.713e-07|
# |  22/200  |6.866e-07|6.767e-07|6.984e-11|6.885e-11|1.346e-12|1.227e-12| 1.17e-08|1.055e-08|1.746e-07|1.718e-07|
# |  24/200  | 7.02e-07|6.841e-07|7.140e-11|6.958e-11|1.530e-12|1.459e-12|1.359e-08|1.286e-08|1.789e-07|1.742e-07|
# |  26/200  |7.031e-07|6.884e-07|7.150e-11|7.003e-11|1.921e-12|2.632e-12|1.734e-08|2.461e-08|1.801e-07|1.783e-07|
# |  28/200  |7.135e-07|6.753e-07|7.254e-11| 6.87e-11|1.890e-12| 5.27e-12|1.714e-08|5.093e-08|1.827e-07|1.816e-07|
# |  30/200  |7.359e-07|7.005e-07|7.488e-11|7.127e-11|3.269e-12|1.475e-12|3.095e-08| 1.3e-08 |1.917e-07|1.784e-07|
# Stopping the training at epoch 30 due to early stopping.
# ============================ nnodely Training Time =============================
# Total time of Training:       70.4897255897522
# ================================================================================
# Selected the model at the epoch 21.
# =============================== Save JSON Model ================================
# Model saved in:               /home/baro/Desktop/inv_pend/rk4_models/saved_models/partially_neuralized.json
# ================================================================================
# ========================== Export Python Torch Model ===========================
# Model exported in:            /home/baro/Desktop/inv_pend/rk4_models/saved_models/partially_neuralized.py
# ================================================================================

# %%
# Model analysis
inverted_pendulum.analyzeModel('data_test', prediction_samples=50, batch_size=128)
# Out:
# =================== nnodely Model Results for data_test ===================
# |     Loss    |        mse        |        FVU        |        AIC        |
# |             |    small better   |    small better   |    lower better   |
# |-------------------------------------------------------------------------|
# |ang_vel_error|     3.892e-04     |     3.285e-05     |     7.651e+05     |
# | angle_error |      3.14e-05     |      3.37e-06     |     7.634e+05     |
# |  pos_error  |     2.483e-07     |     9.491e-07     |     8.090e+05     |
# |  vel_error  |     6.112e-06     |     2.939e-05     |     7.665e+05     |
# |-------------------------------------------------------------------------|
# |    Total    |     1.067e-04     |     1.664e-05     |     7.760e+05     |
# |-------------------------------------------------------------------------|

# %%
prediction_samples = 50
step = 48
inverted_pendulum.trainModel(train_dataset='data', validation_dataset='data_val', optimizer='Adam', prediction_samples=prediction_samples, step=step, training_params=params, early_stopping=earlystopping.early_stop_patience,  
                                                            early_stopping_params={'patience':early_stop_patience}, select_model=earlystopping.select_best_model, lr=1e-3)
inverted_pendulum.exportPythonModel(name=model_name)
# Out:
# ======================== nnodely Model Train Parameters ========================
# models:                       ['pendulum']
# num of epochs:                200
# update per epochs:            133
# └>len(train_indexes)//(batch_size+step)
# shuffle data:                 True
# early stopping:               early_stop_patience
# early stopping params:        {'patience': 10}
# prediction samples:           50
# step:                         48
# closed loop:                  {}
# connect:                      {}
# train dataset:                data
# 	- batch size:                64
# 	- num of samples:            22500
# 	- num of first samples:      15000
# validation dataset:           data_val
# 	- batch size:                128
# 	- num of samples:            15000
# 	- num of first samples:      10000
# minimizers:                   {'ang_vel_error': {'A': 'SamplePart356',
#                                                  'B': 'Add338',
#                                                  'loss': 'mse'},
#                                'angle_error': {'A': 'SamplePart358',
#                                                'B': 'Add350',
#                                                'loss': 'mse'},
#                                'pos_error': {'A': 'SamplePart362',
#                                              'B': 'Add326',
#                                              'loss': 'mse'},
#                                'vel_error': {'A': 'SamplePart360',
#                                              'B': 'Add314',
#                                              'loss': 'mse'}}
# optimizer:                    Adam
# optimizer defaults:           {'lr': 0.001}
# optimizer params:             [{'params': 'a1'},
#                                {'params': 'a10'},
#                                {'params': 'a11'},
#                                {'params': 'a12'},
#                                {'params': 'a13'},
#                                {'params': 'a14'},
#                                {'params': 'a2'},
#                                {'params': 'a4'},
#                                {'params': 'a5'},
#                                {'params': 'a6'},
#                                {'params': 'a7'},
#                                {'params': 'a8'}]
# ================================================================================
# =============================================== nnodely Training ===============================================
# |  Epoch   |   ang_vel_error   |    angle_error    |     pos_error     |     vel_error     |       Total       |
# |          |        Loss       |        Loss       |        Loss       |        Loss       |        Loss       |
# |          |  train  |   val   |  train  |   val   |  train  |   val   |  train  |   val   |  train  |   val   |
# |--------------------------------------------------------------------------------------------------------------|
# |  2/200   | 3.77e-04|5.638e-04|3.106e-05|4.336e-05|6.038e-07|3.965e-07|8.474e-06|8.036e-06|1.043e-04|1.539e-04|
# |  4/200   |3.842e-04|5.325e-04| 3.18e-05|4.018e-05|5.387e-07|4.671e-07|8.201e-06|8.253e-06|1.062e-04|1.453e-04|
# |  6/200   |3.947e-04|5.013e-04|3.192e-05|3.866e-05|6.546e-07|9.304e-07|8.959e-06| 9.9e-06 |1.091e-04|1.377e-04|
# |  8/200   |3.745e-04|5.654e-04|3.021e-05|4.183e-05|7.615e-07|5.809e-07|9.199e-06|8.941e-06|1.037e-04|1.542e-04|
# |  10/200  |3.913e-04|5.442e-04|3.142e-05|4.186e-05|5.057e-07|4.599e-07|7.911e-06|8.202e-06|1.078e-04|1.487e-04|
# |  12/200  |3.604e-04|5.429e-04|2.986e-05|4.157e-05|7.678e-07|3.162e-07|9.053e-06|7.291e-06|1.000e-04|1.480e-04|
# |  14/200  |3.533e-04|5.908e-04|2.905e-05|4.316e-05|6.271e-07|7.051e-07|8.291e-06|1.047e-05|9.783e-05|1.613e-04|
# |  16/200  |3.901e-04|5.997e-04|3.132e-05|4.364e-05|7.637e-07|5.643e-07|9.392e-06|9.504e-06|1.079e-04|1.633e-04|
# |  18/200  |3.903e-04|5.568e-04|3.181e-05|4.235e-05|7.318e-07|9.889e-07| 9.18e-06|1.078e-05| 1.08e-04|1.527e-04|
# |  20/200  |3.790e-04|6.473e-04|3.116e-05|4.561e-05| 7.42e-07|1.434e-06| 9.2e-06 |1.448e-05|1.050e-04|1.772e-04|
# Stopping the training at epoch 20 due to early stopping.
# ============================ nnodely Training Time =============================
# Total time of Training:       696.7557785511017
# ================================================================================
# Selected the model at the epoch 11.
# =============================== Save JSON Model ================================
# Model saved in:               /home/baro/Desktop/inv_pend/rk4_models/saved_models/partially_neuralized.json
# ================================================================================
# ========================== Export Python Torch Model ===========================
# Model exported in:            /home/baro/Desktop/inv_pend/rk4_models/saved_models/partially_neuralized.py
# ================================================================================

# %%
# Closed-loop plot
inverted_pendulum.importPythonModel(name=model_name)
inverted_pendulum.neuralizeModel(sample_time = 0.02)
samples = inverted_pendulum.getSamples(dataset='data_test', window=150, index=0)
result = inverted_pendulum(samples, sampled=True, num_of_samples=150)

#region Plotting
t = np.arange(len(result['est_theta'])) * 0.02
plt.figure(figsize=(14, 9))
plt.subplot(5, 1, 2)
plt.plot(t, result['est_theta'], label=r'Estimated $\theta$')
plt.plot(t, np.array(samples['Yangle']).squeeze(), '--', label=r'True $\theta$')
plt.title('Theta estimation')
plt.xlabel('Time [s]')
plt.ylabel(r'$\theta$ [rad]')
plt.grid()
plt.legend()
plt.subplot(5, 1, 1)
plt.plot(t, result['est_thetadot'], label=r'Estimated $\dot{\theta}$')
plt.plot(t, np.array(samples['Yangular_velocity']).squeeze(), '--', label=r'True $\dot{\theta}$')
plt.title('Angular velocity estimation')
plt.xlabel('Time [s]')
plt.ylabel(r'$\dot{\theta}$ [rad/s]')
plt.grid()
plt.legend()
plt.subplot(5, 1, 4)
plt.plot(t, result['est_x'], label='Estimated X')
plt.plot(t, np.array(samples['Ypos']).squeeze(), '--', label='True x')
plt.title('Position estimation')
plt.xlabel('Time [s]')
plt.ylabel('x [m]')
plt.grid()
plt.legend()
plt.subplot(5, 1, 3)
plt.plot(t, result['est_xdot'], label=r'Estimated $\dot{x}$')
plt.plot(t, np.array(samples['Yvelocity']).squeeze(), '--', label=r'True $\dot{x}$')
plt.title('Velocity estimation')
plt.xlabel('Time [s]')
plt.ylabel(r'$\dot{x}$ [m/s]')
plt.grid()
plt.legend()
plt.subplot(5, 1, 5)
plt.plot(t, np.array(samples['action']).squeeze(), label='F')
plt.title('Applied force')
plt.xlabel('Time [s]')
plt.ylabel('Force [N]')
plt.grid()
plt.legend()
plt.tight_layout()
#endregion

plt.show()
# Out:
# =============================== Load JSON Model ================================
# Model loaded from:            /home/baro/Desktop/inv_pend/rk4_models/saved_models/partially_neuralized.json
# ================================================================================
# [neuralizeModel] Closed loop on Xangle with sample in the future.
# [neuralizeModel] Closed loop on Xangular_velocity with sample in the future.
# [neuralizeModel] Closed loop on Xpos with sample in the future.
# [neuralizeModel] Closed loop on Xvelocity with sample in the future.
# ================================ nnodely Model =================================
# {'Constants': {'Constant34': {'dim': 1, 'values': [2.0]},
#                'Constant35': {'dim': 1, 'values': [2.0]},
#                'Constant36': {'dim': 1, 'values': [2.0]},
#                'Constant38': {'dim': 1, 'values': [2.0]},
#                'Constant39': {'dim': 1, 'values': [2.0]},
#                'Constant40': {'dim': 1, 'values': [2.0]},
#                'Constant41': {'dim': 1, 'values': [2.0]},
#                'Constant42': {'dim': 1, 'values': [2.0]},
#                'Constant43': {'dim': 1, 'values': [2.0]},
#                'Constant45': {'dim': 1, 'values': [2.0]},
#                'Constant46': {'dim': 1, 'values': [2.0]},
#                'Constant47': {'dim': 1, 'values': [2.0]},
#                'Constant48': {'dim': 1, 'values': [2.0]},
#                'Constant49': {'dim': 1, 'values': [2.0]},
#                'Constant50': {'dim': 1, 'values': [2.0]},
#                'Constant51': {'dim': 1, 'values': [2.0]},
#                'Constant52': {'dim': 1, 'values': [2.0]},
#                'Constant53': {'dim': 1, 'values': [2.0]},
#                'Constant54': {'dim': 1, 'values': [2.0]},
#                'Constant55': {'dim': 1, 'values': [2.0]},
#                'Constant56': {'dim': 1, 'values': [6.0]},
#                'Constant57': {'dim': 1, 'values': [2.0]},
#                'Constant58': {'dim': 1, 'values': [2.0]},
#                'Constant59': {'dim': 1, 'values': [6.0]},
#                'Constant60': {'dim': 1, 'values': [2.0]},
#                'Constant61': {'dim': 1, 'values': [2.0]},
#                'Constant62': {'dim': 1, 'values': [6.0]},
#                'Constant63': {'dim': 1, 'values': [2.0]},
#                'Constant64': {'dim': 1, 'values': [2.0]},
#                'Constant65': {'dim': 1, 'values': [6.0]},
#                'dt': {'dim': 1, 'values': [0.019999999552965164]},
#                'g': {'dim': 1, 'values': [9.8100004196167]},
#                'sigma_force': {'dim': 1, 'values': [0.0]},
#                'sigma_omega': {'dim': 1, 'values': [0.0]},
#                'sigma_theta': {'dim': 1, 'values': [0.0]},
#                'sigma_v': {'dim': 1, 'values': [0.0]},
#                'sigma_x': {'dim': 1, 'values': [0.0]}},
#  'Functions': {},
#  'Info': {'SampleTime': 0.02,
#           'nnodely_version': '1.5.2',
#           'ns': [1, 0],
#           'ntot': 1,
#           'num_parameters': 12},
#  'Inputs': {'Xangle': {'closedLoop': 'Add350',
#                        'dim': 1,
#                        'local': 1,
#                        'ns': [1, 0],
#                        'ntot': 1,
#                        'sw': [-1, 0]},
#             'Xangular_velocity': {'closedLoop': 'Add338',
#                                   'dim': 1,
#                                   'local': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Xpos': {'closedLoop': 'Add326',
#                      'dim': 1,
#                      'local': 1,
#                      'ns': [1, 0],
#                      'ntot': 1,
#                      'sw': [-1, 0]},
#             'Xvelocity': {'closedLoop': 'Add314',
#                           'dim': 1,
#                           'local': 1,
#                           'ns': [1, 0],
#                           'ntot': 1,
#                           'sw': [-1, 0]},
#             'Yangle': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yangular_velocity': {'dim': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Ypos': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yvelocity': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'action': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise1': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise2': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise3': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise4': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise5': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]}},
#  'Minimizers': {'ang_vel_error': {'A': 'SamplePart356',
#                                   'B': 'Add338',
#                                   'loss': 'mse'},
#                 'angle_error': {'A': 'SamplePart358',
#                                 'B': 'Add350',
#                                 'loss': 'mse'},
#                 'pos_error': {'A': 'SamplePart362',
#                               'B': 'Add326',
#                               'loss': 'mse'},
#                 'vel_error': {'A': 'SamplePart360',
#                               'B': 'Add314',
#                               'loss': 'mse'}},
#  'Models': 'pendulum',
#  'Outputs': {'est_theta': 'Add350',
#              'est_thetadot': 'Add338',
#              'est_x': 'Add326',
#              'est_xdot': 'Add314'},
#  'Parameters': {'a1': {'dim': 1, 'values': [0.021709894761443138]},
#                 'a10': {'dim': 1, 'values': [0.5258023142814636]},
#                 'a11': {'dim': 1, 'values': [0.03575937822461128]},
#                 'a12': {'dim': 1, 'values': [3.3914072513580322]},
#                 'a13': {'dim': 1, 'values': [0.22385646402835846]},
#                 'a14': {'dim': 1, 'values': [0.22628794610500336]},
#                 'a2': {'dim': 1, 'values': [0.014598706737160683]},
#                 'a4': {'dim': 1, 'values': [0.05111302062869072]},
#                 'a5': {'dim': 1, 'values': [0.034060195088386536]},
#                 'a6': {'dim': 1, 'values': [1.4442225694656372]},
#                 'a7': {'dim': 1, 'values': [0.05105852335691452]},
#                 'a8': {'dim': 1, 'values': [0.34952136874198914]}},
#  'Relations': {'Add103': ['Add', ['Add27', 'Div102']],
#                'Add108': ['Add', ['Add20', 'Div107']],
#                'Add13': ['Add', ['SamplePart8', 'Mul12']],
#                'Add136': ['Add', ['Sub132', 'Mul135']],
#                'Add139': ['Add', ['Add136', 'Mul138']],
#                'Add153': ['Add', ['Sub148', 'Mul152']],
#                'Add157': ['Add', ['Add153', 'Mul156']],
#                'Add172': ['Add', ['Add13', 'Div171']],
#                'Add177': ['Add', ['Add27', 'Div176']],
#                'Add182': ['Add', ['Add20', 'Div181']],
#                'Add20': ['Add', ['SamplePart15', 'Mul19']],
#                'Add210': ['Add', ['Sub206', 'Mul209']],
#                'Add213': ['Add', ['Add210', 'Mul212']],
#                'Add227': ['Add', ['Sub222', 'Mul226']],
#                'Add231': ['Add', ['Add227', 'Mul230']],
#                'Add242': ['Add', ['Add13', 'Mul241']],
#                'Add245': ['Add', ['Add27', 'Mul244']],
#                'Add248': ['Add', ['Add20', 'Mul247']],
#                'Add27': ['Add', ['SamplePart22', 'Mul26']],
#                'Add276': ['Add', ['Sub272', 'Mul275']],
#                'Add279': ['Add', ['Add276', 'Mul278']],
#                'Add293': ['Add', ['Sub288', 'Mul292']],
#                'Add297': ['Add', ['Add293', 'Mul296']],
#                'Add305': ['Add', ['Div66', 'Mul304']],
#                'Add308': ['Add', ['Add305', 'Mul307']],
#                'Add309': ['Add', ['Add308', 'Div280']],
#                'Add314': ['Add', ['Add13', 'Div313']],
#                'Add317': ['Add', ['Add13', 'Mul316']],
#                'Add320': ['Add', ['Add317', 'Mul319']],
#                'Add321': ['Add', ['Add320', 'Add242']],
#                'Add326': ['Add', ['Add6', 'Div325']],
#                'Add329': ['Add', ['Div88', 'Mul328']],
#                'Add332': ['Add', ['Add329', 'Mul331']],
#                'Add333': ['Add', ['Add332', 'Div302']],
#                'Add338': ['Add', ['Add20', 'Div337']],
#                'Add34': ['Add', ['SamplePart29', 'Mul33']],
#                'Add341': ['Add', ['Add20', 'Mul340']],
#                'Add344': ['Add', ['Add341', 'Mul343']],
#                'Add345': ['Add', ['Add344', 'Add248']],
#                'Add350': ['Add', ['Add27', 'Div349']],
#                'Add6': ['Add', ['SamplePart1', 'Mul5']],
#                'Add62': ['Add', ['Sub58', 'Mul61']],
#                'Add65': ['Add', ['Add62', 'Mul64']],
#                'Add79': ['Add', ['Sub74', 'Mul78']],
#                'Add83': ['Add', ['Add79', 'Mul82']],
#                'Add98': ['Add', ['Add13', 'Div97']],
#                'Cos110': ['Cos', ['Add103']],
#                'Cos184': ['Cos', ['Add177']],
#                'Cos250': ['Cos', ['Add245']],
#                'Cos36': ['Cos', ['Add27']],
#                'Div102': ['Div', ['Mul100', 'Constant39']],
#                'Div107': ['Div', ['Mul105', 'Constant40']],
#                'Div140': ['Div', ['Add139', 'Sub116']],
#                'Div162': ['Div', ['Sub161', 'Sub116']],
#                'Div171': ['Div', ['Mul169', 'Constant45']],
#                'Div176': ['Div', ['Mul174', 'Constant46']],
#                'Div181': ['Div', ['Mul179', 'Constant47']],
#                'Div214': ['Div', ['Add213', 'Sub190']],
#                'Div236': ['Div', ['Sub235', 'Sub190']],
#                'Div280': ['Div', ['Add279', 'Sub256']],
#                'Div302': ['Div', ['Sub301', 'Sub256']],
#                'Div313': ['Div', ['Mul311', 'Constant56']],
#                'Div325': ['Div', ['Mul323', 'Constant59']],
#                'Div337': ['Div', ['Mul335', 'Constant62']],
#                'Div349': ['Div', ['Mul347', 'Constant65']],
#                'Div66': ['Div', ['Add65', 'Sub42']],
#                'Div88': ['Div', ['Sub87', 'Sub42']],
#                'Div97': ['Div', ['Mul95', 'Constant38']],
#                'Mul100': ['Mul', ['Add20', 'dt']],
#                'Mul105': ['Mul', ['Div88', 'dt']],
#                'Mul112': ['Mul', ['a14', 'Cos110']],
#                'Mul118': ['Mul', ['a2', 'Add98']],
#                'Mul12': ['Mul', ['SamplePart10', 'sigma_v']],
#                'Mul120': ['Mul', ['a8', 'Add108']],
#                'Mul124': ['Mul', ['a1', 'Pow122']],
#                'Mul125': ['Mul', ['Mul124', 'Sin109']],
#                'Mul129': ['Mul', ['a4', 'g']],
#                'Mul130': ['Mul', ['Mul129', 'Cos110']],
#                'Mul131': ['Mul', ['Mul130', 'Sin109']],
#                'Mul134': ['Mul', ['a5', 'Add108']],
#                'Mul135': ['Mul', ['Mul134', 'Cos110']],
#                'Mul138': ['Mul', ['a6', 'Add34']],
#                'Mul145': ['Mul', ['Neg142', 'Pow144']],
#                'Mul146': ['Mul', ['Mul145', 'Cos110']],
#                'Mul147': ['Mul', ['Mul146', 'Sin109']],
#                'Mul151': ['Mul', ['a10', 'g']],
#                'Mul152': ['Mul', ['Mul151', 'Sin109']],
#                'Mul155': ['Mul', ['a11', 'Add98']],
#                'Mul156': ['Mul', ['Mul155', 'Cos110']],
#                'Mul159': ['Mul', ['a12', 'Cos110']],
#                'Mul160': ['Mul', ['Mul159', 'Add34']],
#                'Mul169': ['Mul', ['Div140', 'dt']],
#                'Mul174': ['Mul', ['Add108', 'dt']],
#                'Mul179': ['Mul', ['Div162', 'dt']],
#                'Mul186': ['Mul', ['a14', 'Cos184']],
#                'Mul19': ['Mul', ['SamplePart17', 'sigma_omega']],
#                'Mul192': ['Mul', ['a2', 'Add172']],
#                'Mul194': ['Mul', ['a8', 'Add182']],
#                'Mul198': ['Mul', ['a1', 'Pow196']],
#                'Mul199': ['Mul', ['Mul198', 'Sin183']],
#                'Mul203': ['Mul', ['a4', 'g']],
#                'Mul204': ['Mul', ['Mul203', 'Cos184']],
#                'Mul205': ['Mul', ['Mul204', 'Sin183']],
#                'Mul208': ['Mul', ['a5', 'Add182']],
#                'Mul209': ['Mul', ['Mul208', 'Cos184']],
#                'Mul212': ['Mul', ['a6', 'Add34']],
#                'Mul219': ['Mul', ['Neg216', 'Pow218']],
#                'Mul220': ['Mul', ['Mul219', 'Cos184']],
#                'Mul221': ['Mul', ['Mul220', 'Sin183']],
#                'Mul225': ['Mul', ['a10', 'g']],
#                'Mul226': ['Mul', ['Mul225', 'Sin183']],
#                'Mul229': ['Mul', ['a11', 'Add172']],
#                'Mul230': ['Mul', ['Mul229', 'Cos184']],
#                'Mul233': ['Mul', ['a12', 'Cos184']],
#                'Mul234': ['Mul', ['Mul233', 'Add34']],
#                'Mul241': ['Mul', ['Div214', 'dt']],
#                'Mul244': ['Mul', ['Add182', 'dt']],
#                'Mul247': ['Mul', ['Div236', 'dt']],
#                'Mul252': ['Mul', ['a14', 'Cos250']],
#                'Mul258': ['Mul', ['a2', 'Add242']],
#                'Mul26': ['Mul', ['SamplePart24', 'sigma_theta']],
#                'Mul260': ['Mul', ['a8', 'Add248']],
#                'Mul264': ['Mul', ['a1', 'Pow262']],
#                'Mul265': ['Mul', ['Mul264', 'Sin249']],
#                'Mul269': ['Mul', ['a4', 'g']],
#                'Mul270': ['Mul', ['Mul269', 'Cos250']],
#                'Mul271': ['Mul', ['Mul270', 'Sin249']],
#                'Mul274': ['Mul', ['a5', 'Add248']],
#                'Mul275': ['Mul', ['Mul274', 'Cos250']],
#                'Mul278': ['Mul', ['a6', 'Add34']],
#                'Mul285': ['Mul', ['Neg282', 'Pow284']],
#                'Mul286': ['Mul', ['Mul285', 'Cos250']],
#                'Mul287': ['Mul', ['Mul286', 'Sin249']],
#                'Mul291': ['Mul', ['a10', 'g']],
#                'Mul292': ['Mul', ['Mul291', 'Sin249']],
#                'Mul295': ['Mul', ['a11', 'Add242']],
#                'Mul296': ['Mul', ['Mul295', 'Cos250']],
#                'Mul299': ['Mul', ['a12', 'Cos250']],
#                'Mul300': ['Mul', ['Mul299', 'Add34']],
#                'Mul304': ['Mul', ['Constant54', 'Div140']],
#                'Mul307': ['Mul', ['Constant55', 'Div214']],
#                'Mul311': ['Mul', ['Add309', 'dt']],
#                'Mul316': ['Mul', ['Constant57', 'Add98']],
#                'Mul319': ['Mul', ['Constant58', 'Add172']],
#                'Mul323': ['Mul', ['Add321', 'dt']],
#                'Mul328': ['Mul', ['Constant60', 'Div162']],
#                'Mul33': ['Mul', ['SamplePart31', 'sigma_force']],
#                'Mul331': ['Mul', ['Constant61', 'Div236']],
#                'Mul335': ['Mul', ['Add333', 'dt']],
#                'Mul340': ['Mul', ['Constant63', 'Add108']],
#                'Mul343': ['Mul', ['Constant64', 'Add182']],
#                'Mul347': ['Mul', ['Add345', 'dt']],
#                'Mul38': ['Mul', ['a14', 'Cos36']],
#                'Mul44': ['Mul', ['a2', 'Add13']],
#                'Mul46': ['Mul', ['a8', 'Add20']],
#                'Mul5': ['Mul', ['SamplePart3', 'sigma_x']],
#                'Mul50': ['Mul', ['a1', 'Pow48']],
#                'Mul51': ['Mul', ['Mul50', 'Sin35']],
#                'Mul55': ['Mul', ['a4', 'g']],
#                'Mul56': ['Mul', ['Mul55', 'Cos36']],
#                'Mul57': ['Mul', ['Mul56', 'Sin35']],
#                'Mul60': ['Mul', ['a5', 'Add20']],
#                'Mul61': ['Mul', ['Mul60', 'Cos36']],
#                'Mul64': ['Mul', ['a6', 'Add34']],
#                'Mul71': ['Mul', ['Neg68', 'Pow70']],
#                'Mul72': ['Mul', ['Mul71', 'Cos36']],
#                'Mul73': ['Mul', ['Mul72', 'Sin35']],
#                'Mul77': ['Mul', ['a10', 'g']],
#                'Mul78': ['Mul', ['Mul77', 'Sin35']],
#                'Mul81': ['Mul', ['a11', 'Add13']],
#                'Mul82': ['Mul', ['Mul81', 'Cos36']],
#                'Mul85': ['Mul', ['a12', 'Cos36']],
#                'Mul86': ['Mul', ['Mul85', 'Add34']],
#                'Mul95': ['Mul', ['Div66', 'dt']],
#                'Neg142': ['Neg', ['a7']],
#                'Neg216': ['Neg', ['a7']],
#                'Neg282': ['Neg', ['a7']],
#                'Neg68': ['Neg', ['a7']],
#                'Pow114': ['Pow', ['Mul112', 'Constant41']],
#                'Pow122': ['Pow', ['Add108', 'Constant42']],
#                'Pow144': ['Pow', ['Add108', 'Constant43']],
#                'Pow188': ['Pow', ['Mul186', 'Constant48']],
#                'Pow196': ['Pow', ['Add182', 'Constant49']],
#                'Pow218': ['Pow', ['Add182', 'Constant50']],
#                'Pow254': ['Pow', ['Mul252', 'Constant51']],
#                'Pow262': ['Pow', ['Add248', 'Constant52']],
#                'Pow284': ['Pow', ['Add248', 'Constant53']],
#                'Pow40': ['Pow', ['Mul38', 'Constant34']],
#                'Pow48': ['Pow', ['Add20', 'Constant35']],
#                'Pow70': ['Pow', ['Add20', 'Constant36']],
#                'SamplePart1': ['SamplePart', ['Xpos'], -1, [-1, 0]],
#                'SamplePart10': ['SamplePart', ['noise1'], -1, [-1, 0]],
#                'SamplePart15': ['SamplePart',
#                                 ['Xangular_velocity'],
#                                 -1,
#                                 [-1, 0]],
#                'SamplePart17': ['SamplePart', ['noise3'], -1, [-1, 0]],
#                'SamplePart22': ['SamplePart', ['Xangle'], -1, [-1, 0]],
#                'SamplePart24': ['SamplePart', ['noise2'], -1, [-1, 0]],
#                'SamplePart29': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart3': ['SamplePart', ['noise4'], -1, [-1, 0]],
#                'SamplePart31': ['SamplePart', ['noise5'], -1, [-1, 0]],
#                'SamplePart356': ['SamplePart',
#                                  ['Yangular_velocity'],
#                                  -1,
#                                  [-1, 0]],
#                'SamplePart358': ['SamplePart', ['Yangle'], -1, [-1, 0]],
#                'SamplePart360': ['SamplePart', ['Yvelocity'], -1, [-1, 0]],
#                'SamplePart362': ['SamplePart', ['Ypos'], -1, [-1, 0]],
#                'SamplePart8': ['SamplePart', ['Xvelocity'], -1, [-1, 0]],
#                'Sin109': ['Sin', ['Add103']],
#                'Sin183': ['Sin', ['Add177']],
#                'Sin249': ['Sin', ['Add245']],
#                'Sin35': ['Sin', ['Add27']],
#                'Sub116': ['Sub', ['a13', 'Pow114']],
#                'Sub126': ['Sub', ['Mul125', 'Mul118']],
#                'Sub132': ['Sub', ['Sub126', 'Mul131']],
#                'Sub148': ['Sub', ['Mul147', 'Mul120']],
#                'Sub161': ['Sub', ['Add157', 'Mul160']],
#                'Sub190': ['Sub', ['a13', 'Pow188']],
#                'Sub200': ['Sub', ['Mul199', 'Mul192']],
#                'Sub206': ['Sub', ['Sub200', 'Mul205']],
#                'Sub222': ['Sub', ['Mul221', 'Mul194']],
#                'Sub235': ['Sub', ['Add231', 'Mul234']],
#                'Sub256': ['Sub', ['a13', 'Pow254']],
#                'Sub266': ['Sub', ['Mul265', 'Mul258']],
#                'Sub272': ['Sub', ['Sub266', 'Mul271']],
#                'Sub288': ['Sub', ['Mul287', 'Mul260']],
#                'Sub301': ['Sub', ['Add297', 'Mul300']],
#                'Sub42': ['Sub', ['a13', 'Pow40']],
#                'Sub52': ['Sub', ['Mul51', 'Mul44']],
#                'Sub58': ['Sub', ['Sub52', 'Mul57']],
#                'Sub74': ['Sub', ['Mul73', 'Mul46']],
#                'Sub87': ['Sub', ['Add83', 'Mul86']]}}
# ================================================================================
# ========================== Import Python Torch Model ===========================
# Model imported from:          /home/baro/Desktop/inv_pend/rk4_models/saved_models/partially_neuralized.py
# ================================================================================
# [neuralizeModel] Closed loop on Xangle with sample in the future.
# [neuralizeModel] Closed loop on Xangular_velocity with sample in the future.
# [neuralizeModel] Closed loop on Xpos with sample in the future.
# [neuralizeModel] Closed loop on Xvelocity with sample in the future.
# ================================ nnodely Model =================================
# {'Constants': {'Constant34': {'dim': 1, 'values': [2.0]},
#                'Constant35': {'dim': 1, 'values': [2.0]},
#                'Constant36': {'dim': 1, 'values': [2.0]},
#                'Constant38': {'dim': 1, 'values': [2.0]},
#                'Constant39': {'dim': 1, 'values': [2.0]},
#                'Constant40': {'dim': 1, 'values': [2.0]},
#                'Constant41': {'dim': 1, 'values': [2.0]},
#                'Constant42': {'dim': 1, 'values': [2.0]},
#                'Constant43': {'dim': 1, 'values': [2.0]},
#                'Constant45': {'dim': 1, 'values': [2.0]},
#                'Constant46': {'dim': 1, 'values': [2.0]},
#                'Constant47': {'dim': 1, 'values': [2.0]},
#                'Constant48': {'dim': 1, 'values': [2.0]},
#                'Constant49': {'dim': 1, 'values': [2.0]},
#                'Constant50': {'dim': 1, 'values': [2.0]},
#                'Constant51': {'dim': 1, 'values': [2.0]},
#                'Constant52': {'dim': 1, 'values': [2.0]},
#                'Constant53': {'dim': 1, 'values': [2.0]},
#                'Constant54': {'dim': 1, 'values': [2.0]},
#                'Constant55': {'dim': 1, 'values': [2.0]},
#                'Constant56': {'dim': 1, 'values': [6.0]},
#                'Constant57': {'dim': 1, 'values': [2.0]},
#                'Constant58': {'dim': 1, 'values': [2.0]},
#                'Constant59': {'dim': 1, 'values': [6.0]},
#                'Constant60': {'dim': 1, 'values': [2.0]},
#                'Constant61': {'dim': 1, 'values': [2.0]},
#                'Constant62': {'dim': 1, 'values': [6.0]},
#                'Constant63': {'dim': 1, 'values': [2.0]},
#                'Constant64': {'dim': 1, 'values': [2.0]},
#                'Constant65': {'dim': 1, 'values': [6.0]},
#                'dt': {'dim': 1, 'values': [0.019999999552965164]},
#                'g': {'dim': 1, 'values': [9.8100004196167]},
#                'sigma_force': {'dim': 1, 'values': [0.0]},
#                'sigma_omega': {'dim': 1, 'values': [0.0]},
#                'sigma_theta': {'dim': 1, 'values': [0.0]},
#                'sigma_v': {'dim': 1, 'values': [0.0]},
#                'sigma_x': {'dim': 1, 'values': [0.0]}},
#  'Functions': {},
#  'Info': {'SampleTime': 0.02,
#           'nnodely_version': '1.5.2',
#           'ns': [1, 0],
#           'ntot': 1,
#           'num_parameters': 12},
#  'Inputs': {'Xangle': {'closedLoop': 'Add350',
#                        'dim': 1,
#                        'local': 1,
#                        'ns': [1, 0],
#                        'ntot': 1,
#                        'sw': [-1, 0]},
#             'Xangular_velocity': {'closedLoop': 'Add338',
#                                   'dim': 1,
#                                   'local': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Xpos': {'closedLoop': 'Add326',
#                      'dim': 1,
#                      'local': 1,
#                      'ns': [1, 0],
#                      'ntot': 1,
#                      'sw': [-1, 0]},
#             'Xvelocity': {'closedLoop': 'Add314',
#                           'dim': 1,
#                           'local': 1,
#                           'ns': [1, 0],
#                           'ntot': 1,
#                           'sw': [-1, 0]},
#             'Yangle': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yangular_velocity': {'dim': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Ypos': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yvelocity': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'action': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise1': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise2': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise3': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise4': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise5': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]}},
#  'Minimizers': {'ang_vel_error': {'A': 'SamplePart356',
#                                   'B': 'Add338',
#                                   'loss': 'mse'},
#                 'angle_error': {'A': 'SamplePart358',
#                                 'B': 'Add350',
#                                 'loss': 'mse'},
#                 'pos_error': {'A': 'SamplePart362',
#                               'B': 'Add326',
#                               'loss': 'mse'},
#                 'vel_error': {'A': 'SamplePart360',
#                               'B': 'Add314',
#                               'loss': 'mse'}},
#  'Models': 'pendulum',
#  'Outputs': {'est_theta': 'Add350',
#              'est_thetadot': 'Add338',
#              'est_x': 'Add326',
#              'est_xdot': 'Add314'},
#  'Parameters': {'a1': {'dim': 1, 'values': [0.021709894761443138]},
#                 'a10': {'dim': 1, 'values': [0.5258023142814636]},
#                 'a11': {'dim': 1, 'values': [0.03575937822461128]},
#                 'a12': {'dim': 1, 'values': [3.3914072513580322]},
#                 'a13': {'dim': 1, 'values': [0.22385646402835846]},
#                 'a14': {'dim': 1, 'values': [0.22628794610500336]},
#                 'a2': {'dim': 1, 'values': [0.014598706737160683]},
#                 'a4': {'dim': 1, 'values': [0.05111302062869072]},
#                 'a5': {'dim': 1, 'values': [0.034060195088386536]},
#                 'a6': {'dim': 1, 'values': [1.4442225694656372]},
#                 'a7': {'dim': 1, 'values': [0.05105852335691452]},
#                 'a8': {'dim': 1, 'values': [0.34952136874198914]}},
#  'Relations': {'Add103': ['Add', ['Add27', 'Div102']],
#                'Add108': ['Add', ['Add20', 'Div107']],
#                'Add13': ['Add', ['SamplePart8', 'Mul12']],
#                'Add136': ['Add', ['Sub132', 'Mul135']],
#                'Add139': ['Add', ['Add136', 'Mul138']],
#                'Add153': ['Add', ['Sub148', 'Mul152']],
#                'Add157': ['Add', ['Add153', 'Mul156']],
#                'Add172': ['Add', ['Add13', 'Div171']],
#                'Add177': ['Add', ['Add27', 'Div176']],
#                'Add182': ['Add', ['Add20', 'Div181']],
#                'Add20': ['Add', ['SamplePart15', 'Mul19']],
#                'Add210': ['Add', ['Sub206', 'Mul209']],
#                'Add213': ['Add', ['Add210', 'Mul212']],
#                'Add227': ['Add', ['Sub222', 'Mul226']],
#                'Add231': ['Add', ['Add227', 'Mul230']],
#                'Add242': ['Add', ['Add13', 'Mul241']],
#                'Add245': ['Add', ['Add27', 'Mul244']],
#                'Add248': ['Add', ['Add20', 'Mul247']],
#                'Add27': ['Add', ['SamplePart22', 'Mul26']],
#                'Add276': ['Add', ['Sub272', 'Mul275']],
#                'Add279': ['Add', ['Add276', 'Mul278']],
#                'Add293': ['Add', ['Sub288', 'Mul292']],
#                'Add297': ['Add', ['Add293', 'Mul296']],
#                'Add305': ['Add', ['Div66', 'Mul304']],
#                'Add308': ['Add', ['Add305', 'Mul307']],
#                'Add309': ['Add', ['Add308', 'Div280']],
#                'Add314': ['Add', ['Add13', 'Div313']],
#                'Add317': ['Add', ['Add13', 'Mul316']],
#                'Add320': ['Add', ['Add317', 'Mul319']],
#                'Add321': ['Add', ['Add320', 'Add242']],
#                'Add326': ['Add', ['Add6', 'Div325']],
#                'Add329': ['Add', ['Div88', 'Mul328']],
#                'Add332': ['Add', ['Add329', 'Mul331']],
#                'Add333': ['Add', ['Add332', 'Div302']],
#                'Add338': ['Add', ['Add20', 'Div337']],
#                'Add34': ['Add', ['SamplePart29', 'Mul33']],
#                'Add341': ['Add', ['Add20', 'Mul340']],
#                'Add344': ['Add', ['Add341', 'Mul343']],
#                'Add345': ['Add', ['Add344', 'Add248']],
#                'Add350': ['Add', ['Add27', 'Div349']],
#                'Add6': ['Add', ['SamplePart1', 'Mul5']],
#                'Add62': ['Add', ['Sub58', 'Mul61']],
#                'Add65': ['Add', ['Add62', 'Mul64']],
#                'Add79': ['Add', ['Sub74', 'Mul78']],
#                'Add83': ['Add', ['Add79', 'Mul82']],
#                'Add98': ['Add', ['Add13', 'Div97']],
#                'Cos110': ['Cos', ['Add103']],
#                'Cos184': ['Cos', ['Add177']],
#                'Cos250': ['Cos', ['Add245']],
#                'Cos36': ['Cos', ['Add27']],
#                'Div102': ['Div', ['Mul100', 'Constant39']],
#                'Div107': ['Div', ['Mul105', 'Constant40']],
#                'Div140': ['Div', ['Add139', 'Sub116']],
#                'Div162': ['Div', ['Sub161', 'Sub116']],
#                'Div171': ['Div', ['Mul169', 'Constant45']],
#                'Div176': ['Div', ['Mul174', 'Constant46']],
#                'Div181': ['Div', ['Mul179', 'Constant47']],
#                'Div214': ['Div', ['Add213', 'Sub190']],
#                'Div236': ['Div', ['Sub235', 'Sub190']],
#                'Div280': ['Div', ['Add279', 'Sub256']],
#                'Div302': ['Div', ['Sub301', 'Sub256']],
#                'Div313': ['Div', ['Mul311', 'Constant56']],
#                'Div325': ['Div', ['Mul323', 'Constant59']],
#                'Div337': ['Div', ['Mul335', 'Constant62']],
#                'Div349': ['Div', ['Mul347', 'Constant65']],
#                'Div66': ['Div', ['Add65', 'Sub42']],
#                'Div88': ['Div', ['Sub87', 'Sub42']],
#                'Div97': ['Div', ['Mul95', 'Constant38']],
#                'Mul100': ['Mul', ['Add20', 'dt']],
#                'Mul105': ['Mul', ['Div88', 'dt']],
#                'Mul112': ['Mul', ['a14', 'Cos110']],
#                'Mul118': ['Mul', ['a2', 'Add98']],
#                'Mul12': ['Mul', ['SamplePart10', 'sigma_v']],
#                'Mul120': ['Mul', ['a8', 'Add108']],
#                'Mul124': ['Mul', ['a1', 'Pow122']],
#                'Mul125': ['Mul', ['Mul124', 'Sin109']],
#                'Mul129': ['Mul', ['a4', 'g']],
#                'Mul130': ['Mul', ['Mul129', 'Cos110']],
#                'Mul131': ['Mul', ['Mul130', 'Sin109']],
#                'Mul134': ['Mul', ['a5', 'Add108']],
#                'Mul135': ['Mul', ['Mul134', 'Cos110']],
#                'Mul138': ['Mul', ['a6', 'Add34']],
#                'Mul145': ['Mul', ['Neg142', 'Pow144']],
#                'Mul146': ['Mul', ['Mul145', 'Cos110']],
#                'Mul147': ['Mul', ['Mul146', 'Sin109']],
#                'Mul151': ['Mul', ['a10', 'g']],
#                'Mul152': ['Mul', ['Mul151', 'Sin109']],
#                'Mul155': ['Mul', ['a11', 'Add98']],
#                'Mul156': ['Mul', ['Mul155', 'Cos110']],
#                'Mul159': ['Mul', ['a12', 'Cos110']],
#                'Mul160': ['Mul', ['Mul159', 'Add34']],
#                'Mul169': ['Mul', ['Div140', 'dt']],
#                'Mul174': ['Mul', ['Add108', 'dt']],
#                'Mul179': ['Mul', ['Div162', 'dt']],
#                'Mul186': ['Mul', ['a14', 'Cos184']],
#                'Mul19': ['Mul', ['SamplePart17', 'sigma_omega']],
#                'Mul192': ['Mul', ['a2', 'Add172']],
#                'Mul194': ['Mul', ['a8', 'Add182']],
#                'Mul198': ['Mul', ['a1', 'Pow196']],
#                'Mul199': ['Mul', ['Mul198', 'Sin183']],
#                'Mul203': ['Mul', ['a4', 'g']],
#                'Mul204': ['Mul', ['Mul203', 'Cos184']],
#                'Mul205': ['Mul', ['Mul204', 'Sin183']],
#                'Mul208': ['Mul', ['a5', 'Add182']],
#                'Mul209': ['Mul', ['Mul208', 'Cos184']],
#                'Mul212': ['Mul', ['a6', 'Add34']],
#                'Mul219': ['Mul', ['Neg216', 'Pow218']],
#                'Mul220': ['Mul', ['Mul219', 'Cos184']],
#                'Mul221': ['Mul', ['Mul220', 'Sin183']],
#                'Mul225': ['Mul', ['a10', 'g']],
#                'Mul226': ['Mul', ['Mul225', 'Sin183']],
#                'Mul229': ['Mul', ['a11', 'Add172']],
#                'Mul230': ['Mul', ['Mul229', 'Cos184']],
#                'Mul233': ['Mul', ['a12', 'Cos184']],
#                'Mul234': ['Mul', ['Mul233', 'Add34']],
#                'Mul241': ['Mul', ['Div214', 'dt']],
#                'Mul244': ['Mul', ['Add182', 'dt']],
#                'Mul247': ['Mul', ['Div236', 'dt']],
#                'Mul252': ['Mul', ['a14', 'Cos250']],
#                'Mul258': ['Mul', ['a2', 'Add242']],
#                'Mul26': ['Mul', ['SamplePart24', 'sigma_theta']],
#                'Mul260': ['Mul', ['a8', 'Add248']],
#                'Mul264': ['Mul', ['a1', 'Pow262']],
#                'Mul265': ['Mul', ['Mul264', 'Sin249']],
#                'Mul269': ['Mul', ['a4', 'g']],
#                'Mul270': ['Mul', ['Mul269', 'Cos250']],
#                'Mul271': ['Mul', ['Mul270', 'Sin249']],
#                'Mul274': ['Mul', ['a5', 'Add248']],
#                'Mul275': ['Mul', ['Mul274', 'Cos250']],
#                'Mul278': ['Mul', ['a6', 'Add34']],
#                'Mul285': ['Mul', ['Neg282', 'Pow284']],
#                'Mul286': ['Mul', ['Mul285', 'Cos250']],
#                'Mul287': ['Mul', ['Mul286', 'Sin249']],
#                'Mul291': ['Mul', ['a10', 'g']],
#                'Mul292': ['Mul', ['Mul291', 'Sin249']],
#                'Mul295': ['Mul', ['a11', 'Add242']],
#                'Mul296': ['Mul', ['Mul295', 'Cos250']],
#                'Mul299': ['Mul', ['a12', 'Cos250']],
#                'Mul300': ['Mul', ['Mul299', 'Add34']],
#                'Mul304': ['Mul', ['Constant54', 'Div140']],
#                'Mul307': ['Mul', ['Constant55', 'Div214']],
#                'Mul311': ['Mul', ['Add309', 'dt']],
#                'Mul316': ['Mul', ['Constant57', 'Add98']],
#                'Mul319': ['Mul', ['Constant58', 'Add172']],
#                'Mul323': ['Mul', ['Add321', 'dt']],
#                'Mul328': ['Mul', ['Constant60', 'Div162']],
#                'Mul33': ['Mul', ['SamplePart31', 'sigma_force']],
#                'Mul331': ['Mul', ['Constant61', 'Div236']],
#                'Mul335': ['Mul', ['Add333', 'dt']],
#                'Mul340': ['Mul', ['Constant63', 'Add108']],
#                'Mul343': ['Mul', ['Constant64', 'Add182']],
#                'Mul347': ['Mul', ['Add345', 'dt']],
#                'Mul38': ['Mul', ['a14', 'Cos36']],
#                'Mul44': ['Mul', ['a2', 'Add13']],
#                'Mul46': ['Mul', ['a8', 'Add20']],
#                'Mul5': ['Mul', ['SamplePart3', 'sigma_x']],
#                'Mul50': ['Mul', ['a1', 'Pow48']],
#                'Mul51': ['Mul', ['Mul50', 'Sin35']],
#                'Mul55': ['Mul', ['a4', 'g']],
#                'Mul56': ['Mul', ['Mul55', 'Cos36']],
#                'Mul57': ['Mul', ['Mul56', 'Sin35']],
#                'Mul60': ['Mul', ['a5', 'Add20']],
#                'Mul61': ['Mul', ['Mul60', 'Cos36']],
#                'Mul64': ['Mul', ['a6', 'Add34']],
#                'Mul71': ['Mul', ['Neg68', 'Pow70']],
#                'Mul72': ['Mul', ['Mul71', 'Cos36']],
#                'Mul73': ['Mul', ['Mul72', 'Sin35']],
#                'Mul77': ['Mul', ['a10', 'g']],
#                'Mul78': ['Mul', ['Mul77', 'Sin35']],
#                'Mul81': ['Mul', ['a11', 'Add13']],
#                'Mul82': ['Mul', ['Mul81', 'Cos36']],
#                'Mul85': ['Mul', ['a12', 'Cos36']],
#                'Mul86': ['Mul', ['Mul85', 'Add34']],
#                'Mul95': ['Mul', ['Div66', 'dt']],
#                'Neg142': ['Neg', ['a7']],
#                'Neg216': ['Neg', ['a7']],
#                'Neg282': ['Neg', ['a7']],
#                'Neg68': ['Neg', ['a7']],
#                'Pow114': ['Pow', ['Mul112', 'Constant41']],
#                'Pow122': ['Pow', ['Add108', 'Constant42']],
#                'Pow144': ['Pow', ['Add108', 'Constant43']],
#                'Pow188': ['Pow', ['Mul186', 'Constant48']],
#                'Pow196': ['Pow', ['Add182', 'Constant49']],
#                'Pow218': ['Pow', ['Add182', 'Constant50']],
#                'Pow254': ['Pow', ['Mul252', 'Constant51']],
#                'Pow262': ['Pow', ['Add248', 'Constant52']],
#                'Pow284': ['Pow', ['Add248', 'Constant53']],
#                'Pow40': ['Pow', ['Mul38', 'Constant34']],
#                'Pow48': ['Pow', ['Add20', 'Constant35']],
#                'Pow70': ['Pow', ['Add20', 'Constant36']],
#                'SamplePart1': ['SamplePart', ['Xpos'], -1, [-1, 0]],
#                'SamplePart10': ['SamplePart', ['noise1'], -1, [-1, 0]],
#                'SamplePart15': ['SamplePart',
#                                 ['Xangular_velocity'],
#                                 -1,
#                                 [-1, 0]],
#                'SamplePart17': ['SamplePart', ['noise3'], -1, [-1, 0]],
#                'SamplePart22': ['SamplePart', ['Xangle'], -1, [-1, 0]],
#                'SamplePart24': ['SamplePart', ['noise2'], -1, [-1, 0]],
#                'SamplePart29': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart3': ['SamplePart', ['noise4'], -1, [-1, 0]],
#                'SamplePart31': ['SamplePart', ['noise5'], -1, [-1, 0]],
#                'SamplePart356': ['SamplePart',
#                                  ['Yangular_velocity'],
#                                  -1,
#                                  [-1, 0]],
#                'SamplePart358': ['SamplePart', ['Yangle'], -1, [-1, 0]],
#                'SamplePart360': ['SamplePart', ['Yvelocity'], -1, [-1, 0]],
#                'SamplePart362': ['SamplePart', ['Ypos'], -1, [-1, 0]],
#                'SamplePart8': ['SamplePart', ['Xvelocity'], -1, [-1, 0]],
#                'Sin109': ['Sin', ['Add103']],
#                'Sin183': ['Sin', ['Add177']],
#                'Sin249': ['Sin', ['Add245']],
#                'Sin35': ['Sin', ['Add27']],
#                'Sub116': ['Sub', ['a13', 'Pow114']],
#                'Sub126': ['Sub', ['Mul125', 'Mul118']],
#                'Sub132': ['Sub', ['Sub126', 'Mul131']],
#                'Sub148': ['Sub', ['Mul147', 'Mul120']],
#                'Sub161': ['Sub', ['Add157', 'Mul160']],
#                'Sub190': ['Sub', ['a13', 'Pow188']],
#                'Sub200': ['Sub', ['Mul199', 'Mul192']],
#                'Sub206': ['Sub', ['Sub200', 'Mul205']],
#                'Sub222': ['Sub', ['Mul221', 'Mul194']],
#                'Sub235': ['Sub', ['Add231', 'Mul234']],
#                'Sub256': ['Sub', ['a13', 'Pow254']],
#                'Sub266': ['Sub', ['Mul265', 'Mul258']],
#                'Sub272': ['Sub', ['Sub266', 'Mul271']],
#                'Sub288': ['Sub', ['Mul287', 'Mul260']],
#                'Sub301': ['Sub', ['Add297', 'Mul300']],
#                'Sub42': ['Sub', ['a13', 'Pow40']],
#                'Sub52': ['Sub', ['Mul51', 'Mul44']],
#                'Sub58': ['Sub', ['Sub52', 'Mul57']],
#                'Sub74': ['Sub', ['Mul73', 'Mul46']],
#                'Sub87': ['Sub', ['Add83', 'Mul86']]}}
# ================================================================================
# [__call__] num_of_samples is ignored if sampled is equal to True

# %%
# Model analysis
inverted_pendulum.analyzeModel('data_test', prediction_samples=50, batch_size=128)
# Out:
# =================== nnodely Model Results for data_test ===================
# |     Loss    |        mse        |        FVU        |        AIC        |
# |             |    small better   |    small better   |    lower better   |
# |-------------------------------------------------------------------------|
# |ang_vel_error|     3.841e-04     |     3.244e-05     |     7.650e+05     |
# | angle_error |     3.075e-05     |     3.301e-06     |     7.634e+05     |
# |  pos_error  |     4.629e-07     |     1.804e-06     |     7.935e+05     |
# |  vel_error  |     6.907e-06     |     3.319e-05     |     7.679e+05     |
# |-------------------------------------------------------------------------|
# |    Total    |     1.056e-04     |     1.768e-05     |     7.725e+05     |
# |-------------------------------------------------------------------------|
