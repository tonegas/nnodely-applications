# %%
from nnodely import *
from nnodely.support import earlystopping
import matplotlib.pyplot as plt
import os
import numpy as np

workspace = os.path.join(os.getcwd(), "saved_models")
inverted_pendulum = Modely(workspace=workspace)
# Out:
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>-- nnodely_v1.5.2 --<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

# %%
# Create neural model

model_name = 'partially_neuralized_model'
pos                 = Input('Xpos')
Ypos                = Input('Ypos')
velocity            = Input('Xvelocity')
Yvelocity           = Input('Yvelocity')
angle               = Input('Xangle')
Yangle              = Input('Yangle')
angular_velocity    = Input('Xangular_velocity')
Yangular_velocity   = Input('Yangular_velocity')
F                   = Input('action')

noise1          = Input('noise1')
noise2          = Input('noise2')
noise3          = Input('noise3')
noise4          = Input('noise4')
sigma_x         = Constant('sigma_x', values=0.0)
sigma_v         = Constant('sigma_v', values=0.0)
sigma_theta     = Constant('sigma_theta', values=0.0)
sigma_omega     = Constant('sigma_omega', values=0.0)

g               = Constant('g', values=9.81)
dt              = Constant('dt', values=0.02)
a1              = Parameter('a1')#, values=0.9)
a2              = Parameter('a2')#, values=0.6)
a4              = Parameter('a4')#, values=2.25)
a5              = Parameter('a5')#, values=1.5)
a6              = Parameter('a6')#, values=50)
a7              = Parameter('a7')#, values=2.25)
a8              = Parameter('a8')#, values=15.5)
a10             = Parameter('a10')#, values=23.25)
a11             = Parameter('a11')#, values=1.5)
a12             = Parameter('a12')#, values=150)
a13             = Parameter('a13')#, values=9.3)
a14             = Parameter('a14')#, values=2.25)

def inv_pend(p, v, alpha, omega, u):
    # Equations of motion for the inverted pendulum on a cart
    sin_theta = Sin(alpha)
    cos_theta = Cos(alpha)
    sigma = a13-(a14*cos_theta)**2
    
    # Friction
    friction_cart = a2*v
    friction_pend = a8*omega

    # Linear acceleration of the cart (v_dot)
    v_dot = (a1*omega**2*sin_theta
             - friction_cart
             - a4*g*cos_theta*sin_theta
             + a5*omega*cos_theta
             + a6*u
    )/ sigma

    # Angular acceleration (omega_dot)
    omega_dot = (- a7*omega**2*cos_theta*sin_theta
                 - friction_pend
                 + a10*g*sin_theta
                 + a11*v*cos_theta
                 - a12*cos_theta*u
    )/ sigma

    p_dot = v
    alpha_dot = omega

    return [p_dot, v_dot, alpha_dot, omega_dot]

# Adding noise to the inputs
x_noisy = pos.last() + noise4.last()*sigma_x
vel_noisy = velocity.last() + noise1.last()*sigma_v
ang_vel_noisy = angular_velocity.last() + noise3.last()*sigma_omega
theta_noisy = angle.last() + noise2.last()*sigma_theta

# Runge-Kutta 4th order method
k1 = inv_pend(x_noisy, vel_noisy, theta_noisy, ang_vel_noisy, F.last())
k2 = inv_pend(x_noisy + k1[0]*dt/2, vel_noisy + k1[1]*dt/2, theta_noisy + k1[2]*dt/2, ang_vel_noisy + k1[3]*dt/2, F.last())
k3 = inv_pend(x_noisy + k2[0]*dt/2, vel_noisy + k2[1]*dt/2, theta_noisy + k2[2]*dt/2, ang_vel_noisy + k2[3]*dt/2, F.last())
k4 = inv_pend(x_noisy + k3[0]*dt, vel_noisy + k3[1]*dt, theta_noisy + k3[2]*dt, ang_vel_noisy + k3[3]*dt, F.last())

# Update state variables
dt_xdot = (k1[1] + 2*k2[1] + 2*k3[1] + k4[1])*dt/6
xdot = vel_noisy + dt_xdot
xdot.closedLoop(velocity)

dt_x = (k1[0] + 2*k2[0] + 2*k3[0] + k4[0])*dt/6
x = x_noisy + dt_x
x.closedLoop(pos)

dt_thetadot = (k1[3] + 2*k2[3] + 2*k3[3] + k4[3])*dt/6
thetadot = ang_vel_noisy + dt_thetadot
thetadot.closedLoop(angular_velocity)

dt_theta = (k1[2] + 2*k2[2] + 2*k3[2] + k4[2])*dt/6
theta = theta_noisy + dt_theta
theta.closedLoop(angle)

# Output and loss
est_theta = Output('est_theta', theta)
est_thetadot = Output('est_thetadot', thetadot)
est_xdot = Output('est_xdot', xdot)
est_x = Output('est_x', x)

inverted_pendulum.addModel('pendulum', [est_thetadot, est_theta, est_xdot, est_x])
inverted_pendulum.addMinimize('ang_vel_error', Yangular_velocity.last(), thetadot, loss_function='mse')
inverted_pendulum.addMinimize('angle_error', Yangle.last(), theta, loss_function='mse')
inverted_pendulum.addMinimize('vel_error', Yvelocity.last(), xdot, loss_function='mse')
inverted_pendulum.addMinimize('pos_error', Ypos.last(), x, loss_function='mse')
inverted_pendulum.neuralizeModel(sample_time = 0.02)
# Out:
# [neuralizeModel] Closed loop on Xpos with sample in the future.
# [neuralizeModel] Closed loop on Xangle with sample in the future.
# [neuralizeModel] Closed loop on Xvelocity with sample in the future.
# [neuralizeModel] Closed loop on Xangular_velocity with sample in the future.
# ================================ nnodely Model =================================
# {'Constants': {'Constant32': {'dim': 1, 'values': [2.0]},
#                'Constant33': {'dim': 1, 'values': [2.0]},
#                'Constant34': {'dim': 1, 'values': [2.0]},
#                'Constant36': {'dim': 1, 'values': [2.0]},
#                'Constant37': {'dim': 1, 'values': [2.0]},
#                'Constant38': {'dim': 1, 'values': [2.0]},
#                'Constant39': {'dim': 1, 'values': [2.0]},
#                'Constant40': {'dim': 1, 'values': [2.0]},
#                'Constant41': {'dim': 1, 'values': [2.0]},
#                'Constant43': {'dim': 1, 'values': [2.0]},
#                'Constant44': {'dim': 1, 'values': [2.0]},
#                'Constant45': {'dim': 1, 'values': [2.0]},
#                'Constant46': {'dim': 1, 'values': [2.0]},
#                'Constant47': {'dim': 1, 'values': [2.0]},
#                'Constant48': {'dim': 1, 'values': [2.0]},
#                'Constant49': {'dim': 1, 'values': [2.0]},
#                'Constant50': {'dim': 1, 'values': [2.0]},
#                'Constant51': {'dim': 1, 'values': [2.0]},
#                'Constant52': {'dim': 1, 'values': [2.0]},
#                'Constant53': {'dim': 1, 'values': [2.0]},
#                'Constant54': {'dim': 1, 'values': [6.0]},
#                'Constant55': {'dim': 1, 'values': [2.0]},
#                'Constant56': {'dim': 1, 'values': [2.0]},
#                'Constant57': {'dim': 1, 'values': [6.0]},
#                'Constant58': {'dim': 1, 'values': [2.0]},
#                'Constant59': {'dim': 1, 'values': [2.0]},
#                'Constant60': {'dim': 1, 'values': [6.0]},
#                'Constant61': {'dim': 1, 'values': [2.0]},
#                'Constant62': {'dim': 1, 'values': [2.0]},
#                'Constant63': {'dim': 1, 'values': [6.0]},
#                'dt': {'dim': 1, 'values': [0.019999999552965164]},
#                'g': {'dim': 1, 'values': [9.8100004196167]},
#                'sigma_omega': {'dim': 1, 'values': [0.0]},
#                'sigma_theta': {'dim': 1, 'values': [0.0]},
#                'sigma_v': {'dim': 1, 'values': [0.0]},
#                'sigma_x': {'dim': 1, 'values': [0.0]}},
#  'Functions': {},
#  'Info': {'SampleTime': 0.02,
#           'nnodely_version': '1.5.2',
#           'ns': [1, 0],
#           'ntot': 1,
#           'num_parameters': 12},
#  'Inputs': {'Xangle': {'closedLoop': 'Add351',
#                        'dim': 1,
#                        'local': 1,
#                        'ns': [1, 0],
#                        'ntot': 1,
#                        'sw': [-1, 0]},
#             'Xangular_velocity': {'closedLoop': 'Add339',
#                                   'dim': 1,
#                                   'local': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Xpos': {'closedLoop': 'Add327',
#                      'dim': 1,
#                      'local': 1,
#                      'ns': [1, 0],
#                      'ntot': 1,
#                      'sw': [-1, 0]},
#             'Xvelocity': {'closedLoop': 'Add315',
#                           'dim': 1,
#                           'local': 1,
#                           'ns': [1, 0],
#                           'ntot': 1,
#                           'sw': [-1, 0]},
#             'Yangle': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yangular_velocity': {'dim': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Ypos': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yvelocity': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'action': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise1': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise2': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise3': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise4': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]}},
#  'Minimizers': {'ang_vel_error': {'A': 'SamplePart353',
#                                   'B': 'Add339',
#                                   'loss': 'mse'},
#                 'angle_error': {'A': 'SamplePart355',
#                                 'B': 'Add351',
#                                 'loss': 'mse'},
#                 'pos_error': {'A': 'SamplePart359',
#                               'B': 'Add327',
#                               'loss': 'mse'},
#                 'vel_error': {'A': 'SamplePart357',
#                               'B': 'Add315',
#                               'loss': 'mse'}},
#  'Models': 'pendulum',
#  'Outputs': {'est_theta': 'Add351',
#              'est_thetadot': 'Add339',
#              'est_x': 'Add327',
#              'est_xdot': 'Add315'},
#  'Parameters': {'a1': {'dim': 1, 'values': [0.09672188758850098]},
#                 'a10': {'dim': 1, 'values': [0.4729723334312439]},
#                 'a11': {'dim': 1, 'values': [0.07608342170715332]},
#                 'a12': {'dim': 1, 'values': [0.45004338026046753]},
#                 'a13': {'dim': 1, 'values': [0.9664662480354309]},
#                 'a14': {'dim': 1, 'values': [0.7095979452133179]},
#                 'a2': {'dim': 1, 'values': [0.4487125873565674]},
#                 'a4': {'dim': 1, 'values': [0.42252427339553833]},
#                 'a5': {'dim': 1, 'values': [0.9189722537994385]},
#                 'a6': {'dim': 1, 'values': [0.7984841465950012]},
#                 'a7': {'dim': 1, 'values': [0.48250889778137207]},
#                 'a8': {'dim': 1, 'values': [0.6854273080825806]}},
#  'Relations': {'Add103': ['Add', ['Add20', 'Div102']],
#                'Add13': ['Add', ['SamplePart8', 'Mul12']],
#                'Add133': ['Add', ['Sub129', 'Mul132']],
#                'Add136': ['Add', ['Add133', 'Mul135']],
#                'Add150': ['Add', ['Sub145', 'Mul149']],
#                'Add154': ['Add', ['Add150', 'Mul153']],
#                'Add169': ['Add', ['Add13', 'Div168']],
#                'Add174': ['Add', ['Add27', 'Div173']],
#                'Add179': ['Add', ['Add20', 'Div178']],
#                'Add20': ['Add', ['SamplePart15', 'Mul19']],
#                'Add209': ['Add', ['Sub205', 'Mul208']],
#                'Add212': ['Add', ['Add209', 'Mul211']],
#                'Add226': ['Add', ['Sub221', 'Mul225']],
#                'Add230': ['Add', ['Add226', 'Mul229']],
#                'Add241': ['Add', ['Add13', 'Mul240']],
#                'Add244': ['Add', ['Add27', 'Mul243']],
#                'Add247': ['Add', ['Add20', 'Mul246']],
#                'Add27': ['Add', ['SamplePart22', 'Mul26']],
#                'Add277': ['Add', ['Sub273', 'Mul276']],
#                'Add280': ['Add', ['Add277', 'Mul279']],
#                'Add294': ['Add', ['Sub289', 'Mul293']],
#                'Add298': ['Add', ['Add294', 'Mul297']],
#                'Add306': ['Add', ['Div61', 'Mul305']],
#                'Add309': ['Add', ['Add306', 'Mul308']],
#                'Add310': ['Add', ['Add309', 'Div281']],
#                'Add315': ['Add', ['Add13', 'Div314']],
#                'Add318': ['Add', ['Add13', 'Mul317']],
#                'Add321': ['Add', ['Add318', 'Mul320']],
#                'Add322': ['Add', ['Add321', 'Add241']],
#                'Add327': ['Add', ['Add6', 'Div326']],
#                'Add330': ['Add', ['Div83', 'Mul329']],
#                'Add333': ['Add', ['Add330', 'Mul332']],
#                'Add334': ['Add', ['Add333', 'Div303']],
#                'Add339': ['Add', ['Add20', 'Div338']],
#                'Add342': ['Add', ['Add20', 'Mul341']],
#                'Add345': ['Add', ['Add342', 'Mul344']],
#                'Add346': ['Add', ['Add345', 'Add247']],
#                'Add351': ['Add', ['Add27', 'Div350']],
#                'Add57': ['Add', ['Sub53', 'Mul56']],
#                'Add6': ['Add', ['SamplePart1', 'Mul5']],
#                'Add60': ['Add', ['Add57', 'Mul59']],
#                'Add74': ['Add', ['Sub69', 'Mul73']],
#                'Add78': ['Add', ['Add74', 'Mul77']],
#                'Add93': ['Add', ['Add13', 'Div92']],
#                'Add98': ['Add', ['Add27', 'Div97']],
#                'Cos107': ['Cos', ['Add98']],
#                'Cos183': ['Cos', ['Add174']],
#                'Cos251': ['Cos', ['Add244']],
#                'Cos31': ['Cos', ['Add27']],
#                'Div102': ['Div', ['Mul100', 'Constant38']],
#                'Div137': ['Div', ['Add136', 'Sub113']],
#                'Div159': ['Div', ['Sub158', 'Sub113']],
#                'Div168': ['Div', ['Mul166', 'Constant43']],
#                'Div173': ['Div', ['Mul171', 'Constant44']],
#                'Div178': ['Div', ['Mul176', 'Constant45']],
#                'Div213': ['Div', ['Add212', 'Sub189']],
#                'Div235': ['Div', ['Sub234', 'Sub189']],
#                'Div281': ['Div', ['Add280', 'Sub257']],
#                'Div303': ['Div', ['Sub302', 'Sub257']],
#                'Div314': ['Div', ['Mul312', 'Constant54']],
#                'Div326': ['Div', ['Mul324', 'Constant57']],
#                'Div338': ['Div', ['Mul336', 'Constant60']],
#                'Div350': ['Div', ['Mul348', 'Constant63']],
#                'Div61': ['Div', ['Add60', 'Sub37']],
#                'Div83': ['Div', ['Sub82', 'Sub37']],
#                'Div92': ['Div', ['Mul90', 'Constant36']],
#                'Div97': ['Div', ['Mul95', 'Constant37']],
#                'Mul100': ['Mul', ['Div83', 'dt']],
#                'Mul109': ['Mul', ['a14', 'Cos107']],
#                'Mul115': ['Mul', ['a2', 'Add93']],
#                'Mul117': ['Mul', ['a8', 'Add103']],
#                'Mul12': ['Mul', ['SamplePart10', 'sigma_v']],
#                'Mul121': ['Mul', ['a1', 'Pow119']],
#                'Mul122': ['Mul', ['Mul121', 'Sin106']],
#                'Mul126': ['Mul', ['a4', 'g']],
#                'Mul127': ['Mul', ['Mul126', 'Cos107']],
#                'Mul128': ['Mul', ['Mul127', 'Sin106']],
#                'Mul131': ['Mul', ['a5', 'Add103']],
#                'Mul132': ['Mul', ['Mul131', 'Cos107']],
#                'Mul135': ['Mul', ['a6', 'SamplePart105']],
#                'Mul142': ['Mul', ['Neg139', 'Pow141']],
#                'Mul143': ['Mul', ['Mul142', 'Cos107']],
#                'Mul144': ['Mul', ['Mul143', 'Sin106']],
#                'Mul148': ['Mul', ['a10', 'g']],
#                'Mul149': ['Mul', ['Mul148', 'Sin106']],
#                'Mul152': ['Mul', ['a11', 'Add93']],
#                'Mul153': ['Mul', ['Mul152', 'Cos107']],
#                'Mul156': ['Mul', ['a12', 'Cos107']],
#                'Mul157': ['Mul', ['Mul156', 'SamplePart105']],
#                'Mul166': ['Mul', ['Div137', 'dt']],
#                'Mul171': ['Mul', ['Add103', 'dt']],
#                'Mul176': ['Mul', ['Div159', 'dt']],
#                'Mul185': ['Mul', ['a14', 'Cos183']],
#                'Mul19': ['Mul', ['SamplePart17', 'sigma_omega']],
#                'Mul191': ['Mul', ['a2', 'Add169']],
#                'Mul193': ['Mul', ['a8', 'Add179']],
#                'Mul197': ['Mul', ['a1', 'Pow195']],
#                'Mul198': ['Mul', ['Mul197', 'Sin182']],
#                'Mul202': ['Mul', ['a4', 'g']],
#                'Mul203': ['Mul', ['Mul202', 'Cos183']],
#                'Mul204': ['Mul', ['Mul203', 'Sin182']],
#                'Mul207': ['Mul', ['a5', 'Add179']],
#                'Mul208': ['Mul', ['Mul207', 'Cos183']],
#                'Mul211': ['Mul', ['a6', 'SamplePart181']],
#                'Mul218': ['Mul', ['Neg215', 'Pow217']],
#                'Mul219': ['Mul', ['Mul218', 'Cos183']],
#                'Mul220': ['Mul', ['Mul219', 'Sin182']],
#                'Mul224': ['Mul', ['a10', 'g']],
#                'Mul225': ['Mul', ['Mul224', 'Sin182']],
#                'Mul228': ['Mul', ['a11', 'Add169']],
#                'Mul229': ['Mul', ['Mul228', 'Cos183']],
#                'Mul232': ['Mul', ['a12', 'Cos183']],
#                'Mul233': ['Mul', ['Mul232', 'SamplePart181']],
#                'Mul240': ['Mul', ['Div213', 'dt']],
#                'Mul243': ['Mul', ['Add179', 'dt']],
#                'Mul246': ['Mul', ['Div235', 'dt']],
#                'Mul253': ['Mul', ['a14', 'Cos251']],
#                'Mul259': ['Mul', ['a2', 'Add241']],
#                'Mul26': ['Mul', ['SamplePart24', 'sigma_theta']],
#                'Mul261': ['Mul', ['a8', 'Add247']],
#                'Mul265': ['Mul', ['a1', 'Pow263']],
#                'Mul266': ['Mul', ['Mul265', 'Sin250']],
#                'Mul270': ['Mul', ['a4', 'g']],
#                'Mul271': ['Mul', ['Mul270', 'Cos251']],
#                'Mul272': ['Mul', ['Mul271', 'Sin250']],
#                'Mul275': ['Mul', ['a5', 'Add247']],
#                'Mul276': ['Mul', ['Mul275', 'Cos251']],
#                'Mul279': ['Mul', ['a6', 'SamplePart249']],
#                'Mul286': ['Mul', ['Neg283', 'Pow285']],
#                'Mul287': ['Mul', ['Mul286', 'Cos251']],
#                'Mul288': ['Mul', ['Mul287', 'Sin250']],
#                'Mul292': ['Mul', ['a10', 'g']],
#                'Mul293': ['Mul', ['Mul292', 'Sin250']],
#                'Mul296': ['Mul', ['a11', 'Add241']],
#                'Mul297': ['Mul', ['Mul296', 'Cos251']],
#                'Mul300': ['Mul', ['a12', 'Cos251']],
#                'Mul301': ['Mul', ['Mul300', 'SamplePart249']],
#                'Mul305': ['Mul', ['Constant52', 'Div137']],
#                'Mul308': ['Mul', ['Constant53', 'Div213']],
#                'Mul312': ['Mul', ['Add310', 'dt']],
#                'Mul317': ['Mul', ['Constant55', 'Add93']],
#                'Mul320': ['Mul', ['Constant56', 'Add169']],
#                'Mul324': ['Mul', ['Add322', 'dt']],
#                'Mul329': ['Mul', ['Constant58', 'Div159']],
#                'Mul33': ['Mul', ['a14', 'Cos31']],
#                'Mul332': ['Mul', ['Constant59', 'Div235']],
#                'Mul336': ['Mul', ['Add334', 'dt']],
#                'Mul341': ['Mul', ['Constant61', 'Add103']],
#                'Mul344': ['Mul', ['Constant62', 'Add179']],
#                'Mul348': ['Mul', ['Add346', 'dt']],
#                'Mul39': ['Mul', ['a2', 'Add13']],
#                'Mul41': ['Mul', ['a8', 'Add20']],
#                'Mul45': ['Mul', ['a1', 'Pow43']],
#                'Mul46': ['Mul', ['Mul45', 'Sin30']],
#                'Mul5': ['Mul', ['SamplePart3', 'sigma_x']],
#                'Mul50': ['Mul', ['a4', 'g']],
#                'Mul51': ['Mul', ['Mul50', 'Cos31']],
#                'Mul52': ['Mul', ['Mul51', 'Sin30']],
#                'Mul55': ['Mul', ['a5', 'Add20']],
#                'Mul56': ['Mul', ['Mul55', 'Cos31']],
#                'Mul59': ['Mul', ['a6', 'SamplePart29']],
#                'Mul66': ['Mul', ['Neg63', 'Pow65']],
#                'Mul67': ['Mul', ['Mul66', 'Cos31']],
#                'Mul68': ['Mul', ['Mul67', 'Sin30']],
#                'Mul72': ['Mul', ['a10', 'g']],
#                'Mul73': ['Mul', ['Mul72', 'Sin30']],
#                'Mul76': ['Mul', ['a11', 'Add13']],
#                'Mul77': ['Mul', ['Mul76', 'Cos31']],
#                'Mul80': ['Mul', ['a12', 'Cos31']],
#                'Mul81': ['Mul', ['Mul80', 'SamplePart29']],
#                'Mul90': ['Mul', ['Div61', 'dt']],
#                'Mul95': ['Mul', ['Add20', 'dt']],
#                'Neg139': ['Neg', ['a7']],
#                'Neg215': ['Neg', ['a7']],
#                'Neg283': ['Neg', ['a7']],
#                'Neg63': ['Neg', ['a7']],
#                'Pow111': ['Pow', ['Mul109', 'Constant39']],
#                'Pow119': ['Pow', ['Add103', 'Constant40']],
#                'Pow141': ['Pow', ['Add103', 'Constant41']],
#                'Pow187': ['Pow', ['Mul185', 'Constant46']],
#                'Pow195': ['Pow', ['Add179', 'Constant47']],
#                'Pow217': ['Pow', ['Add179', 'Constant48']],
#                'Pow255': ['Pow', ['Mul253', 'Constant49']],
#                'Pow263': ['Pow', ['Add247', 'Constant50']],
#                'Pow285': ['Pow', ['Add247', 'Constant51']],
#                'Pow35': ['Pow', ['Mul33', 'Constant32']],
#                'Pow43': ['Pow', ['Add20', 'Constant33']],
#                'Pow65': ['Pow', ['Add20', 'Constant34']],
#                'SamplePart1': ['SamplePart', ['Xpos'], -1, [-1, 0]],
#                'SamplePart10': ['SamplePart', ['noise1'], -1, [-1, 0]],
#                'SamplePart105': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart15': ['SamplePart',
#                                 ['Xangular_velocity'],
#                                 -1,
#                                 [-1, 0]],
#                'SamplePart17': ['SamplePart', ['noise3'], -1, [-1, 0]],
#                'SamplePart181': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart22': ['SamplePart', ['Xangle'], -1, [-1, 0]],
#                'SamplePart24': ['SamplePart', ['noise2'], -1, [-1, 0]],
#                'SamplePart249': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart29': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart3': ['SamplePart', ['noise4'], -1, [-1, 0]],
#                'SamplePart353': ['SamplePart',
#                                  ['Yangular_velocity'],
#                                  -1,
#                                  [-1, 0]],
#                'SamplePart355': ['SamplePart', ['Yangle'], -1, [-1, 0]],
#                'SamplePart357': ['SamplePart', ['Yvelocity'], -1, [-1, 0]],
#                'SamplePart359': ['SamplePart', ['Ypos'], -1, [-1, 0]],
#                'SamplePart8': ['SamplePart', ['Xvelocity'], -1, [-1, 0]],
#                'Sin106': ['Sin', ['Add98']],
#                'Sin182': ['Sin', ['Add174']],
#                'Sin250': ['Sin', ['Add244']],
#                'Sin30': ['Sin', ['Add27']],
#                'Sub113': ['Sub', ['a13', 'Pow111']],
#                'Sub123': ['Sub', ['Mul122', 'Mul115']],
#                'Sub129': ['Sub', ['Sub123', 'Mul128']],
#                'Sub145': ['Sub', ['Mul144', 'Mul117']],
#                'Sub158': ['Sub', ['Add154', 'Mul157']],
#                'Sub189': ['Sub', ['a13', 'Pow187']],
#                'Sub199': ['Sub', ['Mul198', 'Mul191']],
#                'Sub205': ['Sub', ['Sub199', 'Mul204']],
#                'Sub221': ['Sub', ['Mul220', 'Mul193']],
#                'Sub234': ['Sub', ['Add230', 'Mul233']],
#                'Sub257': ['Sub', ['a13', 'Pow255']],
#                'Sub267': ['Sub', ['Mul266', 'Mul259']],
#                'Sub273': ['Sub', ['Sub267', 'Mul272']],
#                'Sub289': ['Sub', ['Mul288', 'Mul261']],
#                'Sub302': ['Sub', ['Add298', 'Mul301']],
#                'Sub37': ['Sub', ['a13', 'Pow35']],
#                'Sub47': ['Sub', ['Mul46', 'Mul39']],
#                'Sub53': ['Sub', ['Sub47', 'Mul52']],
#                'Sub69': ['Sub', ['Mul68', 'Mul41']],
#                'Sub82': ['Sub', ['Add78', 'Mul81']]}}
# ================================================================================

# %%
# Training
data_struct = ['time', 'action', 'Xpos', 'Xangle', 'Xvelocity', 'Xangular_velocity', 'Ypos', 'Yangle', 'Yvelocity', 'Yangular_velocity', 'noise1', 'noise2', 'noise3', 'noise4']
data_folder = os.path.join(os.path.abspath(''),'data')
inverted_pendulum.loadData(name='data', source=data_folder, format=data_struct, delimiter=',', header=0)

prediction_samples = None
step = None
early_stop_patience = 10
inverted_pendulum.exportPythonModel(name=model_name)
inverted_pendulum.importPythonModel(name=model_name)
inverted_pendulum.neuralizeModel(sample_time = 0.02)
params = {'train_batch_size':64, 'num_of_epochs':100, 'lr':1e-3}
inverted_pendulum.trainModel(splits=[100,0,0], optimizer='Adam', prediction_samples=prediction_samples, step=step, training_params=params, early_stopping=earlystopping.early_stop_patience,  
                                                            early_stopping_params={'patience':early_stop_patience,
                                                                                'error':'ang_vel_error'})
inverted_pendulum.exportPythonModel(name=model_name)
inverted_pendulum.exportReport(name=model_name+'_report')
# Out:
# ============================ nnodely Model Dataset =============================
# Dataset Name:                 data
# Number of files:              200
# Total number of samples:      30000
# Shape of Xpos:                (30000, 1, 1)
# Shape of noise2:              (30000, 1, 1)
# Shape of Xangle:              (30000, 1, 1)
# Shape of action:              (30000, 1, 1)
# Shape of noise1:              (30000, 1, 1)
# Shape of Xvelocity:           (30000, 1, 1)
# Shape of noise3:              (30000, 1, 1)
# Shape of Xangular_velocity:   (30000, 1, 1)
# Shape of noise4:              (30000, 1, 1)
# Shape of Ypos:                (30000, 1, 1)
# Shape of Yvelocity:           (30000, 1, 1)
# Shape of Yangle:              (30000, 1, 1)
# Shape of Yangular_velocity:   (30000, 1, 1)
# ================================================================================
# =============================== Save JSON Model ================================
# Model saved in:               /home/baro/Desktop/inv_pend/saved_models/semi_physical_model.json
# ================================================================================
# ========================== Export Python Torch Model ===========================
# Model exported in:            /home/baro/Desktop/inv_pend/saved_models/semi_physical_model.py
# ================================================================================
# =============================== Load JSON Model ================================
# Model loaded from:            /home/baro/Desktop/inv_pend/saved_models/semi_physical_model.json
# ================================================================================
# [neuralizeModel] Closed loop on Xangle with sample in the future.
# [neuralizeModel] Closed loop on Xangular_velocity with sample in the future.
# [neuralizeModel] Closed loop on Xpos with sample in the future.
# [neuralizeModel] Closed loop on Xvelocity with sample in the future.
# ================================ nnodely Model =================================
# {'Constants': {'Constant32': {'dim': 1, 'values': [2.0]},
#                'Constant33': {'dim': 1, 'values': [2.0]},
#                'Constant34': {'dim': 1, 'values': [2.0]},
#                'Constant36': {'dim': 1, 'values': [2.0]},
#                'Constant37': {'dim': 1, 'values': [2.0]},
#                'Constant38': {'dim': 1, 'values': [2.0]},
#                'Constant39': {'dim': 1, 'values': [2.0]},
#                'Constant40': {'dim': 1, 'values': [2.0]},
#                'Constant41': {'dim': 1, 'values': [2.0]},
#                'Constant43': {'dim': 1, 'values': [2.0]},
#                'Constant44': {'dim': 1, 'values': [2.0]},
#                'Constant45': {'dim': 1, 'values': [2.0]},
#                'Constant46': {'dim': 1, 'values': [2.0]},
#                'Constant47': {'dim': 1, 'values': [2.0]},
#                'Constant48': {'dim': 1, 'values': [2.0]},
#                'Constant49': {'dim': 1, 'values': [2.0]},
#                'Constant50': {'dim': 1, 'values': [2.0]},
#                'Constant51': {'dim': 1, 'values': [2.0]},
#                'Constant52': {'dim': 1, 'values': [2.0]},
#                'Constant53': {'dim': 1, 'values': [2.0]},
#                'Constant54': {'dim': 1, 'values': [6.0]},
#                'Constant55': {'dim': 1, 'values': [2.0]},
#                'Constant56': {'dim': 1, 'values': [2.0]},
#                'Constant57': {'dim': 1, 'values': [6.0]},
#                'Constant58': {'dim': 1, 'values': [2.0]},
#                'Constant59': {'dim': 1, 'values': [2.0]},
#                'Constant60': {'dim': 1, 'values': [6.0]},
#                'Constant61': {'dim': 1, 'values': [2.0]},
#                'Constant62': {'dim': 1, 'values': [2.0]},
#                'Constant63': {'dim': 1, 'values': [6.0]},
#                'dt': {'dim': 1, 'values': [0.019999999552965164]},
#                'g': {'dim': 1, 'values': [9.8100004196167]},
#                'sigma_omega': {'dim': 1, 'values': [0.0]},
#                'sigma_theta': {'dim': 1, 'values': [0.0]},
#                'sigma_v': {'dim': 1, 'values': [0.0]},
#                'sigma_x': {'dim': 1, 'values': [0.0]}},
#  'Functions': {},
#  'Info': {'SampleTime': 0.02,
#           'nnodely_version': '1.5.2',
#           'ns': [1, 0],
#           'ntot': 1,
#           'num_parameters': 12},
#  'Inputs': {'Xangle': {'closedLoop': 'Add351',
#                        'dim': 1,
#                        'local': 1,
#                        'ns': [1, 0],
#                        'ntot': 1,
#                        'sw': [-1, 0]},
#             'Xangular_velocity': {'closedLoop': 'Add339',
#                                   'dim': 1,
#                                   'local': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Xpos': {'closedLoop': 'Add327',
#                      'dim': 1,
#                      'local': 1,
#                      'ns': [1, 0],
#                      'ntot': 1,
#                      'sw': [-1, 0]},
#             'Xvelocity': {'closedLoop': 'Add315',
#                           'dim': 1,
#                           'local': 1,
#                           'ns': [1, 0],
#                           'ntot': 1,
#                           'sw': [-1, 0]},
#             'Yangle': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yangular_velocity': {'dim': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Ypos': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yvelocity': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'action': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise1': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise2': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise3': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise4': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]}},
#  'Minimizers': {'ang_vel_error': {'A': 'SamplePart353',
#                                   'B': 'Add339',
#                                   'loss': 'mse'},
#                 'angle_error': {'A': 'SamplePart355',
#                                 'B': 'Add351',
#                                 'loss': 'mse'},
#                 'pos_error': {'A': 'SamplePart359',
#                               'B': 'Add327',
#                               'loss': 'mse'},
#                 'vel_error': {'A': 'SamplePart357',
#                               'B': 'Add315',
#                               'loss': 'mse'}},
#  'Models': 'pendulum',
#  'Outputs': {'est_theta': 'Add351',
#              'est_thetadot': 'Add339',
#              'est_x': 'Add327',
#              'est_xdot': 'Add315'},
#  'Parameters': {'a1': {'dim': 1, 'values': [0.09672188758850098]},
#                 'a10': {'dim': 1, 'values': [0.4729723334312439]},
#                 'a11': {'dim': 1, 'values': [0.07608342170715332]},
#                 'a12': {'dim': 1, 'values': [0.45004338026046753]},
#                 'a13': {'dim': 1, 'values': [0.9664662480354309]},
#                 'a14': {'dim': 1, 'values': [0.7095979452133179]},
#                 'a2': {'dim': 1, 'values': [0.4487125873565674]},
#                 'a4': {'dim': 1, 'values': [0.42252427339553833]},
#                 'a5': {'dim': 1, 'values': [0.9189722537994385]},
#                 'a6': {'dim': 1, 'values': [0.7984841465950012]},
#                 'a7': {'dim': 1, 'values': [0.48250889778137207]},
#                 'a8': {'dim': 1, 'values': [0.6854273080825806]}},
#  'Relations': {'Add103': ['Add', ['Add20', 'Div102']],
#                'Add13': ['Add', ['SamplePart8', 'Mul12']],
#                'Add133': ['Add', ['Sub129', 'Mul132']],
#                'Add136': ['Add', ['Add133', 'Mul135']],
#                'Add150': ['Add', ['Sub145', 'Mul149']],
#                'Add154': ['Add', ['Add150', 'Mul153']],
#                'Add169': ['Add', ['Add13', 'Div168']],
#                'Add174': ['Add', ['Add27', 'Div173']],
#                'Add179': ['Add', ['Add20', 'Div178']],
#                'Add20': ['Add', ['SamplePart15', 'Mul19']],
#                'Add209': ['Add', ['Sub205', 'Mul208']],
#                'Add212': ['Add', ['Add209', 'Mul211']],
#                'Add226': ['Add', ['Sub221', 'Mul225']],
#                'Add230': ['Add', ['Add226', 'Mul229']],
#                'Add241': ['Add', ['Add13', 'Mul240']],
#                'Add244': ['Add', ['Add27', 'Mul243']],
#                'Add247': ['Add', ['Add20', 'Mul246']],
#                'Add27': ['Add', ['SamplePart22', 'Mul26']],
#                'Add277': ['Add', ['Sub273', 'Mul276']],
#                'Add280': ['Add', ['Add277', 'Mul279']],
#                'Add294': ['Add', ['Sub289', 'Mul293']],
#                'Add298': ['Add', ['Add294', 'Mul297']],
#                'Add306': ['Add', ['Div61', 'Mul305']],
#                'Add309': ['Add', ['Add306', 'Mul308']],
#                'Add310': ['Add', ['Add309', 'Div281']],
#                'Add315': ['Add', ['Add13', 'Div314']],
#                'Add318': ['Add', ['Add13', 'Mul317']],
#                'Add321': ['Add', ['Add318', 'Mul320']],
#                'Add322': ['Add', ['Add321', 'Add241']],
#                'Add327': ['Add', ['Add6', 'Div326']],
#                'Add330': ['Add', ['Div83', 'Mul329']],
#                'Add333': ['Add', ['Add330', 'Mul332']],
#                'Add334': ['Add', ['Add333', 'Div303']],
#                'Add339': ['Add', ['Add20', 'Div338']],
#                'Add342': ['Add', ['Add20', 'Mul341']],
#                'Add345': ['Add', ['Add342', 'Mul344']],
#                'Add346': ['Add', ['Add345', 'Add247']],
#                'Add351': ['Add', ['Add27', 'Div350']],
#                'Add57': ['Add', ['Sub53', 'Mul56']],
#                'Add6': ['Add', ['SamplePart1', 'Mul5']],
#                'Add60': ['Add', ['Add57', 'Mul59']],
#                'Add74': ['Add', ['Sub69', 'Mul73']],
#                'Add78': ['Add', ['Add74', 'Mul77']],
#                'Add93': ['Add', ['Add13', 'Div92']],
#                'Add98': ['Add', ['Add27', 'Div97']],
#                'Cos107': ['Cos', ['Add98']],
#                'Cos183': ['Cos', ['Add174']],
#                'Cos251': ['Cos', ['Add244']],
#                'Cos31': ['Cos', ['Add27']],
#                'Div102': ['Div', ['Mul100', 'Constant38']],
#                'Div137': ['Div', ['Add136', 'Sub113']],
#                'Div159': ['Div', ['Sub158', 'Sub113']],
#                'Div168': ['Div', ['Mul166', 'Constant43']],
#                'Div173': ['Div', ['Mul171', 'Constant44']],
#                'Div178': ['Div', ['Mul176', 'Constant45']],
#                'Div213': ['Div', ['Add212', 'Sub189']],
#                'Div235': ['Div', ['Sub234', 'Sub189']],
#                'Div281': ['Div', ['Add280', 'Sub257']],
#                'Div303': ['Div', ['Sub302', 'Sub257']],
#                'Div314': ['Div', ['Mul312', 'Constant54']],
#                'Div326': ['Div', ['Mul324', 'Constant57']],
#                'Div338': ['Div', ['Mul336', 'Constant60']],
#                'Div350': ['Div', ['Mul348', 'Constant63']],
#                'Div61': ['Div', ['Add60', 'Sub37']],
#                'Div83': ['Div', ['Sub82', 'Sub37']],
#                'Div92': ['Div', ['Mul90', 'Constant36']],
#                'Div97': ['Div', ['Mul95', 'Constant37']],
#                'Mul100': ['Mul', ['Div83', 'dt']],
#                'Mul109': ['Mul', ['a14', 'Cos107']],
#                'Mul115': ['Mul', ['a2', 'Add93']],
#                'Mul117': ['Mul', ['a8', 'Add103']],
#                'Mul12': ['Mul', ['SamplePart10', 'sigma_v']],
#                'Mul121': ['Mul', ['a1', 'Pow119']],
#                'Mul122': ['Mul', ['Mul121', 'Sin106']],
#                'Mul126': ['Mul', ['a4', 'g']],
#                'Mul127': ['Mul', ['Mul126', 'Cos107']],
#                'Mul128': ['Mul', ['Mul127', 'Sin106']],
#                'Mul131': ['Mul', ['a5', 'Add103']],
#                'Mul132': ['Mul', ['Mul131', 'Cos107']],
#                'Mul135': ['Mul', ['a6', 'SamplePart105']],
#                'Mul142': ['Mul', ['Neg139', 'Pow141']],
#                'Mul143': ['Mul', ['Mul142', 'Cos107']],
#                'Mul144': ['Mul', ['Mul143', 'Sin106']],
#                'Mul148': ['Mul', ['a10', 'g']],
#                'Mul149': ['Mul', ['Mul148', 'Sin106']],
#                'Mul152': ['Mul', ['a11', 'Add93']],
#                'Mul153': ['Mul', ['Mul152', 'Cos107']],
#                'Mul156': ['Mul', ['a12', 'Cos107']],
#                'Mul157': ['Mul', ['Mul156', 'SamplePart105']],
#                'Mul166': ['Mul', ['Div137', 'dt']],
#                'Mul171': ['Mul', ['Add103', 'dt']],
#                'Mul176': ['Mul', ['Div159', 'dt']],
#                'Mul185': ['Mul', ['a14', 'Cos183']],
#                'Mul19': ['Mul', ['SamplePart17', 'sigma_omega']],
#                'Mul191': ['Mul', ['a2', 'Add169']],
#                'Mul193': ['Mul', ['a8', 'Add179']],
#                'Mul197': ['Mul', ['a1', 'Pow195']],
#                'Mul198': ['Mul', ['Mul197', 'Sin182']],
#                'Mul202': ['Mul', ['a4', 'g']],
#                'Mul203': ['Mul', ['Mul202', 'Cos183']],
#                'Mul204': ['Mul', ['Mul203', 'Sin182']],
#                'Mul207': ['Mul', ['a5', 'Add179']],
#                'Mul208': ['Mul', ['Mul207', 'Cos183']],
#                'Mul211': ['Mul', ['a6', 'SamplePart181']],
#                'Mul218': ['Mul', ['Neg215', 'Pow217']],
#                'Mul219': ['Mul', ['Mul218', 'Cos183']],
#                'Mul220': ['Mul', ['Mul219', 'Sin182']],
#                'Mul224': ['Mul', ['a10', 'g']],
#                'Mul225': ['Mul', ['Mul224', 'Sin182']],
#                'Mul228': ['Mul', ['a11', 'Add169']],
#                'Mul229': ['Mul', ['Mul228', 'Cos183']],
#                'Mul232': ['Mul', ['a12', 'Cos183']],
#                'Mul233': ['Mul', ['Mul232', 'SamplePart181']],
#                'Mul240': ['Mul', ['Div213', 'dt']],
#                'Mul243': ['Mul', ['Add179', 'dt']],
#                'Mul246': ['Mul', ['Div235', 'dt']],
#                'Mul253': ['Mul', ['a14', 'Cos251']],
#                'Mul259': ['Mul', ['a2', 'Add241']],
#                'Mul26': ['Mul', ['SamplePart24', 'sigma_theta']],
#                'Mul261': ['Mul', ['a8', 'Add247']],
#                'Mul265': ['Mul', ['a1', 'Pow263']],
#                'Mul266': ['Mul', ['Mul265', 'Sin250']],
#                'Mul270': ['Mul', ['a4', 'g']],
#                'Mul271': ['Mul', ['Mul270', 'Cos251']],
#                'Mul272': ['Mul', ['Mul271', 'Sin250']],
#                'Mul275': ['Mul', ['a5', 'Add247']],
#                'Mul276': ['Mul', ['Mul275', 'Cos251']],
#                'Mul279': ['Mul', ['a6', 'SamplePart249']],
#                'Mul286': ['Mul', ['Neg283', 'Pow285']],
#                'Mul287': ['Mul', ['Mul286', 'Cos251']],
#                'Mul288': ['Mul', ['Mul287', 'Sin250']],
#                'Mul292': ['Mul', ['a10', 'g']],
#                'Mul293': ['Mul', ['Mul292', 'Sin250']],
#                'Mul296': ['Mul', ['a11', 'Add241']],
#                'Mul297': ['Mul', ['Mul296', 'Cos251']],
#                'Mul300': ['Mul', ['a12', 'Cos251']],
#                'Mul301': ['Mul', ['Mul300', 'SamplePart249']],
#                'Mul305': ['Mul', ['Constant52', 'Div137']],
#                'Mul308': ['Mul', ['Constant53', 'Div213']],
#                'Mul312': ['Mul', ['Add310', 'dt']],
#                'Mul317': ['Mul', ['Constant55', 'Add93']],
#                'Mul320': ['Mul', ['Constant56', 'Add169']],
#                'Mul324': ['Mul', ['Add322', 'dt']],
#                'Mul329': ['Mul', ['Constant58', 'Div159']],
#                'Mul33': ['Mul', ['a14', 'Cos31']],
#                'Mul332': ['Mul', ['Constant59', 'Div235']],
#                'Mul336': ['Mul', ['Add334', 'dt']],
#                'Mul341': ['Mul', ['Constant61', 'Add103']],
#                'Mul344': ['Mul', ['Constant62', 'Add179']],
#                'Mul348': ['Mul', ['Add346', 'dt']],
#                'Mul39': ['Mul', ['a2', 'Add13']],
#                'Mul41': ['Mul', ['a8', 'Add20']],
#                'Mul45': ['Mul', ['a1', 'Pow43']],
#                'Mul46': ['Mul', ['Mul45', 'Sin30']],
#                'Mul5': ['Mul', ['SamplePart3', 'sigma_x']],
#                'Mul50': ['Mul', ['a4', 'g']],
#                'Mul51': ['Mul', ['Mul50', 'Cos31']],
#                'Mul52': ['Mul', ['Mul51', 'Sin30']],
#                'Mul55': ['Mul', ['a5', 'Add20']],
#                'Mul56': ['Mul', ['Mul55', 'Cos31']],
#                'Mul59': ['Mul', ['a6', 'SamplePart29']],
#                'Mul66': ['Mul', ['Neg63', 'Pow65']],
#                'Mul67': ['Mul', ['Mul66', 'Cos31']],
#                'Mul68': ['Mul', ['Mul67', 'Sin30']],
#                'Mul72': ['Mul', ['a10', 'g']],
#                'Mul73': ['Mul', ['Mul72', 'Sin30']],
#                'Mul76': ['Mul', ['a11', 'Add13']],
#                'Mul77': ['Mul', ['Mul76', 'Cos31']],
#                'Mul80': ['Mul', ['a12', 'Cos31']],
#                'Mul81': ['Mul', ['Mul80', 'SamplePart29']],
#                'Mul90': ['Mul', ['Div61', 'dt']],
#                'Mul95': ['Mul', ['Add20', 'dt']],
#                'Neg139': ['Neg', ['a7']],
#                'Neg215': ['Neg', ['a7']],
#                'Neg283': ['Neg', ['a7']],
#                'Neg63': ['Neg', ['a7']],
#                'Pow111': ['Pow', ['Mul109', 'Constant39']],
#                'Pow119': ['Pow', ['Add103', 'Constant40']],
#                'Pow141': ['Pow', ['Add103', 'Constant41']],
#                'Pow187': ['Pow', ['Mul185', 'Constant46']],
#                'Pow195': ['Pow', ['Add179', 'Constant47']],
#                'Pow217': ['Pow', ['Add179', 'Constant48']],
#                'Pow255': ['Pow', ['Mul253', 'Constant49']],
#                'Pow263': ['Pow', ['Add247', 'Constant50']],
#                'Pow285': ['Pow', ['Add247', 'Constant51']],
#                'Pow35': ['Pow', ['Mul33', 'Constant32']],
#                'Pow43': ['Pow', ['Add20', 'Constant33']],
#                'Pow65': ['Pow', ['Add20', 'Constant34']],
#                'SamplePart1': ['SamplePart', ['Xpos'], -1, [-1, 0]],
#                'SamplePart10': ['SamplePart', ['noise1'], -1, [-1, 0]],
#                'SamplePart105': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart15': ['SamplePart',
#                                 ['Xangular_velocity'],
#                                 -1,
#                                 [-1, 0]],
#                'SamplePart17': ['SamplePart', ['noise3'], -1, [-1, 0]],
#                'SamplePart181': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart22': ['SamplePart', ['Xangle'], -1, [-1, 0]],
#                'SamplePart24': ['SamplePart', ['noise2'], -1, [-1, 0]],
#                'SamplePart249': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart29': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart3': ['SamplePart', ['noise4'], -1, [-1, 0]],
#                'SamplePart353': ['SamplePart',
#                                  ['Yangular_velocity'],
#                                  -1,
#                                  [-1, 0]],
#                'SamplePart355': ['SamplePart', ['Yangle'], -1, [-1, 0]],
#                'SamplePart357': ['SamplePart', ['Yvelocity'], -1, [-1, 0]],
#                'SamplePart359': ['SamplePart', ['Ypos'], -1, [-1, 0]],
#                'SamplePart8': ['SamplePart', ['Xvelocity'], -1, [-1, 0]],
#                'Sin106': ['Sin', ['Add98']],
#                'Sin182': ['Sin', ['Add174']],
#                'Sin250': ['Sin', ['Add244']],
#                'Sin30': ['Sin', ['Add27']],
#                'Sub113': ['Sub', ['a13', 'Pow111']],
#                'Sub123': ['Sub', ['Mul122', 'Mul115']],
#                'Sub129': ['Sub', ['Sub123', 'Mul128']],
#                'Sub145': ['Sub', ['Mul144', 'Mul117']],
#                'Sub158': ['Sub', ['Add154', 'Mul157']],
#                'Sub189': ['Sub', ['a13', 'Pow187']],
#                'Sub199': ['Sub', ['Mul198', 'Mul191']],
#                'Sub205': ['Sub', ['Sub199', 'Mul204']],
#                'Sub221': ['Sub', ['Mul220', 'Mul193']],
#                'Sub234': ['Sub', ['Add230', 'Mul233']],
#                'Sub257': ['Sub', ['a13', 'Pow255']],
#                'Sub267': ['Sub', ['Mul266', 'Mul259']],
#                'Sub273': ['Sub', ['Sub267', 'Mul272']],
#                'Sub289': ['Sub', ['Mul288', 'Mul261']],
#                'Sub302': ['Sub', ['Add298', 'Mul301']],
#                'Sub37': ['Sub', ['a13', 'Pow35']],
#                'Sub47': ['Sub', ['Mul46', 'Mul39']],
#                'Sub53': ['Sub', ['Sub47', 'Mul52']],
#                'Sub69': ['Sub', ['Mul68', 'Mul41']],
#                'Sub82': ['Sub', ['Add78', 'Mul81']]}}
# ================================================================================
# ========================== Import Python Torch Model ===========================
# Model imported from:          /home/baro/Desktop/inv_pend/saved_models/semi_physical_model.py
# ================================================================================
# [neuralizeModel] Closed loop on Xangle with sample in the future.
# [neuralizeModel] Closed loop on Xangular_velocity with sample in the future.
# [neuralizeModel] Closed loop on Xpos with sample in the future.
# [neuralizeModel] Closed loop on Xvelocity with sample in the future.
# ================================ nnodely Model =================================
# {'Constants': {'Constant32': {'dim': 1, 'values': [2.0]},
#                'Constant33': {'dim': 1, 'values': [2.0]},
#                'Constant34': {'dim': 1, 'values': [2.0]},
#                'Constant36': {'dim': 1, 'values': [2.0]},
#                'Constant37': {'dim': 1, 'values': [2.0]},
#                'Constant38': {'dim': 1, 'values': [2.0]},
#                'Constant39': {'dim': 1, 'values': [2.0]},
#                'Constant40': {'dim': 1, 'values': [2.0]},
#                'Constant41': {'dim': 1, 'values': [2.0]},
#                'Constant43': {'dim': 1, 'values': [2.0]},
#                'Constant44': {'dim': 1, 'values': [2.0]},
#                'Constant45': {'dim': 1, 'values': [2.0]},
#                'Constant46': {'dim': 1, 'values': [2.0]},
#                'Constant47': {'dim': 1, 'values': [2.0]},
#                'Constant48': {'dim': 1, 'values': [2.0]},
#                'Constant49': {'dim': 1, 'values': [2.0]},
#                'Constant50': {'dim': 1, 'values': [2.0]},
#                'Constant51': {'dim': 1, 'values': [2.0]},
#                'Constant52': {'dim': 1, 'values': [2.0]},
#                'Constant53': {'dim': 1, 'values': [2.0]},
#                'Constant54': {'dim': 1, 'values': [6.0]},
#                'Constant55': {'dim': 1, 'values': [2.0]},
#                'Constant56': {'dim': 1, 'values': [2.0]},
#                'Constant57': {'dim': 1, 'values': [6.0]},
#                'Constant58': {'dim': 1, 'values': [2.0]},
#                'Constant59': {'dim': 1, 'values': [2.0]},
#                'Constant60': {'dim': 1, 'values': [6.0]},
#                'Constant61': {'dim': 1, 'values': [2.0]},
#                'Constant62': {'dim': 1, 'values': [2.0]},
#                'Constant63': {'dim': 1, 'values': [6.0]},
#                'dt': {'dim': 1, 'values': [0.019999999552965164]},
#                'g': {'dim': 1, 'values': [9.8100004196167]},
#                'sigma_omega': {'dim': 1, 'values': [0.0]},
#                'sigma_theta': {'dim': 1, 'values': [0.0]},
#                'sigma_v': {'dim': 1, 'values': [0.0]},
#                'sigma_x': {'dim': 1, 'values': [0.0]}},
#  'Functions': {},
#  'Info': {'SampleTime': 0.02,
#           'nnodely_version': '1.5.2',
#           'ns': [1, 0],
#           'ntot': 1,
#           'num_parameters': 12},
#  'Inputs': {'Xangle': {'closedLoop': 'Add351',
#                        'dim': 1,
#                        'local': 1,
#                        'ns': [1, 0],
#                        'ntot': 1,
#                        'sw': [-1, 0]},
#             'Xangular_velocity': {'closedLoop': 'Add339',
#                                   'dim': 1,
#                                   'local': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Xpos': {'closedLoop': 'Add327',
#                      'dim': 1,
#                      'local': 1,
#                      'ns': [1, 0],
#                      'ntot': 1,
#                      'sw': [-1, 0]},
#             'Xvelocity': {'closedLoop': 'Add315',
#                           'dim': 1,
#                           'local': 1,
#                           'ns': [1, 0],
#                           'ntot': 1,
#                           'sw': [-1, 0]},
#             'Yangle': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yangular_velocity': {'dim': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Ypos': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yvelocity': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'action': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise1': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise2': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise3': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise4': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]}},
#  'Minimizers': {'ang_vel_error': {'A': 'SamplePart353',
#                                   'B': 'Add339',
#                                   'loss': 'mse'},
#                 'angle_error': {'A': 'SamplePart355',
#                                 'B': 'Add351',
#                                 'loss': 'mse'},
#                 'pos_error': {'A': 'SamplePart359',
#                               'B': 'Add327',
#                               'loss': 'mse'},
#                 'vel_error': {'A': 'SamplePart357',
#                               'B': 'Add315',
#                               'loss': 'mse'}},
#  'Models': 'pendulum',
#  'Outputs': {'est_theta': 'Add351',
#              'est_thetadot': 'Add339',
#              'est_x': 'Add327',
#              'est_xdot': 'Add315'},
#  'Parameters': {'a1': {'dim': 1, 'values': [0.09672188758850098]},
#                 'a10': {'dim': 1, 'values': [0.4729723334312439]},
#                 'a11': {'dim': 1, 'values': [0.07608342170715332]},
#                 'a12': {'dim': 1, 'values': [0.45004338026046753]},
#                 'a13': {'dim': 1, 'values': [0.9664662480354309]},
#                 'a14': {'dim': 1, 'values': [0.7095979452133179]},
#                 'a2': {'dim': 1, 'values': [0.4487125873565674]},
#                 'a4': {'dim': 1, 'values': [0.42252427339553833]},
#                 'a5': {'dim': 1, 'values': [0.9189722537994385]},
#                 'a6': {'dim': 1, 'values': [0.7984841465950012]},
#                 'a7': {'dim': 1, 'values': [0.48250889778137207]},
#                 'a8': {'dim': 1, 'values': [0.6854273080825806]}},
#  'Relations': {'Add103': ['Add', ['Add20', 'Div102']],
#                'Add13': ['Add', ['SamplePart8', 'Mul12']],
#                'Add133': ['Add', ['Sub129', 'Mul132']],
#                'Add136': ['Add', ['Add133', 'Mul135']],
#                'Add150': ['Add', ['Sub145', 'Mul149']],
#                'Add154': ['Add', ['Add150', 'Mul153']],
#                'Add169': ['Add', ['Add13', 'Div168']],
#                'Add174': ['Add', ['Add27', 'Div173']],
#                'Add179': ['Add', ['Add20', 'Div178']],
#                'Add20': ['Add', ['SamplePart15', 'Mul19']],
#                'Add209': ['Add', ['Sub205', 'Mul208']],
#                'Add212': ['Add', ['Add209', 'Mul211']],
#                'Add226': ['Add', ['Sub221', 'Mul225']],
#                'Add230': ['Add', ['Add226', 'Mul229']],
#                'Add241': ['Add', ['Add13', 'Mul240']],
#                'Add244': ['Add', ['Add27', 'Mul243']],
#                'Add247': ['Add', ['Add20', 'Mul246']],
#                'Add27': ['Add', ['SamplePart22', 'Mul26']],
#                'Add277': ['Add', ['Sub273', 'Mul276']],
#                'Add280': ['Add', ['Add277', 'Mul279']],
#                'Add294': ['Add', ['Sub289', 'Mul293']],
#                'Add298': ['Add', ['Add294', 'Mul297']],
#                'Add306': ['Add', ['Div61', 'Mul305']],
#                'Add309': ['Add', ['Add306', 'Mul308']],
#                'Add310': ['Add', ['Add309', 'Div281']],
#                'Add315': ['Add', ['Add13', 'Div314']],
#                'Add318': ['Add', ['Add13', 'Mul317']],
#                'Add321': ['Add', ['Add318', 'Mul320']],
#                'Add322': ['Add', ['Add321', 'Add241']],
#                'Add327': ['Add', ['Add6', 'Div326']],
#                'Add330': ['Add', ['Div83', 'Mul329']],
#                'Add333': ['Add', ['Add330', 'Mul332']],
#                'Add334': ['Add', ['Add333', 'Div303']],
#                'Add339': ['Add', ['Add20', 'Div338']],
#                'Add342': ['Add', ['Add20', 'Mul341']],
#                'Add345': ['Add', ['Add342', 'Mul344']],
#                'Add346': ['Add', ['Add345', 'Add247']],
#                'Add351': ['Add', ['Add27', 'Div350']],
#                'Add57': ['Add', ['Sub53', 'Mul56']],
#                'Add6': ['Add', ['SamplePart1', 'Mul5']],
#                'Add60': ['Add', ['Add57', 'Mul59']],
#                'Add74': ['Add', ['Sub69', 'Mul73']],
#                'Add78': ['Add', ['Add74', 'Mul77']],
#                'Add93': ['Add', ['Add13', 'Div92']],
#                'Add98': ['Add', ['Add27', 'Div97']],
#                'Cos107': ['Cos', ['Add98']],
#                'Cos183': ['Cos', ['Add174']],
#                'Cos251': ['Cos', ['Add244']],
#                'Cos31': ['Cos', ['Add27']],
#                'Div102': ['Div', ['Mul100', 'Constant38']],
#                'Div137': ['Div', ['Add136', 'Sub113']],
#                'Div159': ['Div', ['Sub158', 'Sub113']],
#                'Div168': ['Div', ['Mul166', 'Constant43']],
#                'Div173': ['Div', ['Mul171', 'Constant44']],
#                'Div178': ['Div', ['Mul176', 'Constant45']],
#                'Div213': ['Div', ['Add212', 'Sub189']],
#                'Div235': ['Div', ['Sub234', 'Sub189']],
#                'Div281': ['Div', ['Add280', 'Sub257']],
#                'Div303': ['Div', ['Sub302', 'Sub257']],
#                'Div314': ['Div', ['Mul312', 'Constant54']],
#                'Div326': ['Div', ['Mul324', 'Constant57']],
#                'Div338': ['Div', ['Mul336', 'Constant60']],
#                'Div350': ['Div', ['Mul348', 'Constant63']],
#                'Div61': ['Div', ['Add60', 'Sub37']],
#                'Div83': ['Div', ['Sub82', 'Sub37']],
#                'Div92': ['Div', ['Mul90', 'Constant36']],
#                'Div97': ['Div', ['Mul95', 'Constant37']],
#                'Mul100': ['Mul', ['Div83', 'dt']],
#                'Mul109': ['Mul', ['a14', 'Cos107']],
#                'Mul115': ['Mul', ['a2', 'Add93']],
#                'Mul117': ['Mul', ['a8', 'Add103']],
#                'Mul12': ['Mul', ['SamplePart10', 'sigma_v']],
#                'Mul121': ['Mul', ['a1', 'Pow119']],
#                'Mul122': ['Mul', ['Mul121', 'Sin106']],
#                'Mul126': ['Mul', ['a4', 'g']],
#                'Mul127': ['Mul', ['Mul126', 'Cos107']],
#                'Mul128': ['Mul', ['Mul127', 'Sin106']],
#                'Mul131': ['Mul', ['a5', 'Add103']],
#                'Mul132': ['Mul', ['Mul131', 'Cos107']],
#                'Mul135': ['Mul', ['a6', 'SamplePart105']],
#                'Mul142': ['Mul', ['Neg139', 'Pow141']],
#                'Mul143': ['Mul', ['Mul142', 'Cos107']],
#                'Mul144': ['Mul', ['Mul143', 'Sin106']],
#                'Mul148': ['Mul', ['a10', 'g']],
#                'Mul149': ['Mul', ['Mul148', 'Sin106']],
#                'Mul152': ['Mul', ['a11', 'Add93']],
#                'Mul153': ['Mul', ['Mul152', 'Cos107']],
#                'Mul156': ['Mul', ['a12', 'Cos107']],
#                'Mul157': ['Mul', ['Mul156', 'SamplePart105']],
#                'Mul166': ['Mul', ['Div137', 'dt']],
#                'Mul171': ['Mul', ['Add103', 'dt']],
#                'Mul176': ['Mul', ['Div159', 'dt']],
#                'Mul185': ['Mul', ['a14', 'Cos183']],
#                'Mul19': ['Mul', ['SamplePart17', 'sigma_omega']],
#                'Mul191': ['Mul', ['a2', 'Add169']],
#                'Mul193': ['Mul', ['a8', 'Add179']],
#                'Mul197': ['Mul', ['a1', 'Pow195']],
#                'Mul198': ['Mul', ['Mul197', 'Sin182']],
#                'Mul202': ['Mul', ['a4', 'g']],
#                'Mul203': ['Mul', ['Mul202', 'Cos183']],
#                'Mul204': ['Mul', ['Mul203', 'Sin182']],
#                'Mul207': ['Mul', ['a5', 'Add179']],
#                'Mul208': ['Mul', ['Mul207', 'Cos183']],
#                'Mul211': ['Mul', ['a6', 'SamplePart181']],
#                'Mul218': ['Mul', ['Neg215', 'Pow217']],
#                'Mul219': ['Mul', ['Mul218', 'Cos183']],
#                'Mul220': ['Mul', ['Mul219', 'Sin182']],
#                'Mul224': ['Mul', ['a10', 'g']],
#                'Mul225': ['Mul', ['Mul224', 'Sin182']],
#                'Mul228': ['Mul', ['a11', 'Add169']],
#                'Mul229': ['Mul', ['Mul228', 'Cos183']],
#                'Mul232': ['Mul', ['a12', 'Cos183']],
#                'Mul233': ['Mul', ['Mul232', 'SamplePart181']],
#                'Mul240': ['Mul', ['Div213', 'dt']],
#                'Mul243': ['Mul', ['Add179', 'dt']],
#                'Mul246': ['Mul', ['Div235', 'dt']],
#                'Mul253': ['Mul', ['a14', 'Cos251']],
#                'Mul259': ['Mul', ['a2', 'Add241']],
#                'Mul26': ['Mul', ['SamplePart24', 'sigma_theta']],
#                'Mul261': ['Mul', ['a8', 'Add247']],
#                'Mul265': ['Mul', ['a1', 'Pow263']],
#                'Mul266': ['Mul', ['Mul265', 'Sin250']],
#                'Mul270': ['Mul', ['a4', 'g']],
#                'Mul271': ['Mul', ['Mul270', 'Cos251']],
#                'Mul272': ['Mul', ['Mul271', 'Sin250']],
#                'Mul275': ['Mul', ['a5', 'Add247']],
#                'Mul276': ['Mul', ['Mul275', 'Cos251']],
#                'Mul279': ['Mul', ['a6', 'SamplePart249']],
#                'Mul286': ['Mul', ['Neg283', 'Pow285']],
#                'Mul287': ['Mul', ['Mul286', 'Cos251']],
#                'Mul288': ['Mul', ['Mul287', 'Sin250']],
#                'Mul292': ['Mul', ['a10', 'g']],
#                'Mul293': ['Mul', ['Mul292', 'Sin250']],
#                'Mul296': ['Mul', ['a11', 'Add241']],
#                'Mul297': ['Mul', ['Mul296', 'Cos251']],
#                'Mul300': ['Mul', ['a12', 'Cos251']],
#                'Mul301': ['Mul', ['Mul300', 'SamplePart249']],
#                'Mul305': ['Mul', ['Constant52', 'Div137']],
#                'Mul308': ['Mul', ['Constant53', 'Div213']],
#                'Mul312': ['Mul', ['Add310', 'dt']],
#                'Mul317': ['Mul', ['Constant55', 'Add93']],
#                'Mul320': ['Mul', ['Constant56', 'Add169']],
#                'Mul324': ['Mul', ['Add322', 'dt']],
#                'Mul329': ['Mul', ['Constant58', 'Div159']],
#                'Mul33': ['Mul', ['a14', 'Cos31']],
#                'Mul332': ['Mul', ['Constant59', 'Div235']],
#                'Mul336': ['Mul', ['Add334', 'dt']],
#                'Mul341': ['Mul', ['Constant61', 'Add103']],
#                'Mul344': ['Mul', ['Constant62', 'Add179']],
#                'Mul348': ['Mul', ['Add346', 'dt']],
#                'Mul39': ['Mul', ['a2', 'Add13']],
#                'Mul41': ['Mul', ['a8', 'Add20']],
#                'Mul45': ['Mul', ['a1', 'Pow43']],
#                'Mul46': ['Mul', ['Mul45', 'Sin30']],
#                'Mul5': ['Mul', ['SamplePart3', 'sigma_x']],
#                'Mul50': ['Mul', ['a4', 'g']],
#                'Mul51': ['Mul', ['Mul50', 'Cos31']],
#                'Mul52': ['Mul', ['Mul51', 'Sin30']],
#                'Mul55': ['Mul', ['a5', 'Add20']],
#                'Mul56': ['Mul', ['Mul55', 'Cos31']],
#                'Mul59': ['Mul', ['a6', 'SamplePart29']],
#                'Mul66': ['Mul', ['Neg63', 'Pow65']],
#                'Mul67': ['Mul', ['Mul66', 'Cos31']],
#                'Mul68': ['Mul', ['Mul67', 'Sin30']],
#                'Mul72': ['Mul', ['a10', 'g']],
#                'Mul73': ['Mul', ['Mul72', 'Sin30']],
#                'Mul76': ['Mul', ['a11', 'Add13']],
#                'Mul77': ['Mul', ['Mul76', 'Cos31']],
#                'Mul80': ['Mul', ['a12', 'Cos31']],
#                'Mul81': ['Mul', ['Mul80', 'SamplePart29']],
#                'Mul90': ['Mul', ['Div61', 'dt']],
#                'Mul95': ['Mul', ['Add20', 'dt']],
#                'Neg139': ['Neg', ['a7']],
#                'Neg215': ['Neg', ['a7']],
#                'Neg283': ['Neg', ['a7']],
#                'Neg63': ['Neg', ['a7']],
#                'Pow111': ['Pow', ['Mul109', 'Constant39']],
#                'Pow119': ['Pow', ['Add103', 'Constant40']],
#                'Pow141': ['Pow', ['Add103', 'Constant41']],
#                'Pow187': ['Pow', ['Mul185', 'Constant46']],
#                'Pow195': ['Pow', ['Add179', 'Constant47']],
#                'Pow217': ['Pow', ['Add179', 'Constant48']],
#                'Pow255': ['Pow', ['Mul253', 'Constant49']],
#                'Pow263': ['Pow', ['Add247', 'Constant50']],
#                'Pow285': ['Pow', ['Add247', 'Constant51']],
#                'Pow35': ['Pow', ['Mul33', 'Constant32']],
#                'Pow43': ['Pow', ['Add20', 'Constant33']],
#                'Pow65': ['Pow', ['Add20', 'Constant34']],
#                'SamplePart1': ['SamplePart', ['Xpos'], -1, [-1, 0]],
#                'SamplePart10': ['SamplePart', ['noise1'], -1, [-1, 0]],
#                'SamplePart105': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart15': ['SamplePart',
#                                 ['Xangular_velocity'],
#                                 -1,
#                                 [-1, 0]],
#                'SamplePart17': ['SamplePart', ['noise3'], -1, [-1, 0]],
#                'SamplePart181': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart22': ['SamplePart', ['Xangle'], -1, [-1, 0]],
#                'SamplePart24': ['SamplePart', ['noise2'], -1, [-1, 0]],
#                'SamplePart249': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart29': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart3': ['SamplePart', ['noise4'], -1, [-1, 0]],
#                'SamplePart353': ['SamplePart',
#                                  ['Yangular_velocity'],
#                                  -1,
#                                  [-1, 0]],
#                'SamplePart355': ['SamplePart', ['Yangle'], -1, [-1, 0]],
#                'SamplePart357': ['SamplePart', ['Yvelocity'], -1, [-1, 0]],
#                'SamplePart359': ['SamplePart', ['Ypos'], -1, [-1, 0]],
#                'SamplePart8': ['SamplePart', ['Xvelocity'], -1, [-1, 0]],
#                'Sin106': ['Sin', ['Add98']],
#                'Sin182': ['Sin', ['Add174']],
#                'Sin250': ['Sin', ['Add244']],
#                'Sin30': ['Sin', ['Add27']],
#                'Sub113': ['Sub', ['a13', 'Pow111']],
#                'Sub123': ['Sub', ['Mul122', 'Mul115']],
#                'Sub129': ['Sub', ['Sub123', 'Mul128']],
#                'Sub145': ['Sub', ['Mul144', 'Mul117']],
#                'Sub158': ['Sub', ['Add154', 'Mul157']],
#                'Sub189': ['Sub', ['a13', 'Pow187']],
#                'Sub199': ['Sub', ['Mul198', 'Mul191']],
#                'Sub205': ['Sub', ['Sub199', 'Mul204']],
#                'Sub221': ['Sub', ['Mul220', 'Mul193']],
#                'Sub234': ['Sub', ['Add230', 'Mul233']],
#                'Sub257': ['Sub', ['a13', 'Pow255']],
#                'Sub267': ['Sub', ['Mul266', 'Mul259']],
#                'Sub273': ['Sub', ['Sub267', 'Mul272']],
#                'Sub289': ['Sub', ['Mul288', 'Mul261']],
#                'Sub302': ['Sub', ['Add298', 'Mul301']],
#                'Sub37': ['Sub', ['a13', 'Pow35']],
#                'Sub47': ['Sub', ['Mul46', 'Mul39']],
#                'Sub53': ['Sub', ['Sub47', 'Mul52']],
#                'Sub69': ['Sub', ['Mul68', 'Mul41']],
#                'Sub82': ['Sub', ['Add78', 'Mul81']]}}
# ================================================================================
# ======================== nnodely Model Train Parameters ========================
# models:                       ['pendulum']
# num of epochs:                100
# update per epochs:            468
# └>len(train_indexes)//(batch_size+step)
# shuffle data:                 True
# early stopping:               early_stop_patience
# early stopping params:        {'error': 'ang_vel_error', 'patience': 10}
# prediction samples:           0
# step:                         0
# closed loop:                  {}
# connect:                      {}
# train dataset:                data_train
# 	- batch size:                64
# 	- num of samples:            30000
# 	- num of first samples:      30000
# minimizers:                   {'ang_vel_error': {'A': 'SamplePart353',
#                                                  'B': 'Add339',
#                                                  'loss': 'mse'},
#                                'angle_error': {'A': 'SamplePart355',
#                                                'B': 'Add351',
#                                                'loss': 'mse'},
#                                'pos_error': {'A': 'SamplePart359',
#                                              'B': 'Add327',
#                                              'loss': 'mse'},
#                                'vel_error': {'A': 'SamplePart357',
#                                              'B': 'Add315',
#                                              'loss': 'mse'}}
# optimizer:                    Adam
# optimizer defaults:           {'lr': 0.001}
# optimizer params:             [{'params': 'a1'},
#                                {'params': 'a10'},
#                                {'params': 'a11'},
#                                {'params': 'a12'},
#                                {'params': 'a13'},
#                                {'params': 'a14'},
#                                {'params': 'a2'},
#                                {'params': 'a4'},
#                                {'params': 'a5'},
#                                {'params': 'a6'},
#                                {'params': 'a7'},
#                                {'params': 'a8'}]
# ================================================================================
# =============================================== nnodely Training ===============================================
# |  Epoch   |   ang_vel_error   |    angle_error    |     pos_error     |     vel_error     |       Total       |
# |          |        Loss       |        Loss       |        Loss       |        Loss       |        Loss       |
# |          |       train       |       train       |       train       |       train       |       train       |
# |--------------------------------------------------------------------------------------------------------------|
# |  1/100   |     2.657e-02     |     2.688e-06     |     6.463e-07     |     6.451e-03     |     8.255e-03     |
# |  2/100   |     1.032e-02     |     1.046e-06     |     1.723e-07     |     1.719e-03     |      3.01e-03     |
# |  3/100   |     7.465e-03     |     7.577e-07     |     2.895e-08     |     2.859e-04     |     1.938e-03     |
# |  4/100   |     5.266e-03     |     5.352e-07     |     8.028e-09     |      7.98e-05     |     1.337e-03     |
# |  5/100   |     2.828e-03     |      2.88e-07     |     8.610e-09     |     8.651e-05     |     7.288e-04     |
# |  6/100   |     8.557e-04     |     8.709e-08     |     6.444e-09     |     6.432e-05     |     2.300e-04     |
# |  7/100   |     1.114e-04     |     1.132e-08     |     1.090e-09     |     1.087e-05     |     3.056e-05     |
# |  8/100   |     7.321e-06     |     7.433e-10     |     5.711e-11     |     5.671e-07     |     1.972e-06     |
# |  9/100   |     8.852e-07     |     9.007e-11     |     2.849e-12     |     2.672e-08     |      2.28e-07     |
# |  10/100  |     6.746e-07     |     6.863e-11     |     1.279e-12     |     1.101e-08     |     1.714e-07     |
# |  11/100  |     6.733e-07     |     6.851e-11     |     1.312e-12     |     1.135e-08     |     1.712e-07     |
# |  12/100  |     6.773e-07     |     6.893e-11     |     1.370e-12     |     1.191e-08     |     1.723e-07     |
# |  13/100  |     6.783e-07     |     6.900e-11     |     1.406e-12     |     1.228e-08     |     1.727e-07     |
# |  14/100  |     6.847e-07     |     6.967e-11     |     1.532e-12     |     1.362e-08     |     1.746e-07     |
# |  15/100  |     6.909e-07     |     7.029e-11     |     1.695e-12     |     1.515e-08     |     1.765e-07     |
# |  16/100  |     7.156e-07     |     7.279e-11     |     2.496e-12     |     2.324e-08     |     1.847e-07     |
# |  17/100  |     7.158e-07     |     7.282e-11     |     2.587e-12     |     2.425e-08     |     1.850e-07     |
# |  18/100  |      7.15e-07     |     7.273e-11     |     3.664e-12     |     3.487e-08     |     1.875e-07     |
# |  19/100  |     7.603e-07     |     7.729e-11     |     2.853e-12     |     2.661e-08     |     1.967e-07     |
# |  20/100  |     7.522e-07     |     7.648e-11     |     4.148e-12     |     3.973e-08     |     1.980e-07     |
# Stopping the training at epoch 20 due to early stopping.
# ============================ nnodely Training Time =============================
# Total time of Training:       72.70484375953674
# ================================================================================
# The selected model is the LAST model of the training.
# =============================== Save JSON Model ================================
# Model saved in:               /home/baro/Desktop/inv_pend/saved_models/semi_physical_model.json
# ================================================================================
# ========================== Export Python Torch Model ===========================
# Model exported in:            /home/baro/Desktop/inv_pend/saved_models/semi_physical_model.py
# ================================================================================
# ======================== Export Training Results Report ========================
# Report exported in:           /home/baro/Desktop/inv_pend/saved_models/semi_physical_model_report.pdf
# ================================================================================

# %%
# Closed-loop plot
inverted_pendulum.importPythonModel(name=model_name)
inverted_pendulum.neuralizeModel(sample_time = 0.02)
data_folder = os.path.join(os.path.abspath(''),'data_test')
inverted_pendulum.loadData(name='data_test', source=data_folder, format=data_struct, delimiter=',', header=0)
samples = inverted_pendulum.getSamples(dataset='data_test', window=150, index=0)

result = inverted_pendulum(samples, sampled=True, num_of_samples=150)

# Plotting
t = np.arange(len(result['est_theta'])) * 0.02
plt.figure(figsize=(14, 9))
plt.subplot(5, 1, 2)
plt.plot(t, result['est_theta'], label=r'Estimated $\theta$')
plt.plot(t, np.array(samples['Yangle']).squeeze(), '--', label=r'True $\theta$')
plt.title('Theta estimation')
plt.xlabel('Time [s]')
plt.ylabel(r'$\theta$ [rad]')
plt.grid()
plt.legend()
plt.subplot(5, 1, 1)
plt.plot(t, result['est_thetadot'], label=r'Estimated $\dot{\theta}$')
plt.plot(t, np.array(samples['Yangular_velocity']).squeeze(), '--', label=r'True $\dot{\theta}$')
plt.title('Angular velocity estimation')
plt.xlabel('Time [s]')
plt.ylabel(r'$\dot{\theta}$ [rad/s]')
plt.grid()
plt.legend()
plt.subplot(5, 1, 4)
plt.plot(t, result['est_x'], label='Estimated X')
plt.plot(t, np.array(samples['Ypos']).squeeze(), '--', label='True x')
plt.title('Position estimation')
plt.xlabel('Time [s]')
plt.ylabel('x [m]')
plt.grid()
plt.legend()
plt.subplot(5, 1, 3)
plt.plot(t, result['est_xdot'], label=r'Estimated $\dot{x}$')
plt.plot(t, np.array(samples['Yvelocity']).squeeze(), '--', label=r'True $\dot{x}$')
plt.title('Velocity estimation')
plt.xlabel('Time [s]')
plt.ylabel(r'$\dot{x}$ [m/s]')
plt.grid()
plt.legend()
plt.subplot(5, 1, 5)
plt.plot(t, np.array(samples['action']).squeeze(), label='F')
plt.title('Applied force')
plt.xlabel('Time [s]')
plt.ylabel('Force [N]')
plt.grid()
plt.legend()
plt.tight_layout()

img_name = model_name + '_closed_loop.png'
save_path = os.path.join(os.getcwd(), "results", "imgs", img_name)
#plt.savefig(save_path, dpi=300)
plt.show()
# Out:
# =============================== Load JSON Model ================================
# Model loaded from:            /home/baro/Desktop/inv_pend/saved_models/semi_physical_model.json
# ================================================================================
# [neuralizeModel] Closed loop on Xangle with sample in the future.
# [neuralizeModel] Closed loop on Xangular_velocity with sample in the future.
# [neuralizeModel] Closed loop on Xpos with sample in the future.
# [neuralizeModel] Closed loop on Xvelocity with sample in the future.
# ================================ nnodely Model =================================
# {'Constants': {'Constant32': {'dim': 1, 'values': [2.0]},
#                'Constant33': {'dim': 1, 'values': [2.0]},
#                'Constant34': {'dim': 1, 'values': [2.0]},
#                'Constant36': {'dim': 1, 'values': [2.0]},
#                'Constant37': {'dim': 1, 'values': [2.0]},
#                'Constant38': {'dim': 1, 'values': [2.0]},
#                'Constant39': {'dim': 1, 'values': [2.0]},
#                'Constant40': {'dim': 1, 'values': [2.0]},
#                'Constant41': {'dim': 1, 'values': [2.0]},
#                'Constant43': {'dim': 1, 'values': [2.0]},
#                'Constant44': {'dim': 1, 'values': [2.0]},
#                'Constant45': {'dim': 1, 'values': [2.0]},
#                'Constant46': {'dim': 1, 'values': [2.0]},
#                'Constant47': {'dim': 1, 'values': [2.0]},
#                'Constant48': {'dim': 1, 'values': [2.0]},
#                'Constant49': {'dim': 1, 'values': [2.0]},
#                'Constant50': {'dim': 1, 'values': [2.0]},
#                'Constant51': {'dim': 1, 'values': [2.0]},
#                'Constant52': {'dim': 1, 'values': [2.0]},
#                'Constant53': {'dim': 1, 'values': [2.0]},
#                'Constant54': {'dim': 1, 'values': [6.0]},
#                'Constant55': {'dim': 1, 'values': [2.0]},
#                'Constant56': {'dim': 1, 'values': [2.0]},
#                'Constant57': {'dim': 1, 'values': [6.0]},
#                'Constant58': {'dim': 1, 'values': [2.0]},
#                'Constant59': {'dim': 1, 'values': [2.0]},
#                'Constant60': {'dim': 1, 'values': [6.0]},
#                'Constant61': {'dim': 1, 'values': [2.0]},
#                'Constant62': {'dim': 1, 'values': [2.0]},
#                'Constant63': {'dim': 1, 'values': [6.0]},
#                'dt': {'dim': 1, 'values': [0.019999999552965164]},
#                'g': {'dim': 1, 'values': [9.8100004196167]},
#                'sigma_omega': {'dim': 1, 'values': [0.0]},
#                'sigma_theta': {'dim': 1, 'values': [0.0]},
#                'sigma_v': {'dim': 1, 'values': [0.0]},
#                'sigma_x': {'dim': 1, 'values': [0.0]}},
#  'Functions': {},
#  'Info': {'SampleTime': 0.02,
#           'nnodely_version': '1.5.2',
#           'ns': [1, 0],
#           'ntot': 1,
#           'num_parameters': 12},
#  'Inputs': {'Xangle': {'closedLoop': 'Add351',
#                        'dim': 1,
#                        'local': 1,
#                        'ns': [1, 0],
#                        'ntot': 1,
#                        'sw': [-1, 0]},
#             'Xangular_velocity': {'closedLoop': 'Add339',
#                                   'dim': 1,
#                                   'local': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Xpos': {'closedLoop': 'Add327',
#                      'dim': 1,
#                      'local': 1,
#                      'ns': [1, 0],
#                      'ntot': 1,
#                      'sw': [-1, 0]},
#             'Xvelocity': {'closedLoop': 'Add315',
#                           'dim': 1,
#                           'local': 1,
#                           'ns': [1, 0],
#                           'ntot': 1,
#                           'sw': [-1, 0]},
#             'Yangle': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yangular_velocity': {'dim': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Ypos': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yvelocity': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'action': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise1': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise2': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise3': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise4': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]}},
#  'Minimizers': {'ang_vel_error': {'A': 'SamplePart353',
#                                   'B': 'Add339',
#                                   'loss': 'mse'},
#                 'angle_error': {'A': 'SamplePart355',
#                                 'B': 'Add351',
#                                 'loss': 'mse'},
#                 'pos_error': {'A': 'SamplePart359',
#                               'B': 'Add327',
#                               'loss': 'mse'},
#                 'vel_error': {'A': 'SamplePart357',
#                               'B': 'Add315',
#                               'loss': 'mse'}},
#  'Models': 'pendulum',
#  'Outputs': {'est_theta': 'Add351',
#              'est_thetadot': 'Add339',
#              'est_x': 'Add327',
#              'est_xdot': 'Add315'},
#  'Parameters': {'a1': {'dim': 1, 'values': [0.01585010439157486]},
#                 'a10': {'dim': 1, 'values': [0.38438400626182556]},
#                 'a11': {'dim': 1, 'values': [0.022575952112674713]},
#                 'a12': {'dim': 1, 'values': [2.4811575412750244]},
#                 'a13': {'dim': 1, 'values': [0.16351740062236786]},
#                 'a14': {'dim': 1, 'values': [0.1933160424232483]},
#                 'a2': {'dim': 1, 'values': [0.010592124424874783]},
#                 'a4': {'dim': 1, 'values': [0.037365734577178955]},
#                 'a5': {'dim': 1, 'values': [0.024878066033124924]},
#                 'a6': {'dim': 1, 'values': [1.0562189817428589]},
#                 'a7': {'dim': 1, 'values': [0.03726451098918915]},
#                 'a8': {'dim': 1, 'values': [0.25560933351516724]}},
#  'Relations': {'Add103': ['Add', ['Add20', 'Div102']],
#                'Add13': ['Add', ['SamplePart8', 'Mul12']],
#                'Add133': ['Add', ['Sub129', 'Mul132']],
#                'Add136': ['Add', ['Add133', 'Mul135']],
#                'Add150': ['Add', ['Sub145', 'Mul149']],
#                'Add154': ['Add', ['Add150', 'Mul153']],
#                'Add169': ['Add', ['Add13', 'Div168']],
#                'Add174': ['Add', ['Add27', 'Div173']],
#                'Add179': ['Add', ['Add20', 'Div178']],
#                'Add20': ['Add', ['SamplePart15', 'Mul19']],
#                'Add209': ['Add', ['Sub205', 'Mul208']],
#                'Add212': ['Add', ['Add209', 'Mul211']],
#                'Add226': ['Add', ['Sub221', 'Mul225']],
#                'Add230': ['Add', ['Add226', 'Mul229']],
#                'Add241': ['Add', ['Add13', 'Mul240']],
#                'Add244': ['Add', ['Add27', 'Mul243']],
#                'Add247': ['Add', ['Add20', 'Mul246']],
#                'Add27': ['Add', ['SamplePart22', 'Mul26']],
#                'Add277': ['Add', ['Sub273', 'Mul276']],
#                'Add280': ['Add', ['Add277', 'Mul279']],
#                'Add294': ['Add', ['Sub289', 'Mul293']],
#                'Add298': ['Add', ['Add294', 'Mul297']],
#                'Add306': ['Add', ['Div61', 'Mul305']],
#                'Add309': ['Add', ['Add306', 'Mul308']],
#                'Add310': ['Add', ['Add309', 'Div281']],
#                'Add315': ['Add', ['Add13', 'Div314']],
#                'Add318': ['Add', ['Add13', 'Mul317']],
#                'Add321': ['Add', ['Add318', 'Mul320']],
#                'Add322': ['Add', ['Add321', 'Add241']],
#                'Add327': ['Add', ['Add6', 'Div326']],
#                'Add330': ['Add', ['Div83', 'Mul329']],
#                'Add333': ['Add', ['Add330', 'Mul332']],
#                'Add334': ['Add', ['Add333', 'Div303']],
#                'Add339': ['Add', ['Add20', 'Div338']],
#                'Add342': ['Add', ['Add20', 'Mul341']],
#                'Add345': ['Add', ['Add342', 'Mul344']],
#                'Add346': ['Add', ['Add345', 'Add247']],
#                'Add351': ['Add', ['Add27', 'Div350']],
#                'Add57': ['Add', ['Sub53', 'Mul56']],
#                'Add6': ['Add', ['SamplePart1', 'Mul5']],
#                'Add60': ['Add', ['Add57', 'Mul59']],
#                'Add74': ['Add', ['Sub69', 'Mul73']],
#                'Add78': ['Add', ['Add74', 'Mul77']],
#                'Add93': ['Add', ['Add13', 'Div92']],
#                'Add98': ['Add', ['Add27', 'Div97']],
#                'Cos107': ['Cos', ['Add98']],
#                'Cos183': ['Cos', ['Add174']],
#                'Cos251': ['Cos', ['Add244']],
#                'Cos31': ['Cos', ['Add27']],
#                'Div102': ['Div', ['Mul100', 'Constant38']],
#                'Div137': ['Div', ['Add136', 'Sub113']],
#                'Div159': ['Div', ['Sub158', 'Sub113']],
#                'Div168': ['Div', ['Mul166', 'Constant43']],
#                'Div173': ['Div', ['Mul171', 'Constant44']],
#                'Div178': ['Div', ['Mul176', 'Constant45']],
#                'Div213': ['Div', ['Add212', 'Sub189']],
#                'Div235': ['Div', ['Sub234', 'Sub189']],
#                'Div281': ['Div', ['Add280', 'Sub257']],
#                'Div303': ['Div', ['Sub302', 'Sub257']],
#                'Div314': ['Div', ['Mul312', 'Constant54']],
#                'Div326': ['Div', ['Mul324', 'Constant57']],
#                'Div338': ['Div', ['Mul336', 'Constant60']],
#                'Div350': ['Div', ['Mul348', 'Constant63']],
#                'Div61': ['Div', ['Add60', 'Sub37']],
#                'Div83': ['Div', ['Sub82', 'Sub37']],
#                'Div92': ['Div', ['Mul90', 'Constant36']],
#                'Div97': ['Div', ['Mul95', 'Constant37']],
#                'Mul100': ['Mul', ['Div83', 'dt']],
#                'Mul109': ['Mul', ['a14', 'Cos107']],
#                'Mul115': ['Mul', ['a2', 'Add93']],
#                'Mul117': ['Mul', ['a8', 'Add103']],
#                'Mul12': ['Mul', ['SamplePart10', 'sigma_v']],
#                'Mul121': ['Mul', ['a1', 'Pow119']],
#                'Mul122': ['Mul', ['Mul121', 'Sin106']],
#                'Mul126': ['Mul', ['a4', 'g']],
#                'Mul127': ['Mul', ['Mul126', 'Cos107']],
#                'Mul128': ['Mul', ['Mul127', 'Sin106']],
#                'Mul131': ['Mul', ['a5', 'Add103']],
#                'Mul132': ['Mul', ['Mul131', 'Cos107']],
#                'Mul135': ['Mul', ['a6', 'SamplePart105']],
#                'Mul142': ['Mul', ['Neg139', 'Pow141']],
#                'Mul143': ['Mul', ['Mul142', 'Cos107']],
#                'Mul144': ['Mul', ['Mul143', 'Sin106']],
#                'Mul148': ['Mul', ['a10', 'g']],
#                'Mul149': ['Mul', ['Mul148', 'Sin106']],
#                'Mul152': ['Mul', ['a11', 'Add93']],
#                'Mul153': ['Mul', ['Mul152', 'Cos107']],
#                'Mul156': ['Mul', ['a12', 'Cos107']],
#                'Mul157': ['Mul', ['Mul156', 'SamplePart105']],
#                'Mul166': ['Mul', ['Div137', 'dt']],
#                'Mul171': ['Mul', ['Add103', 'dt']],
#                'Mul176': ['Mul', ['Div159', 'dt']],
#                'Mul185': ['Mul', ['a14', 'Cos183']],
#                'Mul19': ['Mul', ['SamplePart17', 'sigma_omega']],
#                'Mul191': ['Mul', ['a2', 'Add169']],
#                'Mul193': ['Mul', ['a8', 'Add179']],
#                'Mul197': ['Mul', ['a1', 'Pow195']],
#                'Mul198': ['Mul', ['Mul197', 'Sin182']],
#                'Mul202': ['Mul', ['a4', 'g']],
#                'Mul203': ['Mul', ['Mul202', 'Cos183']],
#                'Mul204': ['Mul', ['Mul203', 'Sin182']],
#                'Mul207': ['Mul', ['a5', 'Add179']],
#                'Mul208': ['Mul', ['Mul207', 'Cos183']],
#                'Mul211': ['Mul', ['a6', 'SamplePart181']],
#                'Mul218': ['Mul', ['Neg215', 'Pow217']],
#                'Mul219': ['Mul', ['Mul218', 'Cos183']],
#                'Mul220': ['Mul', ['Mul219', 'Sin182']],
#                'Mul224': ['Mul', ['a10', 'g']],
#                'Mul225': ['Mul', ['Mul224', 'Sin182']],
#                'Mul228': ['Mul', ['a11', 'Add169']],
#                'Mul229': ['Mul', ['Mul228', 'Cos183']],
#                'Mul232': ['Mul', ['a12', 'Cos183']],
#                'Mul233': ['Mul', ['Mul232', 'SamplePart181']],
#                'Mul240': ['Mul', ['Div213', 'dt']],
#                'Mul243': ['Mul', ['Add179', 'dt']],
#                'Mul246': ['Mul', ['Div235', 'dt']],
#                'Mul253': ['Mul', ['a14', 'Cos251']],
#                'Mul259': ['Mul', ['a2', 'Add241']],
#                'Mul26': ['Mul', ['SamplePart24', 'sigma_theta']],
#                'Mul261': ['Mul', ['a8', 'Add247']],
#                'Mul265': ['Mul', ['a1', 'Pow263']],
#                'Mul266': ['Mul', ['Mul265', 'Sin250']],
#                'Mul270': ['Mul', ['a4', 'g']],
#                'Mul271': ['Mul', ['Mul270', 'Cos251']],
#                'Mul272': ['Mul', ['Mul271', 'Sin250']],
#                'Mul275': ['Mul', ['a5', 'Add247']],
#                'Mul276': ['Mul', ['Mul275', 'Cos251']],
#                'Mul279': ['Mul', ['a6', 'SamplePart249']],
#                'Mul286': ['Mul', ['Neg283', 'Pow285']],
#                'Mul287': ['Mul', ['Mul286', 'Cos251']],
#                'Mul288': ['Mul', ['Mul287', 'Sin250']],
#                'Mul292': ['Mul', ['a10', 'g']],
#                'Mul293': ['Mul', ['Mul292', 'Sin250']],
#                'Mul296': ['Mul', ['a11', 'Add241']],
#                'Mul297': ['Mul', ['Mul296', 'Cos251']],
#                'Mul300': ['Mul', ['a12', 'Cos251']],
#                'Mul301': ['Mul', ['Mul300', 'SamplePart249']],
#                'Mul305': ['Mul', ['Constant52', 'Div137']],
#                'Mul308': ['Mul', ['Constant53', 'Div213']],
#                'Mul312': ['Mul', ['Add310', 'dt']],
#                'Mul317': ['Mul', ['Constant55', 'Add93']],
#                'Mul320': ['Mul', ['Constant56', 'Add169']],
#                'Mul324': ['Mul', ['Add322', 'dt']],
#                'Mul329': ['Mul', ['Constant58', 'Div159']],
#                'Mul33': ['Mul', ['a14', 'Cos31']],
#                'Mul332': ['Mul', ['Constant59', 'Div235']],
#                'Mul336': ['Mul', ['Add334', 'dt']],
#                'Mul341': ['Mul', ['Constant61', 'Add103']],
#                'Mul344': ['Mul', ['Constant62', 'Add179']],
#                'Mul348': ['Mul', ['Add346', 'dt']],
#                'Mul39': ['Mul', ['a2', 'Add13']],
#                'Mul41': ['Mul', ['a8', 'Add20']],
#                'Mul45': ['Mul', ['a1', 'Pow43']],
#                'Mul46': ['Mul', ['Mul45', 'Sin30']],
#                'Mul5': ['Mul', ['SamplePart3', 'sigma_x']],
#                'Mul50': ['Mul', ['a4', 'g']],
#                'Mul51': ['Mul', ['Mul50', 'Cos31']],
#                'Mul52': ['Mul', ['Mul51', 'Sin30']],
#                'Mul55': ['Mul', ['a5', 'Add20']],
#                'Mul56': ['Mul', ['Mul55', 'Cos31']],
#                'Mul59': ['Mul', ['a6', 'SamplePart29']],
#                'Mul66': ['Mul', ['Neg63', 'Pow65']],
#                'Mul67': ['Mul', ['Mul66', 'Cos31']],
#                'Mul68': ['Mul', ['Mul67', 'Sin30']],
#                'Mul72': ['Mul', ['a10', 'g']],
#                'Mul73': ['Mul', ['Mul72', 'Sin30']],
#                'Mul76': ['Mul', ['a11', 'Add13']],
#                'Mul77': ['Mul', ['Mul76', 'Cos31']],
#                'Mul80': ['Mul', ['a12', 'Cos31']],
#                'Mul81': ['Mul', ['Mul80', 'SamplePart29']],
#                'Mul90': ['Mul', ['Div61', 'dt']],
#                'Mul95': ['Mul', ['Add20', 'dt']],
#                'Neg139': ['Neg', ['a7']],
#                'Neg215': ['Neg', ['a7']],
#                'Neg283': ['Neg', ['a7']],
#                'Neg63': ['Neg', ['a7']],
#                'Pow111': ['Pow', ['Mul109', 'Constant39']],
#                'Pow119': ['Pow', ['Add103', 'Constant40']],
#                'Pow141': ['Pow', ['Add103', 'Constant41']],
#                'Pow187': ['Pow', ['Mul185', 'Constant46']],
#                'Pow195': ['Pow', ['Add179', 'Constant47']],
#                'Pow217': ['Pow', ['Add179', 'Constant48']],
#                'Pow255': ['Pow', ['Mul253', 'Constant49']],
#                'Pow263': ['Pow', ['Add247', 'Constant50']],
#                'Pow285': ['Pow', ['Add247', 'Constant51']],
#                'Pow35': ['Pow', ['Mul33', 'Constant32']],
#                'Pow43': ['Pow', ['Add20', 'Constant33']],
#                'Pow65': ['Pow', ['Add20', 'Constant34']],
#                'SamplePart1': ['SamplePart', ['Xpos'], -1, [-1, 0]],
#                'SamplePart10': ['SamplePart', ['noise1'], -1, [-1, 0]],
#                'SamplePart105': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart15': ['SamplePart',
#                                 ['Xangular_velocity'],
#                                 -1,
#                                 [-1, 0]],
#                'SamplePart17': ['SamplePart', ['noise3'], -1, [-1, 0]],
#                'SamplePart181': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart22': ['SamplePart', ['Xangle'], -1, [-1, 0]],
#                'SamplePart24': ['SamplePart', ['noise2'], -1, [-1, 0]],
#                'SamplePart249': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart29': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart3': ['SamplePart', ['noise4'], -1, [-1, 0]],
#                'SamplePart353': ['SamplePart',
#                                  ['Yangular_velocity'],
#                                  -1,
#                                  [-1, 0]],
#                'SamplePart355': ['SamplePart', ['Yangle'], -1, [-1, 0]],
#                'SamplePart357': ['SamplePart', ['Yvelocity'], -1, [-1, 0]],
#                'SamplePart359': ['SamplePart', ['Ypos'], -1, [-1, 0]],
#                'SamplePart8': ['SamplePart', ['Xvelocity'], -1, [-1, 0]],
#                'Sin106': ['Sin', ['Add98']],
#                'Sin182': ['Sin', ['Add174']],
#                'Sin250': ['Sin', ['Add244']],
#                'Sin30': ['Sin', ['Add27']],
#                'Sub113': ['Sub', ['a13', 'Pow111']],
#                'Sub123': ['Sub', ['Mul122', 'Mul115']],
#                'Sub129': ['Sub', ['Sub123', 'Mul128']],
#                'Sub145': ['Sub', ['Mul144', 'Mul117']],
#                'Sub158': ['Sub', ['Add154', 'Mul157']],
#                'Sub189': ['Sub', ['a13', 'Pow187']],
#                'Sub199': ['Sub', ['Mul198', 'Mul191']],
#                'Sub205': ['Sub', ['Sub199', 'Mul204']],
#                'Sub221': ['Sub', ['Mul220', 'Mul193']],
#                'Sub234': ['Sub', ['Add230', 'Mul233']],
#                'Sub257': ['Sub', ['a13', 'Pow255']],
#                'Sub267': ['Sub', ['Mul266', 'Mul259']],
#                'Sub273': ['Sub', ['Sub267', 'Mul272']],
#                'Sub289': ['Sub', ['Mul288', 'Mul261']],
#                'Sub302': ['Sub', ['Add298', 'Mul301']],
#                'Sub37': ['Sub', ['a13', 'Pow35']],
#                'Sub47': ['Sub', ['Mul46', 'Mul39']],
#                'Sub53': ['Sub', ['Sub47', 'Mul52']],
#                'Sub69': ['Sub', ['Mul68', 'Mul41']],
#                'Sub82': ['Sub', ['Add78', 'Mul81']]}}
# ================================================================================
# ========================== Import Python Torch Model ===========================
# Model imported from:          /home/baro/Desktop/inv_pend/saved_models/semi_physical_model.py
# ================================================================================
# [neuralizeModel] Closed loop on Xangle with sample in the future.
# [neuralizeModel] Closed loop on Xangular_velocity with sample in the future.
# [neuralizeModel] Closed loop on Xpos with sample in the future.
# [neuralizeModel] Closed loop on Xvelocity with sample in the future.
# ================================ nnodely Model =================================
# {'Constants': {'Constant32': {'dim': 1, 'values': [2.0]},
#                'Constant33': {'dim': 1, 'values': [2.0]},
#                'Constant34': {'dim': 1, 'values': [2.0]},
#                'Constant36': {'dim': 1, 'values': [2.0]},
#                'Constant37': {'dim': 1, 'values': [2.0]},
#                'Constant38': {'dim': 1, 'values': [2.0]},
#                'Constant39': {'dim': 1, 'values': [2.0]},
#                'Constant40': {'dim': 1, 'values': [2.0]},
#                'Constant41': {'dim': 1, 'values': [2.0]},
#                'Constant43': {'dim': 1, 'values': [2.0]},
#                'Constant44': {'dim': 1, 'values': [2.0]},
#                'Constant45': {'dim': 1, 'values': [2.0]},
#                'Constant46': {'dim': 1, 'values': [2.0]},
#                'Constant47': {'dim': 1, 'values': [2.0]},
#                'Constant48': {'dim': 1, 'values': [2.0]},
#                'Constant49': {'dim': 1, 'values': [2.0]},
#                'Constant50': {'dim': 1, 'values': [2.0]},
#                'Constant51': {'dim': 1, 'values': [2.0]},
#                'Constant52': {'dim': 1, 'values': [2.0]},
#                'Constant53': {'dim': 1, 'values': [2.0]},
#                'Constant54': {'dim': 1, 'values': [6.0]},
#                'Constant55': {'dim': 1, 'values': [2.0]},
#                'Constant56': {'dim': 1, 'values': [2.0]},
#                'Constant57': {'dim': 1, 'values': [6.0]},
#                'Constant58': {'dim': 1, 'values': [2.0]},
#                'Constant59': {'dim': 1, 'values': [2.0]},
#                'Constant60': {'dim': 1, 'values': [6.0]},
#                'Constant61': {'dim': 1, 'values': [2.0]},
#                'Constant62': {'dim': 1, 'values': [2.0]},
#                'Constant63': {'dim': 1, 'values': [6.0]},
#                'dt': {'dim': 1, 'values': [0.019999999552965164]},
#                'g': {'dim': 1, 'values': [9.8100004196167]},
#                'sigma_omega': {'dim': 1, 'values': [0.0]},
#                'sigma_theta': {'dim': 1, 'values': [0.0]},
#                'sigma_v': {'dim': 1, 'values': [0.0]},
#                'sigma_x': {'dim': 1, 'values': [0.0]}},
#  'Functions': {},
#  'Info': {'SampleTime': 0.02,
#           'nnodely_version': '1.5.2',
#           'ns': [1, 0],
#           'ntot': 1,
#           'num_parameters': 12},
#  'Inputs': {'Xangle': {'closedLoop': 'Add351',
#                        'dim': 1,
#                        'local': 1,
#                        'ns': [1, 0],
#                        'ntot': 1,
#                        'sw': [-1, 0]},
#             'Xangular_velocity': {'closedLoop': 'Add339',
#                                   'dim': 1,
#                                   'local': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Xpos': {'closedLoop': 'Add327',
#                      'dim': 1,
#                      'local': 1,
#                      'ns': [1, 0],
#                      'ntot': 1,
#                      'sw': [-1, 0]},
#             'Xvelocity': {'closedLoop': 'Add315',
#                           'dim': 1,
#                           'local': 1,
#                           'ns': [1, 0],
#                           'ntot': 1,
#                           'sw': [-1, 0]},
#             'Yangle': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yangular_velocity': {'dim': 1,
#                                   'ns': [1, 0],
#                                   'ntot': 1,
#                                   'sw': [-1, 0]},
#             'Ypos': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'Yvelocity': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'action': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise1': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise2': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise3': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]},
#             'noise4': {'dim': 1, 'ns': [1, 0], 'ntot': 1, 'sw': [-1, 0]}},
#  'Minimizers': {'ang_vel_error': {'A': 'SamplePart353',
#                                   'B': 'Add339',
#                                   'loss': 'mse'},
#                 'angle_error': {'A': 'SamplePart355',
#                                 'B': 'Add351',
#                                 'loss': 'mse'},
#                 'pos_error': {'A': 'SamplePart359',
#                               'B': 'Add327',
#                               'loss': 'mse'},
#                 'vel_error': {'A': 'SamplePart357',
#                               'B': 'Add315',
#                               'loss': 'mse'}},
#  'Models': 'pendulum',
#  'Outputs': {'est_theta': 'Add351',
#              'est_thetadot': 'Add339',
#              'est_x': 'Add327',
#              'est_xdot': 'Add315'},
#  'Parameters': {'a1': {'dim': 1, 'values': [0.01585010439157486]},
#                 'a10': {'dim': 1, 'values': [0.38438400626182556]},
#                 'a11': {'dim': 1, 'values': [0.022575952112674713]},
#                 'a12': {'dim': 1, 'values': [2.4811575412750244]},
#                 'a13': {'dim': 1, 'values': [0.16351740062236786]},
#                 'a14': {'dim': 1, 'values': [0.1933160424232483]},
#                 'a2': {'dim': 1, 'values': [0.010592124424874783]},
#                 'a4': {'dim': 1, 'values': [0.037365734577178955]},
#                 'a5': {'dim': 1, 'values': [0.024878066033124924]},
#                 'a6': {'dim': 1, 'values': [1.0562189817428589]},
#                 'a7': {'dim': 1, 'values': [0.03726451098918915]},
#                 'a8': {'dim': 1, 'values': [0.25560933351516724]}},
#  'Relations': {'Add103': ['Add', ['Add20', 'Div102']],
#                'Add13': ['Add', ['SamplePart8', 'Mul12']],
#                'Add133': ['Add', ['Sub129', 'Mul132']],
#                'Add136': ['Add', ['Add133', 'Mul135']],
#                'Add150': ['Add', ['Sub145', 'Mul149']],
#                'Add154': ['Add', ['Add150', 'Mul153']],
#                'Add169': ['Add', ['Add13', 'Div168']],
#                'Add174': ['Add', ['Add27', 'Div173']],
#                'Add179': ['Add', ['Add20', 'Div178']],
#                'Add20': ['Add', ['SamplePart15', 'Mul19']],
#                'Add209': ['Add', ['Sub205', 'Mul208']],
#                'Add212': ['Add', ['Add209', 'Mul211']],
#                'Add226': ['Add', ['Sub221', 'Mul225']],
#                'Add230': ['Add', ['Add226', 'Mul229']],
#                'Add241': ['Add', ['Add13', 'Mul240']],
#                'Add244': ['Add', ['Add27', 'Mul243']],
#                'Add247': ['Add', ['Add20', 'Mul246']],
#                'Add27': ['Add', ['SamplePart22', 'Mul26']],
#                'Add277': ['Add', ['Sub273', 'Mul276']],
#                'Add280': ['Add', ['Add277', 'Mul279']],
#                'Add294': ['Add', ['Sub289', 'Mul293']],
#                'Add298': ['Add', ['Add294', 'Mul297']],
#                'Add306': ['Add', ['Div61', 'Mul305']],
#                'Add309': ['Add', ['Add306', 'Mul308']],
#                'Add310': ['Add', ['Add309', 'Div281']],
#                'Add315': ['Add', ['Add13', 'Div314']],
#                'Add318': ['Add', ['Add13', 'Mul317']],
#                'Add321': ['Add', ['Add318', 'Mul320']],
#                'Add322': ['Add', ['Add321', 'Add241']],
#                'Add327': ['Add', ['Add6', 'Div326']],
#                'Add330': ['Add', ['Div83', 'Mul329']],
#                'Add333': ['Add', ['Add330', 'Mul332']],
#                'Add334': ['Add', ['Add333', 'Div303']],
#                'Add339': ['Add', ['Add20', 'Div338']],
#                'Add342': ['Add', ['Add20', 'Mul341']],
#                'Add345': ['Add', ['Add342', 'Mul344']],
#                'Add346': ['Add', ['Add345', 'Add247']],
#                'Add351': ['Add', ['Add27', 'Div350']],
#                'Add57': ['Add', ['Sub53', 'Mul56']],
#                'Add6': ['Add', ['SamplePart1', 'Mul5']],
#                'Add60': ['Add', ['Add57', 'Mul59']],
#                'Add74': ['Add', ['Sub69', 'Mul73']],
#                'Add78': ['Add', ['Add74', 'Mul77']],
#                'Add93': ['Add', ['Add13', 'Div92']],
#                'Add98': ['Add', ['Add27', 'Div97']],
#                'Cos107': ['Cos', ['Add98']],
#                'Cos183': ['Cos', ['Add174']],
#                'Cos251': ['Cos', ['Add244']],
#                'Cos31': ['Cos', ['Add27']],
#                'Div102': ['Div', ['Mul100', 'Constant38']],
#                'Div137': ['Div', ['Add136', 'Sub113']],
#                'Div159': ['Div', ['Sub158', 'Sub113']],
#                'Div168': ['Div', ['Mul166', 'Constant43']],
#                'Div173': ['Div', ['Mul171', 'Constant44']],
#                'Div178': ['Div', ['Mul176', 'Constant45']],
#                'Div213': ['Div', ['Add212', 'Sub189']],
#                'Div235': ['Div', ['Sub234', 'Sub189']],
#                'Div281': ['Div', ['Add280', 'Sub257']],
#                'Div303': ['Div', ['Sub302', 'Sub257']],
#                'Div314': ['Div', ['Mul312', 'Constant54']],
#                'Div326': ['Div', ['Mul324', 'Constant57']],
#                'Div338': ['Div', ['Mul336', 'Constant60']],
#                'Div350': ['Div', ['Mul348', 'Constant63']],
#                'Div61': ['Div', ['Add60', 'Sub37']],
#                'Div83': ['Div', ['Sub82', 'Sub37']],
#                'Div92': ['Div', ['Mul90', 'Constant36']],
#                'Div97': ['Div', ['Mul95', 'Constant37']],
#                'Mul100': ['Mul', ['Div83', 'dt']],
#                'Mul109': ['Mul', ['a14', 'Cos107']],
#                'Mul115': ['Mul', ['a2', 'Add93']],
#                'Mul117': ['Mul', ['a8', 'Add103']],
#                'Mul12': ['Mul', ['SamplePart10', 'sigma_v']],
#                'Mul121': ['Mul', ['a1', 'Pow119']],
#                'Mul122': ['Mul', ['Mul121', 'Sin106']],
#                'Mul126': ['Mul', ['a4', 'g']],
#                'Mul127': ['Mul', ['Mul126', 'Cos107']],
#                'Mul128': ['Mul', ['Mul127', 'Sin106']],
#                'Mul131': ['Mul', ['a5', 'Add103']],
#                'Mul132': ['Mul', ['Mul131', 'Cos107']],
#                'Mul135': ['Mul', ['a6', 'SamplePart105']],
#                'Mul142': ['Mul', ['Neg139', 'Pow141']],
#                'Mul143': ['Mul', ['Mul142', 'Cos107']],
#                'Mul144': ['Mul', ['Mul143', 'Sin106']],
#                'Mul148': ['Mul', ['a10', 'g']],
#                'Mul149': ['Mul', ['Mul148', 'Sin106']],
#                'Mul152': ['Mul', ['a11', 'Add93']],
#                'Mul153': ['Mul', ['Mul152', 'Cos107']],
#                'Mul156': ['Mul', ['a12', 'Cos107']],
#                'Mul157': ['Mul', ['Mul156', 'SamplePart105']],
#                'Mul166': ['Mul', ['Div137', 'dt']],
#                'Mul171': ['Mul', ['Add103', 'dt']],
#                'Mul176': ['Mul', ['Div159', 'dt']],
#                'Mul185': ['Mul', ['a14', 'Cos183']],
#                'Mul19': ['Mul', ['SamplePart17', 'sigma_omega']],
#                'Mul191': ['Mul', ['a2', 'Add169']],
#                'Mul193': ['Mul', ['a8', 'Add179']],
#                'Mul197': ['Mul', ['a1', 'Pow195']],
#                'Mul198': ['Mul', ['Mul197', 'Sin182']],
#                'Mul202': ['Mul', ['a4', 'g']],
#                'Mul203': ['Mul', ['Mul202', 'Cos183']],
#                'Mul204': ['Mul', ['Mul203', 'Sin182']],
#                'Mul207': ['Mul', ['a5', 'Add179']],
#                'Mul208': ['Mul', ['Mul207', 'Cos183']],
#                'Mul211': ['Mul', ['a6', 'SamplePart181']],
#                'Mul218': ['Mul', ['Neg215', 'Pow217']],
#                'Mul219': ['Mul', ['Mul218', 'Cos183']],
#                'Mul220': ['Mul', ['Mul219', 'Sin182']],
#                'Mul224': ['Mul', ['a10', 'g']],
#                'Mul225': ['Mul', ['Mul224', 'Sin182']],
#                'Mul228': ['Mul', ['a11', 'Add169']],
#                'Mul229': ['Mul', ['Mul228', 'Cos183']],
#                'Mul232': ['Mul', ['a12', 'Cos183']],
#                'Mul233': ['Mul', ['Mul232', 'SamplePart181']],
#                'Mul240': ['Mul', ['Div213', 'dt']],
#                'Mul243': ['Mul', ['Add179', 'dt']],
#                'Mul246': ['Mul', ['Div235', 'dt']],
#                'Mul253': ['Mul', ['a14', 'Cos251']],
#                'Mul259': ['Mul', ['a2', 'Add241']],
#                'Mul26': ['Mul', ['SamplePart24', 'sigma_theta']],
#                'Mul261': ['Mul', ['a8', 'Add247']],
#                'Mul265': ['Mul', ['a1', 'Pow263']],
#                'Mul266': ['Mul', ['Mul265', 'Sin250']],
#                'Mul270': ['Mul', ['a4', 'g']],
#                'Mul271': ['Mul', ['Mul270', 'Cos251']],
#                'Mul272': ['Mul', ['Mul271', 'Sin250']],
#                'Mul275': ['Mul', ['a5', 'Add247']],
#                'Mul276': ['Mul', ['Mul275', 'Cos251']],
#                'Mul279': ['Mul', ['a6', 'SamplePart249']],
#                'Mul286': ['Mul', ['Neg283', 'Pow285']],
#                'Mul287': ['Mul', ['Mul286', 'Cos251']],
#                'Mul288': ['Mul', ['Mul287', 'Sin250']],
#                'Mul292': ['Mul', ['a10', 'g']],
#                'Mul293': ['Mul', ['Mul292', 'Sin250']],
#                'Mul296': ['Mul', ['a11', 'Add241']],
#                'Mul297': ['Mul', ['Mul296', 'Cos251']],
#                'Mul300': ['Mul', ['a12', 'Cos251']],
#                'Mul301': ['Mul', ['Mul300', 'SamplePart249']],
#                'Mul305': ['Mul', ['Constant52', 'Div137']],
#                'Mul308': ['Mul', ['Constant53', 'Div213']],
#                'Mul312': ['Mul', ['Add310', 'dt']],
#                'Mul317': ['Mul', ['Constant55', 'Add93']],
#                'Mul320': ['Mul', ['Constant56', 'Add169']],
#                'Mul324': ['Mul', ['Add322', 'dt']],
#                'Mul329': ['Mul', ['Constant58', 'Div159']],
#                'Mul33': ['Mul', ['a14', 'Cos31']],
#                'Mul332': ['Mul', ['Constant59', 'Div235']],
#                'Mul336': ['Mul', ['Add334', 'dt']],
#                'Mul341': ['Mul', ['Constant61', 'Add103']],
#                'Mul344': ['Mul', ['Constant62', 'Add179']],
#                'Mul348': ['Mul', ['Add346', 'dt']],
#                'Mul39': ['Mul', ['a2', 'Add13']],
#                'Mul41': ['Mul', ['a8', 'Add20']],
#                'Mul45': ['Mul', ['a1', 'Pow43']],
#                'Mul46': ['Mul', ['Mul45', 'Sin30']],
#                'Mul5': ['Mul', ['SamplePart3', 'sigma_x']],
#                'Mul50': ['Mul', ['a4', 'g']],
#                'Mul51': ['Mul', ['Mul50', 'Cos31']],
#                'Mul52': ['Mul', ['Mul51', 'Sin30']],
#                'Mul55': ['Mul', ['a5', 'Add20']],
#                'Mul56': ['Mul', ['Mul55', 'Cos31']],
#                'Mul59': ['Mul', ['a6', 'SamplePart29']],
#                'Mul66': ['Mul', ['Neg63', 'Pow65']],
#                'Mul67': ['Mul', ['Mul66', 'Cos31']],
#                'Mul68': ['Mul', ['Mul67', 'Sin30']],
#                'Mul72': ['Mul', ['a10', 'g']],
#                'Mul73': ['Mul', ['Mul72', 'Sin30']],
#                'Mul76': ['Mul', ['a11', 'Add13']],
#                'Mul77': ['Mul', ['Mul76', 'Cos31']],
#                'Mul80': ['Mul', ['a12', 'Cos31']],
#                'Mul81': ['Mul', ['Mul80', 'SamplePart29']],
#                'Mul90': ['Mul', ['Div61', 'dt']],
#                'Mul95': ['Mul', ['Add20', 'dt']],
#                'Neg139': ['Neg', ['a7']],
#                'Neg215': ['Neg', ['a7']],
#                'Neg283': ['Neg', ['a7']],
#                'Neg63': ['Neg', ['a7']],
#                'Pow111': ['Pow', ['Mul109', 'Constant39']],
#                'Pow119': ['Pow', ['Add103', 'Constant40']],
#                'Pow141': ['Pow', ['Add103', 'Constant41']],
#                'Pow187': ['Pow', ['Mul185', 'Constant46']],
#                'Pow195': ['Pow', ['Add179', 'Constant47']],
#                'Pow217': ['Pow', ['Add179', 'Constant48']],
#                'Pow255': ['Pow', ['Mul253', 'Constant49']],
#                'Pow263': ['Pow', ['Add247', 'Constant50']],
#                'Pow285': ['Pow', ['Add247', 'Constant51']],
#                'Pow35': ['Pow', ['Mul33', 'Constant32']],
#                'Pow43': ['Pow', ['Add20', 'Constant33']],
#                'Pow65': ['Pow', ['Add20', 'Constant34']],
#                'SamplePart1': ['SamplePart', ['Xpos'], -1, [-1, 0]],
#                'SamplePart10': ['SamplePart', ['noise1'], -1, [-1, 0]],
#                'SamplePart105': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart15': ['SamplePart',
#                                 ['Xangular_velocity'],
#                                 -1,
#                                 [-1, 0]],
#                'SamplePart17': ['SamplePart', ['noise3'], -1, [-1, 0]],
#                'SamplePart181': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart22': ['SamplePart', ['Xangle'], -1, [-1, 0]],
#                'SamplePart24': ['SamplePart', ['noise2'], -1, [-1, 0]],
#                'SamplePart249': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart29': ['SamplePart', ['action'], -1, [-1, 0]],
#                'SamplePart3': ['SamplePart', ['noise4'], -1, [-1, 0]],
#                'SamplePart353': ['SamplePart',
#                                  ['Yangular_velocity'],
#                                  -1,
#                                  [-1, 0]],
#                'SamplePart355': ['SamplePart', ['Yangle'], -1, [-1, 0]],
#                'SamplePart357': ['SamplePart', ['Yvelocity'], -1, [-1, 0]],
#                'SamplePart359': ['SamplePart', ['Ypos'], -1, [-1, 0]],
#                'SamplePart8': ['SamplePart', ['Xvelocity'], -1, [-1, 0]],
#                'Sin106': ['Sin', ['Add98']],
#                'Sin182': ['Sin', ['Add174']],
#                'Sin250': ['Sin', ['Add244']],
#                'Sin30': ['Sin', ['Add27']],
#                'Sub113': ['Sub', ['a13', 'Pow111']],
#                'Sub123': ['Sub', ['Mul122', 'Mul115']],
#                'Sub129': ['Sub', ['Sub123', 'Mul128']],
#                'Sub145': ['Sub', ['Mul144', 'Mul117']],
#                'Sub158': ['Sub', ['Add154', 'Mul157']],
#                'Sub189': ['Sub', ['a13', 'Pow187']],
#                'Sub199': ['Sub', ['Mul198', 'Mul191']],
#                'Sub205': ['Sub', ['Sub199', 'Mul204']],
#                'Sub221': ['Sub', ['Mul220', 'Mul193']],
#                'Sub234': ['Sub', ['Add230', 'Mul233']],
#                'Sub257': ['Sub', ['a13', 'Pow255']],
#                'Sub267': ['Sub', ['Mul266', 'Mul259']],
#                'Sub273': ['Sub', ['Sub267', 'Mul272']],
#                'Sub289': ['Sub', ['Mul288', 'Mul261']],
#                'Sub302': ['Sub', ['Add298', 'Mul301']],
#                'Sub37': ['Sub', ['a13', 'Pow35']],
#                'Sub47': ['Sub', ['Mul46', 'Mul39']],
#                'Sub53': ['Sub', ['Sub47', 'Mul52']],
#                'Sub69': ['Sub', ['Mul68', 'Mul41']],
#                'Sub82': ['Sub', ['Add78', 'Mul81']]}}
# ================================================================================
# [check_names] The name 'data_test' is already in defined as Dataset but it is overwritten.
# ============================ nnodely Model Dataset =============================
# Dataset Name:                 data_test
# Number of files:              200
# Total number of samples:      30000
# Shape of Xangle:              (30000, 1, 1)
# Shape of Xangular_velocity:   (30000, 1, 1)
# Shape of Xpos:                (30000, 1, 1)
# Shape of Xvelocity:           (30000, 1, 1)
# Shape of Yangle:              (30000, 1, 1)
# Shape of Yangular_velocity:   (30000, 1, 1)
# Shape of Ypos:                (30000, 1, 1)
# Shape of Yvelocity:           (30000, 1, 1)
# Shape of action:              (30000, 1, 1)
# Shape of noise1:              (30000, 1, 1)
# Shape of noise2:              (30000, 1, 1)
# Shape of noise3:              (30000, 1, 1)
# Shape of noise4:              (30000, 1, 1)
# ================================================================================
# [__call__] num_of_samples is ignored if sampled is equal to True
