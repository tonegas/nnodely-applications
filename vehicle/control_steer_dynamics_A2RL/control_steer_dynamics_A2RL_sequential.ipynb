# %% [markdown]
# # **Neural steering controller for an autonomous race car**
#
# This model implements the Model-Structured Neural Network steering controller MS-NN-steer of the paper titled:
#
# *Model-Structured Neural Networks to Control the Steering Dynamics of Autonomous Race Cars*
#
# This script is called by the main script `main_sequential_training.py`, to optimize the hyperparameters of MS-NN-steer with a grid search.

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### Import packages

# %%
import sys
import os
import torch
import pandas as pd
import scipy as sp
import numpy as np
from nnodely.initializer import *
from nnodely.utils import *
import json

print('Current working directory: ',os.getcwd())
sys.path.append(os.path.join(os.getcwd(),'..'))
from nnodely import *
from nnodely.relation import NeuObj
from nnodely import earlystopping
NeuObj.NeuObj_names = []  # reset the list of NeuObj names

# import a library for plots
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
#mpl.rcParams['text.usetex'] = True
import matplotlib.pyplot as plt
plt.close('all')
SMALL_SIZE = 14
MEDIUM_SIZE = 22
BIGGER_SIZE = 26
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)    # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)     # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rc('grid', linestyle="--", color='grey')

# enable zooming on the plots
# %matplotlib inline
import mpld3
mpld3.enable_notebook()

# read some NN data from the JSON file written by the main_sequential_training.py script
# read the json file
json_file_name = './NN_parameters.json'
with open(json_file_name) as f:
  data = json.load(f)
num_samples_future_feedfw = data['num_samples_future_feedfw']     # number of local models activated in specific intervals of ay
num_channels_vx = data['num_channels_vx']     # number of local models activated in specific intervals of ay
num_channels_ax = data['num_channels_ax']     # number of local models activated in specific intervals of ay
num_seed = data['seed']     # number of local models activated in specific intervals of ay
learning_rate = data['learning_rate']     # number of local models activated in specific intervals of ay

# name with which this NN model will be saved
# Out:
# Current working directory:  c:\Users\mungi\OneDrive\Desktop\Nello\TUM_MS_NNs\nnodely-applications\My_network\A2RL

# %% [markdown]
# ### Configurations and known constant parameters

# %%
# Path to the data folder
data_folder = os.path.join(os.getcwd(),'A2RL_data')

# %% [markdown]
# ## NN model

# %% [markdown]
# ### Custom parametric functions

# %%
# -------------------------------------------------
# Normalization function
# -------------------------------------------------
def normalize_fun(x,x_max):
  return x/x_max

# -------------------------------------------------
# Saturation function
# -------------------------------------------------
def sat_fun(x,x_min,x_max):
  return torch.min(torch.max(x,x_min),x_max)

# -------------------------------------------------
# Absolute value function
# -------------------------------------------------
def abs_fun(x):
  return torch.abs(x)

# -------------------------------------------------
# Handling diagram
# -------------------------------------------------
def handling_diagr_local(curv,ay,ax,vx_norm,  # inputs
                         ay_0,ax_0,L,       # constants
                         k1_vx,k2_vx,            # learnable arrays of parameters
                         S_ay,S_ax          # learnable arrays of parameters
                         ):
  sign_ay = torch.sign(ay)  # sign of the lateral acceleration

  # compute k1, as a function of vx 
  k1_vx_fun = k1_vx[0,0,0]
  for ii in range(1,k1_vx.size(2)):
    k1_vx_fun = k1_vx_fun + k1_vx[0,0,ii]*torch.pow(vx_norm,ii)

  # compute k2, as a function of vx
  k2_vx_fun = k2_vx[0,0,0]
  for ii in range(1,k2_vx.size(2)):
    k2_vx_fun = k2_vx_fun + k2_vx[0,0,ii]*torch.pow(vx_norm,ii)

  # learnable weights of the local model for ay around ay_0
  S_ay_1 = S_ay[0,0,0]
  S_ay_2 = S_ay[0,0,1]
  S_ay_3 = S_ay[0,0,2]
  S_ay_4 = S_ay[0,0,3]

  # learnable weights of the local model for ax around ax_0
  S_ax_1 = S_ax[0,0,0]
  S_ax_2 = S_ax[0,0,1]
  S_ax_3 = S_ax[0,0,2]
  S_ax_4 = S_ax[0,0,3]
  S_ax_5 = S_ax[0,0,4]
    
  # output of the local model of the handling diagram
  output = curv*L + k1_vx_fun*sign_ay + k2_vx_fun*(ay - ay_0*sign_ay) +\
           S_ay_1*S_ax_1*(ay - (ay_0+S_ay_2)*sign_ay)*(S_ax_2 + ax - ax_0)*(1 + \
           S_ay_3*(ay - ay_0*sign_ay) + S_ax_3*(ax - ax_0) + S_ax_4*(ax - ax_0)**2 + \
           S_ay_4*S_ax_5*(ay - ay_0*sign_ay)*(ax - ax_0))
  return output

# %% [markdown]
# ### Hyperparameters and configurations for the internal model

# %%
NeuObj.clearNames(['curv','vx','ay','ax','steer','steer_target','L','ay_center_0','steering_angle']) # reset the list of NeuObj names

# -----------------------------------------------
# Neural model inputs and outputs
# -----------------------------------------------
curv         = Input('curv')          # [1/m] path curvature
vx           = Input('vx')            # [m/s] longitudinal velocity  
ay           = Input('ay')            # [m/s^2] lateral acceleration
ax           = Input('ax')            # [m/s^2] longitudinal acceleration
steer_target = Input('steer_target')  # [rad] steering wheel angle --> this is used only as a training target
L = Constant('L',values=3.115)  # [m] wheelbase
# -----------------------------------------------
# Saturation values for the inputs
# -----------------------------------------------
# Load the training and validation data
name_folder = '/Large/' 
number_training=2792
number_validation= 2992

data_folder_train = os.path.join(data_folder,'training'+ name_folder)
data_folder_valid = os.path.join(data_folder,'validation'+  name_folder)

# Extract the max values of ay and vx from the training set
max_ay   = max(abs(pd.read_csv(os.path.join(data_folder_train,'training_single_lap.csv'))['ay'].values)).item()
max_ay_val   = max(abs(pd.read_csv(os.path.join(data_folder_valid,'Validation_single_lap.csv'))['ay'].values)).item()

max_curv = max(abs(pd.read_csv(os.path.join(data_folder_train,'training_single_lap.csv'))['curv'].values)).item()

min_vx = min(pd.read_csv(os.path.join(data_folder_train,'training_single_lap.csv'))['vx'].values).item()
max_vx = max(pd.read_csv(os.path.join(data_folder_train,'training_single_lap.csv'))['vx'].values).item()
min_vx_val = min(pd.read_csv(os.path.join(data_folder_valid,'Validation_single_lap.csv'))['vx'].values).item()
max_vx_val = max(pd.read_csv(os.path.join(data_folder_valid,'Validation_single_lap.csv'))['vx'].values).item()


min_ax = np.percentile(pd.read_csv(os.path.join(data_folder_train,'training_single_lap.csv'))['ax'].values,0.2,axis=0).item()
max_ax = np.percentile(pd.read_csv(os.path.join(data_folder_train,'training_single_lap.csv'))['ax'].values,99.92,axis=0).item()
min_ax_val = np.percentile(pd.read_csv(os.path.join(data_folder_valid,'Validation_single_lap.csv'))['ax'].values,0.2,axis=0).item()
max_ax_val = np.percentile(pd.read_csv(os.path.join(data_folder_valid,'Validation_single_lap.csv'))['ax'].values,99.92,axis=0).item()


print('max_ay   = ', max_ay)
print('max_ay_2   = ', max_ay_val)
print('max_curv = ', max_curv)
print('min_vx   = ', min_vx)
print('max_vx   = ', max_vx)
print('min_vx_2   = ', min_vx_val)
print('max_vx_2   = ', max_vx_val)
print('min_ax   = ', min_ax)
print('max_ax   = ', max_ax)
print('min_ax_2   = ', min_ax_val)
print('max_ax_2   = ', max_ax_val)

# -----------------------------------------------
# Window sizes, channels, and others
# -----------------------------------------------
# Window size for the inputs
# num_samples_future_feedfw = 15   # number of future samples in the feedforward part of the model

# Channels for the lateral acceleration ay
num_channels_ay = 5
chan_centers_ay = list(np.linspace(0.0, max_ay_val, num_channels_ay))  # centers of the channels

# Channels for the forward speed vx
# num_channels_vx = 7
chan_centers_vx = list(np.linspace(min_vx_val, max_vx_val, num=num_channels_vx))  # centers of the channels

# Channels for the longitudinal acceleration ax
# num_channels_ax         = 7
perc_neg_ax             = 0.5   # percentage of channels dedicated to negative ax
extra_margin_ax_centers = 0.5   # extra margin for the centers of the channels
# Define the center points of the channels (make sure to capture ax = 0)
chan_centers_ax = np.linspace(min_ax_val - extra_margin_ax_centers, 0, num=int(num_channels_ax*perc_neg_ax), endpoint=False)
chan_centers_ax = list(np.append(chan_centers_ax, np.linspace(0, max_ax_val + extra_margin_ax_centers, 
                                                              num=num_channels_ax - int(num_channels_ax*perc_neg_ax))))

print('chan_centers_ay = ', chan_centers_ay)
print('chan_centers_vx = ', chan_centers_vx)
print('chan_centers_ax = ', chan_centers_ax)


# degree of the polynomial to fit k1, as a function of vx
poly_degree_k1_vx = 3
# degree of the polynomial to fit k2, as a function of vx
poly_degree_k2_vx = 1

# -----------------------------------------------
# Initial guesses and constants
# -----------------------------------------------
# Load the initial guesses for the handling diagram model, computed in Matlab with a 2nd order optimizer
initial_guesses_handling_diagr = sp.io.loadmat(os.path.join(data_folder,
                                                            str(num_channels_ay) + '_lin_models_ay_poly_deg_' + 
                                                            str(poly_degree_k1_vx) + '_' + str(poly_degree_k2_vx) + '_vx.mat'))
k1_vx_array_guess = initial_guesses_handling_diagr['optim_params_save']['k1_vx'][0][0][0]
k2_vx_array_guess = initial_guesses_handling_diagr['optim_params_save']['k2_vx'][0][0][0]
# k1_vx_array_guess has now a shape of (24,). Please reshape it to (6, 4)
k1_vx_array_guess = k1_vx_array_guess.reshape(num_channels_ay, poly_degree_k1_vx+1)
k2_vx_array_guess = k2_vx_array_guess.reshape(num_channels_ay, poly_degree_k2_vx+1)


# -----------------------------------------------
# Pre-process the inputs
# -----------------------------------------------
vx_norm = ParamFun(normalize_fun)(vx.sw([0,num_samples_future_feedfw]),max_vx)  # normalized longitudinal velocity
ay_abs  = ParamFun(abs_fun)(ay.sw([0,num_samples_future_feedfw]))  # absolute value of the lateral acceleration

# Saturated inputs
ay_sat     = ParamFun(sat_fun)(ay.sw([0,num_samples_future_feedfw]),-max_ay,max_ay)
curv_sat   = ParamFun(sat_fun)(curv.sw([0,num_samples_future_feedfw]),-max_curv,max_curv)
ax_sat     = ParamFun(sat_fun)(ax.sw([0,num_samples_future_feedfw]),min_ax,max_ax)
vx_sat     = ParamFun(sat_fun)(vx.sw([0,num_samples_future_feedfw]),min_vx,max_vx)
ay_abs_sat = ParamFun(abs_fun)(ay_sat)

# -----------------------------------------------
# Non-trainable parameters
# -----------------------------------------------
# Vehicle data

# -----------------------------------------------
# Local models of the extended handling diagram, 
# to model the quasi-steady-state combined lateral vehicle dynamics
# -----------------------------------------------
# Define the activation functions for the local models (aka channels)
activ_fcns_ay = Fuzzify(centers=chan_centers_ay, functions='Triangular')(ay_abs_sat)
activ_fcns_ax = Fuzzify(centers=chan_centers_ax, functions='Triangular')(ax_sat)

# Define the centers of the channels for ay, ax, and az:
chan_centers_ay_list, chan_centers_ax_list = [], []
for idx_ay in range(num_channels_ay):
  chan_centers_ay_list.append(Constant('ay_center_' + str(idx_ay), values=chan_centers_ay[idx_ay]))
for idx_ax in range(num_channels_ax):
  chan_centers_ax_list.append(Constant('ax_center_' + str(idx_ax), values=chan_centers_ax[idx_ax]))

# Define the learnable arrays of parameters:
# note that the parameters of the ay channels are shared among the ax and az channels, and the same holds for the ax and az channels

# Parameters to learn the vx-dependent shape of the handling diagram with local models
k1_vx_guess_list, k2_vx_guess_list = [], []
for idx_ay in range(num_channels_ay):
  k1_vx_guess_list.append(Parameter('k1_vx_' + str(idx_ay),values=[[list(k1_vx_array_guess[idx_ay,:])]]))  # initial guess
  k2_vx_guess_list.append(Parameter('k2_vx_' + str(idx_ay),values=[[list(k2_vx_array_guess[idx_ay,:])]]))  # initial guess
                          
# Parameters to learn the local models for the handling diagram, as a function of ay, ax and az
S_ay_guess_list, S_ax_guess_list = [], []
num_S_ay_params = 4
num_S_ax_params = 5
# Initialize with random values with a certain standard deviation
np.random.seed(num_seed)  # Imposta il seed per rendere i risultati riproducibili
first_value = np.random.normal(0,1e-4)

for idx_ay in range(num_channels_ay):
  sigma_S_ay = 1e-4
  S_ay_guess = np.random.normal(0,sigma_S_ay,num_S_ay_params)
  S_ay_guess_list.append(Parameter('S_ay_' + str(idx_ay),values=[[list(S_ay_guess)]]))  # initial guess
for idx_ax in range(num_channels_ax):
  sigma_S_ax = 1e-3
  S_ax_guess = np.random.normal(0,sigma_S_ax,num_S_ax_params)
  S_ax_guess_list.append(Parameter('S_ax_' + str(idx_ax),values=[[list(S_ax_guess)]]))  # initial guess

# Handling diagram function for the local models
handling_diagr = ParamFun(handling_diagr_local)

# Handling diagram function generator
def handling_diagr_gen(idx_list):
  # define an auxiliary function to allocate new parameters for each channel:
  # the inputs of this function will be passed by the LocalModel object
  def handling_diagr_map(curv,ay,ax,vx_norm):
    idx_ay, idx_ax = idx_list[0], idx_list[1]   # indices of the channels for ay, ax and az
    ay_0 = chan_centers_ay_list[idx_ay]  # center of the channel for ay
    ax_0 = chan_centers_ax_list[idx_ax]  # center of the channel for ax
    k1_vx = k1_vx_guess_list[idx_ay]     # learnable array of parameters for k1, as a function of vx
    k2_vx = k2_vx_guess_list[idx_ay]     # learnable array of parameters for k2, as a function of vx
    S_ay = S_ay_guess_list[idx_ay]       # learnable array of parameters for the local model of ay
    S_ax = S_ax_guess_list[idx_ax]       # learnable array of parameters for the local model of ax
    return handling_diagr(curv,ay,ax,vx_norm,        # inputs
                          ay_0,ax_0,L,             # constants
                          k1_vx,k2_vx,S_ay,S_ax   # learnable arrays of parameters
                          )
  return handling_diagr_map

out_local_models_handling_diagr = LocalModel(input_function=handling_diagr_gen, pass_indexes=True)((curv_sat,ay_sat,ax_sat,vx_norm),
                                                                                                   (activ_fcns_ay,activ_fcns_ax))

# -----------------------------------------------
# Local models for the transient lateral vehicle dynamics
# -----------------------------------------------
# Define the activation functions for the local models
activ_fcns_vx = Fuzzify(centers=chan_centers_vx, functions='Triangular')(vx.sw([0,num_samples_future_feedfw]))

# Define and call the local model for the transient dynamics
local_model_trans_dyna = LocalModel(output_function=lambda: Fir(W_init = init_exp, 
                                                                W_init_params={'size_index':0, 'max_value':first_value, 
                                                                                       'lambda':5, 'monotonicity':'decreasing'}))
out_local_model_trans_dyna = local_model_trans_dyna(out_local_models_handling_diagr, (activ_fcns_vx,activ_fcns_ax))

# Model output
out_NN = Output('steering_angle', out_local_model_trans_dyna)
# Out:
# max_ay   =  17.4789927602204
# max_curv =  0.0678973712302635
# min_vx   =  12.8619979988317
# max_vx   =  63.5807290222844
# min_ax   =  -16.801766327676518
# max_ax   =  8.896746140973896
# chan_centers_ay =  [np.float64(0.0), np.float64(9.2394963801102), np.float64(18.4789927602204)]
# chan_centers_vx =  [np.float64(9.0), np.float64(22.5), np.float64(36.0), np.float64(49.5), np.float64(63.0), np.float64(76.5), np.float64(90.0)]
# chan_centers_ax =  [np.float64(-17.301766327676518), np.float64(-11.53451088511768), np.float64(-5.76725544255884), np.float64(0.0), np.float64(3.1322487136579653), np.float64(6.264497427315931), np.float64(9.396746140973896)]

# %% [markdown]
# ### Internal architecture

# %% [markdown]
# ### nnodely definitions

# %%
# Create a nnodely model
path_folder_save = os.path.join(os.getcwd(),'A2RL_data/trained_models','control_steer_dynamics_A2RL')  # folder to save the model
steer_controller_extended = nnodely(visualizer='Standard',seed=12,workspace=path_folder_save,save_history=False)  #visualizer=MPLVisulizer()

# Add the neural model to the nnodely structure and neuralization of the model
steer_controller_extended.addModel('steer_ctrl',[out_NN])
steer_controller_extended.addMinimize('steer_error', 
                                      steer_target.next(),  # next means the first value in the "future"
                                      out_NN, 
                                      loss_function='rmse')

# Create the model
steer_controller_extended.neuralizeModel()
# Out:
# ================================ nnodely Model =================================
# {'Constants': {'Constant252': {'dim': 1, 'values': 63.58073043823242},
#                'Constant257': {'dim': 1, 'values': -17.478992462158203},
#                'Constant258': {'dim': 1, 'values': 17.478992462158203},
#                'Constant262': {'dim': 1, 'values': -0.06789737194776535},
#                'Constant263': {'dim': 1, 'values': 0.06789737194776535},
#                'Constant267': {'dim': 1, 'values': -16.80176544189453},
#                'Constant268': {'dim': 1, 'values': 8.896745681762695},
#                'L': {'dim': 1, 'values': 3.115000009536743},
#                'ax_center_0': {'dim': 1, 'values': -17.30176544189453},
#                'ax_center_1': {'dim': 1, 'values': -11.534510612487793},
#                'ax_center_2': {'dim': 1, 'values': -5.7672553062438965},
#                'ax_center_3': {'dim': 1, 'values': 0.0},
#                'ax_center_4': {'dim': 1, 'values': 3.132248640060425},
#                'ax_center_5': {'dim': 1, 'values': 6.26449728012085},
#                'ax_center_6': {'dim': 1, 'values': 9.396745681762695},
#                'ay_center_0': {'dim': 1, 'values': 0.0},
#                'ay_center_1': {'dim': 1, 'values': 9.239496231079102},
#                'ay_center_2': {'dim': 1, 'values': 18.478992462158203}},
#  'Functions': {'FFuzzify275': {'centers': [0.0,
#                                            9.2394963801102,
#                                            18.4789927602204],
#                                'dim_out': {'dim': 3},
#                                'functions': 'Triangular',
#                                'names': 'Triangular'},
#                'FFuzzify276': {'centers': [-17.301766327676518,
#                                            -11.53451088511768,
#                                            -5.76725544255884,
#                                            0.0,
#                                            3.1322487136579653,
#                                            6.264497427315931,
#                                            9.396746140973896],
#                                'dim_out': {'dim': 7},
#                                'functions': 'Triangular',
#                                'names': 'Triangular'},
#                'FFuzzify305': {'centers': [9.0,
#                                            22.5,
#                                            36.0,
#                                            49.5,
#                                            63.0,
#                                            76.5,
#                                            90.0],
#                                'dim_out': {'dim': 7},
#                                'functions': 'Triangular',
#                                'names': 'Triangular'},
#                'FParamFun250': {'code': 'def normalize_fun(x,x_max):\n'
#                                         '  return x/x_max\n',
#                                 'in_dim': [{'dim': 1, 'sw': 15}, {'dim': 1}],
#                                 'map_over_dim': False,
#                                 'n_input': 2,
#                                 'name': 'normalize_fun',
#                                 'out_dim': {'dim': 1, 'sw': 15},
#                                 'params_and_consts': []},
#                'FParamFun254': {'code': 'def sat_fun(x,x_min,x_max):\n'
#                                         '  return '
#                                         'torch.min(torch.max(x,x_min),x_max)\n',
#                                 'in_dim': [{'dim': 1, 'sw': 15},
#                                            {'dim': 1},
#                                            {'dim': 1}],
#                                 'map_over_dim': False,
#                                 'n_input': 3,
#                                 'name': 'sat_fun',
#                                 'out_dim': {'dim': 1, 'sw': 15},
#                                 'params_and_consts': []},
#                'FParamFun259': {'code': 'def sat_fun(x,x_min,x_max):\n'
#                                         '  return '
#                                         'torch.min(torch.max(x,x_min),x_max)\n',
#                                 'in_dim': [{'dim': 1, 'sw': 15},
#                                            {'dim': 1},
#                                            {'dim': 1}],
#                                 'map_over_dim': False,
#                                 'n_input': 3,
#                                 'name': 'sat_fun',
#                                 'out_dim': {'dim': 1, 'sw': 15},
#                                 'params_and_consts': []},
#                'FParamFun264': {'code': 'def sat_fun(x,x_min,x_max):\n'
#                                         '  return '
#                                         'torch.min(torch.max(x,x_min),x_max)\n',
#                                 'in_dim': [{'dim': 1, 'sw': 15},
#                                            {'dim': 1},
#                                            {'dim': 1}],
#                                 'map_over_dim': False,
#                                 'n_input': 3,
#                                 'name': 'sat_fun',
#                                 'out_dim': {'dim': 1, 'sw': 15},
#                                 'params_and_consts': []},
#                'FParamFun274': {'code': 'def abs_fun(x):\n'
#                                         '  return torch.abs(x)\n',
#                                 'in_dim': [{'dim': 1, 'sw': 15}],
#                                 'map_over_dim': False,
#                                 'n_input': 1,
#                                 'name': 'abs_fun',
#                                 'out_dim': {'dim': 1, 'sw': 15},
#                                 'params_and_consts': []},
#                'FParamFun303': {'code': 'def '
#                                         'handling_diagr_local(curv,ay,ax,vx_norm,  '
#                                         '# inputs\n'
#                                         '                         '
#                                         'ay_0,ax_0,L,       # constants\n'
#                                         '                         '
#                                         'k1_vx,k2_vx,            # learnable '
#                                         'arrays of parameters\n'
#                                         '                         '
#                                         'S_ay,S_ax          # learnable arrays '
#                                         'of parameters\n'
#                                         '                         ):\n'
#                                         '  sign_ay = torch.sign(ay)  # sign of '
#                                         'the lateral acceleration\n'
#                                         '\n'
#                                         '  # compute k1, as a function of vx \n'
#                                         '  k1_vx_fun = k1_vx[0,0,0]\n'
#                                         '  for ii in range(1,k1_vx.size(2)):\n'
#                                         '    k1_vx_fun = k1_vx_fun + '
#                                         'k1_vx[0,0,ii]*torch.pow(vx_norm,ii)\n'
#                                         '\n'
#                                         '  # compute k2, as a function of vx\n'
#                                         '  k2_vx_fun = k2_vx[0,0,0]\n'
#                                         '  for ii in range(1,k2_vx.size(2)):\n'
#                                         '    k2_vx_fun = k2_vx_fun + '
#                                         'k2_vx[0,0,ii]*torch.pow(vx_norm,ii)\n'
#                                         '\n'
#                                         '  # learnable weights of the local '
#                                         'model for ay around ay_0\n'
#                                         '  S_ay_1 = S_ay[0,0,0]\n'
#                                         '  S_ay_2 = S_ay[0,0,1]\n'
#                                         '  S_ay_3 = S_ay[0,0,2]\n'
#                                         '  S_ay_4 = S_ay[0,0,3]\n'
#                                         '\n'
#                                         '  # learnable weights of the local '
#                                         'model for ax around ax_0\n'
#                                         '  S_ax_1 = S_ax[0,0,0]\n'
#                                         '  S_ax_2 = S_ax[0,0,1]\n'
#                                         '  S_ax_3 = S_ax[0,0,2]\n'
#                                         '  S_ax_4 = S_ax[0,0,3]\n'
#                                         '  S_ax_5 = S_ax[0,0,4]\n'
#                                         '\n'
#                                         '  # output of the local model of the '
#                                         'handling diagram\n'
#                                         '  output = curv*L + k1_vx_fun*sign_ay '
#                                         '+ k2_vx_fun*(ay - ay_0*sign_ay) +\\\n'
#                                         '           S_ay_1*S_ax_1*(ay - '
#                                         '(ay_0+S_ay_2)*sign_ay)*(S_ax_2 + ax - '
#                                         'ax_0)*(1 + \\\n'
#                                         '           S_ay_3*(ay - ay_0*sign_ay) '
#                                         '+ S_ax_3*(ax - ax_0) + S_ax_4*(ax - '
#                                         'ax_0)**2 + \\\n'
#                                         '           S_ay_4*S_ax_5*(ay - '
#                                         'ay_0*sign_ay)*(ax - ax_0))\n'
#                                         '  return output\n',
#                                 'in_dim': [{'dim': 1, 'sw': 15},
#                                            {'dim': 1, 'sw': 15},
#                                            {'dim': 1, 'sw': 15},
#                                            {'dim': 1, 'sw': 15},
#                                            {'dim': 1},
#                                            {'dim': 1},
#                                            {'dim': 1},
#                                            {'dim': [1, 4], 'sw': 1},
#                                            {'dim': [1, 2], 'sw': 1},
#                                            {'dim': [1, 4], 'sw': 1},
#                                            {'dim': [1, 5], 'sw': 1}],
#                                 'map_over_dim': False,
#                                 'n_input': 11,
#                                 'name': 'handling_diagr_local',
#                                 'out_dim': {'dim': 1, 'sw': 15},
#                                 'params_and_consts': []}},
#  'Info': {'SampleTime': 1, 'ns': [0, 15], 'ntot': 15},
#  'Inputs': {'ax': {'dim': 1,
#                    'ns': [0, 15],
#                    'ntot': 15,
#                    'sw': [0, 15],
#                    'tw': [0, 0]},
#             'ay': {'dim': 1,
#                    'ns': [0, 15],
#                    'ntot': 15,
#                    'sw': [0, 15],
#                    'tw': [0, 0]},
#             'curv': {'dim': 1,
#                      'ns': [0, 15],
#                      'ntot': 15,
#                      'sw': [0, 15],
#                      'tw': [0, 0]},
#             'steer_target': {'dim': 1,
#                              'ns': [0, 1],
#                              'ntot': 1,
#                              'sw': [0, 1],
#                              'tw': [0, 0]},
#             'vx': {'dim': 1,
#                    'ns': [0, 15],
#                    'ntot': 15,
#                    'sw': [0, 15],
#                    'tw': [0, 0]}},
#  'Minimizers': {'steer_error': {'A': 'SamplePart2243',
#                                 'B': 'steering_angle',
#                                 'loss': 'rmse'}},
#  'Models': 'steer_ctrl',
#  'Outputs': {'steering_angle': 'Add2240'},
#  'Parameters': {'PFir307p': {'dim': 1,
#                              'init_fun': {'code': 'def init_exp(indexes, '
#                                                   'params_size, dict_param = '
#                                                   "{'size_index':0, "
#                                                   "'max_value':1, 'lambda':3, "
#                                                   "'monotonicity':'decreasing'}):\n"
#                                                   "    '''\n"
#                                                   '    Initializes parameters '
#                                                   'using an increasing or '
#                                                   'decreasing exponential '
#                                                   'function.\n'
#                                                   '\n'
#                                                   '    Parameters\n'
#                                                   '    ----------\n'
#                                                   '    indexes : list\n'
#                                                   '        List of indexes for '
#                                                   'the parameters.\n'
#                                                   '    params_size : list\n'
#                                                   '        List of sizes for '
#                                                   'each dimension of the '
#                                                   'parameters.\n'
#                                                   '    dict_param : dict, '
#                                                   'optional\n'
#                                                   '        Dictionary '
#                                                   'containing the '
#                                                   'initialization parameters. '
#                                                   "Default is {'size_index': "
#                                                   "0, 'max_value': 1, "
#                                                   "'lambda': 3, "
#                                                   "'monotonicity': "
#                                                   "'decreasing'}.\n"
#                                                   '        - size_index : int\n'
#                                                   '            The index of '
#                                                   'the dimension to apply the '
#                                                   'exponential function.\n'
#                                                   '        - max_value : int '
#                                                   'or float\n'
#                                                   '            The maximum '
#                                                   'value of the exponential '
#                                                   'function.\n'
#                                                   '        - lambda : int or '
#                                                   'float\n'
#                                                   '            The rate '
#                                                   'parameter of the '
#                                                   'exponential function.\n'
#                                                   '        - monotonicity : '
#                                                   'str\n'
#                                                   '            The '
#                                                   'monotonicity of the '
#                                                   'exponential function. Can '
#                                                   "be 'increasing' or "
#                                                   "'decreasing'.\n"
#                                                   '\n'
#                                                   '    Raises\n'
#                                                   '    ------\n'
#                                                   '    ValueError\n'
#                                                   '        If the monotonicity '
#                                                   "is not 'increasing' or "
#                                                   "'decreasing'.\n"
#                                                   "    '''\n"
#                                                   '    import numpy as np\n'
#                                                   '    size_index = '
#                                                   "dict_param['size_index']\n"
#                                                   '    monotonicity = '
#                                                   "dict_param['monotonicity']\n"
#                                                   '    if monotonicity == '
#                                                   "'increasing':\n"
#                                                   '        # increasing '
#                                                   'exponential, the '
#                                                   "'max_value' is the value at "
#                                                   'x=1, i.e, at the end of the '
#                                                   'range\n'
#                                                   '        x = 1 if '
#                                                   'params_size[size_index]-1 '
#                                                   '== 0 else '
#                                                   'indexes[size_index]/(params_size[size_index]-1)\n'
#                                                   '        out = '
#                                                   "dict_param['max_value']*np.exp(dict_param['lambda']*(x-1))\n"
#                                                   '    elif monotonicity == '
#                                                   "'decreasing':\n"
#                                                   '        # decreasing '
#                                                   'exponential, the '
#                                                   "'max_value' is the value at "
#                                                   'x=0, i.e, at the beginning '
#                                                   'of the range\n'
#                                                   '        x = 0 if '
#                                                   'params_size[size_index]-1 '
#                                                   '== 0 else '
#                                                   'indexes[size_index]/(params_size[size_index]-1)\n'
#                                                   '        out = '
#                                                   "dict_param['max_value']*np.exp(-dict_param['lambda']*x)\n"
#                                                   '    else:\n'
#                                                   '        raise '
#                                                   "ValueError('The parameter "
#                                                   'monotonicity must be either '
#                                                   'increasing or '
#                                                   "decreasing.')\n"
#                                                   '    return out\n',
#                                           'name': 'init_exp',
#                                           'params': {'lambda': 5,
#                                                      'max_value': 0.00016243453636632417,
#                                                      'monotonicity': 'decreasing',
#                                                      'size_index': 0}},
#                              'sw': 15},
#                 'PFir308p': {'dim': 1,
#                              'init_fun': {'code': 'def init_exp(indexes, '
#                                                   'params_size, dict_param = '
#                                                   "{'size_index':0, "
#                                                   "'max_value':1, 'lambda':3, "
#                                                   "'monotonicity':'decreasing'}):\n"
#                                                   "    '''\n"
#                                                   '    Initializes parameters '
#                                                   'using an increasing or '
#                                                   'decreasing exponential '
#                                                   'function.\n'
#                                                   '\n'
#                                                   '    Parameters\n'
#                                                   '    ----------\n'
#                                                   '    indexes : list\n'
#                                                   '        List of indexes for '
#                                                   'the parameters.\n'
#                                                   '    params_size : list\n'
#                                                   '        List of sizes for '
#                                                   'each dimension of the '
#                                                   'parameters.\n'
#                                                   '    dict_param : dict, '
#                                                   'optional\n'
#                                                   '        Dictionary '
#                                                   'containing the '
#                                                   'initialization parameters. '
#                                                   "Default is {'size_index': "
#                                                   "0, 'max_value': 1, "
#                                                   "'lambda': 3, "
#                                                   "'monotonicity': "
#                                                   "'decreasing'}.\n"
#                                                   '        - size_index : int\n'
#                                                   '            The index of '
#                                                   'the dimension to apply the '
#                                                   'exponential function.\n'
#                                                   '        - max_value : int '
#                                                   'or float\n'
#                                                   '            The maximum '
#                                                   'value of the exponential '
#                                                   'function.\n'
#                                                   '        - lambda : int or '
#                                                   'float\n'
#                                                   '            The rate '
#                                                   'parameter of the '
#                                                   'exponential function.\n'
#                                                   '        - monotonicity : '
#                                                   'str\n'
#                                                   '            The '
#                                                   'monotonicity of the '
#                                                   'exponential function. Can '
#                                                   "be 'increasing' or "
#                                                   "'decreasing'.\n"
#                                                   '\n'
#                                                   '    Raises\n'
#                                                   '    ------\n'
#                                                   '    ValueError\n'
#                                                   '        If the monotonicity '
#                                                   "is not 'increasing' or "
#                                                   "'decreasing'.\n"
#                                                   "    '''\n"
#                                                   '    import numpy as np\n'
#                                                   '    size_index = '
#                                                   "dict_param['size_index']\n"
#                                                   '    monotonicity = '
#                                                   "dict_param['monotonicity']\n"
#                                                   '    if monotonicity == '
#                                                   "'increasing':\n"
#                                                   '        # increasing '
#                                                   'exponential, the '
#                                                   "'max_value' is the value at "
#                                                   'x=1, i.e, at the end of the '
#                                                   'range\n'
#                                                   '        x = 1 if '
#                                                   'params_size[size_index]-1 '
#                                                   '== 0 else '
#                                                   'indexes[size_index]/(params_size[size_index]-1)\n'
#                                                   '        out = '
#                                                   "dict_param['max_value']*np.exp(dict_param['lambda']*(x-1))\n"
#                                                   '    elif monotonicity == '
#                                                   "'decreasing':\n"
#                                                   '        # decreasing '
#                                                   'exponential, the '
#                                                   "'max_value' is the value at "
#                                                   'x=0, i.e, at the beginning '
#                                                   'of the range\n'
#                                                   '        x = 0 if '
#                                                   'params_size[size_index]-1 '
#                                                   '== 0 else '
#                                                   'indexes[size_index]/(params_size[size_index]-1)\n'
#                                                   '        out = '
#                                                   "dict_param['max_value']*np.exp(-dict_param['lambda']*x)\n"
#                                                   '    else:\n'
#                                                   '        raise '
#                                                   "ValueError('The parameter "
#                                                   'monotonicity must be either '
#                                                   'increasing or '
#                                                   "decreasing.')\n"
#                                                   '    return out\n',
#                                           'name': 'init_exp',
#                                           'params': {'lambda': 5,
#                                                      'max_value': 0.00016243453636632417,
#                                                      'monotonicity': 'decreasing',
#                                                      'size_index': 0}},
#                              'sw': 15},
#                 'PFir309p': {'dim': 1,
#                              'init_fun': {'code': 'def init_exp(indexes, '
#                                                   'params_size, dict_param = '
#                                                   "{'size_index':0, "
#                                                   "'max_value':1, 'lambda':3, "
#                                                   "'monotonicity':'decreasing'}):\n"
#                                                   "    '''\n"
#                                                   '    Initializes parameters '
#                                                   'using an increasing or '
#                                                   'decreasing exponential '
#                                                   'function.\n'
#                                                   '\n'
#                                                   '    Parameters\n'
#                                                   '    ----------\n'
#                                                   '    indexes : list\n'
#                                                   '        List of indexes for '
#                                                   'the parameters.\n'
#                                                   '    params_size : list\n'
#                                                   '        List of sizes for '
#                                                   'each dimension of the '
#                                                   'parameters.\n'
#                                                   '    dict_param : dict, '
#                                                   'optional\n'
#                                                   '        Dictionary '
#                                                   'containing the '
#                                                   'initialization parameters. '
#                                                   "Default is {'size_index': "
#                                                   "0, 'max_value': 1, "
#                                                   "'lambda': 3, "
#                                                   "'monotonicity': "
#                                                   "'decreasing'}.\n"
#                                                   '        - size_index : int\n'
#                                                   '            The index of '
#                                                   'the dimension to apply the '
#                                                   'exponential function.\n'
#                                                   '        - max_value : int '
#                                                   'or float\n'
#                                                   '            The maximum '
#                                                   'value of the exponential '
#                                                   'function.\n'
#                                                   '        - lambda : int or '
#                                                   'float\n'
#                                                   '            The rate '
#                                                   'parameter of the '
#                                                   'exponential function.\n'
#                                                   '        - monotonicity : '
#                                                   'str\n'
#                                                   '            The '
#                                                   'monotonicity of the '
#                                                   'exponential function. Can '
#                                                   "be 'increasing' or "
#                                                   "'decreasing'.\n"
#                                                   '\n'
#                                                   '    Raises\n'
#                                                   '    ------\n'
#                                                   '    ValueError\n'
#                                                   '        If the monotonicity '
#                                                   "is not 'increasing' or "
#                                                   "'decreasing'.\n"
#                                                   "    '''\n"
#                                                   '    import numpy as np\n'
#                                                   '    size_index = '
#                                                   "dict_param['size_index']\n"
#                                                   '    monotonicity = '
#                                                   "dict_param['monotonicity']\n"
#                                                   '    if monotonicity == '
#                                                   "'increasing':\n"
#                                                   '        # increasing '
#                                                   'exponential, the '
#                                                   "'max_value' is the value at "
#                                                   'x=1, i.e, at the end of the '
#                                                   'range\n'
#                                                   '        x = 1 if '
#                                                   'params_size[size_index]-1 '
#                                                   '== 0 else '
#                                                   'indexes[size_index]/(params_size[size_index]-1)\n'
#                                                   '        out = '
#                                                   "dict_param['max_value']*np.exp(dict_param['lambda']*(x-1))\n"
#                                                   '    elif monotonicity == '
#                                                   "'decreasing':\n"
#                                                   '        # decreasing '
#                                                   'exponential, the '
#                                                   "'max_value' is the value at "
#                                                   'x=0, i.e, at the beginning '
#                                                   'of the range\n'
#                                                   '        x = 0 if '
#                                                   'params_size[size_index]-1 '
#                                                   '== 0 else '
#                                                   'indexes[size_index]/(params_size[size_index]-1)\n'
#                                                   '        out = '
#                                                   "dict_param['max_value']*np.exp(-dict_param['lambda']*x)\n"
#                                                   '    else:\n'
#                                                   '        raise '
#                                                   "ValueError('The parameter "
#                                                   'monotonicity must be either '
#                                                   'increasing or '
#                                                   "decreasing.')\n"
#                                                   '    return out\n',
#                                           'name': 'init_exp',
#                                           'params': {'lambda': 5,
#                                                      'max_value': 0.00016243453636632417,
#                                                      'monotonicity': 'decreasing',
#                                                      'size_index': 0}},
#                              'sw': 15},
#                 'PFir310p': {'dim': 1,
#                              'init_fun': {'code': 'def init_exp(indexes, '
#                                                   'params_size, dict_param = '
#                                                   "{'size_index':0, "
#                                                   "'max_value':1, 'lambda':3, "
#                                                   "'monotonicity':'decreasing'}):\n"
#                                                   "    '''\n"
#                                                   '    Initializes parameters '
#                                                   'using an increasing or '
#                                                   'decreasing exponential '
#                                                   'function.\n'
#                                                   '\n'
#                                                   '    Parameters\n'
#                                                   '    ----------\n'
#                                                   '    indexes : list\n'
#                                                   '        List of indexes for '
#                                                   'the parameters.\n'
#                                                   '    params_size : list\n'
#                                                   '        List of sizes for '
#                                                   'each dimension of the '
#                                                   'parameters.\n'
#                                                   '    dict_param : dict, '
#                                                   'optional\n'
#                                                   '        Dictionary '
#                                                   'containing the '
#                                                   'initialization parameters. '
#                                                   "Default is {'size_index': "
#                                                   "0, 'max_value': 1, "
#                                                   "'lambda': 3, "
#                                                   "'monotonicity': "
#                                                   "'decreasing'}.\n"
#                                                   '        - size_index : int\n'
#                                                   '            The index of '
#                                                   'the dimension to apply the '
#                                                   'exponential function.\n'
#                                                   '        - max_value : int '
#                                                   'or float\n'
#                                                   '            The maximum '
#                                                   'value of the exponential '
#                                                   'function.\n'
#                                                   '        - lambda : int or '
#                                                   'float\n'
#                                                   '            The rate '
#                                                   'parameter of the '
#                                                   'exponential function.\n'
#                                                   '        - monotonicity : '
#                                                   'str\n'
#                                                   '            The '
#                                                   'monotonicity of the '
#                                                   'exponential function. Can '
#                                                   "be 'increasing' or "
#                                                   "'decreasing'.\n"
#                                                   '\n'
#                                                   '    Raises\n'
#                                                   '    ------\n'
#                                                   '    ValueError\n'
#                                                   '        If the monotonicity '
#                                                   "is not 'increasing' or "
#                                                   "'decreasing'.\n"
#                                                   "    '''\n"
#                                                   '    import numpy as np\n'
#                                                   '    size_index = '
#                                                   "dict_param['size_index']\n"
#                                                   '    monotonicity = '
#                                                   "dict_param['monotonicity']\n"
#                                                   '    if monotonicity == '
#                                                   "'increasing':\n"
#                                                   '        # increasing '
#                                                   'exponential, the '
#                                                   "'max_value' is the value at "
#                                                   'x=1, i.e, at the end of the '
#                                                   'range\n'
#                                                   '        x = 1 if '
#                                                   'params_size[size_index]-1 '
#                                                   '== 0 else '
#                                                   'indexes[size_index]/(params_size[size_index]-1)\n'
#                                                   '        out = '
#                                                   "dict_param['max_value']*np.exp(dict_param['lambda']*(x-1))\n"
#                                                   '    elif monotonicity == '
#                                                   "'decreasing':\n"
#                                                   '        # decreasing '
#                                                   'exponential, the '
#                                                   "'max_value' is the value at "
#                                                   'x=0, i.e, at the beginning '
#                                                   'of the range\n'
#                                                   '        x = 0 if '
#                                                   'params_size[size_index]-1 '
#                                                   '== 0 else '
#                                                   'indexes[size_index]/(params_size[size_index]-1)\n'
#                                                   '        out = '
#                                                   "dict_param['max_value']*np.exp(-dict_param['lambda']*x)\n"
#                                                   '    else:\n'
#                                                   '        raise '
#                                                   "ValueError('The parameter "
#                                                   'monotonicity must be either '
#                                                   'increasing or '
#                                                   "decreasing.')\n"
#                                                   '    return out\n',
#                                           'name': 'init_exp',
#                                           'params': {'lambda': 5,
#                                                      'max_value': 0.00016243453636632417,
#                                                      'monotonicity': 'decreasing',
#                                                      'size_index': 0}},
#                              'sw': 15},
#                 'PFir311p': {'dim': 1,
#                              'init_fun': {'code': 'def init_exp(indexes, '
#                                                   'params_size, dict_param = '
#                                                   "{'size_index':0, "
#                                                   "'max_value':1, 'lambda':3, "
#                                                   "'monotonicity':'decreasing'}):\n"
#                                                   "    '''\n"
#                                                   '    Initializes parameters '
#                                                   'using an increasing or '
#                                                   'decreasing exponential '
#                                                   'function.\n'
#                                                   '\n'
#                                                   '    Parameters\n'
#                                                   '    ----------\n'
#                                                   '    indexes : list\n'
#                                                   '        List of indexes for '
#                                                   'the parameters.\n'
#                                                   '    params_size : list\n'
#                                                   '        List of sizes for '
#                                                   'each dimension of the '
#                                                   'parameters.\n'
#                                                   '    dict_param : dict, '
#                                                   'optional\n'
#                                                   '        Dictionary '
#                                                   'containing the '
#                                                   'initialization parameters. '
#                                                   "Default is {'size_index': "
#                                                   "0, 'max_value': 1, "
#                                                   "'lambda': 3, "
#                                                   "'monotonicity': "
#                                                   "'decreasing'}.\n"
#                                                   '        - size_index : int\n'
#                                                   '            The index of '
#                                                   'the dimension to apply the '
#                                                   'exponential function.\n'
#                                                   '        - max_value : int '
#                                                   'or float\n'
#                                                   '            The maximum '
#                                                   'value of the exponential '
#                                                   'function.\n'
#                                                   '        - lambda : int or '
#                                                   'float\n'
#                                                   '            The rate '
#                                                   'parameter of the '
#                                                   'exponential function.\n'
#                                                   '        - monotonicity : '
#                                                   'str\n'
#                                                   '            The '
#                                                   'monotonicity of the '
#                                                   'exponential function. Can '
#                                                   "be 'increasing' or "
#                                                   "'decreasing'.\n"
#                                                   '\n'
#                                                   '    Raises\n'
#                                                   '    ------\n'
#                                                   '    ValueError\n'
#                                                   '        If the monotonicity '
#                                                   "is not 'increasing' or "
#                                                   "'decreasing'.\n"
#                                                   "    '''\n"
#                                                   '    import numpy as np\n'
#                                                   '    size_index = '
#                                                   "dict_param['size_index']\n"
#                                                   '    monotonicity = '
#                                                   "dict_param['monotonicity']\n"
#                                                   '    if monotonicity == '
#                                                   "'increasing':\n"
#                                                   '        # increasing '
#                                                   'exponential, the '
#                                                   "'max_value' is the value at "
#                                                   'x=1, i.e, at the end of the '
#                                                   'range\n'
#                                                   '        x = 1 if '
#                                                   'params_size[size_index]-1 '
#                                                   '== 0 else '
#                                                   'indexes[size_index]/(params_size[size_index]-1)\n'
#                                                   '        out = '
#                                                   "dict_param['max_value']*np.exp(dict_param['lambda']*(x-1))\n"
#                                                   '    elif monotonicity == '
#                                                   "'decreasing':\n"
#                                                   '        # decreasing '
#                                                   'exponential, the '
# ...
#                                  'ParamFun1595',
#                                  'ParamFun1617',
#                                  'ParamFun1585',
#                                  'ay_center_1',
#                                  'ax_center_3',
#                                  'L',
#                                  'k1_vx_1',
#                                  'k2_vx_1',
#                                  'S_ay_1',
#                                  'S_ax_3'],
#                                 'FParamFun303'],
#                'ParamFun1805': ['ParamFun',
#                                 ['ParamFun1606',
#                                  'ParamFun1595',
#                                  'ParamFun1617',
#                                  'ParamFun1585',
#                                  'ay_center_1',
#                                  'ax_center_4',
#                                  'L',
#                                  'k1_vx_1',
#                                  'k2_vx_1',
#                                  'S_ay_1',
#                                  'S_ax_4'],
#                                 'FParamFun303'],
#                'ParamFun1817': ['ParamFun',
#                                 ['ParamFun1606',
#                                  'ParamFun1595',
#                                  'ParamFun1617',
#                                  'ParamFun1585',
#                                  'ay_center_1',
#                                  'ax_center_5',
#                                  'L',
#                                  'k1_vx_1',
#                                  'k2_vx_1',
#                                  'S_ay_1',
#                                  'S_ax_5'],
#                                 'FParamFun303'],
#                'ParamFun1829': ['ParamFun',
#                                 ['ParamFun1606',
#                                  'ParamFun1595',
#                                  'ParamFun1617',
#                                  'ParamFun1585',
#                                  'ay_center_1',
#                                  'ax_center_6',
#                                  'L',
#                                  'k1_vx_1',
#                                  'k2_vx_1',
#                                  'S_ay_1',
#                                  'S_ax_6'],
#                                 'FParamFun303'],
#                'ParamFun1841': ['ParamFun',
#                                 ['ParamFun1606',
#                                  'ParamFun1595',
#                                  'ParamFun1617',
#                                  'ParamFun1585',
#                                  'ay_center_2',
#                                  'ax_center_0',
#                                  'L',
#                                  'k1_vx_2',
#                                  'k2_vx_2',
#                                  'S_ay_2',
#                                  'S_ax_0'],
#                                 'FParamFun303'],
#                'ParamFun1853': ['ParamFun',
#                                 ['ParamFun1606',
#                                  'ParamFun1595',
#                                  'ParamFun1617',
#                                  'ParamFun1585',
#                                  'ay_center_2',
#                                  'ax_center_1',
#                                  'L',
#                                  'k1_vx_2',
#                                  'k2_vx_2',
#                                  'S_ay_2',
#                                  'S_ax_1'],
#                                 'FParamFun303'],
#                'ParamFun1865': ['ParamFun',
#                                 ['ParamFun1606',
#                                  'ParamFun1595',
#                                  'ParamFun1617',
#                                  'ParamFun1585',
#                                  'ay_center_2',
#                                  'ax_center_2',
#                                  'L',
#                                  'k1_vx_2',
#                                  'k2_vx_2',
#                                  'S_ay_2',
#                                  'S_ax_2'],
#                                 'FParamFun303'],
#                'ParamFun1877': ['ParamFun',
#                                 ['ParamFun1606',
#                                  'ParamFun1595',
#                                  'ParamFun1617',
#                                  'ParamFun1585',
#                                  'ay_center_2',
#                                  'ax_center_3',
#                                  'L',
#                                  'k1_vx_2',
#                                  'k2_vx_2',
#                                  'S_ay_2',
#                                  'S_ax_3'],
#                                 'FParamFun303'],
#                'ParamFun1889': ['ParamFun',
#                                 ['ParamFun1606',
#                                  'ParamFun1595',
#                                  'ParamFun1617',
#                                  'ParamFun1585',
#                                  'ay_center_2',
#                                  'ax_center_4',
#                                  'L',
#                                  'k1_vx_2',
#                                  'k2_vx_2',
#                                  'S_ay_2',
#                                  'S_ax_4'],
#                                 'FParamFun303'],
#                'ParamFun1901': ['ParamFun',
#                                 ['ParamFun1606',
#                                  'ParamFun1595',
#                                  'ParamFun1617',
#                                  'ParamFun1585',
#                                  'ay_center_2',
#                                  'ax_center_5',
#                                  'L',
#                                  'k1_vx_2',
#                                  'k2_vx_2',
#                                  'S_ay_2',
#                                  'S_ax_5'],
#                                 'FParamFun303'],
#                'ParamFun1913': ['ParamFun',
#                                 ['ParamFun1606',
#                                  'ParamFun1595',
#                                  'ParamFun1617',
#                                  'ParamFun1585',
#                                  'ay_center_2',
#                                  'ax_center_6',
#                                  'L',
#                                  'k1_vx_2',
#                                  'k2_vx_2',
#                                  'S_ay_2',
#                                  'S_ax_6'],
#                                 'FParamFun303'],
#                'SamplePart1584': ['SamplePart', ['vx'], -1, [0, 15]],
#                'SamplePart1594': ['SamplePart', ['ay'], -1, [0, 15]],
#                'SamplePart1605': ['SamplePart', ['curv'], -1, [0, 15]],
#                'SamplePart1616': ['SamplePart', ['ax'], -1, [0, 15]],
#                'SamplePart1946': ['SamplePart', ['vx'], -1, [0, 15]],
#                'SamplePart2243': ['SamplePart', ['steer_target'], -1, [0, 1]],
#                'Select1681': ['Select', ['Fuzzify1638'], 3, 0],
#                'Select1682': ['Select', ['Fuzzify1639'], 7, 0],
#                'Select1693': ['Select', ['Fuzzify1638'], 3, 0],
#                'Select1694': ['Select', ['Fuzzify1639'], 7, 1],
#                'Select1705': ['Select', ['Fuzzify1638'], 3, 0],
#                'Select1706': ['Select', ['Fuzzify1639'], 7, 2],
#                'Select1717': ['Select', ['Fuzzify1638'], 3, 0],
#                'Select1718': ['Select', ['Fuzzify1639'], 7, 3],
#                'Select1729': ['Select', ['Fuzzify1638'], 3, 0],
#                'Select1730': ['Select', ['Fuzzify1639'], 7, 4],
#                'Select1741': ['Select', ['Fuzzify1638'], 3, 0],
#                'Select1742': ['Select', ['Fuzzify1639'], 7, 5],
#                'Select1753': ['Select', ['Fuzzify1638'], 3, 0],
#                'Select1754': ['Select', ['Fuzzify1639'], 7, 6],
#                'Select1765': ['Select', ['Fuzzify1638'], 3, 1],
#                'Select1766': ['Select', ['Fuzzify1639'], 7, 0],
#                'Select1777': ['Select', ['Fuzzify1638'], 3, 1],
#                'Select1778': ['Select', ['Fuzzify1639'], 7, 1],
#                'Select1789': ['Select', ['Fuzzify1638'], 3, 1],
#                'Select1790': ['Select', ['Fuzzify1639'], 7, 2],
#                'Select1801': ['Select', ['Fuzzify1638'], 3, 1],
#                'Select1802': ['Select', ['Fuzzify1639'], 7, 3],
#                'Select1813': ['Select', ['Fuzzify1638'], 3, 1],
#                'Select1814': ['Select', ['Fuzzify1639'], 7, 4],
#                'Select1825': ['Select', ['Fuzzify1638'], 3, 1],
#                'Select1826': ['Select', ['Fuzzify1639'], 7, 5],
#                'Select1837': ['Select', ['Fuzzify1638'], 3, 1],
#                'Select1838': ['Select', ['Fuzzify1639'], 7, 6],
#                'Select1849': ['Select', ['Fuzzify1638'], 3, 2],
#                'Select1850': ['Select', ['Fuzzify1639'], 7, 0],
#                'Select1861': ['Select', ['Fuzzify1638'], 3, 2],
#                'Select1862': ['Select', ['Fuzzify1639'], 7, 1],
#                'Select1873': ['Select', ['Fuzzify1638'], 3, 2],
#                'Select1874': ['Select', ['Fuzzify1639'], 7, 2],
#                'Select1885': ['Select', ['Fuzzify1638'], 3, 2],
#                'Select1886': ['Select', ['Fuzzify1639'], 7, 3],
#                'Select1897': ['Select', ['Fuzzify1638'], 3, 2],
#                'Select1898': ['Select', ['Fuzzify1639'], 7, 4],
#                'Select1909': ['Select', ['Fuzzify1638'], 3, 2],
#                'Select1910': ['Select', ['Fuzzify1639'], 7, 5],
#                'Select1921': ['Select', ['Fuzzify1638'], 3, 2],
#                'Select1922': ['Select', ['Fuzzify1639'], 7, 6],
#                'Select1948': ['Select', ['Fuzzify1947'], 7, 0],
#                'Select1949': ['Select', ['Fuzzify1639'], 7, 0],
#                'Select1953': ['Select', ['Fuzzify1947'], 7, 0],
#                'Select1954': ['Select', ['Fuzzify1639'], 7, 1],
#                'Select1958': ['Select', ['Fuzzify1947'], 7, 0],
#                'Select1959': ['Select', ['Fuzzify1639'], 7, 2],
#                'Select1963': ['Select', ['Fuzzify1947'], 7, 0],
#                'Select1964': ['Select', ['Fuzzify1639'], 7, 3],
#                'Select1968': ['Select', ['Fuzzify1947'], 7, 0],
#                'Select1969': ['Select', ['Fuzzify1639'], 7, 4],
#                'Select1973': ['Select', ['Fuzzify1947'], 7, 0],
#                'Select1974': ['Select', ['Fuzzify1639'], 7, 5],
#                'Select1978': ['Select', ['Fuzzify1947'], 7, 0],
#                'Select1979': ['Select', ['Fuzzify1639'], 7, 6],
#                'Select1983': ['Select', ['Fuzzify1947'], 7, 1],
#                'Select1984': ['Select', ['Fuzzify1639'], 7, 0],
#                'Select1988': ['Select', ['Fuzzify1947'], 7, 1],
#                'Select1989': ['Select', ['Fuzzify1639'], 7, 1],
#                'Select1993': ['Select', ['Fuzzify1947'], 7, 1],
#                'Select1994': ['Select', ['Fuzzify1639'], 7, 2],
#                'Select1998': ['Select', ['Fuzzify1947'], 7, 1],
#                'Select1999': ['Select', ['Fuzzify1639'], 7, 3],
#                'Select2003': ['Select', ['Fuzzify1947'], 7, 1],
#                'Select2004': ['Select', ['Fuzzify1639'], 7, 4],
#                'Select2008': ['Select', ['Fuzzify1947'], 7, 1],
#                'Select2009': ['Select', ['Fuzzify1639'], 7, 5],
#                'Select2013': ['Select', ['Fuzzify1947'], 7, 1],
#                'Select2014': ['Select', ['Fuzzify1639'], 7, 6],
#                'Select2018': ['Select', ['Fuzzify1947'], 7, 2],
#                'Select2019': ['Select', ['Fuzzify1639'], 7, 0],
#                'Select2023': ['Select', ['Fuzzify1947'], 7, 2],
#                'Select2024': ['Select', ['Fuzzify1639'], 7, 1],
#                'Select2028': ['Select', ['Fuzzify1947'], 7, 2],
#                'Select2029': ['Select', ['Fuzzify1639'], 7, 2],
#                'Select2033': ['Select', ['Fuzzify1947'], 7, 2],
#                'Select2034': ['Select', ['Fuzzify1639'], 7, 3],
#                'Select2038': ['Select', ['Fuzzify1947'], 7, 2],
#                'Select2039': ['Select', ['Fuzzify1639'], 7, 4],
#                'Select2043': ['Select', ['Fuzzify1947'], 7, 2],
#                'Select2044': ['Select', ['Fuzzify1639'], 7, 5],
#                'Select2048': ['Select', ['Fuzzify1947'], 7, 2],
#                'Select2049': ['Select', ['Fuzzify1639'], 7, 6],
#                'Select2053': ['Select', ['Fuzzify1947'], 7, 3],
#                'Select2054': ['Select', ['Fuzzify1639'], 7, 0],
#                'Select2058': ['Select', ['Fuzzify1947'], 7, 3],
#                'Select2059': ['Select', ['Fuzzify1639'], 7, 1],
#                'Select2063': ['Select', ['Fuzzify1947'], 7, 3],
#                'Select2064': ['Select', ['Fuzzify1639'], 7, 2],
#                'Select2068': ['Select', ['Fuzzify1947'], 7, 3],
#                'Select2069': ['Select', ['Fuzzify1639'], 7, 3],
#                'Select2073': ['Select', ['Fuzzify1947'], 7, 3],
#                'Select2074': ['Select', ['Fuzzify1639'], 7, 4],
#                'Select2078': ['Select', ['Fuzzify1947'], 7, 3],
#                'Select2079': ['Select', ['Fuzzify1639'], 7, 5],
#                'Select2083': ['Select', ['Fuzzify1947'], 7, 3],
#                'Select2084': ['Select', ['Fuzzify1639'], 7, 6],
#                'Select2088': ['Select', ['Fuzzify1947'], 7, 4],
#                'Select2089': ['Select', ['Fuzzify1639'], 7, 0],
#                'Select2093': ['Select', ['Fuzzify1947'], 7, 4],
#                'Select2094': ['Select', ['Fuzzify1639'], 7, 1],
#                'Select2098': ['Select', ['Fuzzify1947'], 7, 4],
#                'Select2099': ['Select', ['Fuzzify1639'], 7, 2],
#                'Select2103': ['Select', ['Fuzzify1947'], 7, 4],
#                'Select2104': ['Select', ['Fuzzify1639'], 7, 3],
#                'Select2108': ['Select', ['Fuzzify1947'], 7, 4],
#                'Select2109': ['Select', ['Fuzzify1639'], 7, 4],
#                'Select2113': ['Select', ['Fuzzify1947'], 7, 4],
#                'Select2114': ['Select', ['Fuzzify1639'], 7, 5],
#                'Select2118': ['Select', ['Fuzzify1947'], 7, 4],
#                'Select2119': ['Select', ['Fuzzify1639'], 7, 6],
#                'Select2123': ['Select', ['Fuzzify1947'], 7, 5],
#                'Select2124': ['Select', ['Fuzzify1639'], 7, 0],
#                'Select2128': ['Select', ['Fuzzify1947'], 7, 5],
#                'Select2129': ['Select', ['Fuzzify1639'], 7, 1],
#                'Select2133': ['Select', ['Fuzzify1947'], 7, 5],
#                'Select2134': ['Select', ['Fuzzify1639'], 7, 2],
#                'Select2138': ['Select', ['Fuzzify1947'], 7, 5],
#                'Select2139': ['Select', ['Fuzzify1639'], 7, 3],
#                'Select2143': ['Select', ['Fuzzify1947'], 7, 5],
#                'Select2144': ['Select', ['Fuzzify1639'], 7, 4],
#                'Select2148': ['Select', ['Fuzzify1947'], 7, 5],
#                'Select2149': ['Select', ['Fuzzify1639'], 7, 5],
#                'Select2153': ['Select', ['Fuzzify1947'], 7, 5],
#                'Select2154': ['Select', ['Fuzzify1639'], 7, 6],
#                'Select2158': ['Select', ['Fuzzify1947'], 7, 6],
#                'Select2159': ['Select', ['Fuzzify1639'], 7, 0],
#                'Select2163': ['Select', ['Fuzzify1947'], 7, 6],
#                'Select2164': ['Select', ['Fuzzify1639'], 7, 1],
#                'Select2168': ['Select', ['Fuzzify1947'], 7, 6],
#                'Select2169': ['Select', ['Fuzzify1639'], 7, 2],
#                'Select2173': ['Select', ['Fuzzify1947'], 7, 6],
#                'Select2174': ['Select', ['Fuzzify1639'], 7, 3],
#                'Select2178': ['Select', ['Fuzzify1947'], 7, 6],
#                'Select2179': ['Select', ['Fuzzify1639'], 7, 4],
#                'Select2183': ['Select', ['Fuzzify1947'], 7, 6],
#                'Select2184': ['Select', ['Fuzzify1639'], 7, 5],
#                'Select2188': ['Select', ['Fuzzify1947'], 7, 6],
#                'Select2189': ['Select', ['Fuzzify1639'], 7, 6]},
#  'States': {}}
# ================================================================================

# %% [markdown]
# ## Training and validation datasets

# %%
# Pass the training and the validation datasets to the nnodely structure
data_struct = ['ay','ax','vx','curv','steer_target','',''] 
steer_controller_extended.loadData(name='Training', source=data_folder_train, format=data_struct, skiplines=1)
steer_controller_extended.loadData(name='Validation', source=data_folder_valid, format=data_struct, skiplines=1)

# check the definition of the windows in the inputs and outputs
#samples_test_set = steer_controller_extended.get_samples('training_set', index=100, window=1) 
#print(samples_test_set)
# Out:
# ============================ nnodely Model Dataset =============================
# Dataset Name:                 Training
# Number of files:              1
# Total number of samples:      2787
# Shape of ax:                  (2787, 15, 1)
# Shape of vx:                  (2787, 15, 1)
# Shape of ay:                  (2787, 15, 1)
# Shape of curv:                (2787, 15, 1)
# Shape of steer_target:        (2787, 1, 1)
# ================================================================================
# ============================ nnodely Model Dataset =============================
# Dataset Name:                 Validation
# Number of files:              1
# Total number of samples:      1987
# Shape of ax:                  (1987, 15, 1)
# Shape of vx:                  (1987, 15, 1)
# Shape of ay:                  (1987, 15, 1)
# Shape of curv:                (1987, 15, 1)
# Shape of steer_target:        (1987, 1, 1)
# ================================================================================
# ============================ nnodely Model Dataset =============================
# Dataset Name:                 Test
# Number of files:              4
# Total number of samples:      9945
# Shape of ax:                  (9945, 15, 1)
# Shape of vx:                  (9945, 15, 1)
# Shape of ay:                  (9945, 15, 1)
# Shape of curv:                (9945, 15, 1)
# Shape of steer_target:        (9945, 1, 1)
# ================================================================================

# %% [markdown]
# ## Training

# %%
num_epochs = 8000
batch_size = 1000
learn_rate = learning_rate  # learning rate
early_stop_patience = 1500
training_pars = {'num_of_epochs':num_epochs, 
                 'val_batch_size':batch_size, 
                 'train_batch_size':batch_size, 
                 'lr':learn_rate}

flag_train_now = 1
if flag_train_now:
  train_result = steer_controller_extended.trainModel(train_dataset='Training', validation_dataset='Validation',
                                                      training_params=training_pars, optimizer='Adam', shuffle_data=True,
                                                      early_stopping=earlystopping.early_stop_patience,  
                                                      early_stopping_params={'patience':early_stop_patience,
                                                                              'error':'steer_error'})  
else:
  # Load the trained model
  steer_controller_extended.loadModel()
# Out:
# ======================== nnodely Model Train Parameters ========================
# models:                       ['steer_ctrl']
# num of epochs:                8000
# update per epochs:            2.787
# └>(n_samples-batch_size)/batch_size+1
# shuffle data:                 True
# early stopping:               early_stop_patience
# early stopping params:        {'error': 'steer_error', 'patience': 1500}
# train dataset:                Training
# 	- num of samples:            2787
# 	- batch size:                1000
# 	- unused samples:            0.0
# 	  └>n_samples-update_per_epochs*batch_size
# val dataset:                  Validation
# val {batch size, samples}:    {1000, 1987}
# minimizers:                   {'steer_error': {'A': 'SamplePart2243',
#                                                'B': 'steering_angle',
#                                                'loss': 'rmse'}}
# optimizer:                    Adam
# optimizer defaults:           {'lr': 0.001}
# optimizer params:             [{'params': 'PFir307p'},
#                                {'params': 'PFir308p'},
#                                {'params': 'PFir309p'},
#                                {'params': 'PFir310p'},
#                                {'params': 'PFir311p'},
#                                {'params': 'PFir312p'},
#                                {'params': 'PFir313p'},
#                                {'params': 'PFir314p'},
#                                {'params': 'PFir315p'},
#                                {'params': 'PFir316p'},
#                                {'params': 'PFir317p'},
#                                {'params': 'PFir318p'},
#                                {'params': 'PFir319p'},
#                                {'params': 'PFir320p'},
#                                {'params': 'PFir321p'},
#                                {'params': 'PFir322p'},
#                                {'params': 'PFir323p'},
#                                {'params': 'PFir324p'},
#                                {'params': 'PFir325p'},
#                                {'params': 'PFir326p'},
#                                {'params': 'PFir327p'},
#                                {'params': 'PFir328p'},
#                                {'params': 'PFir329p'},
#                                {'params': 'PFir330p'},
#                                {'params': 'PFir331p'},
#                                {'params': 'PFir332p'},
#                                {'params': 'PFir333p'},
#                                {'params': 'PFir334p'},
#                                {'params': 'PFir335p'},
#                                {'params': 'PFir336p'},
#                                {'params': 'PFir337p'},
#                                {'params': 'PFir338p'},
#                                {'params': 'PFir339p'},
#                                {'params': 'PFir340p'},
#                                {'params': 'PFir341p'},
#                                {'params': 'PFir342p'},
#                                {'params': 'PFir343p'},
#                                {'params': 'PFir344p'},
#                                {'params': 'PFir345p'},
#                                {'params': 'PFir346p'},
#                                {'params': 'PFir347p'},
#                                {'params': 'PFir348p'},
#                                {'params': 'PFir349p'},
#                                {'params': 'PFir350p'},
#                                {'params': 'PFir351p'},
#                                {'params': 'PFir352p'},
#                                {'params': 'PFir353p'},
#                                {'params': 'PFir354p'},
#                                {'params': 'PFir355p'},
#                                {'params': 'S_ax_0'},
#                                {'params': 'S_ax_1'},
#                                {'params': 'S_ax_2'},
#                                {'params': 'S_ax_3'},
#                                {'params': 'S_ax_4'},
#                                {'params': 'S_ax_5'},
#                                {'params': 'S_ax_6'},
#                                {'params': 'S_ay_0'},
#                                {'params': 'S_ay_1'},
#                                {'params': 'S_ay_2'},
#                                {'params': 'k1_vx_0'},
#                                {'params': 'k1_vx_1'},
#                                {'params': 'k1_vx_2'},
#                                {'params': 'k2_vx_0'},
#                                {'params': 'k2_vx_1'},
#                                {'params': 'k2_vx_2'}]
# ================================================================================
# ================= nnodely Training =================
# |  Epoch   |    steer_error    |       Total       |
# |          |        Loss       |        Loss       |
# |          |  train  |   val   |  train  |   val   |
# |--------------------------------------------------|
# | 10
# |1590/8000 |1.223e-03|3.459e-03|1.223e-03|3.459e-03|
# |1600/8000 |1.237e-03|3.509e-03|1.237e-03|3.509e-03|
# |1610/8000 |1.216e-03|3.418e-03|1.216e-03|3.418e-03|
# |1620/8000 |1.217e-03|3.511e-03|1.217e-03|3.511e-03|
# |1629/8000 | 1.21e-03|3.471e-03| 1.21e-03|3.471e-03|Stopping the training at epoch 1629 due to early stopping.
# ============================ nnodely Training Time =============================
# Total time of Training:       459.2986190319061
# ================================================================================
# The selected model is the LAST model of the training.
# =================== nnodely Model Results for Training ==================
# |    Loss   |        rmse       |        FVU        |        AIC        |
# |           |    small better   |    small better   |    lower better   |
# |-----------------------------------------------------------------------|
# |steer_error|     1.165e-03     |     9.128e-04     |     -1.974e+04    |
# |-----------------------------------------------------------------------|
# |   Total   |     1.165e-03     |     9.128e-04     |     -1.974e+04    |
# |-----------------------------------------------------------------------|
# ================== nnodely Model Results for Validation =================
# |    Loss   |        rmse       |        FVU        |        AIC        |
# |           |    small better   |    small better   |    lower better   |
# |-----------------------------------------------------------------------|
# |steer_error|     3.482e-03     |     6.043e-03     |     -6.882e+03    |
# |-----------------------------------------------------------------------|
# |   Total   |     3.482e-03     |     6.043e-03     |     -6.882e+03    |
# |-----------------------------------------------------------------------|

# %%
# Print the trained NN parameters
steer_controller_extended.neuralizeModel()

with open("Results.txt", "a") as file:
    file.write("\n Model with seed  "+ str(num_seed) + ' ax ' + str(num_channels_ax) + ' vx ' + str(num_channels_vx) + ' future_steer ' + str(num_samples_future_feedfw) + ' learning rate ' + str(learning_rate)  + ' Results ' + str(steer_controller_extended.performance))
# Out:
# ================================ nnodely Model =================================
# {'Constants': {'Constant252': {'dim': 1, 'values': 63.58073043823242},
#                'Constant257': {'dim': 1, 'values': -17.478992462158203},
#                'Constant258': {'dim': 1, 'values': 17.478992462158203},
#                'Constant262': {'dim': 1, 'values': -0.06789737194776535},
#                'Constant263': {'dim': 1, 'values': 0.06789737194776535},
#                'Constant267': {'dim': 1, 'values': -16.80176544189453},
#                'Constant268': {'dim': 1, 'values': 8.896745681762695},
#                'L': {'dim': 1, 'values': 3.115000009536743},
#                'ax_center_0': {'dim': 1, 'values': -17.30176544189453},
#                'ax_center_1': {'dim': 1, 'values': -11.534510612487793},
#                'ax_center_2': {'dim': 1, 'values': -5.7672553062438965},
#                'ax_center_3': {'dim': 1, 'values': 0.0},
#                'ax_center_4': {'dim': 1, 'values': 3.132248640060425},
#                'ax_center_5': {'dim': 1, 'values': 6.26449728012085},
#                'ax_center_6': {'dim': 1, 'values': 9.396745681762695},
#                'ay_center_0': {'dim': 1, 'values': 0.0},
#                'ay_center_1': {'dim': 1, 'values': 9.239496231079102},
#                'ay_center_2': {'dim': 1, 'values': 18.478992462158203}},
#  'Functions': {'FFuzzify275': {'centers': [0.0,
#                                            9.2394963801102,
#                                            18.4789927602204],
#                                'dim_out': {'dim': 3},
#                                'functions': 'Triangular',
#                                'names': 'Triangular'},
#                'FFuzzify276': {'centers': [-17.301766327676518,
#                                            -11.53451088511768,
#                                            -5.76725544255884,
#                                            0.0,
#                                            3.1322487136579653,
#                                            6.264497427315931,
#                                            9.396746140973896],
#                                'dim_out': {'dim': 7},
#                                'functions': 'Triangular',
#                                'names': 'Triangular'},
#                'FFuzzify305': {'centers': [9.0,
#                                            22.5,
#                                            36.0,
#                                            49.5,
#                                            63.0,
#                                            76.5,
#                                            90.0],
#                                'dim_out': {'dim': 7},
#                                'functions': 'Triangular',
#                                'names': 'Triangular'},
#                'FParamFun250': {'code': 'def normalize_fun(x,x_max):\n'
#                                         '  return x/x_max\n',
#                                 'in_dim': [{'dim': 1, 'sw': 15}, {'dim': 1}],
#                                 'map_over_dim': False,
#                                 'n_input': 2,
#                                 'name': 'normalize_fun',
#                                 'out_dim': {'dim': 1, 'sw': 15},
#                                 'params_and_consts': []},
#                'FParamFun254': {'code': 'def sat_fun(x,x_min,x_max):\n'
#                                         '  return '
#                                         'torch.min(torch.max(x,x_min),x_max)\n',
#                                 'in_dim': [{'dim': 1, 'sw': 15},
#                                            {'dim': 1},
#                                            {'dim': 1}],
#                                 'map_over_dim': False,
#                                 'n_input': 3,
#                                 'name': 'sat_fun',
#                                 'out_dim': {'dim': 1, 'sw': 15},
#                                 'params_and_consts': []},
#                'FParamFun259': {'code': 'def sat_fun(x,x_min,x_max):\n'
#                                         '  return '
#                                         'torch.min(torch.max(x,x_min),x_max)\n',
#                                 'in_dim': [{'dim': 1, 'sw': 15},
#                                            {'dim': 1},
#                                            {'dim': 1}],
#                                 'map_over_dim': False,
#                                 'n_input': 3,
#                                 'name': 'sat_fun',
#                                 'out_dim': {'dim': 1, 'sw': 15},
#                                 'params_and_consts': []},
#                'FParamFun264': {'code': 'def sat_fun(x,x_min,x_max):\n'
#                                         '  return '
#                                         'torch.min(torch.max(x,x_min),x_max)\n',
#                                 'in_dim': [{'dim': 1, 'sw': 15},
#                                            {'dim': 1},
#                                            {'dim': 1}],
#                                 'map_over_dim': False,
#                                 'n_input': 3,
#                                 'name': 'sat_fun',
#                                 'out_dim': {'dim': 1, 'sw': 15},
#                                 'params_and_consts': []},
#                'FParamFun274': {'code': 'def abs_fun(x):\n'
#                                         '  return torch.abs(x)\n',
#                                 'in_dim': [{'dim': 1, 'sw': 15}],
#                                 'map_over_dim': False,
#                                 'n_input': 1,
#                                 'name': 'abs_fun',
#                                 'out_dim': {'dim': 1, 'sw': 15},
#                                 'params_and_consts': []},
#                'FParamFun303': {'code': 'def '
#                                         'handling_diagr_local(curv,ay,ax,vx_norm,  '
#                                         '# inputs\n'
#                                         '                         '
#                                         'ay_0,ax_0,L,       # constants\n'
#                                         '                         '
#                                         'k1_vx,k2_vx,            # learnable '
#                                         'arrays of parameters\n'
#                                         '                         '
#                                         'S_ay,S_ax          # learnable arrays '
#                                         'of parameters\n'
#                                         '                         ):\n'
#                                         '  sign_ay = torch.sign(ay)  # sign of '
#                                         'the lateral acceleration\n'
#                                         '\n'
#                                         '  # compute k1, as a function of vx \n'
#                                         '  k1_vx_fun = k1_vx[0,0,0]\n'
#                                         '  for ii in range(1,k1_vx.size(2)):\n'
#                                         '    k1_vx_fun = k1_vx_fun + '
#                                         'k1_vx[0,0,ii]*torch.pow(vx_norm,ii)\n'
#                                         '\n'
#                                         '  # compute k2, as a function of vx\n'
#                                         '  k2_vx_fun = k2_vx[0,0,0]\n'
#                                         '  for ii in range(1,k2_vx.size(2)):\n'
#                                         '    k2_vx_fun = k2_vx_fun + '
#                                         'k2_vx[0,0,ii]*torch.pow(vx_norm,ii)\n'
#                                         '\n'
#                                         '  # learnable weights of the local '
#                                         'model for ay around ay_0\n'
#                                         '  S_ay_1 = S_ay[0,0,0]\n'
#                                         '  S_ay_2 = S_ay[0,0,1]\n'
#                                         '  S_ay_3 = S_ay[0,0,2]\n'
#                                         '  S_ay_4 = S_ay[0,0,3]\n'
#                                         '\n'
#                                         '  # learnable weights of the local '
#                                         'model for ax around ax_0\n'
#                                         '  S_ax_1 = S_ax[0,0,0]\n'
#                                         '  S_ax_2 = S_ax[0,0,1]\n'
#                                         '  S_ax_3 = S_ax[0,0,2]\n'
#                                         '  S_ax_4 = S_ax[0,0,3]\n'
#                                         '  S_ax_5 = S_ax[0,0,4]\n'
#                                         '\n'
#                                         '  # output of the local model of the '
#                                         'handling diagram\n'
#                                         '  output = curv*L + k1_vx_fun*sign_ay '
#                                         '+ k2_vx_fun*(ay - ay_0*sign_ay) +\\\n'
#                                         '           S_ay_1*S_ax_1*(ay - '
#                                         '(ay_0+S_ay_2)*sign_ay)*(S_ax_2 + ax - '
#                                         'ax_0)*(1 + \\\n'
#                                         '           S_ay_3*(ay - ay_0*sign_ay) '
#                                         '+ S_ax_3*(ax - ax_0) + S_ax_4*(ax - '
#                                         'ax_0)**2 + \\\n'
#                                         '           S_ay_4*S_ax_5*(ay - '
#                                         'ay_0*sign_ay)*(ax - ax_0))\n'
#                                         '  return output\n',
#                                 'in_dim': [{'dim': 1, 'sw': 15},
#                                            {'dim': 1, 'sw': 15},
#                                            {'dim': 1, 'sw': 15},
#                                            {'dim': 1, 'sw': 15},
#                                            {'dim': 1},
#                                            {'dim': 1},
#                                            {'dim': 1},
#                                            {'dim': [1, 4], 'sw': 1},
#                                            {'dim': [1, 2], 'sw': 1},
#                                            {'dim': [1, 4], 'sw': 1},
#                                            {'dim': [1, 5], 'sw': 1}],
#                                 'map_over_dim': False,
#                                 'n_input': 11,
#                                 'name': 'handling_diagr_local',
#                                 'out_dim': {'dim': 1, 'sw': 15},
#                                 'params_and_consts': []}},
#  'Info': {'SampleTime': 1, 'ns': [0, 15], 'ntot': 15},
#  'Inputs': {'ax': {'dim': 1,
#                    'ns': [0, 15],
#                    'ntot': 15,
#                    'sw': [0, 15],
#                    'tw': [0, 0]},
#             'ay': {'dim': 1,
#                    'ns': [0, 15],
#                    'ntot': 15,
#                    'sw': [0, 15],
#                    'tw': [0, 0]},
#             'curv': {'dim': 1,
#                      'ns': [0, 15],
#                      'ntot': 15,
#                      'sw': [0, 15],
#                      'tw': [0, 0]},
#             'steer_target': {'dim': 1,
#                              'ns': [0, 1],
#                              'ntot': 1,
#                              'sw': [0, 1],
#                              'tw': [0, 0]},
#             'vx': {'dim': 1,
#                    'ns': [0, 15],
#                    'ntot': 15,
#                    'sw': [0, 15],
#                    'tw': [0, 0]}},
#  'Minimizers': {'steer_error': {'A': 'SamplePart2243',
#                                 'B': 'steering_angle',
#                                 'loss': 'rmse'}},
#  'Models': 'steer_ctrl',
#  'Outputs': {'steering_angle': 'Add2240'},
#  'Parameters': {'PFir307p': {'dim': 1,
#                              'sw': 15,
#                              'values': [[1.1235707998275757],
#                                         [1.64242684841156],
#                                         [1.1555585861206055],
#                                         [1.5400501489639282],
#                                         [1.0588315725326538],
#                                         [1.2798386812210083],
#                                         [0.027488475665450096],
#                                         [0.22317318618297577],
#                                         [0.5261502265930176],
#                                         [0.15705259144306183],
#                                         [-0.31784287095069885],
#                                         [-0.060678429901599884],
#                                         [0.1653723418712616],
#                                         [-0.8504836559295654],
#                                         [-0.9274383783340454]]},
#                 'PFir308p': {'dim': 1,
#                              'sw': 15,
#                              'values': [[0.39590543508529663],
#                                         [0.5405651330947876],
#                                         [0.651716947555542],
#                                         [0.5313789248466492],
#                                         [0.09160537272691727],
#                                         [0.16609857976436615],
#                                         [0.0566161684691906],
#                                         [-0.0469822958111763],
#                                         [0.017309777438640594],
#                                         [-0.14259900152683258],
#                                         [0.21749909222126007],
#                                         [0.0713634118437767],
#                                         [0.15983209013938904],
#                                         [0.10146268457174301],
#                                         [0.0463879369199276]]},
#                 'PFir309p': {'dim': 1,
#                              'sw': 15,
#                              'values': [[0.09905633330345154],
#                                         [0.22608765959739685],
#                                         [0.15310153365135193],
#                                         [0.09921088814735413],
#                                         [0.04034195840358734],
#                                         [0.004593436140567064],
#                                         [0.015207636170089245],
#                                         [0.0754064992070198],
#                                         [0.030696986243128777],
#                                         [0.05750643461942673],
#                                         [0.059418436139822006],
#                                         [0.05477185174822807],
#                                         [-0.025322504341602325],
#                                         [-0.02961031347513199],
#                                         [-0.008711514063179493]]},
#                 'PFir310p': {'dim': 1,
#                              'sw': 15,
#                              'values': [[0.13226227462291718],
#                                         [0.21100273728370667],
#                                         [0.20090968906879425],
#                                         [0.1832532435655594],
#                                         [0.1368207186460495],
#                                         [0.10903901606798172],
#                                         [0.07898123562335968],
#                                         [0.04174326732754707],
#                                         [0.04685691371560097],
#                                         [0.03184952959418297],
#                                         [0.016016684472560883],
#                                         [-0.015923716127872467],
#                                         [-0.024426884949207306],
#                                         [-0.0405103899538517],
#                                         [-0.0476318821310997]]},
#                 'PFir311p': {'dim': 1,
#                              'sw': 15,
#                              'values': [[0.14880488812923431],
#                                         [0.18956001102924347],
#                                         [0.21041812002658844],
#                                         [0.1396017223596573],
#                                         [0.12996989488601685],
#                                         [0.0860559493303299],
#                                         [0.0957711860537529],
#                                         [0.05755174532532692],
#                                         [0.01392949279397726],
#                                         [-0.0028127534314990044],
#                                         [0.006185348145663738],
#                                         [0.02254619263112545],
#                                         [-0.026639314368367195],
#                                         [0.024955132976174355],
#                                         [-0.032736558467149734]]},
#                 'PFir312p': {'dim': 1,
#                              'sw': 15,
#                              'values': [[0
': {'dim': 1,
#                              'sw': 15,
#                              'values': [[0.0469040647149086],
#                                         [0.06784859299659729],
#                                         [0.11810970306396484],
#                                         [0.05434179678559303],
#                                         [0.06957939267158508],
#                                         [0.039527926594018936],
#                                         [0.03976020589470863],
#                                         [0.03522123023867607],
#                                         [0.031995803117752075],
#                                         [0.05262510105967522],
#                                         [0.012847569771111012],
#                                         [0.018260089680552483],
#                                         [0.027289729565382004],
#                                         [0.051342759281396866],
#                                         [0.0654335469007492]]},
#                 'PFir339p': {'dim': 1,
#                              'sw': 15,
#                              'values': [[-0.13265006244182587],
#                                         [-0.0038834474980831146],
#                                         [-0.01151411235332489],
#                                         [0.03305239975452423],
#                                         [0.024684475734829903],
#                                         [0.007095688953995705],
#                                         [-0.015030909329652786],
#                                         [-0.004031269811093807],
#                                         [-0.017478972673416138],
#                                         [0.024826567620038986],
#                                         [0.01564048044383526],
#                                         [-0.001070747384801507],
#                                         [0.01188975665718317],
#                                         [0.028336981311440468],
#                                         [0.04820674657821655]]},
#                 'PFir340p': {'dim': 1,
#                              'sw': 15,
#                              'values': [[-0.15256303548812866],
#                                         [0.22625647485256195],
#                                         [0.1148219183087349],
#                                         [0.08801738172769547],
#                                         [0.0411716029047966],
#                                         [0.003272261703386903],
#                                         [-0.09758974611759186],
#                                         [-0.09157564491033554],
#                                         [0.4659143090248108],
#                                         [-0.27779924869537354],
#                                         [-0.4945806562900543],
#                                         [-0.46518996357917786],
#                                         [-0.29751646518707275],
#                                         [-0.8027191758155823],
#                                         [-0.9419190883636475]]},
#                 'PFir341p': {'dim': 1,
#                              'sw': 15,
#                              'values': [[0.0001624345313757658],
#                                         [0.00011365098180249333],
#                                         [7.951847510412335e-05],
#                                         [5.563689046539366e-05],
#                                         [3.892760651069693e-05],
#                                         [2.723657598835416e-05],
#                                         [1.9056684323004447e-05],
#                                         [1.3333438801055308e-05],
#                                         [9.329040949523915e-06],
#                                         [6.527273853862425e-06],
#                                         [4.5669539758819155e-06],
#                                         [3.1953723009792157e-06],
#                                         [2.2357144189300016e-06],
#                                         [1.5642679045413388e-06],
#                                         [1.0944753512376337e-06]]},
#                 'PFir342p': {'dim': 1,
#                              'sw': 15,
#                              'values': [[0.0001624345313757658],
#                                         [0.00011365098180249333],
# ...
#                                  'k2_vx_1',
#                                  'S_ay_1',
#                                  'S_ax_3'],
#                                 'FParamFun303'],
#                'ParamFun1805': ['ParamFun',
#                                 ['ParamFun1606',
#                                  'ParamFun1595',
#                                  'ParamFun1617',
#                                  'ParamFun1585',
#                                  'ay_center_1',
#                                  'ax_center_4',
#                                  'L',
#                                  'k1_vx_1',
#                                  'k2_vx_1',
#                                  'S_ay_1',
#                                  'S_ax_4'],
#                                 'FParamFun303'],
#                'ParamFun1817': ['ParamFun',
#                                 ['ParamFun1606',
#                                  'ParamFun1595',
#                                  'ParamFun1617',
#                                  'ParamFun1585',
#                                  'ay_center_1',
#                                  'ax_center_5',
#                                  'L',
#                                  'k1_vx_1',
#                                  'k2_vx_1',
#                                  'S_ay_1',
#                                  'S_ax_5'],
#                                 'FParamFun303'],
#                'ParamFun1829': ['ParamFun',
#                                 ['ParamFun1606',
#                                  'ParamFun1595',
#                                  'ParamFun1617',
#                                  'ParamFun1585',
#                                  'ay_center_1',
#                                  'ax_center_6',
#                                  'L',
#                                  'k1_vx_1',
#                                  'k2_vx_1',
#                                  'S_ay_1',
#                                  'S_ax_6'],
#                                 'FParamFun303'],
#                'ParamFun1841': ['ParamFun',
#                                 ['ParamFun1606',
#                                  'ParamFun1595',
#                                  'ParamFun1617',
#                                  'ParamFun1585',
#                                  'ay_center_2',
#                                  'ax_center_0',
#                                  'L',
#                                  'k1_vx_2',
#                                  'k2_vx_2',
#                                  'S_ay_2',
#                                  'S_ax_0'],
#                                 'FParamFun303'],
#                'ParamFun1853': ['ParamFun',
#                                 ['ParamFun1606',
#                                  'ParamFun1595',
#                                  'ParamFun1617',
#                                  'ParamFun1585',
#                                  'ay_center_2',
#                                  'ax_center_1',
#                                  'L',
#                                  'k1_vx_2',
#                                  'k2_vx_2',
#                                  'S_ay_2',
#                                  'S_ax_1'],
#                                 'FParamFun303'],
#                'ParamFun1865': ['ParamFun',
#                                 ['ParamFun1606',
#                                  'ParamFun1595',
#                                  'ParamFun1617',
#                                  'ParamFun1585',
#                                  'ay_center_2',
#                                  'ax_center_2',
#                                  'L',
#                                  'k1_vx_2',
#                                  'k2_vx_2',
#                                  'S_ay_2',
#                                  'S_ax_2'],
#                                 'FParamFun303'],
#                'ParamFun1877': ['ParamFun',
#                                 ['ParamFun1606',
#                                  'ParamFun1595',
#                                  'ParamFun1617',
#                                  'ParamFun1585',
#                                  'ay_center_2',
#                                  'ax_center_3',
#                                  'L',
#                                  'k1_vx_2',
#                                  'k2_vx_2',
#                                  'S_ay_2',
#                                  'S_ax_3'],
#                                 'FParamFun303'],
#                'ParamFun1889': ['ParamFun',
#                                 ['ParamFun1606',
#                                  'ParamFun1595',
#                                  'ParamFun1617',
#                                  'ParamFun1585',
#                                  'ay_center_2',
#                                  'ax_center_4',
#                                  'L',
#                                  'k1_vx_2',
#                                  'k2_vx_2',
#                                  'S_ay_2',
#                                  'S_ax_4'],
#                                 'FParamFun303'],
#                'ParamFun1901': ['ParamFun',
#                                 ['ParamFun1606',
#                                  'ParamFun1595',
#                                  'ParamFun1617',
#                                  'ParamFun1585',
#                                  'ay_center_2',
#                                  'ax_center_5',
#                                  'L',
#                                  'k1_vx_2',
#                                  'k2_vx_2',
#                                  'S_ay_2',
#                                  'S_ax_5'],
#                                 'FParamFun303'],
#                'ParamFun1913': ['ParamFun',
#                                 ['ParamFun1606',
#                                  'ParamFun1595',
#                                  'ParamFun1617',
#                                  'ParamFun1585',
#                                  'ay_center_2',
#                                  'ax_center_6',
#                                  'L',
#                                  'k1_vx_2',
#                                  'k2_vx_2',
#                                  'S_ay_2',
#                                  'S_ax_6'],
#                                 'FParamFun303'],
#                'SamplePart1584': ['SamplePart', ['vx'], -1, [0, 15]],
#                'SamplePart1594': ['SamplePart', ['ay'], -1, [0, 15]],
#                'SamplePart1605': ['SamplePart', ['curv'], -1, [0, 15]],
#                'SamplePart1616': ['SamplePart', ['ax'], -1, [0, 15]],
#                'SamplePart1946': ['SamplePart', ['vx'], -1, [0, 15]],
#                'SamplePart2243': ['SamplePart', ['steer_target'], -1, [0, 1]],
#                'Select1681': ['Select', ['Fuzzify1638'], 3, 0],
#                'Select1682': ['Select', ['Fuzzify1639'], 7, 0],
#                'Select1693': ['Select', ['Fuzzify1638'], 3, 0],
#                'Select1694': ['Select', ['Fuzzify1639'], 7, 1],
#                'Select1705': ['Select', ['Fuzzify1638'], 3, 0],
#                'Select1706': ['Select', ['Fuzzify1639'], 7, 2],
#                'Select1717': ['Select', ['Fuzzify1638'], 3, 0],
#                'Select1718': ['Select', ['Fuzzify1639'], 7, 3],
#                'Select1729': ['Select', ['Fuzzify1638'], 3, 0],
#                'Select1730': ['Select', ['Fuzzify1639'], 7, 4],
#                'Select1741': ['Select', ['Fuzzify1638'], 3, 0],
#                'Select1742': ['Select', ['Fuzzify1639'], 7, 5],
#                'Select1753': ['Select', ['Fuzzify1638'], 3, 0],
#                'Select1754': ['Select', ['Fuzzify1639'], 7, 6],
#                'Select1765': ['Select', ['Fuzzify1638'], 3, 1],
#                'Select1766': ['Select', ['Fuzzify1639'], 7, 0],
#                'Select1777': ['Select', ['Fuzzify1638'], 3, 1],
#                'Select1778': ['Select', ['Fuzzify1639'], 7, 1],
#                'Select1789': ['Select', ['Fuzzify1638'], 3, 1],
#                'Select1790': ['Select', ['Fuzzify1639'], 7, 2],
#                'Select1801': ['Select', ['Fuzzify1638'], 3, 1],
#                'Select1802': ['Select', ['Fuzzify1639'], 7, 3],
#                'Select1813': ['Select', ['Fuzzify1638'], 3, 1],
#                'Select1814': ['Select', ['Fuzzify1639'], 7, 4],
#                'Select1825': ['Select', ['Fuzzify1638'], 3, 1],
#                'Select1826': ['Select', ['Fuzzify1639'], 7, 5],
#                'Select1837': ['Select', ['Fuzzify1638'], 3, 1],
#                'Select1838': ['Select', ['Fuzzify1639'], 7, 6],
#                'Select1849': ['Select', ['Fuzzify1638'], 3, 2],
#                'Select1850': ['Select', ['Fuzzify1639'], 7, 0],
#                'Select1861': ['Select', ['Fuzzify1638'], 3, 2],
#                'Select1862': ['Select', ['Fuzzify1639'], 7, 1],
#                'Select1873': ['Select', ['Fuzzify1638'], 3, 2],
#                'Select1874': ['Select', ['Fuzzify1639'], 7, 2],
#                'Select1885': ['Select', ['Fuzzify1638'], 3, 2],
#                'Select1886': ['Select', ['Fuzzify1639'], 7, 3],
#                'Select1897': ['Select', ['Fuzzify1638'], 3, 2],
#                'Select1898': ['Select', ['Fuzzify1639'], 7, 4],
#                'Select1909': ['Select', ['Fuzzify1638'], 3, 2],
#                'Select1910': ['Select', ['Fuzzify1639'], 7, 5],
#                'Select1921': ['Select', ['Fuzzify1638'], 3, 2],
#                'Select1922': ['Select', ['Fuzzify1639'], 7, 6],
#                'Select1948': ['Select', ['Fuzzify1947'], 7, 0],
#                'Select1949': ['Select', ['Fuzzify1639'], 7, 0],
#                'Select1953': ['Select', ['Fuzzify1947'], 7, 0],
#                'Select1954': ['Select', ['Fuzzify1639'], 7, 1],
#                'Select1958': ['Select', ['Fuzzify1947'], 7, 0],
#                'Select1959': ['Select', ['Fuzzify1639'], 7, 2],
#                'Select1963': ['Select', ['Fuzzify1947'], 7, 0],
#                'Select1964': ['Select', ['Fuzzify1639'], 7, 3],
#                'Select1968': ['Select', ['Fuzzify1947'], 7, 0],
#                'Select1969': ['Select', ['Fuzzify1639'], 7, 4],
#                'Select1973': ['Select', ['Fuzzify1947'], 7, 0],
#                'Select1974': ['Select', ['Fuzzify1639'], 7, 5],
#                'Select1978': ['Select', ['Fuzzify1947'], 7, 0],
#                'Select1979': ['Select', ['Fuzzify1639'], 7, 6],
#                'Select1983': ['Select', ['Fuzzify1947'], 7, 1],
#                'Select1984': ['Select', ['Fuzzify1639'], 7, 0],
#                'Select1988': ['Select', ['Fuzzify1947'], 7, 1],
#                'Select1989': ['Select', ['Fuzzify1639'], 7, 1],
#                'Select1993': ['Select', ['Fuzzify1947'], 7, 1],
#                'Select1994': ['Select', ['Fuzzify1639'], 7, 2],
#                'Select1998': ['Select', ['Fuzzify1947'], 7, 1],
#                'Select1999': ['Select', ['Fuzzify1639'], 7, 3],
#                'Select2003': ['Select', ['Fuzzify1947'], 7, 1],
#                'Select2004': ['Select', ['Fuzzify1639'], 7, 4],
#                'Select2008': ['Select', ['Fuzzify1947'], 7, 1],
#                'Select2009': ['Select', ['Fuzzify1639'], 7, 5],
#                'Select2013': ['Select', ['Fuzzify1947'], 7, 1],
#                'Select2014': ['Select', ['Fuzzify1639'], 7, 6],
#                'Select2018': ['Select', ['Fuzzify1947'], 7, 2],
#                'Select2019': ['Select', ['Fuzzify1639'], 7, 0],
#                'Select2023': ['Select', ['Fuzzify1947'], 7, 2],
#                'Select2024': ['Select', ['Fuzzify1639'], 7, 1],
#                'Select2028': ['Select', ['Fuzzify1947'], 7, 2],
#                'Select2029': ['Select', ['Fuzzify1639'], 7, 2],
#                'Select2033': ['Select', ['Fuzzify1947'], 7, 2],
#                'Select2034': ['Select', ['Fuzzify1639'], 7, 3],
#                'Select2038': ['Select', ['Fuzzify1947'], 7, 2],
#                'Select2039': ['Select', ['Fuzzify1639'], 7, 4],
#                'Select2043': ['Select', ['Fuzzify1947'], 7, 2],
#                'Select2044': ['Select', ['Fuzzify1639'], 7, 5],
#                'Select2048': ['Select', ['Fuzzify1947'], 7, 2],
#                'Select2049': ['Select', ['Fuzzify1639'], 7, 6],
#                'Select2053': ['Select', ['Fuzzify1947'], 7, 3],
#                'Select2054': ['Select', ['Fuzzify1639'], 7, 0],
#                'Select2058': ['Select', ['Fuzzify1947'], 7, 3],
#                'Select2059': ['Select', ['Fuzzify1639'], 7, 1],
#                'Select2063': ['Select', ['Fuzzify1947'], 7, 3],
#                'Select2064': ['Select', ['Fuzzify1639'], 7, 2],
#                'Select2068': ['Select', ['Fuzzify1947'], 7, 3],
#                'Select2069': ['Select', ['Fuzzify1639'], 7, 3],
#                'Select2073': ['Select', ['Fuzzify1947'], 7, 3],
#                'Select2074': ['Select', ['Fuzzify1639'], 7, 4],
#                'Select2078': ['Select', ['Fuzzify1947'], 7, 3],
#                'Select2079': ['Select', ['Fuzzify1639'], 7, 5],
#                'Select2083': ['Select', ['Fuzzify1947'], 7, 3],
#                'Select2084': ['Select', ['Fuzzify1639'], 7, 6],
#                'Select2088': ['Select', ['Fuzzify1947'], 7, 4],
#                'Select2089': ['Select', ['Fuzzify1639'], 7, 0],
#                'Select2093': ['Select', ['Fuzzify1947'], 7, 4],
#                'Select2094': ['Select', ['Fuzzify1639'], 7, 1],
#                'Select2098': ['Select', ['Fuzzify1947'], 7, 4],
#                'Select2099': ['Select', ['Fuzzify1639'], 7, 2],
#                'Select2103': ['Select', ['Fuzzify1947'], 7, 4],
#                'Select2104': ['Select', ['Fuzzify1639'], 7, 3],
#                'Select2108': ['Select', ['Fuzzify1947'], 7, 4],
#                'Select2109': ['Select', ['Fuzzify1639'], 7, 4],
#                'Select2113': ['Select', ['Fuzzify1947'], 7, 4],
#                'Select2114': ['Select', ['Fuzzify1639'], 7, 5],
#                'Select2118': ['Select', ['Fuzzify1947'], 7, 4],
#                'Select2119': ['Select', ['Fuzzify1639'], 7, 6],
#                'Select2123': ['Select', ['Fuzzify1947'], 7, 5],
#                'Select2124': ['Select', ['Fuzzify1639'], 7, 0],
#                'Select2128': ['Select', ['Fuzzify1947'], 7, 5],
#                'Select2129': ['Select', ['Fuzzify1639'], 7, 1],
#                'Select2133': ['Select', ['Fuzzify1947'], 7, 5],
#                'Select2134': ['Select', ['Fuzzify1639'], 7, 2],
#                'Select2138': ['Select', ['Fuzzify1947'], 7, 5],
#                'Select2139': ['Select', ['Fuzzify1639'], 7, 3],
#                'Select2143': ['Select', ['Fuzzify1947'], 7, 5],
#                'Select2144': ['Select', ['Fuzzify1639'], 7, 4],
#                'Select2148': ['Select', ['Fuzzify1947'], 7, 5],
#                'Select2149': ['Select', ['Fuzzify1639'], 7, 5],
#                'Select2153': ['Select', ['Fuzzify1947'], 7, 5],
#                'Select2154': ['Select', ['Fuzzify1639'], 7, 6],
#                'Select2158': ['Select', ['Fuzzify1947'], 7, 6],
#                'Select2159': ['Select', ['Fuzzify1639'], 7, 0],
#                'Select2163': ['Select', ['Fuzzify1947'], 7, 6],
#                'Select2164': ['Select', ['Fuzzify1639'], 7, 1],
#                'Select2168': ['Select', ['Fuzzify1947'], 7, 6],
#                'Select2169': ['Select', ['Fuzzify1639'], 7, 2],
#                'Select2173': ['Select', ['Fuzzify1947'], 7, 6],
#                'Select2174': ['Select', ['Fuzzify1639'], 7, 3],
#                'Select2178': ['Select', ['Fuzzify1947'], 7, 6],
#                'Select2179': ['Select', ['Fuzzify1639'], 7, 4],
#                'Select2183': ['Select', ['Fuzzify1947'], 7, 6],
#                'Select2184': ['Select', ['Fuzzify1639'], 7, 5],
#                'Select2188': ['Select', ['Fuzzify1947'], 7, 6],
#                'Select2189': ['Select', ['Fuzzify1639'], 7, 6]},
#  'States': {}}
# ================================================================================
# =============================== Save JSON Model ================================
# Model saved in:               c:\Users\mungi\OneDrive\Desktop\Nello\TUM_MS_NNs\nnodely-applications\My_network\A2RL\A2RL_data/trained_models\steer_controller_ax_different\net.json
# ================================================================================
