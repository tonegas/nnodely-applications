# %% [markdown]
# # Proposed Model Structured Neural network (Ablation 1 Lateral)

# %% [markdown]
# ## Initialization

# %%
import os

print('Current working directory: ',os.getcwd())
# Out:
# Current working directory:  c:\Users\mungi\OneDrive\Desktop\Nello\VSD

# %%
import sys
import os
import torch
import pandas as pd
import scipy as sp
import numpy as np
from nnodely.support.initializer import *
from nnodely.support.utils import *

print('Current working directory: ',os.getcwd())
sys.path.append(os.path.join(os.getcwd(),'..'))
from nnodely import *
from nnodely.support import earlystopping

# import a library for plots
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
#mpl.rcParams['text.usetex'] = True
import matplotlib.pyplot as plt
plt.close('all')
SMALL_SIZE = 14
MEDIUM_SIZE = 22
BIGGER_SIZE = 26
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)    # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)     # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rc('grid', linestyle="--", color='grey')

# enable zooming on the plots
# %matplotlib inline
import mpld3
mpld3.enable_notebook()
# Out:
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>-- nnodely_v1.5.1 --<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# Current working directory:  c:\Users\mungi\OneDrive\Desktop\Nello\VSD

# %% [markdown]
# ## Datasets

# %%
from scipy.interpolate import interp1d

data_folder = os.path.join(os.getcwd(),'Dataset')

####### TRAINING DATA ########
data_folder_train = os.path.join(data_folder,'Complete Dynamics/training')
training_data=pd.read_csv(os.path.join(data_folder_train,'ftg_stanley_total_training.csv'))

####### VALIDATION DATA ########
data_folder_Validation = os.path.join(data_folder,'Complete Dynamics/validation')
Validation_data=pd.read_csv(os.path.join(data_folder_Validation,'ftg_stanley_total_validation.csv'))

####### TEST DATA ########

flag=0 # flag to chosse the test dataset
# flag=0 -> fg_single_mass_processed.csv
# flag=1 -> fg_double_mass_processed.csv
# flag=2 -> Frastagliate_tot.csv
# flag=3 -> Intermedie_tot.csv
# flag=4 -> Normal_1weight_v03.csv
# flag=5 -> Normal_2weights_v025.csv

data_folder_Test= os.path.join(data_folder,'Robusteness')

if flag==0:
    Test_data=pd.read_csv(os.path.join(data_folder_Test,'single_mass.csv'))
elif flag==1:
    Test_data=pd.read_csv(os.path.join(data_folder_Test,'double_mass.csv'))
elif flag==2:
    Test_data=pd.read_csv(os.path.join(data_folder_Test,'tire_set_1.csv'))
elif flag==3:
    Test_data=pd.read_csv(os.path.join(data_folder_Test,'tire_set_2.csv'))
elif flag==4:
    Test_data=pd.read_csv(os.path.join(data_folder_Test,'Normal_1weight.csv'))
elif flag==5:
    Test_data=pd.read_csv(os.path.join(data_folder_Test,'Normal_2weights.csv'))

# %% [markdown]
# ## MS NN Structure

# %%
# -----------------------------------------------
# Neural model inputs and outputs
# -----------------------------------------------
yaw_rate         = Input('yaw_rate')      # [rad/s] yaw_rate
vx               = Input('vx')            # [m/s] longitudinal velocity  
steer            = Input('steer')         # [rad] steering wheel angle 
ax               = Input('ax')            # [m/s^2] longitudinal acceleration

ratio_rpm_v=4244.0 

# -----------------------------------------------
min_vx_train = min(training_data["Speed"].values/ratio_rpm_v)
max_vx_train = max(training_data["Speed"].values/ratio_rpm_v)
max_vx_val = max(Validation_data["Speed"].values/ratio_rpm_v)
min_delta_train = min(training_data["steering_angle"].values)
max_delta_train = max(training_data["steering_angle"].values)

min_ax_train = min(training_data["accx"].values*9.81)
min_ax_val = min(Validation_data["accx"].values*9.81)

max_ax_train = max(training_data["accx"].values*9.81)
# -----------------------------------------------
# Hyperparameters
# -----------------------------------------------
# Window size for the inputs
num_samples_past    = 20 # number of samples in the past for the steering wheel angle prediction

# Number of channels for forward speed
num_channels_vx = 2
num_channels_delta = 5
num_channels_ax = 2

chan_centers_vx = list(np.linspace(min_vx_train, max_vx_train, num=num_channels_vx))  # centers of the channels
chan_centers_delta = list(np.linspace(min_delta_train, max_delta_train, num=num_channels_delta))  # centers of the channels
chan_centers_ax = list(np.linspace(min_ax_val, max_ax_train, num=num_channels_ax))  # centers of the channels

# Define the centers of the channels for ay, ax, and az:
chan_centers_steer_list, chan_centers_speed_list,chan_centers_ax_list = [], [], []
for idx_ay in range(num_channels_delta):
  chan_centers_steer_list.append(Constant('steer_center_' + str(idx_ay), values=chan_centers_delta[idx_ay]))
for idx_vx in range(num_channels_vx):
  chan_centers_speed_list.append(Constant('vx_center_' + str(idx_vx), values=chan_centers_vx[idx_vx]))
for idx_ax in range(num_channels_ax):
  chan_centers_ax_list.append(Constant('ax_center_' + str(idx_ax), values=chan_centers_ax[idx_ax]))

# -----------------------------------------------
# Understeering gradient correction
# -----------------------------------------------
# Custom function to model the understeering gradient correction
def understeer_corr_local(input,vx,input_0, vx_0,ax,ax_0,  # inputs
                    k1,k2,k3,k4          # learnable parameter 
                  ):
  return vx*(k1+ k2*(input - input_0) + k3* (vx-vx_0)+k4*(ax-ax_0)) 

understeer_corr = ParamFun(understeer_corr_local)

def understeer_corr_gen(idx_list):
  def understeer_corr_map(input,vx,ax):
    idx_ax=idx_list[2]
    idx_steer=idx_list[1]
    idx_speed=idx_list[0]
    k1 = Parameter('k1_'+ str(idx_speed)+ '_' + str(idx_steer)+ '_' + str(idx_ax),values=[[1e-5]])  # initial guess for the understeering gradient learnable parameter
    k2 = Parameter('k2_'+ str(idx_speed)+ '_' + str(idx_steer)+ '_' + str(idx_ax),values=[[1e-5]])  # initial guess for the understeering gradient learnable parameter
    k3 = Parameter('k3_'+ str(idx_speed)+ '_' + str(idx_steer)+ '_' + str(idx_ax),values=[[1e-5]])  # initial guess for the understeering gradient learnable parameter
    k4 = Parameter('k4_'+ str(idx_speed)+ '_' + str(idx_steer)+ '_' + str(idx_ax),values=[[1e-5]])  # initial guess for the understeering gradient learnable parameter

    input_0 = chan_centers_steer_list[idx_steer]
    vx_0 = chan_centers_speed_list[idx_speed]
    ax_0 = chan_centers_ax_list[idx_ax]
    return understeer_corr(input,vx,input_0,vx_0,ax,ax_0,k1,k2,k3,k4)
  return understeer_corr_map

# L = Constant('L',values=0.384)  # [m] wheelbase

fuzz_lateral_transient = Fuzzify(centers=chan_centers_vx, functions='Triangular')(vx.sw(num_samples_past))

fuzz_lateral_ss_2 = Fuzzify(centers=chan_centers_delta, functions='Triangular')(steer.sw(num_samples_past))
fuzz_lateral_ss_1 = Fuzzify(centers=chan_centers_vx, functions='Triangular')(vx.sw(num_samples_past))
fuzz_lateral_ss_3 = Fuzzify(centers=chan_centers_ax, functions='Triangular')(ax.sw(num_samples_past))

# Parametric function to model the understeering gradient correction
local_model_ss = LocalModel(input_function=understeer_corr_gen,pass_indexes=True)((steer.sw(num_samples_past), vx.sw(num_samples_past),ax.sw(num_samples_past)), (fuzz_lateral_ss_1, fuzz_lateral_ss_2,fuzz_lateral_ss_3))

local_model_transient = LocalModel(output_function=lambda: Fir(W_init = init_negexp, W_init_params={'size_index':0, 'first_value':0.0001, 'lambda':5, 'monotonicity':'increasing'}))(local_model_ss, fuzz_lateral_transient)

# Model output: trajectory curvature at the current time step
yaw_rate_out = Output('yaw_rate_', local_model_transient)  # output of the model

# %% [markdown]
# ### nnodely definitions

# %%
# Create a nnodely model
path_folder   = os.path.join(os.getcwd(),'trained_models','Ablation_1_Lateral')    # folder to save the model 
lateral_dynamics   = nnodely(visualizer='Standard',seed=12,workspace=path_folder,save_history=False)  #visualizer=MPLVisulizer()

# Add the neural model to the nnodely structure and neuralization of the model
lateral_dynamics.addModel('yaw_rate',[yaw_rate_out])
lateral_dynamics.addMinimize('yaw_rate_error', 
                                    yaw_rate.next(),  # next means the first value in the "future"
                                    yaw_rate_out, 
                                    loss_function='rmse')

# %%
lateral_dynamics.neuralizeModel()
# Out:
# ================================ nnodely Model =================================
# {'Constants': {'ax_center_0': {'dim': 1, 'values': [-6.545853614807129]},
#                'ax_center_1': {'dim': 1, 'values': [5.759031772613525]},
#                'steer_center_0': {'dim': 1, 'values': [-0.26957762241363525]},
#                'steer_center_1': {'dim': 1, 'values': [-0.09745820611715317]},
#                'steer_center_2': {'dim': 1, 'values': [0.07466120272874832]},
#                'steer_center_3': {'dim': 1, 'values': [0.2467806041240692]},
#                'steer_center_4': {'dim': 1, 'values': [0.4189000129699707]},
#                'vx_center_0': {'dim': 1, 'values': [-0.3245462477207184]},
#                'vx_center_1': {'dim': 1, 'values': [3.6042771339416504]}},
#  'Functions': {'FFuzzify15': {'centers': [-0.3245462443934415,
#                                           3.6042770373580395],
#                               'dim_out': {'dim': 2},
#                               'functions': 'Triangular',
#                               'names': 'Triangular'},
#                'FFuzzify16': {'centers': [-0.2695776118175756,
#                                           -0.09745820562068902,
#                                           0.07466120057619757,
#                                           0.24678060677308417,
#                                           0.4189000129699707],
#                               'dim_out': {'dim': 5},
#                               'functions': 'Triangular',
#                               'names': 'Triangular'},
#                'FFuzzify17': {'centers': [-0.3245462443934415,
#                                           3.6042770373580395],
#                               'dim_out': {'dim': 2},
#                               'functions': 'Triangular',
#                               'names': 'Triangular'},
#                'FFuzzify18': {'centers': [-6.545853607889415,
#                                           5.759031814278202],
#                               'dim_out': {'dim': 2},
#                               'functions': 'Triangular',
#                               'names': 'Triangular'},
#                'FParamFun14': {'code': 'def '
#                                        'understeer_corr_local(input,vx,input_0, '
#                                        'vx_0,ax,ax_0,  # inputs\n'
#                                        '                    '
#                                        'k1,k2,k3,k4          # learnable '
#                                        'parameter \n'
#                                        '                  ):\n'
#                                        '  return vx*(k1+ k2*(input - input_0) '
#                                        '+ k3* (vx-vx_0)+k4*(ax-ax_0)) \n',
#                                'in_dim': [{'dim': 1, 'sw': 20},
#                                           {'dim': 1, 'sw': 20},
#                                           {'dim': 1},
#                                           {'dim': 1},
#                                           {'dim': 1, 'sw': 20},
#                                           {'dim': 1},
#                                           {'dim': [1, 1]},
#                                           {'dim': [1, 1]},
#                                           {'dim': [1, 1]},
#                                           {'dim': [1, 1]}],
#                                'map_over_dim': False,
#                                'n_input': 10,
#                                'name': 'understeer_corr_local',
#                                'params_and_consts': []}},
#  'Info': {'SampleTime': 1,
#           'nnodely_version': '1.5.1',
#           'ns': [20, 1],
#           'ntot': 21,
#           'num_parameters': 120},
#  'Inputs': {'ax': {'dim': 1, 'ns': [20, 0], 'ntot': 20, 'sw': [-20, 0]},
#             'steer': {'dim': 1, 'ns': [20, 0], 'ntot': 20, 'sw': [-20, 0]},
#             'vx': {'dim': 1, 'ns': [20, 0], 'ntot': 20, 'sw': [-20, 0]},
#             'yaw_rate': {'dim': 1, 'ns': [0, 1], 'ntot': 1, 'sw': [0, 1]}},
#  'Minimizers': {'yaw_rate_error': {'A': 'SamplePart465',
#                                    'B': 'Add463',
#                                    'loss': 'rmse'}},
#  'Models': 'yaw_rate',
#  'Outputs': {'yaw_rate_': 'Add463'},
#  'Parameters': {'PFir101W': {'dim': 1,
#                              'init_fun': {'code': 'def init_negexp(indexes, '
#                                                   'params_size, dict_param = '
#                                                   "{'size_index':0, "
#                                                   "'first_value':1, "
#                                                   "'lambda':3}):\n"
#                                                   "    '''\n"
#                                                   '    Initializes parameters '
#                                                   'using a negative decay '
#                                                   'exponential function.\n'
#                                                   '\n'
#                                                   '    Parameters\n'
#                                                   '    ----------\n'
#                                                   '    indexes : list\n'
#                                                   '        List of indexes for '
#                                                   'the parameters.\n'
#                                                   '    params_size : list\n'
#                                                   '        List of sizes for '
#                                                   'each dimension of the '
#                                                   'parameters.\n'
#                                                   '    dict_param : dict, '
#                                                   'optional\n'
#                                                   '        Dictionary '
#                                                   'containing the '
#                                                   'initialization parameters. '
#                                                   "Default is {'size_index': "
#                                                   "0, 'first_value': 1, "
#                                                   "'lambda': 3}.\n"
#                                                   '            size_index : '
#                                                   'int\n'
#                                                   '                The index '
#                                                   'of the dimension to apply '
#                                                   'the exponential function.\n'
#                                                   '            first_value : '
#                                                   'int or float\n'
#                                                   '                The value '
#                                                   'at the start of the range.\n'
#                                                   '            lambda : int or '
#                                                   'float\n'
#                                                   '                The decay '
#                                                   'rate parameter of the '
#                                                   'exponential function.\n'
#                                                   "    '''\n"
#                                                   '    import numpy as np\n'
#                                                   '    size_index = '
#                                                   "dict_param['size_index']\n"
#                                                   '    # check if the size of '
#                                                   'the list of parameters is '
#                                                   '1, to avoid a division by '
#                                                   'zero\n'
#                                                   '    x = 1 if '
#                                                   'params_size[size_index]-1 '
#                                                   '== 0 else '
#                                                   'indexes[size_index]/(params_size[size_index]-1)\n'
#                                                   '    return '
#                                                   "dict_param['first_value']*np.exp(-dict_param['lambda']*(1-x))\n",
#                                           'name': 'init_negexp',
#                                           'params': {'first_value': 0.0001,
#                                                      'lambda': 5,
#                                                      'monotonicity': 'increasing',
#                                                      'size_index': 0}},
#                              'sw': 20,
#                              'values': [[6.737947160218027e-07],
#                                         [8.766285759520542e-07],
#                                         [1.1405219311200199e-06],
#                                         [1.4838556126051117e-06],
#                                         [1.930543930939166e-06],
#                                         [2.511699676688295e-06],
#                                         [3.2678019579179818e-06],
#                                         [4.2515152927080635e-06],
#                                         [5.531358056032332e-06],
#                                         [7.196474598458735e-06],
#                                         [9.362844139104709e-06],
#                                         [1.21813609439414e-05],
#                                         [1.5848341718083248e-05],
#                                         [2.0619203496607952e-05],
#                                         [2.682624472072348e-05],
#                                         [3.490180824883282e-05],
#                                         [4.5408371079247445e-05],
#                                         [5.9077752666780725e-05],
#                                         [7.686205208301544e-05],
#                                         [9.999999747378752e-05]]},
#                 'PFir103W': {'dim': 1,
#                              'init_fun': {'code': 'def init_negexp(indexes, '
#                                                   'params_size, dict_param = '
#                                                   "{'size_index':0, "
#                                                   "'first_value':1, "
#                                                   "'lambda':3}):\n"
#                                                   "    '''\n"
#                                                   '    Initializes parameters '
#                                                   'using a negative decay '
#                                                   'exponential function.\n'
#                                                   '\n'
#                                                   '    Parameters\n'
#                                                   '    ----------\n'
#                                                   '    indexes : list\n'
#                                                   '        List of indexes for '
#                                                   'the parameters.\n'
#                                                   '    params_size : list\n'
#                                                   '        List of sizes for '
#                                                   'each dimension of the '
#                                                   'parameters.\n'
#                                                   '    dict_param : dict, '
#                                                   'optional\n'
#                                                   '        Dictionary '
#                                                   'containing the '
#                                                   'initialization parameters. '
#                                                   "Default is {'size_index': "
#                                                   "0, 'first_value': 1, "
#                                                   "'lambda': 3}.\n"
#                                                   '            size_index : '
#                                                   'int\n'
#                                                   '                The index '
#                                                   'of the dimension to apply '
#                                                   'the exponential function.\n'
#                                                   '            first_value : '
#                                                   'int or float\n'
#                                                   '                The value '
#                                                   'at the start of the range.\n'
#                                                   '            lambda : int or '
#                                                   'float\n'
#                                                   '                The decay '
#                                                   'rate parameter of the '
#                                                   'exponential function.\n'
#                                                   "    '''\n"
#                                                   '    import numpy as np\n'
#                                                   '    size_index = '
#                                                   "dict_param['size_index']\n"
#                                                   '    # check if the size of '
#                                                   'the list of parameters is '
#                                                   '1, to avoid a division by '
#                                                   'zero\n'
#                                                   '    x = 1 if '
#                                                   'params_size[size_index]-1 '
#                                                   '== 0 else '
#                                                   'indexes[size_index]/(params_size[size_index]-1)\n'
#                                                   '    return '
#                                                   "dict_param['first_value']*np.exp(-dict_param['lambda']*(1-x))\n",
#                                           'name': 'init_negexp',
#                                           'params': {'first_value': 0.0001,
#                                                      'lambda': 5,
#                                                      'monotonicity': 'increasing',
#                                                      'size_index': 0}},
#                              'sw': 20,
#                              'values': [[6.737947160218027e-07],
#                                         [8.766285759520542e-07],
#                                         [1.1405219311200199e-06],
#                                         [1.4838556126051117e-06],
#                                         [1.930543930939166e-06],
#                                         [2.511699676688295e-06],
#                                         [3.2678019579179818e-06],
#                                         [4.2515152927080635e-06],
#                                         [5.531358056032332e-06],
#                                         [7.196474598458735e-06],
#                                         [9.362844139104709e-06],
#                                         [1.21813609439414e-05],
#                                         [1.5848341718083248e-05],
#                                         [2.0619203496607952e-05],
#                                         [2.682624472072348e-05],
#                                         [3.490180824883282e-05],
#                                         [4.5408371079247445e-05],
#                                         [5.9077752666780725e-05],
#                                         [7.686205208301544e-05],
#                                         [9.999999747378752e-05]]},
#                 'k1_0_0_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k1_0_0_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k1_0_1_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k1_0_1_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k1_0_2_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k1_0_2_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k1_0_3_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k1_0_3_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k1_0_4_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k1_0_4_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k1_1_0_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k1_1_0_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k1_1_1_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k1_1_1_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k1_1_2_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k1_1_2_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k1_1_3_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k1_1_3_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k1_1_4_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k1_1_4_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k2_0_0_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k2_0_0_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k2_0_1_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k2_0_1_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k2_0_2_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k2_0_2_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k2_0_3_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k2_0_3_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k2_0_4_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k2_0_4_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k2_1_0_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k2_1_0_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k2_1_1_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k2_1_1_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k2_1_2_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k2_1_2_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k2_1_3_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k2_1_3_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k2_1_4_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k2_1_4_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k3_0_0_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k3_0_0_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k3_0_1_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k3_0_1_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k3_0_2_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k3_0_2_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k3_0_3_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k3_0_3_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k3_0_4_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k3_0_4_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k3_1_0_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k3_1_0_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k3_1_1_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k3_1_1_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k3_1_2_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k3_1_2_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k3_1_3_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k3_1_3_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k3_1_4_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k3_1_4_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k4_0_0_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k4_0_0_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k4_0_1_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k4_0_1_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k4_0_2_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k4_0_2_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k4_0_3_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k4_0_3_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k4_0_4_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k4_0_4_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k4_1_0_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k4_1_0_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k4_1_1_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k4_1_1_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k4_1_2_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k4_1_2_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k4_1_3_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k4_1_3_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k4_1_4_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]},
#                 'k4_1_4_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[9.999999747378752e-06]]}},
#  'Relations': {'Add438': ['Add', ['Mul38', 'Mul59']],
#                'Add439': ['Add', ['Add438', 'Mul80']],
#                'Add440': ['Add', ['Add439', 'Mul101']],
#                'Add441': ['Add', ['Add440', 'Mul122']],
#                'Add442': ['Add', ['Add441', 'Mul143']],
#                'Add443': ['Add', ['Add442', 'Mul164']],
#                'Add444': ['Add', ['Add443', 'Mul185']],
#                'Add445': ['Add', ['Add444', 'Mul206']],
#                'Add446': ['Add', ['Add445', 'Mul227']],
#                'Add447': ['Add', ['Add446', 'Mul248']],
#                'Add448': ['Add', ['Add447', 'Mul269']],
#                'Add449': ['Add', ['Add448', 'Mul290']],
#                'Add450': ['Add', ['Add449', 'Mul311']],
#                'Add451': ['Add', ['Add450', 'Mul332']],
#                'Add452': ['Add', ['Add451', 'Mul353']],
#                'Add453': ['Add', ['Add452', 'Mul374']],
#                'Add454': ['Add', ['Add453', 'Mul395']],
#                'Add455': ['Add', ['Add454', 'Mul416']],
#                'Add456': ['Add', ['Add455', 'Mul437']],
#                'Add463': ['Add', ['Fir459', 'Fir462']],
#                'Fir459': ['Fir', ['Mul458'], 'PFir101W', None, 0],
#                'Fir462': ['Fir', ['Mul461'], 'PFir103W', None, 0],
#                'Fuzzify11': ['Fuzzify', ['SamplePart10'], 'FFuzzify18'],
#                'Fuzzify2': ['Fuzzify', ['SamplePart1'], 'FFuzzify15'],
#                'Fuzzify5': ['Fuzzify', ['SamplePart4'], 'FFuzzify16'],
#                'Fuzzify8': ['Fuzzify', ['SamplePart7'], 'FFuzzify17'],
#                'Mul100': ['Mul', ['Mul98', 'Select99']],
#                'Mul101': ['Mul', ['ParamFun81', 'Mul100']],
#                'Mul119': ['Mul', ['Select117', 'Select118']],
#                'Mul121': ['Mul', ['Mul119', 'Select120']],
#                'Mul122': ['Mul', ['ParamFun102', 'Mul121']],
#                'Mul140': ['Mul', ['Select138', 'Select139']],
#                'Mul142': ['Mul', ['Mul140', 'Select141']],
#                'Mul143': ['Mul', ['ParamFun123', 'Mul142']],
#                'Mul161': ['Mul', ['Select159', 'Select160']],
#                'Mul163': ['Mul', ['Mul161', 'Select162']],
#                'Mul164': ['Mul', ['ParamFun144', 'Mul163']],
#                'Mul182': ['Mul', ['Select180', 'Select181']],
#                'Mul184': ['Mul', ['Mul182', 'Select183']],
#                'Mul185': ['Mul', ['ParamFun165', 'Mul184']],
#                'Mul203': ['Mul', ['Select201', 'Select202']],
#                'Mul205': ['Mul', ['Mul203', 'Select204']],
#                'Mul206': ['Mul', ['ParamFun186', 'Mul205']],
#                'Mul224': ['Mul', ['Select222', 'Select223']],
#                'Mul226': ['Mul', ['Mul224', 'Select225']],
#                'Mul227': ['Mul', ['ParamFun207', 'Mul226']],
#                'Mul245': ['Mul', ['Select243', 'Select244']],
#                'Mul247': ['Mul', ['Mul245', 'Select246']],
#                'Mul248': ['Mul', ['ParamFun228', 'Mul247']],
#                'Mul266': ['Mul', ['Select264', 'Select265']],
#                'Mul268': ['Mul', ['Mul266', 'Select267']],
#                'Mul269': ['Mul', ['ParamFun249', 'Mul268']],
#                'Mul287': ['Mul', ['Select285', 'Select286']],
#                'Mul289': ['Mul', ['Mul287', 'Select288']],
#                'Mul290': ['Mul', ['ParamFun270', 'Mul289']],
#                'Mul308': ['Mul', ['Select306', 'Select307']],
#                'Mul310': ['Mul', ['Mul308', 'Select309']],
#                'Mul311': ['Mul', ['ParamFun291', 'Mul310']],
#                'Mul329': ['Mul', ['Select327', 'Select328']],
#                'Mul331': ['Mul', ['Mul329', 'Select330']],
#                'Mul332': ['Mul', ['ParamFun312', 'Mul331']],
#                'Mul35': ['Mul', ['Select33', 'Select34']],
#                'Mul350': ['Mul', ['Select348', 'Select349']],
#                'Mul352': ['Mul', ['Mul350', 'Select351']],
#                'Mul353': ['Mul', ['ParamFun333', 'Mul352']],
#                'Mul37': ['Mul', ['Mul35', 'Select36']],
#                'Mul371': ['Mul', ['Select369', 'Select370']],
#                'Mul373': ['Mul', ['Mul371', 'Select372']],
#                'Mul374': ['Mul', ['ParamFun354', 'Mul373']],
#                'Mul38': ['Mul', ['ParamFun18', 'Mul37']],
#                'Mul392': ['Mul', ['Select390', 'Select391']],
#                'Mul394': ['Mul', ['Mul392', 'Select393']],
#                'Mul395': ['Mul', ['ParamFun375', 'Mul394']],
#                'Mul413': ['Mul', ['Select411', 'Select412']],
#                'Mul415': ['Mul', ['Mul413', 'Select414']],
#                'Mul416': ['Mul', ['ParamFun396', 'Mul415']],
#                'Mul434': ['Mul', ['Select432', 'Select433']],
#                'Mul436': ['Mul', ['Mul434', 'Select435']],
#                'Mul437': ['Mul', ['ParamFun417', 'Mul436']],
#                'Mul458': ['Mul', ['Add456', 'Select457']],
#                'Mul461': ['Mul', ['Add456', 'Select460']],
#                'Mul56': ['Mul', ['Select54', 'Select55']],
#                'Mul58': ['Mul', ['Mul56', 'Select57']],
#                'Mul59': ['Mul', ['ParamFun39', 'Mul58']],
#                'Mul77': ['Mul', ['Select75', 'Select76']],
#                'Mul79': ['Mul', ['Mul77', 'Select78']],
#                'Mul80': ['Mul', ['ParamFun60', 'Mul79']],
#                'Mul98': ['Mul', ['Select96', 'Select97']],
#                'ParamFun102': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_2',
#                                 'vx_center_0',
#                                 'SamplePart17',
#                                 'ax_center_0',
#                                 'k1_0_2_0',
#                                 'k2_0_2_0',
#                                 'k3_0_2_0',
#                                 'k4_0_2_0'],
#                                'FParamFun14'],
#                'ParamFun123': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_2',
#                                 'vx_center_0',
#                                 'SamplePart17',
#                                 'ax_center_1',
#                                 'k1_0_2_1',
#                                 'k2_0_2_1',
#                                 'k3_0_2_1',
#                                 'k4_0_2_1'],
#                                'FParamFun14'],
#                'ParamFun144': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_3',
#                                 'vx_center_0',
#                                 'SamplePart17',
#                                 'ax_center_0',
#                                 'k1_0_3_0',
#                                 'k2_0_3_0',
#                                 'k3_0_3_0',
#                                 'k4_0_3_0'],
#                                'FParamFun14'],
#                'ParamFun165': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_3',
#                                 'vx_center_0',
#                                 'SamplePart17',
#                                 'ax_center_1',
#                                 'k1_0_3_1',
#                                 'k2_0_3_1',
#                                 'k3_0_3_1',
#                                 'k4_0_3_1'],
#                                'FParamFun14'],
#                'ParamFun18': ['ParamFun',
#                               ['SamplePart13',
#                                'SamplePart15',
#                                'steer_center_0',
#                                'vx_center_0',
#                                'SamplePart17',
#                                'ax_center_0',
#                                'k1_0_0_0',
#                                'k2_0_0_0',
#                                'k3_0_0_0',
#                                'k4_0_0_0'],
#                               'FParamFun14'],
#                'ParamFun186': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_4',
#                                 'vx_center_0',
#                                 'SamplePart17',
#                                 'ax_center_0',
#                                 'k1_0_4_0',
#                                 'k2_0_4_0',
#                                 'k3_0_4_0',
#                                 'k4_0_4_0'],
#                                'FParamFun14'],
#                'ParamFun207': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_4',
#                                 'vx_center_0',
#                                 'SamplePart17',
#                                 'ax_center_1',
#                                 'k1_0_4_1',
#                                 'k2_0_4_1',
#                                 'k3_0_4_1',
#                                 'k4_0_4_1'],
#                                'FParamFun14'],
#                'ParamFun228': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_0',
#                                 'vx_center_1',
#                                 'SamplePart17',
#                                 'ax_center_0',
#                                 'k1_1_0_0',
#                                 'k2_1_0_0',
#                                 'k3_1_0_0',
#                                 'k4_1_0_0'],
#                                'FParamFun14'],
#                'ParamFun249': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_0',
#                                 'vx_center_1',
#                                 'SamplePart17',
#                                 'ax_center_1',
#                                 'k1_1_0_1',
#                                 'k2_1_0_1',
#                                 'k3_1_0_1',
#                                 'k4_1_0_1'],
#                                'FParamFun14'],
#                'ParamFun270': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_1',
#                                 'vx_center_1',
#                                 'SamplePart17',
#                                 'ax_center_0',
#                                 'k1_1_1_0',
#                                 'k2_1_1_0',
#                                 'k3_1_1_0',
#                                 'k4_1_1_0'],
#                                'FParamFun14'],
#                'ParamFun291': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_1',
#                                 'vx_center_1',
#                                 'SamplePart17',
#                                 'ax_center_1',
#                                 'k1_1_1_1',
#                                 'k2_1_1_1',
#                                 'k3_1_1_1',
#                                 'k4_1_1_1'],
#                                'FParamFun14'],
#                'ParamFun312': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_2',
#                                 'vx_center_1',
#                                 'SamplePart17',
#                                 'ax_center_0',
#                                 'k1_1_2_0',
#                                 'k2_1_2_0',
#                                 'k3_1_2_0',
#                                 'k4_1_2_0'],
#                                'FParamFun14'],
#                'ParamFun333': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_2',
#                                 'vx_center_1',
#                                 'SamplePart17',
#                                 'ax_center_1',
#                                 'k1_1_2_1',
#                                 'k2_1_2_1',
#                                 'k3_1_2_1',
#                                 'k4_1_2_1'],
#                                'FParamFun14'],
#                'ParamFun354': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_3',
#                                 'vx_center_1',
#                                 'SamplePart17',
#                                 'ax_center_0',
#                                 'k1_1_3_0',
#                                 'k2_1_3_0',
#                                 'k3_1_3_0',
#                                 'k4_1_3_0'],
#                                'FParamFun14'],
#                'ParamFun375': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_3',
#                                 'vx_center_1',
#                                 'SamplePart17',
#                                 'ax_center_1',
#                                 'k1_1_3_1',
#                                 'k2_1_3_1',
#                                 'k3_1_3_1',
#                                 'k4_1_3_1'],
#                                'FParamFun14'],
#                'ParamFun39': ['ParamFun',
#                               ['SamplePart13',
#                                'SamplePart15',
#                                'steer_center_0',
#                                'vx_center_0',
#                                'SamplePart17',
#                                'ax_center_1',
#                                'k1_0_0_1',
#                                'k2_0_0_1',
#                                'k3_0_0_1',
#                                'k4_0_0_1'],
#                               'FParamFun14'],
#                'ParamFun396': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_4',
#                                 'vx_center_1',
#                                 'SamplePart17',
#                                 'ax_center_0',
#                                 'k1_1_4_0',
#                                 'k2_1_4_0',
#                                 'k3_1_4_0',
#                                 'k4_1_4_0'],
#                                'FParamFun14'],
#                'ParamFun417': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_4',
#                                 'vx_center_1',
#                                 'SamplePart17',
#                                 'ax_center_1',
#                                 'k1_1_4_1',
#                                 'k2_1_4_1',
#                                 'k3_1_4_1',
#                                 'k4_1_4_1'],
#                                'FParamFun14'],
#                'ParamFun60': ['ParamFun',
#                               ['SamplePart13',
#                                'SamplePart15',
#                                'steer_center_1',
#                                'vx_center_0',
#                                'SamplePart17',
#                                'ax_center_0',
#                                'k1_0_1_0',
#                                'k2_0_1_0',
#                                'k3_0_1_0',
#                                'k4_0_1_0'],
#                               'FParamFun14'],
#                'ParamFun81': ['ParamFun',
#                               ['SamplePart13',
#                                'SamplePart15',
#                                'steer_center_1',
#                                'vx_center_0',
#                                'SamplePart17',
#                                'ax_center_1',
#                                'k1_0_1_1',
#                                'k2_0_1_1',
#                                'k3_0_1_1',
#                                'k4_0_1_1'],
#                               'FParamFun14'],
#                'SamplePart1': ['SamplePart', ['vx'], -1, [-20, 0]],
#                'SamplePart10': ['SamplePart', ['ax'], -1, [-20, 0]],
#                'SamplePart13': ['SamplePart', ['steer'], -1, [-20, 0]],
#                'SamplePart15': ['SamplePart', ['vx'], -1, [-20, 0]],
#                'SamplePart17': ['SamplePart', ['ax'], -1, [-20, 0]],
#                'SamplePart4': ['SamplePart', ['steer'], -1, [-20, 0]],
#                'SamplePart465': ['SamplePart', ['yaw_rate'], -1, [0, 1]],
#                'SamplePart7': ['SamplePart', ['vx'], -1, [-20, 0]],
#                'Select117': ['Select', ['Fuzzify8'], 2, 0],
#                'Select118': ['Select', ['Fuzzify5'], 5, 2],
#                'Select120': ['Select', ['Fuzzify11'], 2, 0],
#                'Select138': ['Select', ['Fuzzify8'], 2, 0],
#                'Select139': ['Select', ['Fuzzify5'], 5, 2],
#                'Select141': ['Select', ['Fuzzify11'], 2, 1],
#                'Select159': ['Select', ['Fuzzify8'], 2, 0],
#                'Select160': ['Select', ['Fuzzify5'], 5, 3],
#                'Select162': ['Select', ['Fuzzify11'], 2, 0],
#                'Select180': ['Select', ['Fuzzify8'], 2, 0],
#                'Select181': ['Select', ['Fuzzify5'], 5, 3],
#                'Select183': ['Select', ['Fuzzify11'], 2, 1],
#                'Select201': ['Select', ['Fuzzify8'], 2, 0],
#                'Select202': ['Select', ['Fuzzify5'], 5, 4],
#                'Select204': ['Select', ['Fuzzify11'], 2, 0],
#                'Select222': ['Select', ['Fuzzify8'], 2, 0],
#                'Select223': ['Select', ['Fuzzify5'], 5, 4],
#                'Select225': ['Select', ['Fuzzify11'], 2, 1],
#                'Select243': ['Select', ['Fuzzify8'], 2, 1],
#                'Select244': ['Select', ['Fuzzify5'], 5, 0],
#                'Select246': ['Select', ['Fuzzify11'], 2, 0],
#                'Select264': ['Select', ['Fuzzify8'], 2, 1],
#                'Select265': ['Select', ['Fuzzify5'], 5, 0],
#                'Select267': ['Select', ['Fuzzify11'], 2, 1],
#                'Select285': ['Select', ['Fuzzify8'], 2, 1],
#                'Select286': ['Select', ['Fuzzify5'], 5, 1],
#                'Select288': ['Select', ['Fuzzify11'], 2, 0],
#                'Select306': ['Select', ['Fuzzify8'], 2, 1],
#                'Select307': ['Select', ['Fuzzify5'], 5, 1],
#                'Select309': ['Select', ['Fuzzify11'], 2, 1],
#                'Select327': ['Select', ['Fuzzify8'], 2, 1],
#                'Select328': ['Select', ['Fuzzify5'], 5, 2],
#                'Select33': ['Select', ['Fuzzify8'], 2, 0],
#                'Select330': ['Select', ['Fuzzify11'], 2, 0],
#                'Select34': ['Select', ['Fuzzify5'], 5, 0],
#                'Select348': ['Select', ['Fuzzify8'], 2, 1],
#                'Select349': ['Select', ['Fuzzify5'], 5, 2],
#                'Select351': ['Select', ['Fuzzify11'], 2, 1],
#                'Select36': ['Select', ['Fuzzify11'], 2, 0],
#                'Select369': ['Select', ['Fuzzify8'], 2, 1],
#                'Select370': ['Select', ['Fuzzify5'], 5, 3],
#                'Select372': ['Select', ['Fuzzify11'], 2, 0],
#                'Select390': ['Select', ['Fuzzify8'], 2, 1],
#                'Select391': ['Select', ['Fuzzify5'], 5, 3],
#                'Select393': ['Select', ['Fuzzify11'], 2, 1],
#                'Select411': ['Select', ['Fuzzify8'], 2, 1],
#                'Select412': ['Select', ['Fuzzify5'], 5, 4],
#                'Select414': ['Select', ['Fuzzify11'], 2, 0],
#                'Select432': ['Select', ['Fuzzify8'], 2, 1],
#                'Select433': ['Select', ['Fuzzify5'], 5, 4],
#                'Select435': ['Select', ['Fuzzify11'], 2, 1],
#                'Select457': ['Select', ['Fuzzify2'], 2, 0],
#                'Select460': ['Select', ['Fuzzify2'], 2, 1],
#                'Select54': ['Select', ['Fuzzify8'], 2, 0],
#                'Select55': ['Select', ['Fuzzify5'], 5, 0],
#                'Select57': ['Select', ['Fuzzify11'], 2, 1],
#                'Select75': ['Select', ['Fuzzify8'], 2, 0],
#                'Select76': ['Select', ['Fuzzify5'], 5, 1],
#                'Select78': ['Select', ['Fuzzify11'], 2, 0],
#                'Select96': ['Select', ['Fuzzify8'], 2, 0],
#                'Select97': ['Select', ['Fuzzify5'], 5, 1],
#                'Select99': ['Select', ['Fuzzify11'], 2, 1]}}
# ================================================================================

# %% [markdown]
# ## Training and validation datasets

# %%
perc=0.6 # percentage of data used for training

speed_ms_train=(training_data["Speed"].values)/ratio_rpm_v
steer_rads_train=training_data["steering_angle"].values
yaw_rate_train=np.deg2rad(training_data["yaw_rate"].values)
ax_train=-training_data["accx"].values*9.81
size_train= round(len(ax_train)*perc)
dataset_training = {'steer': steer_rads_train[:size_train], 'vx': speed_ms_train[:size_train], 'yaw_rate' : yaw_rate_train[:size_train],'ax':ax_train[:size_train]}

speed_ms_validation=(Validation_data["Speed"].values)/ratio_rpm_v
steer_rads_validation=Validation_data["steering_angle"].values
yaw_rate_validation=np.deg2rad(Validation_data["yaw_rate"].values)
ax_validation=-Validation_data["accx"].values*9.81

dataset_validation = {'steer': steer_rads_validation[:], 'vx': speed_ms_validation[:], 'yaw_rate' : yaw_rate_validation[:],'ax':ax_validation[:]}

speed_ms_test=(Test_data["Speed"].values)/ratio_rpm_v
steer_rads_test=Test_data["steering_angle"].values
yaw_rate_test=np.deg2rad(Test_data["yaw_rate"].values)
ax_test=-Test_data["accx"].values*9.81

dataset_test = {'steer': steer_rads_test[:], 'vx': speed_ms_test[:], 'yaw_rate' : yaw_rate_test[:],'ax':ax_test[:]}

# Pass the training and the validation datasets to the nnodely structure

lateral_dynamics.loadData(name='training_set', source=dataset_training)
lateral_dynamics.loadData(name='validation_set', source=dataset_validation)
lateral_dynamics.loadData(name='Test_set', source=dataset_test)
# Out:
# ============================ nnodely Model Dataset =============================
# Dataset Name:                 training_set
# Number of files:              1
# Total number of samples:      1499
# Shape of vx:                  (1499, 20, 1)
# Shape of ax:                  (1499, 20, 1)
# Shape of steer:               (1499, 20, 1)
# Shape of yaw_rate:            (1499, 1, 1)
# ================================================================================
# ============================ nnodely Model Dataset =============================
# Dataset Name:                 validation_set
# Number of files:              1
# Total number of samples:      1177
# Shape of vx:                  (1177, 20, 1)
# Shape of ax:                  (1177, 20, 1)
# Shape of steer:               (1177, 20, 1)
# Shape of yaw_rate:            (1177, 1, 1)
# ================================================================================
# ============================ nnodely Model Dataset =============================
# Dataset Name:                 Test_set
# Number of files:              1
# Total number of samples:      499
# Shape of vx:                  (499, 20, 1)
# Shape of ax:                  (499, 20, 1)
# Shape of steer:               (499, 20, 1)
# Shape of yaw_rate:            (499, 1, 1)
# ================================================================================

# %% [markdown]
# ## Training

# %%
num_epochs = 1000
batch_size = 100 
learn_rate = 1e-3 
early_stop_patience = 300 
training_pars = {'num_of_epochs':num_epochs, 
                 'val_batch_size':batch_size, 
                 'train_batch_size':batch_size, 
                 'lr':learn_rate}

flag_train_now = 1
if flag_train_now:
  train_result_open_loop = lateral_dynamics.trainAndAnalyze(train_dataset='training_set',  validation_dataset= 'validation_set', test_dataset= 'Test_set',
                                                              training_params=training_pars, optimizer='Adam', shuffle_data=True,
                                                              early_stopping=earlystopping.early_stop_patience,  
                                                              early_stopping_params={'patience':early_stop_patience,
                                                                                    'error':'yaw_rate_error'})  
  lateral_dynamics.saveModel()
else:
  # Load the trained model
  lateral_dynamics.loadModel()
# Out:
# ======================== nnodely Model Train Parameters ========================
# models:                       ['yaw_rate']
# num of epochs:                7000
# update per epochs:            14
# └>(n_samples-batch_size)/batch_size+1
# shuffle data:                 True
# early stopping:               early_stop_patience
# early stopping params:        {'error': 'yaw_rate_error', 'patience': 300}
# train dataset:                training_set
# 	- batch size:                100
# 	- num of samples:            1499
# validation dataset:           validation_set
# 	- batch size:                100
# 	- num of samples:            1177
# minimizers:                   {'yaw_rate_error': {'A': 'SamplePart465',
#                                                   'B': 'Add463',
#                                                   'loss': 'rmse'}}
# optimizer:                    Adam
# optimizer defaults:           {'lr': 0.001}
# optimizer params:             [{'params': 'PFir101W'},
#                                {'params': 'PFir103W'},
#                                {'params': 'k1_0_0_0'},
#                                {'params': 'k1_0_0_1'},
#                                {'params': 'k1_0_1_0'},
#                                {'params': 'k1_0_1_1'},
#                                {'params': 'k1_0_2_0'},
#                                {'params': 'k1_0_2_1'},
#                                {'params': 'k1_0_3_0'},
#                                {'params': 'k1_0_3_1'},
#                                {'params': 'k1_0_4_0'},
#                                {'params': 'k1_0_4_1'},
#                                {'params': 'k1_1_0_0'},
#                                {'params': 'k1_1_0_1'},
#                                {'params': 'k1_1_1_0'},
#                                {'params': 'k1_1_1_1'},
#                                {'params': 'k1_1_2_0'},
#                                {'params': 'k1_1_2_1'},
#                                {'params': 'k1_1_3_0'},
#                                {'params': 'k1_1_3_1'},
#                                {'params': 'k1_1_4_0'},
#                                {'params': 'k1_1_4_1'},
#                                {'params': 'k2_0_0_0'},
#                                {'params': 'k2_0_0_1'},
#                                {'params': 'k2_0_1_0'},
#                                {'params': 'k2_0_1_1'},
#                                {'params': 'k2_0_2_0'},
#                                {'params': 'k2_0_2_1'},
#                                {'params': 'k2_0_3_0'},
#                                {'params': 'k2_0_3_1'},
#                                {'params': 'k2_0_4_0'},
#                                {'params': 'k2_0_4_1'},
#                                {'params': 'k2_1_0_0'},
#                                {'params': 'k2_1_0_1'},
#                                {'params': 'k2_1_1_0'},
#                                {'params': 'k2_1_1_1'},
#                                {'params': 'k2_1_2_0'},
#                                {'params': 'k2_1_2_1'},
#                                {'params': 'k2_1_3_0'},
#                                {'params': 'k2_1_3_1'},
#                                {'params': 'k2_1_4_0'},
#                                {'params': 'k2_1_4_1'},
#                                {'params': 'k3_0_0_0'},
#                                {'params': 'k3_0_0_1'},
#                                {'params': 'k3_0_1_0'},
#                                {'params': 'k3_0_1_1'},
#                                {'params': 'k3_0_2_0'},
#                                {'params': 'k3_0_2_1'},
#                                {'params': 'k3_0_3_0'},
#                                {'params': 'k3_0_3_1'},
#                                {'params': 'k3_0_4_0'},
#                                {'params': 'k3_0_4_1'},
#                                {'params': 'k3_1_0_0'},
#                                {'params': 'k3_1_0_1'},
#                                {'params': 'k3_1_1_0'},
#                                {'params': 'k3_1_1_1'},
#                                {'params': 'k3_1_2_0'},
#                                {'params': 'k3_1_2_1'},
#                                {'params': 'k3_1_3_0'},
#                                {'params': 'k3_1_3_1'},
#                                {'params': 'k3_1_4_0'},
#                                {'params': 'k3_1_4_1'},
#                                {'params': 'k4_0_0_0'},
#                                {'params': 'k4_0_0_1'},
#                                {'params': 'k4_0_1_0'},
#                                {'params': 'k4_0_1_1'},
#                                {'params': 'k4_0_2_0'},
#                                {'params': 'k4_0_2_1'},
#                                {'params': 'k4_0_3_0'},
#                                {'params': 'k4_0_3_1'},
#                                {'params': 'k4_0_4_0'},
#                                {'params': 'k4_0_4_1'},
#                                {'params': 'k4_1_0_0'},
#                                {'params': 'k4_1_0_1'},
#                                {'params': 'k4_1_1_0'},
#                                {'params': 'k4_1_1_1'},
#                                {'params': 'k4_1_2_0'},
#                                {'params': 'k4_1_2_1'},
#                                {'params': 'k4_1_3_0'},
#                                {'params': 'k4_1_3_1'},
#                                {'params': 'k4_1_4_0'},
#                                {'params': 'k4_1_4_1'}]
# ================================================================================
# ================= nnodely Training =================
# |  Epoch   |   yaw_rate_error  |       Total       |
# |          |        Loss       |        Loss       |
# |          |  train  |   val   |  train  |   val   |
# |--------------------------------------------------|
# | 10/7000  |3.553e-01|3.074e-01|3.553e-01|3.074e-01|
# | 20/7000  |1.268e-01|1.314e-01|1.268e-01|1.314e-01|
# | 30/7000  |1.077e-01|1.251e-01|1.077e-01|1.251e-01|
# | 40/7000  |1.027e-01|1.232e-01|1.027e-01|1.232e-01|
# | 50/7000  |9.913e-02|1.219e-01|9.913e-02|1.219e-01|
# | 60/7000  |9.753e-02|1.220e-01|9.753e-02|1.220e-01|
# | 70/7000  |9.703e-02|1.230e-01|9.703e-02|1.230e-01|
# | 80/7000  |9.462e-02|1.251e-01|9.462e-02|1.251e-01|
# | 90/7000  |9.435e-02|1.253e-01|9.435e-02|1.253e-01|
# | 100/7000 |9.584e-02|1.294e-01|9.584e-02|1.294e-01|
# | 110/7000 |9.364e-02|1.280e-01|9.364e-02|1.280e-01|
# | 120/7000 |9.436e-02|1.295e-01|9.436e-02|1.295e-01|
# | 130/7000 |9.322e-02|1.291e-01|9.322e-02|1.291e-01|
# | 140/7000 |9.267e-02|1.316e-01|9.267e-02|1.316e-01|
# | 150/7000 |9.254e-02|1.311e-01|9.254e-02|1.311e-01|
# | 160/7000 |9.280e-02|1.288e-01|9.280e-02|1.288e-01|
# | 170/7000 | 9.21e-02|1.298e-01| 9.21e-02|1.298e-01|
# | 180/7000 |9.285e-02|1.301e-01|9.285e-02|1.301e-01|
# | 190/7000 |9.353e-02|1.307e-01|9.353e-02|1.307e-01|
# | 200/7000 |9.129e-02|1.318e-01|9.129e-02|1.318e-01|
# | 210/7000 |9.197e-02|1.312e-01|9.197e-02|1.312e-01|
# | 220/7000 |9.185e-02|1.319e-01|9.185e-02|1.319e-01|
# | 230/7000 |9.031e-02|1.317e-01|9.031e-02|1.317e-01|
# | 240/7000 |9.081e-02| 1.31e-01|9.081e-02| 1.31e-01|
# | 250/7000 |9.144e-02|1.311e-01|9.144e-02|1.311e-01|
# | 260/7000 |9.006e-02|1.333e-01|9.006e-02|1.333e-01|
# | 270/7000 |9.009e-02|1.327e-01|9.009e-02|1.327e-01|
# | 280/7000 |9.083e-02|1.330e-01|9.083e-02|1.330e-01|
# | 290/7000 |8.924e-02|1.323e-01|8.924e-02|1.323e-01|
# | 300/7000 |9.014e-02|1.334e-01|9.014e-02|1.334e-01|
# | 310/7000 |9.116e-02|1.316e-01|9.116e-02|1.316e-01|
# | 320/7000 |8.972e-02|1.318e-01|8.972e-02|1.318e-01|
# | 330/7000 |9.142e-02|1.366e-01|9.142e-02|1.366e-01|
# | 340/7000 |8.919e-02|1.338e-01|8.919e-02|1.338e-01|
# | 350/7000 |8.779e-02|1.321e-01|8.779e-02|1.321e-01|
# | 354/7000 |8.923e-02|1.363e-01|8.923e-02|1.363e-01|============================ nnodely Training Time =============================
# Total time of Training:       189.39079928398132
# ================================================================================
# ================== nnodely Model Results for training_set ==================
# |     Loss     |        rmse       |        FVU        |        AIC        |
# |              |    small better   |    small better   |    lower better   |
# |--------------------------------------------------------------------------|
# |yaw_rate_error|     8.747e-02     |     1.917e-02     |     -2.565e+03    |
# |--------------------------------------------------------------------------|
# |    Total     |     8.747e-02     |     1.917e-02     |     -2.565e+03    |
# |--------------------------------------------------------------------------|
# ================= nnodely Model Results for validation_set =================
# |     Loss     |        rmse       |        FVU        |        AIC        |
# |              |    small better   |    small better   |    lower better   |
# |--------------------------------------------------------------------------|
# |yaw_rate_error|     1.342e-01     |      5.32e-02     |     -6.178e+02    |
# |--------------------------------------------------------------------------|
# |    Total     |     1.342e-01     |      5.32e-02     |     -6.178e+02    |
# |--------------------------------------------------------------------------|
# ==================== nnodely Model Results for Test_set ====================
# |     Loss     |        rmse       |        FVU        |        AIC        |
# |              |    small better   |    small better   |    lower better   |
# |--------------------------------------------------------------------------|
# |yaw_rate_error|     3.497e-01     |     1.597e-01     |     5.256e+02     |
# |--------------------------------------------------------------------------|
# |    Total     |     3.497e-01     |     1.597e-01     |     5.256e+02     |
# |--------------------------------------------------------------------------|
# =============================== Save JSON Model ================================
# Model saved in:               c:\Users\mungi\OneDrive\Desktop\Nello\VSD\trained_models\Ablation_1_Lateral\net.json
# ================================================================================

# %%
# Print the trained NN parameters
lateral_dynamics.neuralizeModel()
# Out:
# ================================ nnodely Model =================================
# {'Constants': {'ax_center_0': {'dim': 1, 'values': [-6.545853614807129]},
#                'ax_center_1': {'dim': 1, 'values': [5.759031772613525]},
#                'steer_center_0': {'dim': 1, 'values': [-0.26957762241363525]},
#                'steer_center_1': {'dim': 1, 'values': [-0.09745820611715317]},
#                'steer_center_2': {'dim': 1, 'values': [0.07466120272874832]},
#                'steer_center_3': {'dim': 1, 'values': [0.2467806041240692]},
#                'steer_center_4': {'dim': 1, 'values': [0.4189000129699707]},
#                'vx_center_0': {'dim': 1, 'values': [-0.3245462477207184]},
#                'vx_center_1': {'dim': 1, 'values': [3.6042771339416504]}},
#  'Functions': {'FFuzzify15': {'centers': [-0.3245462443934415,
#                                           3.6042770373580395],
#                               'dim_out': {'dim': 2},
#                               'functions': 'Triangular',
#                               'names': 'Triangular'},
#                'FFuzzify16': {'centers': [-0.2695776118175756,
#                                           -0.09745820562068902,
#                                           0.07466120057619757,
#                                           0.24678060677308417,
#                                           0.4189000129699707],
#                               'dim_out': {'dim': 5},
#                               'functions': 'Triangular',
#                               'names': 'Triangular'},
#                'FFuzzify17': {'centers': [-0.3245462443934415,
#                                           3.6042770373580395],
#                               'dim_out': {'dim': 2},
#                               'functions': 'Triangular',
#                               'names': 'Triangular'},
#                'FFuzzify18': {'centers': [-6.545853607889415,
#                                           5.759031814278202],
#                               'dim_out': {'dim': 2},
#                               'functions': 'Triangular',
#                               'names': 'Triangular'},
#                'FParamFun14': {'code': 'def '
#                                        'understeer_corr_local(input,vx,input_0, '
#                                        'vx_0,ax,ax_0,  # inputs\n'
#                                        '                    '
#                                        'k1,k2,k3,k4          # learnable '
#                                        'parameter \n'
#                                        '                  ):\n'
#                                        '  return vx*(k1+ k2*(input - input_0) '
#                                        '+ k3* (vx-vx_0)+k4*(ax-ax_0)) \n',
#                                'in_dim': [{'dim': 1, 'sw': 20},
#                                           {'dim': 1, 'sw': 20},
#                                           {'dim': 1},
#                                           {'dim': 1},
#                                           {'dim': 1, 'sw': 20},
#                                           {'dim': 1},
#                                           {'dim': [1, 1]},
#                                           {'dim': [1, 1]},
#                                           {'dim': [1, 1]},
#                                           {'dim': [1, 1]}],
#                                'map_over_dim': False,
#                                'n_input': 10,
#                                'name': 'understeer_corr_local',
#                                'params_and_consts': []}},
#  'Info': {'SampleTime': 1,
#           'nnodely_version': '1.5.1',
#           'ns': [20, 1],
#           'ntot': 21,
#           'num_parameters': 120},
#  'Inputs': {'ax': {'dim': 1, 'ns': [20, 0], 'ntot': 20, 'sw': [-20, 0]},
#             'steer': {'dim': 1, 'ns': [20, 0], 'ntot': 20, 'sw': [-20, 0]},
#             'vx': {'dim': 1, 'ns': [20, 0], 'ntot': 20, 'sw': [-20, 0]},
#             'yaw_rate': {'dim': 1, 'ns': [0, 1], 'ntot': 1, 'sw': [0, 1]}},
#  'Minimizers': {'yaw_rate_error': {'A': 'SamplePart465',
#                                    'B': 'Add463',
#                                    'loss': 'rmse'}},
#  'Models': 'yaw_rate',
#  'Outputs': {'yaw_rate_': 'Add463'},
#  'Parameters': {'PFir101W': {'dim': 1,
#                              'init_fun': {'code': 'def init_negexp(indexes, '
#                                                   'params_size, dict_param = '
#                                                   "{'size_index':0, "
#                                                   "'first_value':1, "
#                                                   "'lambda':3}):\n"
#                                                   "    '''\n"
#                                                   '    Initializes parameters '
#                                                   'using a negative decay '
#                                                   'exponential function.\n'
#                                                   '\n'
#                                                   '    Parameters\n'
#                                                   '    ----------\n'
#                                                   '    indexes : list\n'
#                                                   '        List of indexes for '
#                                                   'the parameters.\n'
#                                                   '    params_size : list\n'
#                                                   '        List of sizes for '
#                                                   'each dimension of the '
#                                                   'parameters.\n'
#                                                   '    dict_param : dict, '
#                                                   'optional\n'
#                                                   '        Dictionary '
#                                                   'containing the '
#                                                   'initialization parameters. '
#                                                   "Default is {'size_index': "
#                                                   "0, 'first_value': 1, "
#                                                   "'lambda': 3}.\n"
#                                                   '            size_index : '
#                                                   'int\n'
#                                                   '                The index '
#                                                   'of the dimension to apply '
#                                                   'the exponential function.\n'
#                                                   '            first_value : '
#                                                   'int or float\n'
#                                                   '                The value '
#                                                   'at the start of the range.\n'
#                                                   '            lambda : int or '
#                                                   'float\n'
#                                                   '                The decay '
#                                                   'rate parameter of the '
#                                                   'exponential function.\n'
#                                                   "    '''\n"
#                                                   '    import numpy as np\n'
#                                                   '    size_index = '
#                                                   "dict_param['size_index']\n"
#                                                   '    # check if the size of '
#                                                   'the list of parameters is '
#                                                   '1, to avoid a division by '
#                                                   'zero\n'
#                                                   '    x = 1 if '
#                                                   'params_size[size_index]-1 '
#                                                   '== 0 else '
#                                                   'indexes[size_index]/(params_size[size_index]-1)\n'
#                                                   '    return '
#                                                   "dict_param['first_value']*np.exp(-dict_param['lambda']*(1-x))\n",
#                                           'name': 'init_negexp',
#                                           'params': {'first_value': 0.0001,
#                                                      'lambda': 5,
#                                                      'monotonicity': 'increasing',
#                                                      'size_index': 0}},
#                              'sw': 20,
#                              'values': [[0.0759812742471695],
#                                         [0.015660446137189865],
#                                         [-0.019184662029147148],
#                                         [0.0038066208362579346],
#                                         [0.0026632233057171106],
#                                         [-0.003161096479743719],
#                                         [-0.031588297337293625],
#                                         [0.005034069065004587],
#                                         [0.049941692501306534],
#                                         [0.017628829926252365],
#                                         [-0.03176897391676903],
#                                         [-0.044734518975019455],
#                                         [-0.059819482266902924],
#                                         [-0.036787956953048706],
#                                         [0.0036761651281267405],
#                                         [-0.00517928134649992],
#                                         [0.028733599931001663],
#                                         [0.3297024369239807],
#                                         [0.49952682852745056],
#                                         [0.10275736451148987]]},
#                 'PFir103W': {'dim': 1,
#                              'init_fun': {'code': 'def init_negexp(indexes, '
#                                                   'params_size, dict_param = '
#                                                   "{'size_index':0, "
#                                                   "'first_value':1, "
#                                                   "'lambda':3}):\n"
#                                                   "    '''\n"
#                                                   '    Initializes parameters '
#                                                   'using a negative decay '
#                                                   'exponential function.\n'
#                                                   '\n'
#                                                   '    Parameters\n'
#                                                   '    ----------\n'
#                                                   '    indexes : list\n'
#                                                   '        List of indexes for '
#                                                   'the parameters.\n'
#                                                   '    params_size : list\n'
#                                                   '        List of sizes for '
#                                                   'each dimension of the '
#                                                   'parameters.\n'
#                                                   '    dict_param : dict, '
#                                                   'optional\n'
#                                                   '        Dictionary '
#                                                   'containing the '
#                                                   'initialization parameters. '
#                                                   "Default is {'size_index': "
#                                                   "0, 'first_value': 1, "
#                                                   "'lambda': 3}.\n"
#                                                   '            size_index : '
#                                                   'int\n'
#                                                   '                The index '
#                                                   'of the dimension to apply '
#                                                   'the exponential function.\n'
#                                                   '            first_value : '
#                                                   'int or float\n'
#                                                   '                The value '
#                                                   'at the start of the range.\n'
#                                                   '            lambda : int or '
#                                                   'float\n'
#                                                   '                The decay '
#                                                   'rate parameter of the '
#                                                   'exponential function.\n'
#                                                   "    '''\n"
#                                                   '    import numpy as np\n'
#                                                   '    size_index = '
#                                                   "dict_param['size_index']\n"
#                                                   '    # check if the size of '
#                                                   'the list of parameters is '
#                                                   '1, to avoid a division by '
#                                                   'zero\n'
#                                                   '    x = 1 if '
#                                                   'params_size[size_index]-1 '
#                                                   '== 0 else '
#                                                   'indexes[size_index]/(params_size[size_index]-1)\n'
#                                                   '    return '
#                                                   "dict_param['first_value']*np.exp(-dict_param['lambda']*(1-x))\n",
#                                           'name': 'init_negexp',
#                                           'params': {'first_value': 0.0001,
#                                                      'lambda': 5,
#                                                      'monotonicity': 'increasing',
#                                                      'size_index': 0}},
#                              'sw': 20,
#                              'values': [[-0.028964029625058174],
#                                         [-0.009729637764394283],
#                                         [0.009318110533058643],
#                                         [0.0008932867203839123],
#                                         [0.004553090315312147],
#                                         [0.02240610681474209],
#                                         [0.037890199571847916],
#                                         [-0.0018364302814006805],
#                                         [-0.030583323910832405],
#                                         [-0.006796905305236578],
#                                         [0.01949571818113327],
#                                         [0.011952350847423077],
#                                         [0.0224162545055151],
#                                         [-0.008048376999795437],
#                                         [-0.019689125940203667],
#                                         [0.023511292412877083],
#                                         [0.1325271725654602],
#                                         [0.20185299217700958],
#                                         [0.301457017660141],
#                                         [0.3833523690700531]]},
#                 'k1_0_0_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.23332370817661285]]},
#                 'k1_0_0_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.3402855694293976]]},
#                 'k1_0_1_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.2156510055065155]]},
#                 'k1_0_1_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.10184118896722794]]},
#                 'k1_0_2_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.026166599243879318]]},
#                 'k1_0_2_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.11533506959676743]]},
#                 'k1_0_3_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.6113595366477966]]},
#                 'k1_0_3_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.002102115424349904]]},
#                 'k1_0_4_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.3570075035095215]]},
#                 'k1_0_4_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.21503764390945435]]},
#                 'k1_1_0_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.05598203092813492]]},
#                 'k1_1_0_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.10139041393995285]]},
#                 'k1_1_1_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.1675375998020172]]},
#                 'k1_1_1_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.3573962152004242]]},
#                 'k1_1_2_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.08013255149126053]]},
#                 'k1_1_2_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.14269554615020752]]},
#                 'k1_1_3_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.09640412032604218]]},
#                 'k1_1_3_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.4196862578392029]]},
#                 'k1_1_4_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.019727546721696854]]},
#                 'k1_1_4_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.4250112473964691]]},
#                 'k2_0_0_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.32793059945106506]]},
#                 'k2_0_0_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.4844147562980652]]},
#                 'k2_0_1_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.033950306475162506]]},
#                 'k2_0_1_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.1888670027256012]]},
#                 'k2_0_2_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.16860757768154144]]},
#                 'k2_0_2_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.1597549468278885]]},
#                 'k2_0_3_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.8836414217948914]]},
#                 'k2_0_3_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.6394421458244324]]},
#                 'k2_0_4_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-2.025691509246826]]},
#                 'k2_0_4_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-1.5043483972549438]]},
#                 'k2_1_0_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.08816192299127579]]},
#                 'k2_1_0_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.02586839720606804]]},
#                 'k2_1_1_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.39811238646507263]]},
#                 'k2_1_1_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.30004388093948364]]},
#                 'k2_1_2_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.2536342442035675]]},
#                 'k2_1_2_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[1.007189393043518]]},
#                 'k2_1_3_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.050679564476013184]]},
#                 'k2_1_3_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.7526519894599915]]},
#                 'k2_1_4_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.04835303872823715]]},
#                 'k2_1_4_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.3470284938812256]]},
#                 'k3_0_0_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.06417634338140488]]},
#                 'k3_0_0_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.08057410269975662]]},
#                 'k3_0_1_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.13540562987327576]]},
#                 'k3_0_1_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.02266222983598709]]},
#                 'k3_0_2_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.05973434075713158]]},
#                 'k3_0_2_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.053299680352211]]},
#                 'k3_0_3_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.18327878415584564]]},
#                 'k3_0_3_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.04039539769291878]]},
#                 'k3_0_4_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.4494708478450775]]},
#                 'k3_0_4_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.45916518568992615]]},
#                 'k3_1_0_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.06419625133275986]]},
#                 'k3_1_0_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.08059395104646683]]},
#                 'k3_1_1_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.13542550802230835]]},
#                 'k3_1_1_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.022682223469018936]]},
#                 'k3_1_2_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.059754181653261185]]},
#                 'k3_1_2_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.05327979475259781]]},
#                 'k3_1_3_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.1832585483789444]]},
#                 'k3_1_3_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.04037538915872574]]},
#                 'k3_1_4_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.4494507312774658]]},
#                 'k3_1_4_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.45914512872695923]]},
#                 'k4_0_0_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.39693301916122437]]},
#                 'k4_0_0_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.3969529867172241]]},
#                 'k4_0_1_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.019862329587340355]]},
#                 'k4_0_1_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.01988241635262966]]},
#                 'k4_0_2_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.04813539609313011]]},
#                 'k4_0_2_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.0481153279542923]]},
#                 'k4_0_3_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.10411575436592102]]},
#                 'k4_0_3_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.10409580916166306]]},
#                 'k4_0_4_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.10307113826274872]]},
#                 'k4_0_4_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.10305112600326538]]},
#                 'k4_1_0_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.05749323591589928]]},
#                 'k4_1_0_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.05747321620583534]]},
#                 'k4_1_1_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.03545510396361351]]},
#                 'k4_1_1_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.035475119948387146]]},
#                 'k4_1_2_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.0221555233001709]]},
#                 'k4_1_2_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.02213543839752674]]},
#                 'k4_1_3_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.033204998821020126]]},
#                 'k4_1_3_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.03318503871560097]]},
#                 'k4_1_4_0': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[-0.10495643317699432]]},
#                 'k4_1_4_1': {'dim': [1, 1],
#                              'init_values': [[9.999999747378752e-06]],
#                              'values': [[0.10497640073299408]]}},
#  'Relations': {'Add438': ['Add', ['Mul38', 'Mul59']],
#                'Add439': ['Add', ['Add438', 'Mul80']],
#                'Add440': ['Add', ['Add439', 'Mul101']],
#                'Add441': ['Add', ['Add440', 'Mul122']],
#                'Add442': ['Add', ['Add441', 'Mul143']],
#                'Add443': ['Add', ['Add442', 'Mul164']],
#                'Add444': ['Add', ['Add443', 'Mul185']],
#                'Add445': ['Add', ['Add444', 'Mul206']],
#                'Add446': ['Add', ['Add445', 'Mul227']],
#                'Add447': ['Add', ['Add446', 'Mul248']],
#                'Add448': ['Add', ['Add447', 'Mul269']],
#                'Add449': ['Add', ['Add448', 'Mul290']],
#                'Add450': ['Add', ['Add449', 'Mul311']],
#                'Add451': ['Add', ['Add450', 'Mul332']],
#                'Add452': ['Add', ['Add451', 'Mul353']],
#                'Add453': ['Add', ['Add452', 'Mul374']],
#                'Add454': ['Add', ['Add453', 'Mul395']],
#                'Add455': ['Add', ['Add454', 'Mul416']],
#                'Add456': ['Add', ['Add455', 'Mul437']],
#                'Add463': ['Add', ['Fir459', 'Fir462']],
#                'Fir459': ['Fir', ['Mul458'], 'PFir101W', None, 0],
#                'Fir462': ['Fir', ['Mul461'], 'PFir103W', None, 0],
#                'Fuzzify11': ['Fuzzify', ['SamplePart10'], 'FFuzzify18'],
#                'Fuzzify2': ['Fuzzify', ['SamplePart1'], 'FFuzzify15'],
#                'Fuzzify5': ['Fuzzify', ['SamplePart4'], 'FFuzzify16'],
#                'Fuzzify8': ['Fuzzify', ['SamplePart7'], 'FFuzzify17'],
#                'Mul100': ['Mul', ['Mul98', 'Select99']],
#                'Mul101': ['Mul', ['ParamFun81', 'Mul100']],
#                'Mul119': ['Mul', ['Select117', 'Select118']],
#                'Mul121': ['Mul', ['Mul119', 'Select120']],
#                'Mul122': ['Mul', ['ParamFun102', 'Mul121']],
#                'Mul140': ['Mul', ['Select138', 'Select139']],
#                'Mul142': ['Mul', ['Mul140', 'Select141']],
#                'Mul143': ['Mul', ['ParamFun123', 'Mul142']],
#                'Mul161': ['Mul', ['Select159', 'Select160']],
#                'Mul163': ['Mul', ['Mul161', 'Select162']],
#                'Mul164': ['Mul', ['ParamFun144', 'Mul163']],
#                'Mul182': ['Mul', ['Select180', 'Select181']],
#                'Mul184': ['Mul', ['Mul182', 'Select183']],
#                'Mul185': ['Mul', ['ParamFun165', 'Mul184']],
#                'Mul203': ['Mul', ['Select201', 'Select202']],
#                'Mul205': ['Mul', ['Mul203', 'Select204']],
#                'Mul206': ['Mul', ['ParamFun186', 'Mul205']],
#                'Mul224': ['Mul', ['Select222', 'Select223']],
#                'Mul226': ['Mul', ['Mul224', 'Select225']],
#                'Mul227': ['Mul', ['ParamFun207', 'Mul226']],
#                'Mul245': ['Mul', ['Select243', 'Select244']],
#                'Mul247': ['Mul', ['Mul245', 'Select246']],
#                'Mul248': ['Mul', ['ParamFun228', 'Mul247']],
#                'Mul266': ['Mul', ['Select264', 'Select265']],
#                'Mul268': ['Mul', ['Mul266', 'Select267']],
#                'Mul269': ['Mul', ['ParamFun249', 'Mul268']],
#                'Mul287': ['Mul', ['Select285', 'Select286']],
#                'Mul289': ['Mul', ['Mul287', 'Select288']],
#                'Mul290': ['Mul', ['ParamFun270', 'Mul289']],
#                'Mul308': ['Mul', ['Select306', 'Select307']],
#                'Mul310': ['Mul', ['Mul308', 'Select309']],
#                'Mul311': ['Mul', ['ParamFun291', 'Mul310']],
#                'Mul329': ['Mul', ['Select327', 'Select328']],
#                'Mul331': ['Mul', ['Mul329', 'Select330']],
#                'Mul332': ['Mul', ['ParamFun312', 'Mul331']],
#                'Mul35': ['Mul', ['Select33', 'Select34']],
#                'Mul350': ['Mul', ['Select348', 'Select349']],
#                'Mul352': ['Mul', ['Mul350', 'Select351']],
#                'Mul353': ['Mul', ['ParamFun333', 'Mul352']],
#                'Mul37': ['Mul', ['Mul35', 'Select36']],
#                'Mul371': ['Mul', ['Select369', 'Select370']],
#                'Mul373': ['Mul', ['Mul371', 'Select372']],
#                'Mul374': ['Mul', ['ParamFun354', 'Mul373']],
#                'Mul38': ['Mul', ['ParamFun18', 'Mul37']],
#                'Mul392': ['Mul', ['Select390', 'Select391']],
#                'Mul394': ['Mul', ['Mul392', 'Select393']],
#                'Mul395': ['Mul', ['ParamFun375', 'Mul394']],
#                'Mul413': ['Mul', ['Select411', 'Select412']],
#                'Mul415': ['Mul', ['Mul413', 'Select414']],
#                'Mul416': ['Mul', ['ParamFun396', 'Mul415']],
#                'Mul434': ['Mul', ['Select432', 'Select433']],
#                'Mul436': ['Mul', ['Mul434', 'Select435']],
#                'Mul437': ['Mul', ['ParamFun417', 'Mul436']],
#                'Mul458': ['Mul', ['Add456', 'Select457']],
#                'Mul461': ['Mul', ['Add456', 'Select460']],
#                'Mul56': ['Mul', ['Select54', 'Select55']],
#                'Mul58': ['Mul', ['Mul56', 'Select57']],
#                'Mul59': ['Mul', ['ParamFun39', 'Mul58']],
#                'Mul77': ['Mul', ['Select75', 'Select76']],
#                'Mul79': ['Mul', ['Mul77', 'Select78']],
#                'Mul80': ['Mul', ['ParamFun60', 'Mul79']],
#                'Mul98': ['Mul', ['Select96', 'Select97']],
#                'ParamFun102': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_2',
#                                 'vx_center_0',
#                                 'SamplePart17',
#                                 'ax_center_0',
#                                 'k1_0_2_0',
#                                 'k2_0_2_0',
#                                 'k3_0_2_0',
#                                 'k4_0_2_0'],
#                                'FParamFun14'],
#                'ParamFun123': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_2',
#                                 'vx_center_0',
#                                 'SamplePart17',
#                                 'ax_center_1',
#                                 'k1_0_2_1',
#                                 'k2_0_2_1',
#                                 'k3_0_2_1',
#                                 'k4_0_2_1'],
#                                'FParamFun14'],
#                'ParamFun144': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_3',
#                                 'vx_center_0',
#                                 'SamplePart17',
#                                 'ax_center_0',
#                                 'k1_0_3_0',
#                                 'k2_0_3_0',
#                                 'k3_0_3_0',
#                                 'k4_0_3_0'],
#                                'FParamFun14'],
#                'ParamFun165': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_3',
#                                 'vx_center_0',
#                                 'SamplePart17',
#                                 'ax_center_1',
#                                 'k1_0_3_1',
#                                 'k2_0_3_1',
#                                 'k3_0_3_1',
#                                 'k4_0_3_1'],
#                                'FParamFun14'],
#                'ParamFun18': ['ParamFun',
#                               ['SamplePart13',
#                                'SamplePart15',
#                                'steer_center_0',
#                                'vx_center_0',
#                                'SamplePart17',
#                                'ax_center_0',
#                                'k1_0_0_0',
#                                'k2_0_0_0',
#                                'k3_0_0_0',
#                                'k4_0_0_0'],
#                               'FParamFun14'],
#                'ParamFun186': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_4',
#                                 'vx_center_0',
#                                 'SamplePart17',
#                                 'ax_center_0',
#                                 'k1_0_4_0',
#                                 'k2_0_4_0',
#                                 'k3_0_4_0',
#                                 'k4_0_4_0'],
#                                'FParamFun14'],
#                'ParamFun207': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_4',
#                                 'vx_center_0',
#                                 'SamplePart17',
#                                 'ax_center_1',
#                                 'k1_0_4_1',
#                                 'k2_0_4_1',
#                                 'k3_0_4_1',
#                                 'k4_0_4_1'],
#                                'FParamFun14'],
#                'ParamFun228': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_0',
#                                 'vx_center_1',
#                                 'SamplePart17',
#                                 'ax_center_0',
#                                 'k1_1_0_0',
#                                 'k2_1_0_0',
#                                 'k3_1_0_0',
#                                 'k4_1_0_0'],
#                                'FParamFun14'],
#                'ParamFun249': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_0',
#                                 'vx_center_1',
#                                 'SamplePart17',
#                                 'ax_center_1',
#                                 'k1_1_0_1',
#                                 'k2_1_0_1',
#                                 'k3_1_0_1',
#                                 'k4_1_0_1'],
#                                'FParamFun14'],
#                'ParamFun270': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_1',
#                                 'vx_center_1',
#                                 'SamplePart17',
#                                 'ax_center_0',
#                                 'k1_1_1_0',
#                                 'k2_1_1_0',
#                                 'k3_1_1_0',
#                                 'k4_1_1_0'],
#                                'FParamFun14'],
#                'ParamFun291': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_1',
#                                 'vx_center_1',
#                                 'SamplePart17',
#                                 'ax_center_1',
#                                 'k1_1_1_1',
#                                 'k2_1_1_1',
#                                 'k3_1_1_1',
#                                 'k4_1_1_1'],
#                                'FParamFun14'],
#                'ParamFun312': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_2',
#                                 'vx_center_1',
#                                 'SamplePart17',
#                                 'ax_center_0',
#                                 'k1_1_2_0',
#                                 'k2_1_2_0',
#                                 'k3_1_2_0',
#                                 'k4_1_2_0'],
#                                'FParamFun14'],
#                'ParamFun333': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_2',
#                                 'vx_center_1',
#                                 'SamplePart17',
#                                 'ax_center_1',
#                                 'k1_1_2_1',
#                                 'k2_1_2_1',
#                                 'k3_1_2_1',
#                                 'k4_1_2_1'],
#                                'FParamFun14'],
#                'ParamFun354': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_3',
#                                 'vx_center_1',
#                                 'SamplePart17',
#                                 'ax_center_0',
#                                 'k1_1_3_0',
#                                 'k2_1_3_0',
#                                 'k3_1_3_0',
#                                 'k4_1_3_0'],
#                                'FParamFun14'],
#                'ParamFun375': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_3',
#                                 'vx_center_1',
#                                 'SamplePart17',
#                                 'ax_center_1',
#                                 'k1_1_3_1',
#                                 'k2_1_3_1',
#                                 'k3_1_3_1',
#                                 'k4_1_3_1'],
#                                'FParamFun14'],
#                'ParamFun39': ['ParamFun',
#                               ['SamplePart13',
#                                'SamplePart15',
#                                'steer_center_0',
#                                'vx_center_0',
#                                'SamplePart17',
#                                'ax_center_1',
#                                'k1_0_0_1',
#                                'k2_0_0_1',
#                                'k3_0_0_1',
#                                'k4_0_0_1'],
#                               'FParamFun14'],
#                'ParamFun396': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_4',
#                                 'vx_center_1',
#                                 'SamplePart17',
#                                 'ax_center_0',
#                                 'k1_1_4_0',
#                                 'k2_1_4_0',
#                                 'k3_1_4_0',
#                                 'k4_1_4_0'],
#                                'FParamFun14'],
#                'ParamFun417': ['ParamFun',
#                                ['SamplePart13',
#                                 'SamplePart15',
#                                 'steer_center_4',
#                                 'vx_center_1',
#                                 'SamplePart17',
#                                 'ax_center_1',
#                                 'k1_1_4_1',
#                                 'k2_1_4_1',
#                                 'k3_1_4_1',
#                                 'k4_1_4_1'],
#                                'FParamFun14'],
#                'ParamFun60': ['ParamFun',
#                               ['SamplePart13',
#                                'SamplePart15',
#                                'steer_center_1',
#                                'vx_center_0',
#                                'SamplePart17',
#                                'ax_center_0',
#                                'k1_0_1_0',
#                                'k2_0_1_0',
#                                'k3_0_1_0',
#                                'k4_0_1_0'],
#                               'FParamFun14'],
#                'ParamFun81': ['ParamFun',
#                               ['SamplePart13',
#                                'SamplePart15',
#                                'steer_center_1',
#                                'vx_center_0',
#                                'SamplePart17',
#                                'ax_center_1',
#                                'k1_0_1_1',
#                                'k2_0_1_1',
#                                'k3_0_1_1',
#                                'k4_0_1_1'],
#                               'FParamFun14'],
#                'SamplePart1': ['SamplePart', ['vx'], -1, [-20, 0]],
#                'SamplePart10': ['SamplePart', ['ax'], -1, [-20, 0]],
#                'SamplePart13': ['SamplePart', ['steer'], -1, [-20, 0]],
#                'SamplePart15': ['SamplePart', ['vx'], -1, [-20, 0]],
#                'SamplePart17': ['SamplePart', ['ax'], -1, [-20, 0]],
#                'SamplePart4': ['SamplePart', ['steer'], -1, [-20, 0]],
#                'SamplePart465': ['SamplePart', ['yaw_rate'], -1, [0, 1]],
#                'SamplePart7': ['SamplePart', ['vx'], -1, [-20, 0]],
#                'Select117': ['Select', ['Fuzzify8'], 2, 0],
#                'Select118': ['Select', ['Fuzzify5'], 5, 2],
#                'Select120': ['Select', ['Fuzzify11'], 2, 0],
#                'Select138': ['Select', ['Fuzzify8'], 2, 0],
#                'Select139': ['Select', ['Fuzzify5'], 5, 2],
#                'Select141': ['Select', ['Fuzzify11'], 2, 1],
#                'Select159': ['Select', ['Fuzzify8'], 2, 0],
#                'Select160': ['Select', ['Fuzzify5'], 5, 3],
#                'Select162': ['Select', ['Fuzzify11'], 2, 0],
#                'Select180': ['Select', ['Fuzzify8'], 2, 0],
#                'Select181': ['Select', ['Fuzzify5'], 5, 3],
#                'Select183': ['Select', ['Fuzzify11'], 2, 1],
#                'Select201': ['Select', ['Fuzzify8'], 2, 0],
#                'Select202': ['Select', ['Fuzzify5'], 5, 4],
#                'Select204': ['Select', ['Fuzzify11'], 2, 0],
#                'Select222': ['Select', ['Fuzzify8'], 2, 0],
#                'Select223': ['Select', ['Fuzzify5'], 5, 4],
#                'Select225': ['Select', ['Fuzzify11'], 2, 1],
#                'Select243': ['Select', ['Fuzzify8'], 2, 1],
#                'Select244': ['Select', ['Fuzzify5'], 5, 0],
#                'Select246': ['Select', ['Fuzzify11'], 2, 0],
#                'Select264': ['Select', ['Fuzzify8'], 2, 1],
#                'Select265': ['Select', ['Fuzzify5'], 5, 0],
#                'Select267': ['Select', ['Fuzzify11'], 2, 1],
#                'Select285': ['Select', ['Fuzzify8'], 2, 1],
#                'Select286': ['Select', ['Fuzzify5'], 5, 1],
#                'Select288': ['Select', ['Fuzzify11'], 2, 0],
#                'Select306': ['Select', ['Fuzzify8'], 2, 1],
#                'Select307': ['Select', ['Fuzzify5'], 5, 1],
#                'Select309': ['Select', ['Fuzzify11'], 2, 1],
#                'Select327': ['Select', ['Fuzzify8'], 2, 1],
#                'Select328': ['Select', ['Fuzzify5'], 5, 2],
#                'Select33': ['Select', ['Fuzzify8'], 2, 0],
#                'Select330': ['Select', ['Fuzzify11'], 2, 0],
#                'Select34': ['Select', ['Fuzzify5'], 5, 0],
#                'Select348': ['Select', ['Fuzzify8'], 2, 1],
#                'Select349': ['Select', ['Fuzzify5'], 5, 2],
#                'Select351': ['Select', ['Fuzzify11'], 2, 1],
#                'Select36': ['Select', ['Fuzzify11'], 2, 0],
#                'Select369': ['Select', ['Fuzzify8'], 2, 1],
#                'Select370': ['Select', ['Fuzzify5'], 5, 3],
#                'Select372': ['Select', ['Fuzzify11'], 2, 0],
#                'Select390': ['Select', ['Fuzzify8'], 2, 1],
#                'Select391': ['Select', ['Fuzzify5'], 5, 3],
#                'Select393': ['Select', ['Fuzzify11'], 2, 1],
#                'Select411': ['Select', ['Fuzzify8'], 2, 1],
#                'Select412': ['Select', ['Fuzzify5'], 5, 4],
#                'Select414': ['Select', ['Fuzzify11'], 2, 0],
#                'Select432': ['Select', ['Fuzzify8'], 2, 1],
#                'Select433': ['Select', ['Fuzzify5'], 5, 4],
#                'Select435': ['Select', ['Fuzzify11'], 2, 1],
#                'Select457': ['Select', ['Fuzzify2'], 2, 0],
#                'Select460': ['Select', ['Fuzzify2'], 2, 1],
#                'Select54': ['Select', ['Fuzzify8'], 2, 0],
#                'Select55': ['Select', ['Fuzzify5'], 5, 0],
#                'Select57': ['Select', ['Fuzzify11'], 2, 1],
#                'Select75': ['Select', ['Fuzzify8'], 2, 0],
#                'Select76': ['Select', ['Fuzzify5'], 5, 1],
#                'Select78': ['Select', ['Fuzzify11'], 2, 0],
#                'Select96': ['Select', ['Fuzzify8'], 2, 0],
#                'Select97': ['Select', ['Fuzzify5'], 5, 1],
#                'Select99': ['Select', ['Fuzzify11'], 2, 1]}}
# ================================================================================

# %% [markdown]
# ## Results

# %%
# Test on a new dataset
num_samples_use  = np.size(yaw_rate_validation)-num_samples_past
samples_Validation_set = lateral_dynamics.getSamples('validation_set', index=0, window=num_samples_use) 
out_nn_test_set  = lateral_dynamics(samples_Validation_set, sampled=True)
out_nn_Validation_set_extract = np.asarray(out_nn_test_set['yaw_rate_'])

# Extract the samples
samples_Validation_set_extract = np.zeros((len(samples_Validation_set['yaw_rate']),1))
for i in range(0,len(samples_Validation_set_extract)):
  samples_Validation_set_extract[i] = samples_Validation_set['yaw_rate'][i]

# Compute the MSE on the test set
mse_calc = 0
for i in range(0,len(samples_Validation_set_extract)):
  mse_calc = mse_calc + (samples_Validation_set_extract[i] - out_nn_Validation_set_extract[i])**2 
mse_calc = np.sqrt(mse_calc/len(samples_Validation_set_extract))
print('RMSE on the test set: ', mse_calc, ' rad^2')

flag_plot_results = True
if flag_plot_results:
  # plot the results
  plt.figure()
  plt.plot((samples_Validation_set_extract
            ),label='Ground Truth',linewidth=2)
  plt.plot((out_nn_Validation_set_extract
            ),label='NN',linestyle='--',linewidth=2)
  plt.xlabel('Sample')
  plt.ylabel('Yaw rate [rad/s]')
  plt.legend()
  plt.grid()
  plt.show()
# Out:
# RMSE on the test set:  [0.16010417]  rad^2
# c:\Users\mungi\anaconda3\envs\myenv\lib\site-packages\mpld3\mplexporter\utils.py:300: MatplotlibDeprecationWarning: The converter attribute was deprecated in Matplotlib 3.10 and will be removed in 3.12. Use get_converter and set_converter methods instead.
#   isinstance(axis.converter, matplotlib.dates._SwitchableDateConverter)
# c:\Users\mungi\anaconda3\envs\myenv\lib\site-packages\mpld3\mplexporter\utils.py:303: MatplotlibDeprecationWarning: The converter attribute was deprecated in Matplotlib 3.10 and will be removed in 3.12. Use get_converter and set_converter methods instead.
#   isinstance(axis.converter, matplotlib.dates.DateConverter)
# c:\Users\mungi\anaconda3\envs\myenv\lib\site-packages\mpld3\mplexporter\utils.py:306: MatplotlibDeprecationWarning: The converter attribute was deprecated in Matplotlib 3.10 and will be removed in 3.12. Use get_converter and set_converter methods instead.
#   isinstance(axis.converter, matplotlib.dates.ConciseDateConverter)
# c:\Users\mungi\anaconda3\envs\myenv\lib\site-packages\mpld3\mplexporter\utils.py:300: MatplotlibDeprecationWarning: The converter attribute was deprecated in Matplotlib 3.10 and will be removed in 3.12. Use get_converter and set_converter methods instead.
#   isinstance(axis.converter, matplotlib.dates._SwitchableDateConverter)
# c:\Users\mungi\anaconda3\envs\myenv\lib\site-packages\mpld3\mplexporter\utils.py:303: MatplotlibDeprecationWarning: The converter attribute was deprecated in Matplotlib 3.10 and will be removed in 3.12. Use get_converter and set_converter methods instead.
#   isinstance(axis.converter, matplotlib.dates.DateConverter)
# c:\Users\mungi\anaconda3\envs\myenv\lib\site-packages\mpld3\mplexporter\utils.py:306: MatplotlibDeprecationWarning: The converter attribute was deprecated in Matplotlib 3.10 and will be removed in 3.12. Use get_converter and set_converter methods instead.
#   isinstance(axis.converter, matplotlib.dates.ConciseDateConverter)

# %%
# Test on a new dataset
num_samples_use  = size_train-num_samples_past
samples_training_set = lateral_dynamics.getSamples('training_set', index=0, window=num_samples_use) 
out_nn_trainig_set  = lateral_dynamics(samples_training_set, sampled=True)
out_nn_training_set_extract = np.asarray(out_nn_trainig_set['yaw_rate_'])

# Extract the samples
samples_training_set_extract = np.zeros((len(samples_training_set['yaw_rate']),1))
for i in range(0,len(samples_training_set_extract)):
  samples_training_set_extract[i] = samples_training_set['yaw_rate'][i]

# Compute the MSE on the test set
mse_calc = 0
for i in range(0,len(samples_training_set_extract)):
  mse_calc = mse_calc + (samples_training_set_extract[i] - out_nn_training_set_extract[i])**2 
mse_calc = np.sqrt(mse_calc/len(samples_training_set_extract))
print('RMSE on the test set: ', mse_calc, ' rad^2')

flag_plot_results = True
if flag_plot_results:
  # plot the results
  plt.figure()
  plt.plot((samples_training_set_extract
            ),label='Ground Truth',linewidth=2)
  plt.plot((out_nn_training_set_extract
            ),label='NN',linestyle='--',linewidth=2)
  plt.xlabel('Sample')
  plt.ylabel('Yaw rate [rad/s]')
  plt.legend()
  plt.grid()
  plt.show()
# Out:
# RMSE on the test set:  [0.08887335]  rad^2
# c:\Users\mungi\anaconda3\envs\myenv\lib\site-packages\mpld3\mplexporter\utils.py:300: MatplotlibDeprecationWarning: The converter attribute was deprecated in Matplotlib 3.10 and will be removed in 3.12. Use get_converter and set_converter methods instead.
#   isinstance(axis.converter, matplotlib.dates._SwitchableDateConverter)
# c:\Users\mungi\anaconda3\envs\myenv\lib\site-packages\mpld3\mplexporter\utils.py:303: MatplotlibDeprecationWarning: The converter attribute was deprecated in Matplotlib 3.10 and will be removed in 3.12. Use get_converter and set_converter methods instead.
#   isinstance(axis.converter, matplotlib.dates.DateConverter)
# c:\Users\mungi\anaconda3\envs\myenv\lib\site-packages\mpld3\mplexporter\utils.py:306: MatplotlibDeprecationWarning: The converter attribute was deprecated in Matplotlib 3.10 and will be removed in 3.12. Use get_converter and set_converter methods instead.
#   isinstance(axis.converter, matplotlib.dates.ConciseDateConverter)
# c:\Users\mungi\anaconda3\envs\myenv\lib\site-packages\mpld3\mplexporter\utils.py:300: MatplotlibDeprecationWarning: The converter attribute was deprecated in Matplotlib 3.10 and will be removed in 3.12. Use get_converter and set_converter methods instead.
#   isinstance(axis.converter, matplotlib.dates._SwitchableDateConverter)
# c:\Users\mungi\anaconda3\envs\myenv\lib\site-packages\mpld3\mplexporter\utils.py:303: MatplotlibDeprecationWarning: The converter attribute was deprecated in Matplotlib 3.10 and will be removed in 3.12. Use get_converter and set_converter methods instead.
#   isinstance(axis.converter, matplotlib.dates.DateConverter)
# c:\Users\mungi\anaconda3\envs\myenv\lib\site-packages\mpld3\mplexporter\utils.py:306: MatplotlibDeprecationWarning: The converter attribute was deprecated in Matplotlib 3.10 and will be removed in 3.12. Use get_converter and set_converter methods instead.
#   isinstance(axis.converter, matplotlib.dates.ConciseDateConverter)

# %%
# Test on a new dataset
num_samples_use  = np.size(yaw_rate_test)-num_samples_past
samples_test_set = lateral_dynamics.getSamples('Test_set', index=0, window=num_samples_use) 
out_nn_test_set  = lateral_dynamics(samples_test_set, sampled=True)
out_nn_test_set_extract = np.asarray(out_nn_test_set['yaw_rate_'])

# Extract the samples
samples_test_set_extract = np.zeros((len(samples_test_set['yaw_rate']),1))
for i in range(0,len(samples_test_set_extract)):
  samples_test_set_extract[i] = samples_test_set['yaw_rate'][i]

# Compute the MSE on the test set
mse_calc = 0
for i in range(0,len(samples_test_set_extract)):
  mse_calc = mse_calc + (samples_test_set_extract[i] - out_nn_test_set_extract[i])**2 
mse_calc = np.sqrt(mse_calc/len(samples_test_set_extract))
print('RMSE on the test set: ', mse_calc, ' rad^2')

flag_plot_results = True
if flag_plot_results:
  # plot the results
  plt.figure()
  plt.plot((samples_test_set_extract
            ),label='Ground Truth',linewidth=2)
  plt.plot((out_nn_test_set_extract
            ),label='NN',linestyle='--',linewidth=2)
  plt.xlabel('Sample')
  plt.ylabel('Yaw rate [rad/s]')
  plt.legend()
  plt.grid()
  plt.show()
# Out:
# RMSE on the test set:  [0.33490552]  rad^2
# c:\Users\mungi\anaconda3\envs\myenv\lib\site-packages\mpld3\mplexporter\utils.py:300: MatplotlibDeprecationWarning: The converter attribute was deprecated in Matplotlib 3.10 and will be removed in 3.12. Use get_converter and set_converter methods instead.
#   isinstance(axis.converter, matplotlib.dates._SwitchableDateConverter)
# c:\Users\mungi\anaconda3\envs\myenv\lib\site-packages\mpld3\mplexporter\utils.py:303: MatplotlibDeprecationWarning: The converter attribute was deprecated in Matplotlib 3.10 and will be removed in 3.12. Use get_converter and set_converter methods instead.
#   isinstance(axis.converter, matplotlib.dates.DateConverter)
# c:\Users\mungi\anaconda3\envs\myenv\lib\site-packages\mpld3\mplexporter\utils.py:306: MatplotlibDeprecationWarning: The converter attribute was deprecated in Matplotlib 3.10 and will be removed in 3.12. Use get_converter and set_converter methods instead.
#   isinstance(axis.converter, matplotlib.dates.ConciseDateConverter)
# c:\Users\mungi\anaconda3\envs\myenv\lib\site-packages\mpld3\mplexporter\utils.py:300: MatplotlibDeprecationWarning: The converter attribute was deprecated in Matplotlib 3.10 and will be removed in 3.12. Use get_converter and set_converter methods instead.
#   isinstance(axis.converter, matplotlib.dates._SwitchableDateConverter)
# c:\Users\mungi\anaconda3\envs\myenv\lib\site-packages\mpld3\mplexporter\utils.py:303: MatplotlibDeprecationWarning: The converter attribute was deprecated in Matplotlib 3.10 and will be removed in 3.12. Use get_converter and set_converter methods instead.
#   isinstance(axis.converter, matplotlib.dates.DateConverter)
# c:\Users\mungi\anaconda3\envs\myenv\lib\site-packages\mpld3\mplexporter\utils.py:306: MatplotlibDeprecationWarning: The converter attribute was deprecated in Matplotlib 3.10 and will be removed in 3.12. Use get_converter and set_converter methods instead.
#   isinstance(axis.converter, matplotlib.dates.ConciseDateConverter)
